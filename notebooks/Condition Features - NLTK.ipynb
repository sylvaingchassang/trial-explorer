# %%
import pandas as pd
import numpy as np

from tqdm import tqdm_notebook
from tqdm import tqdm
import datetime as dt
import pickle

import pdaactconn as pc
from trialexplorer.mesh_terms import MeSHCatalog
from trialexplorer import AACTStudySet
from trialexplorer import studysimilarity as ssim

import matplotlib.pyplot as plt
# %matplotlib inline

tqdm.pandas()

# %%
# selecting all interventional studies
conn = pc.AACTConnection(source=pc.AACTConnection.LOCAL)
ss = AACTStudySet.AACTStudySet(conn= conn, tqdm_handler=tqdm_notebook)
ss.add_constraint("study_type = 'Interventional'")
ss.load_studies()
# Out:
# 255092 studies loaded!

# %%
# loading all dimensional data
ss.add_dimensions('conditions')
ss.refresh_dim_data()
# Out:
# Successfuly added these 1 dimensions: ['conditions']
# Failed to add these 0 dimensions: []
# HBox(children=(IntProgress(value=0, max=511), HTML(value='')))
# Syncing the temp table temp_cur_studies in 511 chunks x 500 records each
#
# Creating index on the temp table
#  - Loading dimension conditions
#  -- Loading raw data
#  -- Sorting index

# %%
c = ss.dimensions['conditions']
c.data.head()
# Out:
#                    id                            name  \
# nct_id
# NCT00000102  10058348  Congenital Adrenal Hyperplasia
# NCT00000106  10057277              Rheumatic Diseases
# NCT00000108  10057274         Cardiovascular Diseases
# NCT00000108  10057275                Coronary Disease
# NCT00000110  10057273                         Obesity
#
#                               downcase_name
# nct_id
# NCT00000102  congenital adrenal hyperplasia
# NCT00000106              rheumatic diseases
# NCT00000108         cardiovascular diseases
# NCT00000108                coronary disease
# NCT00000110                         obesity

# %%
all_conds = c.data['downcase_name'].unique()

extracted_adj_vb = {}
extracted_stages = {}

for cur_cond in tqdm(all_conds):
    extracted_adj_vb[cur_cond] = ssim.extract_adj_and_vb(cur_cond)
    extracted_stages[cur_cond] = ssim.full_extract(cur_cond)
# Out:
# 100%|██████████| 64114/64114 [00:20<00:00, 3107.12it/s]

# %% [markdown]
# # Stage Distances:

# %%
reload(ssim)
# only a subset of the data matters here:
typed_conds = [x for x in all_conds if 'stage' in x \
                                      or 'type' in x \
                                      or 'grade' in x \
                                      or 'genotype' in x \
                                      or 'ajcc' in x \
                                      or 'hepatitis' in x]

test_conds = np.random.choice(typed_conds, 20)

# compare everything vs the first selected
for cur_cond in test_conds:
    print("Computing the distance between select 2 stage extractions")
    print(cur_cond)
    print("extracted:", extracted_stages[cur_cond])
    print(test_conds[0])
    print("extracted:", extracted_stages[test_conds[0]])
    print(ssim.stage_sim_dist(extracted_stages[cur_cond], extracted_stages[test_conds[0]]))
    print('')
# Out:
# Computing the distance between select 2 stage extractions
# stage iib colorectal cancer
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['2b'], 'ajcc': [], 'hepatitis': []}
# stage iib colorectal cancer
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['2b'], 'ajcc': [], 'hepatitis': []}
# 0.0
#
# Computing the distance between select 2 stage extractions
# locally advanced or metastatic non-clear cell type renal cell carcinoma
# extracted: None
# stage iib colorectal cancer
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['2b'], 'ajcc': [], 'hepatitis': []}
# 10.0
#
# Computing the distance between select 2 stage extractions
# stage iv uterine corpus cancer ajcc v8
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['4'], 'ajcc': ['v8'], 'hepatitis': []}
# stage iib colorectal cancer
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['2b'], 'ajcc': [], 'hepatitis': []}
# 10.0
#
# Computing the distance between select 2 stage extractions
# hepatitis, autoimmune
# extracted: None
# stage iib colorectal cancer
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['2b'], 'ajcc': [], 'hepatitis': []}
# 10.0
#
# Computing the distance between select 2 stage extractions
# dyslipidemia (fredrickson type ⅱb)
# extracted: {'type': ['2b'], 'genotyp_': [], 'grade': [], 'stage': [], 'ajcc': [], 'hepatitis': []}
# stage iib colorectal cancer
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['2b'], 'ajcc': [], 'hepatitis': []}
# 0.0
#
# Computing the distance between select 2 stage extractions
# dementia alzheimer's type
# extracted: None
# stage iib colorectal cancer
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['2b'], 'ajcc': [], 'hepatitis': []}
# 10.0
#
# Computing the distance between select 2 stage extractions
# stage iiic ovarian cancer ajcc v6 and v7
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['3c'], 'ajcc': ['v6', 'v7'], 'hepatitis': []}
# stage iib colorectal cancer
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['2b'], 'ajcc': [], 'hepatitis': []}
# 10.0
#
# Computing the distance between select 2 stage extractions
# insulin resistance and type 2 diabetes
# extracted: {'type': ['2'], 'genotyp_': [], 'grade': [], 'stage': [], 'ajcc': [], 'hepatitis': []}
# stage iib colorectal cancer
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['2b'], 'ajcc': [], 'hepatitis': []}
# 0.5
#
# Computing the distance between select 2 stage extractions
# stage iiic vulvar cancer ajcc v7
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['3c'], 'ajcc': ['v7'], 'hepatitis': []}
# stage iib colorectal cancer
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['2b'], 'ajcc': [], 'hepatitis': []}
# 10.0
#
# Computing the distance between select 2 stage extractions
# patients with type 2 diabetes (fsg: more than 7.1 and not higher than 15.8 mmol/l)
# extracted: {'type': ['2'], 'genotyp_': [], 'grade': [], 'stage': [], 'ajcc': [], 'hepatitis': []}
# stage iib colorectal cancer
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['2b'], 'ajcc': [], 'hepatitis': []}
# 0.5
#
# Computing the distance between select 2 stage extractions
# severe compressive ulnar nerve neuropathy (mcgowan grade iii)
# extracted: {'type': [], 'genotyp_': [], 'grade': ['3'], 'stage': [], 'ajcc': [], 'hepatitis': []}
# stage iib colorectal cancer
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['2b'], 'ajcc': [], 'hepatitis': []}
# 1.5
#
# Computing the distance between select 2 stage extractions
# stage ii laryngeal verrucous carcinoma
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['2'], 'ajcc': [], 'hepatitis': []}
# stage iib colorectal cancer
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['2b'], 'ajcc': [], 'hepatitis': []}
# 0.5
#
# Computing the distance between select 2 stage extractions
# non-squamous non-small cell lung cancer stage iiia
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['3a'], 'ajcc': [], 'hepatitis': []}
# stage iib colorectal cancer
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['2b'], 'ajcc': [], 'hepatitis': []}
# 1.5
#
# Computing the distance between select 2 stage extractions
# low-grade glioma
# extracted: None
# stage iib colorectal cancer
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['2b'], 'ajcc': [], 'hepatitis': []}
# 10.0
#
# Computing the distance between select 2 stage extractions
# chronic hepatitis e
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': [], 'ajcc': [], 'hepatitis': ['e']}
# stage iib colorectal cancer
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['2b'], 'ajcc': [], 'hepatitis': []}
# 10.0
#
# Computing the distance between select 2 stage extractions
# stage iiia mycosis fungoides and sezary syndrome ajcc v8
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['3a'], 'ajcc': ['v8'], 'hepatitis': []}
# stage iib colorectal cancer
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['2b'], 'ajcc': [], 'hepatitis': []}
# 10.0
#
# Computing the distance between select 2 stage extractions
# stage ii bladder cancer ajcc v6 and v7
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['2'], 'ajcc': ['v6', 'v7'], 'hepatitis': []}
# stage iib colorectal cancer
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['2b'], 'ajcc': [], 'hepatitis': []}
# 10.0
#
# Computing the distance between select 2 stage extractions
# stage iv rectal cancer ajcc v7
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['4'], 'ajcc': ['v7'], 'hepatitis': []}
# stage iib colorectal cancer
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['2b'], 'ajcc': [], 'hepatitis': []}
# 10.0
#
# Computing the distance between select 2 stage extractions
# stage ivc laryngeal verrucous carcinoma
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['4c'], 'ajcc': [], 'hepatitis': []}
# stage iib colorectal cancer
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['2b'], 'ajcc': [], 'hepatitis': []}
# 2.5
#
# Computing the distance between select 2 stage extractions
# platinum sensitive recurrent high-grade serous ovarian cancer with mutated p53
# extracted: None
# stage iib colorectal cancer
# extracted: {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['2b'], 'ajcc': [], 'hepatitis': []}
# 10.0

# %% [markdown]
# # Adj, Verb Distances

# %%
reload(ssim)
ssim.list_jaccard_sim([], [])
# Out:
# 1.0

# %%
reload(ssim)
test_conds = np.random.choice(all_conds, 20)

# compare everything vs the first selected
for cur_cond in test_conds:
    print(cur_cond)
    print("extracted:", extracted_adj_vb[cur_cond])
    print(test_conds[0])
    print("extracted:", extracted_adj_vb[test_conds[0]])
    print(ssim.adj_and_vb_dist(extracted_adj_vb[cur_cond], extracted_adj_vb[test_conds[0]]))
    print()
# Out:
# verrucous oral leukoplakia
# extracted: (['verrucous', 'oral'], [])
# verrucous oral leukoplakia
# extracted: (['verrucous', 'oral'], [])
# (0.0, 0.0)
#
# lumbar radiculitis
# extracted: ([], [])
# verrucous oral leukoplakia
# extracted: (['verrucous', 'oral'], [])
# (1.0, 0.0)
#
# locoregional analgesia in breast surgery
# extracted: (['locoregional'], [])
# verrucous oral leukoplakia
# extracted: (['verrucous', 'oral'], [])
# (1.0, 0.0)
#
# biliary neoplasms
# extracted: (['biliary'], [])
# verrucous oral leukoplakia
# extracted: (['verrucous', 'oral'], [])
# (1.0, 0.0)
#
# impact of different medications on biomarkers of idiopathic rhinitis
# extracted: (['different', 'idiopathic'], [])
# verrucous oral leukoplakia
# extracted: (['verrucous', 'oral'], [])
# (1.0, 0.0)
#
# abdominal wall relaxation after rectus sheath block
# extracted: (['abdominal', 'rectus'], [])
# verrucous oral leukoplakia
# extracted: (['verrucous', 'oral'], [])
# (1.0, 0.0)
#
# treatments of striae gravidarum
# extracted: ([], [])
# verrucous oral leukoplakia
# extracted: (['verrucous', 'oral'], [])
# (1.0, 0.0)
#
# recurrent superficial bladder cancer
# extracted: (['recurrent', 'superficial'], [])
# verrucous oral leukoplakia
# extracted: (['verrucous', 'oral'], [])
# (1.0, 0.0)
#
# erythrocyte glutathione deficiency
# extracted: ([], [])
# verrucous oral leukoplakia
# extracted: (['verrucous', 'oral'], [])
# (1.0, 0.0)
#
# neuroplasticity
# extracted: ([], [])
# verrucous oral leukoplakia
# extracted: (['verrucous', 'oral'], [])
# (1.0, 0.0)
#
# advanced recurrent ovarian tumors
# extracted: (['advanced', 'ovarian'], [])
# verrucous oral leukoplakia
# extracted: (['verrucous', 'oral'], [])
# (1.0, 0.0)
#
# obese adolescent
# extracted: (['obese'], [])
# verrucous oral leukoplakia
# extracted: (['verrucous', 'oral'], [])
# (1.0, 0.0)
#
# preventive medicine
# extracted: (['preventive'], [])
# verrucous oral leukoplakia
# extracted: (['verrucous', 'oral'], [])
# (1.0, 0.0)
#
# waist circumferential reduction
# extracted: (['waist', 'circumferential'], [])
# verrucous oral leukoplakia
# extracted: (['verrucous', 'oral'], [])
# (1.0, 0.0)
#
# chronic encephalopathy
# extracted: (['chronic'], [])
# verrucous oral leukoplakia
# extracted: (['verrucous', 'oral'], [])
# (1.0, 0.0)
#
# dental pulp disease
# extracted: (['dental'], [])
# verrucous oral leukoplakia
# extracted: (['verrucous', 'oral'], [])
# (1.0, 0.0)
#
# acute calculous cholecystitis
# extracted: (['calculous'], [])
# verrucous oral leukoplakia
# extracted: (['verrucous', 'oral'], [])
# (1.0, 0.0)
#
# immunological deficiency
# extracted: (['immunological'], [])
# verrucous oral leukoplakia
# extracted: (['verrucous', 'oral'], [])
# (1.0, 0.0)
#
# diabetes mellitus complication
# extracted: ([], ['mellitus'])
# verrucous oral leukoplakia
# extracted: (['verrucous', 'oral'], [])
# (1.0, 1.0)
#
# protein losing enteropathy
# extracted: (['enteropathy'], ['losing'])
# verrucous oral leukoplakia
# extracted: (['verrucous', 'oral'], [])
# (1.0, 1.0)
