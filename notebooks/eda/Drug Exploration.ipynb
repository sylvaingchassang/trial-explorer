# %%
import pandas as pd
import numpy as numpy
from fuzzywuzzy import fuzz
from tqdm import tqdm_notebook as tqdm

import pdaactconn as pc
from trialexplorer import AACTStudySet

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
conn = pc.AACTConnection(source=pc.AACTConnection.LOCAL)
ss = AACTStudySet.AACTStudySet(conn=conn, tqdm_handler=tqdm)

# %% [markdown]
# # Understanding the Distribution of Keywords

# %%
df = conn.query("SELECT * FROM keywords")
df.head(1)
# Out:
#          id       nct_id        name downcase_name
# 0  13772176  NCT02140372  colchicine    colchicine

# %%
len(df['downcase_name'].unique())
# Out:
# 202888

# %%
s_counts = df.groupby('downcase_name')['name'].count()
s_counts = s_counts.sort_values(ascending=False)

# %%
freq_thres = 100
df_freq = s_counts[s_counts > freq_thres]
df_freq.shape
# Out:
# (1136,)

# %%
for kw in df_freq.index:
    print(df_freq[kw], ' - ', kw)
# Out:
# 2626  -  quality of life
# 2521  -  pharmacokinetics
# 2502  -  obesity
# 2377  -  pain
# 2357  -  breast cancer
# 2289  -  safety
# 2250  -  cancer
# 2213  -  exercise
# 2177  -  depression
# 1929  -  children
# 1849  -  hiv
# 1818  -  diabetes
# 1626  -  stroke
# 1401  -  physical activity
# 1346  -  hypertension
# 1321  -  inflammation
# 1291  -  asthma
# 1284  -  schizophrenia
# 1271  -  rehabilitation
# 1244  -  prevention
# 1208  -  pregnancy
# 1191  -  treatment
# 1180  -  copd
# 1166  -  heart failure
# 1151  -  prostate cancer
# 1117  -  chemotherapy
# 1031  -  surgery
# 1026  -  randomized controlled trial
# 1015  -  anxiety
# 1013  -  pediatric
# 978  -  vaccine
# 974  -  immunotherapy
# 920  -  efficacy
# 903  -  mri
# 883  -  elderly
# 865  -  lung cancer
# 836  -  type 2 diabetes
# 832  -  cognition
# 828  -  healthy volunteers
# 819  -  coronary artery disease
# 812  -  diabetes mellitus
# 792  -  atrial fibrillation
# 791  -  osteoarthritis
# 743  -  colorectal cancer
# 739  -  metastatic
# 736  -  multiple sclerosis
# 731  -  radiotherapy
# 726  -  insulin resistance
# 720  -  healthy volunteer
# 719  -  rheumatoid arthritis
# 709  -  blood pressure
# 708  -  nsclc
# 707  -  multiple myeloma
# 704  -  weight loss
# 702  -  adolescents
# 692  -  biomarkers
# 688  -  lymphoma
# 683  -  drug therapy
# 672  -  nutrition
# 671  -  vitamin d
# 671  -  parkinson's disease
# 668  -  diet
# 655  -  bioequivalence
# 654  -  magnetic resonance imaging
# 652  -  leukemia
# 648  -  ultrasound
# 633  -  cardiovascular disease
# 627  -  hemodialysis
# 622  -  pediatrics
# 612  -  fatigue
# 597  -  non-small cell lung cancer
# 595  -  influenza
# 591  -  healthy subjects
# 589  -  acquired immunodeficiency syndrome
# 585  -  unspecified adult solid tumor, protocol specific
# 583  -  dementia
# 581  -  metabolic syndrome
# 581  -  melanoma
# 578  -  clinical trial
# 569  -  intervention
# 564  -  sleep
# 561  -  chronic pain
# 560  -  tolerability
# 558  -  overweight
# 555  -  smoking cessation
# 553  -  smoking
# 552  -  alzheimer's disease
# 551  -  anemia
# 541  -  chronic kidney disease
# 532  -  healthy
# 522  -  epilepsy
# 522  -  stress
# 520  -  pancreatic cancer
# 517  -  osteoporosis
# 517  -  sepsis
# 517  -  stage iv breast cancer
# 515  -  oxidative stress
# 515  -  screening
# 513  -  bevacizumab
# 513  -  adolescent
# 510  -  hepatitis c
# 507  -  immunogenicity
# 505  -  myocardial infarction
# 504  -  ovarian cancer
# 497  -  adherence
# 496  -  infection
# 496  -  stage iiia breast cancer
# 490  -  cardiac surgery
# 487  -  insulin
# 486  -  treatment experienced
# 483  -  aml
# 482  -  metformin
# 475  -  phase 1
# 471  -  mortality
# 470  -  mechanical ventilation
# 469  -  cystic fibrosis
# 460  -  ptsd
# 459  -  primary care
# 458  -  aging
# 456  -  hepatocellular carcinoma
# 455  -  hv
# 453  -  fmri
# 451  -  refractory
# 451  -  pharmacodynamics
# 450  -  stage ii breast cancer
# 450  -  low back pain
# 447  -  chronic obstructive pulmonary disease
# 447  -  colonoscopy
# 446  -  rituximab
# 444  -  analgesia
# 444  -  solid tumors
# 443  -  women
# 442  -  postoperative pain
# 436  -  malaria
# 434  -  acupuncture
# 434  -  dexamethasone
# 433  -  major depressive disorder
# 433  -  atherosclerosis
# 432  -  psoriasis
# 431  -  body composition
# 430  -  recurrent breast cancer
# 430  -  type 2 diabetes mellitus
# 417  -  child
# 417  -  drug therapy, combination
# 415  -  anesthesia
# 415  -  bariatric surgery
# 414  -  randomized
# 411  -  gastric cancer
# 410  -  adult
# 410  -  knee
# 408  -  placebo
# 407  -  type 1 diabetes
# 406  -  glaucoma
# 401  -  hiv-1
# 401  -  biomarker
# 398  -  stage iiib breast cancer
# 398  -  telemedicine
# 395  -  recurrent grade 3 follicular lymphoma
# 395  -  head and neck cancer
# 395  -  mindfulness
# 395  -  prognosis
# 393  -  recurrent grade 2 follicular lymphoma
# 393  -  bipolar disorder
# 391  -  recurrent grade 1 follicular lymphoma
# 391  -  endothelial function
# 390  -  recurrent adult diffuse large cell lymphoma
# 381  -  cisplatin
# 380  -  adults
# 380  -  physical therapy
# 373  -  acute myeloid leukemia
# 371  -  adhd
# 370  -  recurrent mantle cell lymphoma
# 369  -  diagnosis
# 366  -  recurrent small lymphocytic lymphoma
# 364  -  balance
# 364  -  gemcitabine
# 362  -  stage iiib non-small cell lung cancer
# 362  -  paclitaxel
# 361  -  splenic marginal zone lymphoma
# 361  -  nodal marginal zone b-cell lymphoma
# 360  -  traumatic brain injury
# 360  -  radiation
# 359  -  percutaneous coronary intervention
# 359  -  probiotics
# 358  -  insomnia
# 358  -  obstructive sleep apnea
# 356  -  hiv seronegativity
# 356  -  education
# 354  -  extranodal marginal zone b-cell lymphoma of mucosa-associated lymphoid tissue
# 354  -  cognitive behavioral therapy
# 353  -  bioavailability
# 352  -  rectal cancer
# 351  -  rare disease
# 351  -  phase i
# 351  -  crohn's disease
# 350  -  spinal cord injury
# 349  -  cytokines
# 349  -  propofol
# 347  -  metastatic breast cancer
# 346  -  recurrent adult diffuse mixed cell lymphoma
# 346  -  recurrent marginal zone lymphoma
# 346  -  recurrent adult immunoblastic large cell lymphoma
# 344  -  dexmedetomidine
# 342  -  ulcerative colitis
# 340  -  recurrent adult diffuse small cleaved cell lymphoma
# 336  -  tuberculosis
# 335  -  cervical cancer
# 333  -  gait
# 332  -  pharmacokinetic
# 332  -  solid tumor
# 331  -  recurrent adult acute myeloid leukemia
# 330  -  stage iv non-small cell lung cancer
# 330  -  infertility
# 330  -  emergency department
# 330  -  recurrent adult burkitt lymphoma
# 330  -  physiotherapy
# 330  -  radiation therapy
# 329  -  trauma
# 327  -  memory
# 324  -  laparoscopy
# 320  -  stage iv colon cancer
# 318  -  mds
# 317  -  total knee arthroplasty
# 317  -  migraine
# 315  -  alcohol
# 315  -  recurrent adult lymphoblastic lymphoma
# 313  -  refractory multiple myeloma
# 312  -  genetics
# 311  -  neoplasms
# 311  -  cyclophosphamide
# 311  -  hcv
# 309  -  relapsed
# 309  -  aids
# 309  -  stage iv adult diffuse large cell lymphoma
# 308  -  ketamine
# 308  -  sedation
# 307  -  previously treated myelodysplastic syndromes
# 307  -  docetaxel
# 306  -  stage iiic breast cancer
# 306  -  recurrent non-small cell lung cancer
# 304  -  anti-hiv agents
# 303  -  cholesterol
# 301  -  stage iii multiple myeloma
# 300  -  colon cancer
# 299  -  insulin sensitivity
# 299  -  cardiovascular diseases
# 298  -  recurrence
# 298  -  stage iv grade 2 follicular lymphoma
# 298  -  stage iv grade 3 follicular lymphoma
# 297  -  stage iv grade 1 follicular lymphoma
# 296  -  metabolism
# 295  -  acute coronary syndrome
# 294  -  cirrhosis
# 294  -  tacrolimus
# 293  -  secondary myelodysplastic syndromes
# 293  -  risk factors
# 293  -  virtual reality
# 291  -  autism
# 290  -  recurrent adult hodgkin lymphoma
# 290  -  vaccination
# 290  -  recurrent prostate cancer
# 289  -  prostate
# 289  -  de novo myelodysplastic syndromes
# 289  -  infant
# 288  -  stage iv rectal cancer
# 288  -  recurrent colon cancer
# 287  -  arthritis
# 287  -  capecitabine
# 286  -  carboplatin
# 285  -  fibromyalgia
# 285  -  imaging
# 285  -  zidovudine
# 285  -  questionnaire
# 285  -  infants
# 284  -  stage iv mantle cell lymphoma
# 282  -  treatment naive
# 280  -  kidney transplantation
# 279  -  outcome
# 279  -  transcranial magnetic stimulation
# 279  -  cerebral palsy
# 278  -  gene therapy
# 278  -  chronic lymphocytic leukemia
# 277  -  survival
# 277  -  recurrent adult acute lymphoblastic leukemia
# 276  -  stage iii adult diffuse large cell lymphoma
# 276  -  aspirin
# 276  -  mental health
# 276  -  older adults
# 275  -  stage ii multiple myeloma
# 274  -  dyslipidemia
# 274  -  adenocarcinoma of the prostate
# 274  -  aids-related complex
# 273  -  cognitive function
# 273  -  pneumonia
# 272  -  mild cognitive impairment
# 272  -  kidney
# 272  -  pet
# 272  -  stage iv prostate cancer
# 272  -  stage iv melanoma
# 270  -  secondary acute myeloid leukemia
# 270  -  refractory chronic lymphocytic leukemia
# 269  -  immunosuppression
# 267  -  brain tumor
# 267  -  adult acute myeloid leukemia with 11q23 (mll) abnormalities
# 266  -  stage iii grade 3 follicular lymphoma
# 265  -  adult acute myeloid leukemia with t(16;16)(p13;q22)
# 264  -  recurrent rectal cancer
# 263  -  adult acute myeloid leukemia with inv(16)(p13;q22)
# 263  -  palliative care
# 263  -  stage iii grade 2 follicular lymphoma
# 262  -  oncology
# 261  -  glioblastoma
# 261  -  stage iii grade 1 follicular lymphoma
# 261  -  adult acute myeloid leukemia with t(8;21)(q22;q22)
# 261  -  intensive care unit
# 260  -  stage iv adult immunoblastic large cell lymphoma
# 260  -  lung
# 260  -  therapy
# 259  -  microbiome
# 258  -  glucose
# 258  -  stage iv small lymphocytic lymphoma
# 257  -  brain
# 257  -  oxaliplatin
# 257  -  relapsing chronic myelogenous leukemia
# 256  -  chronic phase chronic myelogenous leukemia
# 256  -  veterans
# 256  -  cesarean section
# 255  -  bladder cancer
# 255  -  dialysis
# 254  -  acute kidney injury
# 254  -  myelodysplastic syndrome
# 254  -  allergy
# 254  -  stem cells
# 254  -  stage iv adult diffuse mixed cell lymphoma
# 253  -  echocardiography
# 252  -  stage iv adult burkitt lymphoma
# 252  -  medication adherence
# 251  -  stage iii mantle cell lymphoma
# 251  -  stage iv marginal zone lymphoma
# 251  -  atopic dermatitis
# 251  -  everolimus
# 250  -  sickle cell disease
# 250  -  epidemiology
# 249  -  hepatitis b
# 249  -  liver transplantation
# 249  -  inflammatory bowel disease
# 248  -  relapse
# 248  -  cll
# 248  -  positron emission tomography
# 248  -  diarrhea
# 248  -  hypoglycemia
# 247  -  chronic myelomonocytic leukemia
# 247  -  pulmonary hypertension
# 246  -  prophylaxis
# 246  -  monoclonal antibody
# 246  -  breast
# 245  -  stage i breast cancer
# 245  -  parkinson disease
# 244  -  liver
# 244  -  ultrasonography
# 244  -  adult gliosarcoma
# 244  -  clopidogrel
# 244  -  stage iv adult diffuse small cleaved cell lymphoma
# 243  -  oxytocin
# 242  -  stage iv adult lymphoblastic lymphoma
# 242  -  constipation
# 242  -  adult glioblastoma
# 241  -  recurrent melanoma
# 240  -  pain management
# 240  -  adult giant cell glioblastoma
# 240  -  sleep apnea
# 239  -  stage i multiple myeloma
# 239  -  transplant
# 237  -  psychotherapy
# 236  -  neuropathic pain
# 235  -  delirium
# 235  -  nicotine
# 233  -  esophageal cancer
# 233  -  recurrent ovarian epithelial cancer
# 231  -  methotrexate
# 231  -  wound healing
# 231  -  opioid
# 230  -  self-management
# 230  -  stage iiia non-small cell lung cancer
# 229  -  intensive care
# 229  -  gerd
# 227  -  lenalidomide
# 227  -  cognitive impairment
# 227  -  blastic phase chronic myelogenous leukemia
# 226  -  carcinoma
# 226  -  accelerated phase chronic myelogenous leukemia
# 226  -  headache
# 225  -  stage iii adult immunoblastic large cell lymphoma
# 225  -  mhealth
# 225  -  heart rate variability
# 224  -  critical care
# 224  -  transcranial direct current stimulation
# 224  -  stage iii small lymphocytic lymphoma
# 223  -  phase ii
# 223  -  nitric oxide
# 222  -  menopause
# 222  -  glioma
# 222  -  malnutrition
# 221  -  stage iii adult diffuse mixed cell lymphoma
# 221  -  ischemic stroke
# 221  -  antibiotics
# 221  -  lidocaine
# 220  -  septic shock
# 220  -  sorafenib
# 219  -  viral load
# 219  -  stage iv chronic lymphocytic leukemia
# 219  -  stage iii adult burkitt lymphoma
# 218  -  optical coherence tomography
# 218  -  walking
# 218  -  complications
# 218  -  transplantation
# 217  -  urinary incontinence
# 217  -  stage iii marginal zone lymphoma
# 217  -  adult acute myeloid leukemia with t(15;17)(q22;q12)
# 216  -  pembrolizumab
# 215  -  bortezomib
# 215  -  stage iv ovarian epithelial cancer
# 214  -  cardiopulmonary bypass
# 214  -  internet
# 213  -  rct
# 213  -  motivational interviewing
# 213  -  contraception
# 213  -  stent
# 212  -  chronic
# 212  -  diabetes mellitus, type 2
# 212  -  microbiota
# 212  -  recurrent cutaneous t-cell non-hodgkin lymphoma
# 211  -  patient education
# 211  -  stage iii adult diffuse small cleaved cell lymphoma
# 211  -  adult acute myeloid leukemia in remission
# 210  -  primary health care
# 210  -  adenocarcinoma
# 210  -  eeg
# 209  -  effectiveness
# 209  -  deep brain stimulation
# 209  -  cataract
# 208  -  neoadjuvant chemotherapy
# 207  -  all
# 207  -  stage iii chronic lymphocytic leukemia
# 206  -  nivolumab
# 206  -  bleeding
# 206  -  noncontiguous stage ii adult diffuse large cell lymphoma
# 205  -  arterial stiffness
# 204  -  recurrent
# 204  -  non-hodgkin's lymphoma
# 204  -  amd
# 204  -  observational
# 204  -  angioplasty
# 204  -  patients
# 204  -  bone mineral density
# 204  -  stage iii adult lymphoblastic lymphoma
# 204  -  female
# 203  -  stage iii prostate cancer
# 203  -  training
# 202  -  registry
# 202  -  compliance
# 202  -  patient satisfaction
# 201  -  general anesthesia
# 201  -  advanced cancer
# 201  -  acute myocardial infarction
# 200  -  ivf
# 200  -  attention
# 200  -  tranexamic acid
# 199  -  irritable bowel syndrome
# 199  -  overactive bladder
# 199  -  tobacco
# 198  -  intubation
# 198  -  endothelial dysfunction
# 198  -  tdcs
# 198  -  stage iv adult hodgkin lymphoma
# 197  -  ribavirin
# 197  -  irinotecan
# 196  -  cetuximab
# 196  -  knee osteoarthritis
# 196  -  anaplastic large cell lymphoma
# 195  -  reverse transcriptase inhibitors
# 194  -  advanced solid tumors
# 194  -  stage iv pancreatic cancer
# 194  -  substance abuse
# 194  -  hiv protease inhibitors
# 193  -  erectile dysfunction
# 193  -  renal cell carcinoma
# 193  -  hyperglycemia
# 193  -  chronic hepatitis c
# 193  -  yoga
# 193  -  testosterone
# 192  -  temozolomide
# 192  -  erlotinib
# 191  -  morphine
# 191  -  allergic rhinitis
# 191  -  acute lymphoblastic leukemia
# 190  -  hiv infection
# 190  -  recurrent childhood acute myeloid leukemia
# 190  -  fallopian tube cancer
# 189  -  aged
# 188  -  adult acute lymphoblastic leukemia in remission
# 188  -  appetite
# 188  -  metastatic colorectal cancer
# 188  -  advanced
# 188  -  randomized clinical trial
# 163  -  stage iii colon cancer
# 163  -  behavioral intervention
# 163  -  diabetic retinopathy
# 163  -  breastfeeding
# 163  -  neuropathy
# 163  -  glioblastoma multiforme
# 162  -  satiety
# 162  -  bupivacaine
# 162  -  risperidone
# 162  -  pd-l1
# 162  -  recovery
# 162  -  squamous cell carcinoma
# 162  -  small cell lung cancer
# 162  -  cardiac arrest
# 161  -  randomized trial
# 161  -  stage i prostate cancer
# 161  -  volunteers
# 161  -  vomiting
# 161  -  cell therapy
# 161  -  egfr
# 161  -  helicobacter pylori
# 161  -  acetaminophen
# 160  -  critical illness
# 160  -  neoadjuvant
# 160  -  aerobic exercise
# 160  -  lamivudine
# 159  -  noncontiguous stage ii adult immunoblastic large cell lymphoma
# 159  -  aids-related opportunistic infections
# 159  -  ranibizumab
# 159  -  noncontiguous stage ii small lymphocytic lymphoma
# 158  -  gut microbiota
# 158  -  blood glucose
# 158  -  noncontiguous stage ii marginal zone lymphoma
# 158  -  noncontiguous stage ii adult diffuse mixed cell lymphoma
# 158  -  stage iii rectal cancer
# 158  -  mdd
# 157  -  sevoflurane
# 157  -  adalimumab
# 157  -  noncontiguous stage ii adult burkitt lymphoma
# 156  -  amyotrophic lateral sclerosis
# 156  -  venous thromboembolism
# 156  -  peritoneal dialysis
# 156  -  age-related macular degeneration
# 156  -  stemi
# 156  -  ischemia
# 156  -  childhood myelodysplastic syndromes
# 155  -  mood
# 155  -  hematopoietic stem cell transplantation
# 155  -  metabolomics
# 155  -  lipids
# 154  -  recurrent pancreatic cancer
# 154  -  photodynamic therapy
# 154  -  combination therapy
# 154  -  total hip arthroplasty
# 154  -  total knee replacement
# 154  -  trastuzumab
# 153  -  stage iii squamous cell carcinoma of the oropharynx
# 153  -  hepatitis c virus
# 153  -  congenital heart disease
# 153  -  health promotion
# 153  -  body weight
# 153  -  tbi
# 153  -  liver cirrhosis
# 153  -  intraocular pressure
# 153  -  myocardial ischemia
# 153  -  adenocarcinoma of the pancreas
# 152  -  methadone
# 152  -  postmenopausal
# 152  -  toxicity
# 152  -  midazolam
# 152  -  obese
# 152  -  spinal anesthesia
# 152  -  recurrent adult t-cell leukemia/lymphoma
# 152  -  pulmonary rehabilitation
# 152  -  japanese
# 151  -  autonomic nervous system
# 151  -  prednisone
# 151  -  untreated adult acute myeloid leukemia
# 151  -  buprenorphine
# 151  -  systemic lupus erythematosus
# 150  -  antibody
# 150  -  unresectable
# 150  -  occupational therapy
# 150  -  cognitive training
# 149  -  recurrent renal cell cancer
# 149  -  energy expenditure
# 149  -  remifentanil
# 148  -  noncontiguous stage ii adult diffuse small cleaved cell lymphoma
# 148  -  glp-1
# 148  -  myeloma
# 148  -  hcc
# 147  -  posttraumatic stress disorder
# 147  -  male
# 147  -  stage iia prostate cancer
# 147  -  morbidity
# 147  -  laser
# 147  -  lifestyle
# 147  -  fentanyl
# 147  -  stem cell transplantation
# 147  -  doxorubicin
# 147  -  angioimmunoblastic t-cell lymphoma
# 146  -  noncontiguous stage ii adult lymphoblastic lymphoma
# 146  -  stage iib prostate cancer
# 146  -  lupus
# 146  -  hip
# 145  -  cost-effectiveness
# 145  -  macular edema
# 145  -  suicide
# 145  -  endometriosis
# 145  -  pd
# 144  -  acute
# 144  -  growth
# 144  -  ritonavir
# 144  -  graft versus host disease
# 144  -  adjuvant
# 144  -  hba1c
# 144  -  heart rate
# 144  -  ms
# 144  -  hiv/aids
# 144  -  iron
# 144  -  eczema
# 143  -  radiofrequency ablation
# 143  -  manual therapy
# 143  -  periodontitis
# 143  -  pharmacologic actions
# 142  -  locally advanced
# 142  -  skin
# 142  -  misoprostol
# 142  -  gbm
# 141  -  quality improvement
# 141  -  pci
# 141  -  corticosteroids
# 141  -  renal
# 141  -  hypothermia
# 141  -  opioids
# 141  -  gvhd
# 141  -  neutropenia
# 141  -  sirolimus
# 141  -  muscle
# 141  -  body mass index
# 141  -  polycystic ovary syndrome
# 141  -  neck pain
# 140  -  catheter ablation
# 140  -  fibrosis
# 140  -  ticagrelor
# 139  -  dysphagia
# 139  -  preeclampsia
# 139  -  hypotension
# 139  -  acute ischemic stroke
# 139  -  als
# 139  -  diabetic macular edema
# 139  -  protein
# 139  -  behavior
# 139  -  stage iii squamous cell carcinoma of the larynx
# 139  -  stage iii squamous cell carcinoma of the hypopharynx
# 139  -  falls
# 139  -  angiogenesis
# 138  -  antiretroviral therapy
# 138  -  skin cancer
# 138  -  thrombocytopenia
# 138  -  therapeutic uses
# 138  -  immunity
# 138  -  adolescence
# 138  -  mobile health
# 137  -  meningitis
# 137  -  spasticity
# 137  -  cocaine
# 137  -  stem cell
# 137  -  extensive stage small cell lung cancer
# 137  -  cardiac
# 137  -  recurrent childhood large cell lymphoma
# 137  -  postoperative complications
# 137  -  metastatic melanoma
# 137  -  traditional chinese medicine
# 136  -  hemoglobin
# 136  -  laparoscopic surgery
# 136  -  colorectal
# 136  -  rtms
# 136  -  communication
# 136  -  pregabalin
# 136  -  deep vein thrombosis
# 136  -  crossover
# 136  -  bone marrow
# 135  -  hiv infections
# 135  -  hepatitis
# 135  -  recurrent childhood lymphoblastic lymphoma
# 135  -  infliximab
# 135  -  cognitive behavior therapy
# 135  -  drug-drug interaction
# 135  -  autism spectrum disorder
# 135  -  counseling
# 134  -  contiguous stage ii adult diffuse large cell lymphoma
# 134  -  myelodysplastic syndromes
# 134  -  adenocarcinoma of the lung
# 134  -  african american
# 134  -  polysomnography
# 134  -  observational study
# 134  -  glycemic control
# 134  -  sunitinib
# 134  -  statin
# 133  -  cardiac output
# 133  -  neonates
# 133  -  physical fitness
# 133  -  physiological effects of drugs
# 133  -  stage iii squamous cell carcinoma of the lip and oral cavity
# 133  -  continuous positive airway pressure
# 132  -  ibuprofen
# 132  -  gastric bypass
# 132  -  breast neoplasms
# 131  -  cardiac resynchronization therapy
# 131  -  recurrent squamous cell carcinoma of the oropharynx
# 131  -  brachytherapy
# 131  -  kidney cancer
# 131  -  decision making
# 131  -  ocular hypertension
# 130  -  statins
# 130  -  stage iv adult t-cell leukemia/lymphoma
# 117  -  caregiver
# 116  -  human papillomavirus
# 116  -  vascular function
# 116  -  disseminated neuroblastoma
# 116  -  upper extremity
# 116  -  substance use
# 116  -  polycythemia vera
# 116  -  renal impairment
# 116  -  follow-up
# 116  -  acute myelogenous leukemia
# 116  -  neoplasm
# 115  -  stage ii pancreatic cancer
# 115  -  stage i adult diffuse large cell lymphoma
# 115  -  ankylosing spondylitis
# 115  -  open-label
# 115  -  cabg
# 115  -  family
# 115  -  health
# 115  -  large cell lung cancer
# 115  -  pacemaker
# 115  -  ibd
# 115  -  health literacy
# 115  -  ibs
# 114  -  neonate
# 114  -  symptoms
# 114  -  cannabis
# 114  -  prostatectomy
# 114  -  pertussis
# 114  -  vascular diseases
# 114  -  postpartum
# 114  -  simvastatin
# 114  -  genetic
# 114  -  food intake
# 114  -  liver disease
# 114  -  concussion
# 113  -  ercp
# 113  -  nafld
# 113  -  stage i non-small cell lung cancer
# 113  -  hypogonadism
# 113  -  follicular lymphoma
# 113  -  cardiac rehabilitation
# 113  -  social support
# 112  -  health behavior
# 112  -  neuroblastoma
# 112  -  bipolar
# 112  -  exercise capacity
# 112  -  metastatic cancer
# 112  -  durvalumab
# 112  -  antidepressant
# 112  -  drug evaluation
# 112  -  metastasis
# 112  -  artificial pancreas
# 112  -  blood transfusion
# 112  -  adipose tissue
# 112  -  pemetrexed
# 112  -  autologous
# 111  -  physical function
# 111  -  resistance
# 111  -  peripheral artery disease
# 111  -  cough
# 111  -  chest pain
# 111  -  efavirenz
# 111  -  contiguous stage ii grade 3 follicular lymphoma
# 111  -  placebo-controlled
# 111  -  electroencephalography
# 111  -  food effect
# 111  -  vitamin d deficiency
# 110  -  shoulder
# 110  -  brain metastases
# 110  -  stage iv gastric cancer
# 110  -  weight
# 110  -  chronic low back pain
# 110  -  stage iii adult t-cell leukemia/lymphoma
# 110  -  weight gain
# 110  -  recurrent small cell lung cancer
# 110  -  elderly patients
# 110  -  exenatide
# 110  -  cytokine
# 110  -  chemoradiotherapy
# 110  -  parenting
# 110  -  patient safety
# 110  -  oct
# 109  -  surgical site infection
# 109  -  overall survival
# 109  -  hyaluronic acid
# 109  -  inflammatory markers
# 109  -  dental caries
# 109  -  adenocarcinoma of the esophagus
# 109  -  stage iv mycosis fungoides/sezary syndrome
# 109  -  osa
# 109  -  ipilimumab
# 109  -  vitamin c
# 109  -  hot flashes
# 109  -  stage ii chronic lymphocytic leukemia
# 109  -  amputation
# 109  -  contiguous stage ii grade 2 follicular lymphoma
# 109  -  fever
# 109  -  azithromycin
# 109  -  contiguous stage ii mantle cell lymphoma
# 109  -  prolymphocytic leukemia
# 108  -  chronic myeloid leukemia
# 108  -  parenteral nutrition
# 108  -  cardiomyopathy
# 108  -  nicotine dependence
# 108  -  renal function
# 108  -  continuous glucose monitoring
# 108  -  pad
# 108  -  tinnitus
# 108  -  sleep quality
# 108  -  hearing loss
# 108  -  haart
# 108  -  contiguous stage ii grade 1 follicular lymphoma
# 107  -  aids vaccines
# 107  -  antibiotic
# 107  -  hemorrhage
# 107  -  strength
# 107  -  coronary artery bypass grafting
# 107  -  bone marrow transplant
# 107  -  pelvic organ prolapse
# 107  -  revlimid
# 107  -  high risk
# 107  -  stage iii melanoma
# 107  -  zinc
# 107  -  sickle cell anemia
# 107  -  rivaroxaban
# 107  -  cholangiocarcinoma
# 107  -  aneurysm
# 107  -  rituxan
# 107  -  nursing
# 107  -  recurrent squamous cell carcinoma of the nasopharynx
# 106  -  gastroesophageal reflux disease
# 106  -  stage i chronic lymphocytic leukemia
# 106  -  sexual dysfunction
# 106  -  drug interaction
# 106  -  blood loss
# 106  -  mood disorders
# 106  -  weaning
# 106  -  parents
# 106  -  thalidomide
# 105  -  stage iv esophageal cancer
# 105  -  ards
# 105  -  hematologic diseases
# 105  -  monitoring
# 105  -  plaque psoriasis
# 105  -  working memory
# 105  -  triglycerides
# 105  -  brain cancer
# 105  -  lifestyle intervention
# 105  -  sleep disorders
# 105  -  recurrent squamous cell carcinoma of the paranasal sinus and nasal cavity
# 105  -  advanced adult primary liver cancer
# 105  -  varenicline
# 104  -  nash
# 104  -  coronary disease
# 104  -  dlbcl
# 104  -  staphylococcus aureus
# 104  -  fasting
# 104  -  kidney disease
# 104  -  estrogen
# 104  -  childhood chronic myelogenous leukemia
# 104  -  ct
# 103  -  cataract surgery
# 103  -  letrozole
# 103  -  recurrent ovarian germ cell tumor
# 103  -  repetitive transcranial magnetic stimulation
# 103  -  stage ib breast cancer
# 103  -  triple negative breast cancer
# 103  -  diffuse large b-cell lymphoma
# 103  -  epidural
# 103  -  stage iii cutaneous t-cell non-hodgkin lymphoma
# 103  -  anorexia nervosa
# 103  -  implementation
# 103  -  aripiprazole
# 103  -  hormones
# 103  -  lapatinib
# 103  -  gestational diabetes
# 103  -  corticosteroid
# 103  -  plasmodium falciparum
# 103  -  platelets
# 103  -  brain diseases
# 102  -  stage ia breast cancer
# 102  -  oxygen
# 102  -  interferon
# 102  -  essential thrombocythemia
# 102  -  gabapentin
# 102  -  stage iii esophageal cancer
# 102  -  naltrexone
# 102  -  central nervous system diseases
# 102  -  smartphone
# 101  -  stage i mantle cell lymphoma
# 101  -  ovarian
# 101  -  melphalan
# 101  -  primary peritoneal cavity cancer
# 101  -  cohort
# 101  -  cesarean delivery
# 101  -  neuroprotection
# 101  -  intravenous

# %% [markdown]
# ### Notes:
#
# need to classify the diseases into various categories of "what is being researched"

# %% [markdown]
# # Understanding the Distribution of Meshterms
#
# These terms are on 2 tables:
# - browse_interventions
# - browse_conditions

# %% [markdown]
# ### browse_interventions

# %%
df_bi = conn.query('SELECT * FROM browse_interventions')
df_bi.shape
# Out:
# (318367, 4)

# %%
s_bi_mt = df_bi.groupby('mesh_term')['mesh_term'].count().sort_values(ascending=False)

# %%
freq_thres_bi = 100
top_bi = s_bi_mt[s_bi_mt > freq_thres_bi]
top_bi.shape
# Out:
# (637,)

# %%
for kw in top_bi.index:
    print(top_bi[kw], ' - ', kw)
# Out:
# 6284  -  Vaccines
# 107  -  Lorazepam
# 107  -  Fanasil, pyrimethamine drug combination
# 106  -  Coenzyme Q10
# 106  -  Sumatriptan
# 106  -  Ledipasvir
# 106  -  Contraceptives, Oral, Combined
# 105  -  Dabrafenib
# 105  -  Lisinopril
# 105  -  Treprostinil
# 105  -  Basiliximab
# 105  -  Insulin aspart, insulin aspart protamine drug combination 30:70
# 105  -  Vitamin B 6
# 105  -  Bosentan
# 104  -  Amitriptyline
# 104  -  Hydrocodone
# 104  -  Maytansine
# 103  -  Antirheumatic Agents
# 103  -  Natalizumab
# 103  -  Enalaprilat
# 102  -  Veliparib
# 102  -  Tolvaptan
# 101  -  Ramucirumab

# %% [markdown]
# ### Notes:
#
# These are the kind of drugs used as interventions

# %% [markdown]
# # browse_conditions

# %%
df_bc = conn.query('SELECT * FROM browse_conditions')
df_bc.shape
# Out:
# (543355, 4)

# %%
s_bc_mt = df_bc.groupby('mesh_term')['mesh_term'].count().sort_values(ascending=False)

# %%
freq_thres_bc = 100
top_bc = s_bc_mt[s_bc_mt > freq_thres_bc]
top_bc.shape
# Out:
# (815,)

# %%
for kw in top_bc.index:
    print(top_bc[kw], ' - ', kw)
# Out:
# 7419  -  Diabetes Mellitus
# 7307  -  Breast Neoplasms
# 6724  -  Syndrome
# 5644  -  Diabetes Mellitus, Type 2
# 5237  -  Disease
# 5214  -  Neoplasms
# 5028  -  Carcinoma
# 4737  -  Lung Neoplasms
# 4730  -  Leukemia
# 4553  -  Hypertension
# 4468  -  Lymphoma
# 4449  -  Depression
# 4388  -  Infection
# 3997  -  Prostatic Neoplasms
# 3726  -  Coronary Artery Disease
# 3601  -  Depressive Disorder
# 3573  -  Carcinoma, Non-Small-Cell Lung
# 3354  -  HIV Infections
# 3313  -  Heart Failure
# 3307  -  Stroke
# 3307  -  Osteoarthritis
# 3067  -  Wounds and Injuries
# 3014  -  Cardiovascular Diseases
# 2992  -  Colorectal Neoplasms
# 2959  -  Hepatitis
# 2933  -  Communicable Diseases
# 2797  -  Arthritis
# 2759  -  Kidney Diseases
# 2752  -  Asthma
# 2724  -  Heart Diseases
# 2621  -  Pulmonary Disease, Chronic Obstructive
# 2532  -  Schizophrenia
# 2504  -  Lung Diseases
# 2413  -  Obesity
# 2406  -  Myocardial Ischemia
# 2371  -  Multiple Myeloma
# 2318  -  Sclerosis
# 2317  -  Parkinson Disease
# 2296  -  Fibrosis
# 2271  -  Hepatitis A
# 2193  -  Diabetes Mellitus, Type 1
# 2179  -  Coronary Disease
# 2140  -  Adenocarcinoma
# 2120  -  Leukemia, Myeloid
# 2090  -  Atrial Fibrillation
# 2071  -  Lung Diseases, Obstructive
# 2046  -  Hepatitis C
# 2021  -  Hemorrhage
# 2021  -  Arthritis, Rheumatoid
# 2016  -  Melanoma
# 2009  -  Alzheimer Disease
# 2008  -  Infarction
# 2003  -  Neoplasms, Plasma Cell
# 1979  -  Pain, Postoperative
# 1959  -  Neoplasm Metastasis
# 1932  -  Ischemia
# 1927  -  Multiple Sclerosis
# 1899  -  Inflammation
# 105  -  Complex Regional Pain Syndromes
# 104  -  Neoplasms, Squamous Cell
# 104  -  Tennis Elbow
# 104  -  Suicide, Attempted
# 104  -  Abscess
# 104  -  Liver Cirrhosis, Biliary
# 103  -  Glycogen Storage Disease Type II
# 103  -  Dentin Sensitivity
# 103  -  Gaucher Disease
# 103  -  Neoplasm, Residual
# 103  -  Turner Syndrome
# 103  -  Latent Tuberculosis
# 102  -  Aortic Aneurysm, Thoracic
# 102  -  Body Weight Changes
# 102  -  Hemorrhoids
# 102  -  Hypercapnia
# 102  -  Patellofemoral Pain Syndrome
# 101  -  Pneumonia, Bacterial
# 101  -  Ankle Fractures
# 101  -  Arteritis
# 101  -  Intracranial Hypertension
# 101  -  Prehypertension

# %% [markdown]
# ### Let's classify the top diseases ...

# %%
# ftp://nlmpubs.nlm.nih.gov/online/mesh/MESH_FILES/xmlmesh/desc2020.xml

import xml.etree.ElementTree as ET
tree = ET.parse('raw_data/desc2020.xml')
root = tree.getroot()

# %%
len(root.getchildren())
# Out:
# 29640

# %%
all_text = []
for c in root.getchildren():
    cur_text = c.find('DescriptorName').find('String').text
    all_text.append(cur_text)

# %%
num_search = 815
found = []
not_found = []

for i in range(0, num_search):
    cur_find = top_bc.index[i]
    if cur_find in all_text:
        found.append(cur_find)
    else:
        not_found.append(cur_find)
        
print('%.1f%% found! in top %s' % (len(found) / num_search * 100, num_search))
# Out:
# 99.9% found! in top 815

# %%
not_found
# Out:
# ['Infection']

# %%
'Infections' in all_text
# Out:
# True

# %%
for cur_str in root.iter('String'):
    if cur_str.text == 'Infection':
        print(cur_str.text)
        break
# Out:
# Infection

# %%
for c in root.getchildren():
    cur_text = c.find('DescriptorName').find('String').text
    if cur_text == 'Infections':
        break

# %%
c.getchildren()
# Out:
# [<Element 'DescriptorUI' at 0x7fabef92fea8>,
#  <Element 'DescriptorName' at 0x7fabef92fef8>,
#  <Element 'DateCreated' at 0x7fabef92ff98>,
#  <Element 'DateRevised' at 0x7fabef934138>,
#  <Element 'DateEstablished' at 0x7fabef934278>,
#  <Element 'AllowableQualifiersList' at 0x7fabef9343b8>,
#  <Element 'Annotation' at 0x7fabef8c5728>,
#  <Element 'HistoryNote' at 0x7fabef8c5778>,
#  <Element 'OnlineNote' at 0x7fabef8c5818>,
#  <Element 'PublicMeSHNote' at 0x7fabef8c5868>,
#  <Element 'EntryCombinationList' at 0x7fabef8c5908>,
#  <Element 'SeeRelatedList' at 0x7fabef8c5e08>,
#  <Element 'TreeNumberList' at 0x7fabef8c9048>,
#  <Element 'ConceptList' at 0x7fabef8c90e8>]

# %%
c.find('TreeNumberList').find('TreeNumber').text
# Out:
# 'C01'

# %%
if_terms = c.find('ConceptList').find('Concept').find('TermList').getchildren()

# %%
for term in if_terms:
    print(term.find('String').text)
# Out:
# Infections
# Infection and Infestation
# Infestation and Infection
# Infections and Infestations
# Infestations and Infections
# Infection

# %% [markdown]
# ### let's see the terms and their mapped concept lists

# %%
for term in root[0].find('ConceptList').find('Concept').find('TermList').getchildren():
    print(term.find('String').text)
# Out:
# Calcimycin

# %%
term_dict = {}
for c in root.getchildren():
    cur_text = c.find('DescriptorName').find('String').text
    all_terms = c.find('ConceptList').find('Concept').find('TermList').getchildren()
    cur_terms = []
    for term in all_terms:
        cur_terms.append(term.find('String').text)
    term_dict[cur_text] = cur_terms

# %%
term_dict
# Out:
# {'Calcimycin': ['Calcimycin'],
#  'Temefos': ['Temefos', 'Temephos'],
#  'Abattoirs': ['Abattoirs',
#   'Abattoir',
#   'Slaughter Houses',
#   'House, Slaughter',
#   'Houses, Slaughter',
#   'Slaughter House',
#   'Slaughterhouses',
#   'Slaughterhouse'],
#  'Abbreviations as Topic': ['Abbreviations as Topic'],
#  'Abdomen': ['Abdomen', 'Abdomens'],
#  'Abdomen, Acute': ['Abdomen, Acute',
#   'Abdomens, Acute',
#   'Acute Abdomen',
#   'Acute Abdomens'],
#  'Abdominal Injuries': ['Abdominal Injuries',
#   'Injuries, Abdominal',
#   'Abdominal Injury',
#   'Injury, Abdominal'],
#  'Abdominal Neoplasms': ['Abdominal Neoplasms',
#   'Abdominal Neoplasm',
#   'Neoplasm, Abdominal',
#   'Neoplasms, Abdominal'],
#  'Abdominal Muscles': ['Abdominal Muscles',
#   'Abdominal Muscle',
#   'Muscle, Abdominal',
#   'Muscles, Abdominal'],
#  'Abducens Nerve': ['Abducens Nerve',
#   'Nerve, Abducens',
#   'Sixth Cranial Nerve',
#   'Cranial Nerve, Sixth',
#   'Nerve, Sixth Cranial',
#   'Nerves, Sixth Cranial',
#   'Sixth Cranial Nerves',
#   'Nerve VI',
#   'Nerve VIs',
#   'Nervus Abducens',
#   'Abducen, Nervus',
#   'Abducens, Nervus',
#   'Nervus Abducen',
#   'Abducent Nerve',
#   'Abducent Nerves',
#   'Nerve, Abducent',
#   'Cranial Nerve VI',
#   'Cranial Nerve VIs',
#   'Nerve VI, Cranial',
#   'Nerve VIs, Cranial'],
#  'Abelson murine leukemia virus': ['Abelson murine leukemia virus',
#   'Abelson Leukemia Virus',
#   'Leukemia Virus, Abelson',
#   'Virus, Abelson Leukemia'],
#  'Abetalipoproteinemia': ['Abetalipoproteinemia',
#   'Bassen-Kornzweig Disease',
#   'Bassen Kornzweig Disease',
#   'Microsomal Triglyceride Transfer Protein Deficiency Disease',
#   'Betalipoprotein Deficiency Disease',
#   'Betalipoprotein Deficiency Diseases',
#   'Deficiency Disease, Betalipoprotein',
#   'Deficiency Diseases, Betalipoprotein',
#   'Disease, Betalipoprotein Deficiency',
#   'Diseases, Betalipoprotein Deficiency',
#   'Microsomal Triglyceride Transfer Protein Deficiency',
#   'Acanthocytosis',
#   'Acanthocytoses',
#   'Bassen-Kornzweig Syndrome',
#   'Bassen Kornzweig Syndrome'],
#  'Congenital Abnormalities': ['Congenital Abnormalities',
#   'Abnormality, Congenital',
#   'Congenital Abnormality',
#   'Deformities',
#   'Deformity',
#   'Congenital Defects',
#   'Congenital Defect',
#   'Defect, Congenital',
#   'Defects, Congenital',
#   'Abnormalities, Congenital',
#   'Birth Defects',
#   'Birth Defect',
#   'Defect, Birth',
#   'Defects, Birth'],
#  'Abnormalities, Drug-Induced': ['Abnormalities, Drug-Induced',
#   'Abnormalities, Drug Induced',
#   'Drug-Induced Abnormalities',
#   'Abnormality, Drug-Induced',
#   'Drug Induced Abnormalities',
#   'Drug-Induced Abnormality'],
#  'Abnormalities, Multiple': ['Abnormalities, Multiple',
#   'Multiple Abnormalities'],
#  'Abnormalities, Radiation-Induced': ['Abnormalities, Radiation-Induced',
#   'Abnormalities, Radiation Induced',
#   'Radiation-Induced Abnormalities',
#   'Abnormality, Radiation-Induced',
#   'Radiation Induced Abnormalities',
#   'Radiation-Induced Abnormality'],
#  'ABO Blood-Group System': ['ABO Blood-Group System',
#   'ABO Blood Group System',
#   'ABO Blood-Group Systems',
#   'Blood-Group System, ABO',
#   'Blood-Group Systems, ABO',
#   'System, ABO Blood-Group',
#   'Systems, ABO Blood-Group',
#   'H Blood Group System',
#   'H Blood Group',
#   'Blood Group, H',
#   'Blood Groups, H',
#   'H Blood Groups',
#   'ABH Blood Group',
#   'ABH Blood Groups',
#   'Blood Group, ABH',
#   'Blood Groups, ABH'],
#  'Abomasum': ['Abomasum', 'Abomasums'],
#  'Abortifacient Agents': ['Abortifacient Agents',
#   'Agents, Abortifacient',
#   'Contraceptive Agents, Postconception',
#   'Agents, Postconception Contraceptive',
#   'Postconception Contraceptive Agents',
#   'Abortifacients'],
#  'Abortifacient Agents, Nonsteroidal': ['Abortifacient Agents, Nonsteroidal',
#   'Agents, Nonsteroidal Abortifacient',
#   'Nonsteroidal Abortifacient Agents',
#   'Abortifacient Agents, Non-Steroidal',
#   'Abortifacient Agents, Non Steroidal',
#   'Agents, Non-Steroidal Abortifacient',
#   'Non-Steroidal Abortifacient Agents'],
#  'Abortifacient Agents, Steroidal': ['Abortifacient Agents, Steroidal',
#   'Agents, Steroidal Abortifacient',
#   'Steroidal Abortifacient Agents',
#   'Steroid Abortifacients',
#   'Abortifacients, Steroid'],
#  'Abortion, Spontaneous': ['Abortion, Spontaneous',
#   'Abortions, Spontaneous',
#   'Spontaneous Abortions',
#   'Spontaneous Abortion'],
#  'Abortion Applicants': ['Abortion Applicants',
#   'Abortion Applicant',
#   'Applicant, Abortion',
#   'Applicants, Abortion',
#   'Abortion Seekers',
#   'Abortion Seeker',
#   'Seeker, Abortion',
#   'Seekers, Abortion'],
#  'Abortion, Criminal': ['Abortion, Criminal',
#   'Abortions, Criminal',
#   'Criminal Abortion',
#   'Criminal Abortions',
#   'Abortion, Illegal',
#   'Illegal Abortion',
#   'Abortions, Illegal',
#   'Illegal Abortions'],
#  'Abortion, Eugenic': ['Abortion, Eugenic',
#   'Abortions, Eugenic',
#   'Eugenic Abortions',
#   'Eugenic Abortion'],
#  'Abortion, Habitual': ['Abortion, Habitual',
#   'Habitual Abortion',
#   'Habitual Abortions',
#   'Miscarriage, Recurrent',
#   'Recurrent Miscarriage',
#   'Recurrent Miscarriages',
#   'Abortion, Recurrent',
#   'Recurrent Abortion',
#   'Recurrent Abortions',
#   'Recurrent Early Pregnancy Loss'],
#  'Abortion, Incomplete': ['Abortion, Incomplete',
#   'Abortions, Incomplete',
#   'Incomplete Abortion',
#   'Incomplete Abortions'],
#  'Abortion, Induced': ['Abortion, Induced',
#   'Induced Abortion',
#   'Abortions, Induced',
#   'Induced Abortions',
#   'Abortion (Induced)',
#   'Abortions (Induced)'],
#  'Abortion, Legal': ['Abortion, Legal',
#   'Abortions, Legal',
#   'Legal Abortion',
#   'Legal Abortions'],
#  'Abortion, Missed': ['Abortion, Missed',
#   'Abortions, Missed',
#   'Missed Abortion',
#   'Missed Abortions'],
#  'Abortion, Septic': ['Abortion, Septic',
#   'Abortions, Septic',
#   'Septic Abortions',
#   'Septic Abortion'],
#  'Abortion, Therapeutic': ['Abortion, Therapeutic',
#   'Therapeutic Abortion',
#   'Abortions, Therapeutic',
#   'Therapeutic Abortions'],
#  'Abortion, Threatened': ['Abortion, Threatened',
#   'Threatened Abortion',
#   'Threatened Abortions',
#   'Threatened Miscarriage',
#   'Miscarriage, Threatened',
#   'Threatened Miscarriages'],
#  'Abortion, Veterinary': ['Abortion, Veterinary',
#   'Veterinary Abortion',
#   'Abortions, Veterinary',
#   'Veterinary Abortions'],
#  'Abreaction': ['Abreaction', 'Abreactions'],
#  'Abrin': ['Abrin'],
#  'Abruptio Placentae': ['Abruptio Placentae',
#   'Placental Abruption',
#   'Abruption, Placental',
#   'Abruptions, Placental',
#   'Placental Abruptions'],
#  'Abscess': ['Abscess', 'Abscesses'],
#  'Peritonsillar Abscess': ['Peritonsillar Abscess',
#   'Abscesses, Peritonsillar',
#   'Peritonsillar Abscesses',
#   'Abscess, Peritonsillar'],
#  'Abscisic Acid': ['Abscisic Acid',
#   'Abscissic Acid',
#   '2,4-Pentadienoic acid, 5-(1-hydroxy-2,6,6-trimethyl-4-oxo-2-cyclohexen-1-yl)-3-methyl-, (S-(Z,E))-',
#   'Abscissins'],
#  'Absenteeism': ['Absenteeism'],
#  'Absorption': ['Absorption'],
#  'Abstracting and Indexing': ['Abstracting and Indexing',
#   'Indexing and Abstracting as Topic',
#   'Abstracting and Indexing as Topic',
#   'Indexing and Abstracting'],
#  'Dental Abutments': ['Dental Abutments',
#   'Abutments, Dental',
#   'Abutment, Dental',
#   'Dental Abutment'],
#  'Acacia': ['Acacia',
#   'Acacias',
#   'Wattle Tree',
#   'Tree, Wattle',
#   'Trees, Wattle',
#   'Wattle Trees',
#   'Locust Tree',
#   'Locust Trees',
#   'Tree, Locust',
#   'Trees, Locust'],
#  'Academic Medical Centers': ['Academic Medical Centers',
#   'Medical Center, University',
#   'University Medical Center',
#   'Medical Centers, University',
#   'University Medical Centers',
#   'Center, University Medical',
#   'Center, Academic Medical',
#   'Centers, Academic Medical',
#   'Medical Center, Academic',
#   'Medical Centers, Academic',
#   'Centers, University Medical',
#   'Academic Medical Center'],
#  'Academies and Institutes': ['Academies and Institutes',
#   'Institutes and Academies',
#   'Academy and Institute',
#   'Institute and Academy'],
#  'Acanthamoeba': ['Acanthamoeba', 'Acanthamoebas'],
#  'Acanthocephala': ['Acanthocephala',
#   'Acanthocephalas',
#   'Thorny-Headed Worms',
#   'Thorny Headed Worms',
#   'Thorny-Headed Worm',
#   'Worm, Thorny-Headed',
#   'Worms, Thorny-Headed'],
#  'Acanthocytes': ['Acanthocytes', 'Acanthocyte'],
#  'Acantholysis': ['Acantholysis', 'Acantholyses'],
#  'Acanthosis Nigricans': ['Acanthosis Nigricans',
#   'Acanthosis Nigrican',
#   'Nigrican, Acanthosis',
#   'Nigricans, Acanthosis'],
#  'Acari': ['Acari'],
#  'Acceleration': ['Acceleration', 'Accelerations'],
#  'Accessory Nerve': ['Accessory Nerve',
#   'Accessory Nerves',
#   'Nerve, Accessory',
#   'Nerves, Accessory',
#   'Spinal Accessory Nerve',
#   'Accessory Nerve, Spinal',
#   'Accessory Nerves, Spinal',
#   'Nerve, Spinal Accessory',
#   'Nerves, Spinal Accessory',
#   'Spinal Accessory Nerves',
#   'Nerve XI',
#   'Nerve XIs',
#   'Nervus Accessorius',
#   'Accessorius, Nervus',
#   'Cranial Nerve XI',
#   'Eleventh Cranial Nerve',
#   'Cranial Nerve, Eleventh',
#   'Cranial Nerves, Eleventh',
#   'Eleventh Cranial Nerves',
#   'Nerve, Eleventh Cranial',
#   'Nerves, Eleventh Cranial'],
#  'Accident Prevention': ['Accident Prevention',
#   'Prevention, Accident',
#   'Accident Preventions',
#   'Preventions, Accident'],
#  'Accident Proneness': ['Accident Proneness',
#   'Accident Pronenesses',
#   'Proneness, Accident',
#   'Pronenesses, Accident'],
#  'Accidental Falls': ['Accidental Falls',
#   'Falls',
#   'Falling',
#   'Falls, Accidental',
#   'Accidental Fall',
#   'Fall, Accidental'],
#  'Accidents': ['Accidents', 'Accident'],
#  'Accidents, Aviation': ['Accidents, Aviation',
#   'Accident, Aviation',
#   'Aviation Accident',
#   'Aviation Accidents'],
#  'Accidents, Home': ['Accidents, Home',
#   'Home Accidents',
#   'Accident, Home',
#   'Home Accident'],
#  'Accidents, Occupational': ['Accidents, Occupational',
#   'Occupational Accidents',
#   'Accident, Occupational',
#   'Occupational Accident'],
#  'Accidents, Traffic': ['Accidents, Traffic',
#   'Accident, Traffic',
#   'Traffic Accident',
#   'Traffic Accidents'],
#  'Acclimatization': ['Acclimatization', 'Acclimation'],
#  'Accommodation, Ocular': ['Accommodation, Ocular',
#   'Ocular Distance Accommodation',
#   'Accommodation, Ocular Distance',
#   'Distance Accommodation, Ocular',
#   'Ocular Distance Accommodations',
#   'Ocular Accommodation'],
#  'Accounting': ['Accounting', 'Accountings'],
#  'Oil and Gas Industry': ['Oil and Gas Industry', 'Gas and Oil Industry'],
#  'Coal Industry': ['Coal Industry',
#   'Coal Industries',
#   'Industries, Coal',
#   'Industry, Coal'],
#  'Driving Under the Influence': ['Driving Under the Influence'],
#  'Human Embryonic Stem Cells': ['Human Embryonic Stem Cells',
#   'hESCs',
#   'Stem Cells, Human Embryonic',
#   'Human Embryonic Stem Cell',
#   'Cells, Human Embryonic Stem'],
#  'Mouse Embryonic Stem Cells': ['Mouse Embryonic Stem Cells',
#   'mESCs',
#   'Stem Cells, Mouse Embryonic',
#   'Cells, Mouse Embryonic Stem',
#   'Mouse Embryonic Stem Cell'],
#  'Embryonic Germ Cells': ['Embryonic Germ Cells',
#   'Cell, Embryonic Germ',
#   'Cells, Embryonic Germ',
#   'Embryonic Germ Cell',
#   'Germ Cell, Embryonic',
#   'EG Cells',
#   'Cell, EG',
#   'Cells, EG',
#   'EG Cell',
#   'Germ Cells, Embryonic'],
#  'Work Performance': ['Work Performance',
#   'Performance, Work',
#   'Performances, Work',
#   'Work Performances',
#   'Performance at Work'],
#  'Criminal Behavior': ['Criminal Behavior',
#   'Behavior, Criminal',
#   'Behaviors, Criminal',
#   'Criminal Behaviors',
#   'Criminal Conduct',
#   'Conduct, Criminal',
#   'Criminal Intent',
#   'Criminal Intents',
#   'Intent, Criminal',
#   'Intents, Criminal',
#   'Illicit Behavior',
#   'Behavior, Illicit',
#   'Behaviors, Illicit',
#   'Illicit Behaviors',
#   'Unlawful Behavior',
#   'Behavior, Unlawful',
#   'Behaviors, Unlawful',
#   'Unlawful Behaviors',
#   'Illegal Behavior',
#   'Behavior, Illegal',
#   'Behaviors, Illegal',
#   'Illegal Behaviors'],
#  'Clinical Decision-Making': ['Clinical Decision-Making',
#   'Clinical Decision Making',
#   'Decision-Making, Clinical',
#   'Medical Decision-Making',
#   'Decision-Making, Medical',
#   'Medical Decision Making'],
#  'Cognitive Aging': ['Cognitive Aging', 'Aging, Cognitive'],
#  'Cognitive Neuroscience': ['Cognitive Neuroscience',
#   'Neuroscience, Cognitive'],
#  'Emotional Adjustment': ['Emotional Adjustment',
#   'Adjustment, Emotional',
#   'Adjustments, Emotional',
#   'Emotional Adjustments',
#   'Psychological Adjustment',
#   'Adjustment, Psychological',
#   'Adjustments, Psychological',
#   'Psychological Adjustments',
#   'Emotional Adaptation',
#   'Adaptation, Emotional',
#   'Adaptations, Emotional',
#   'Emotional Adaptations'],
#  'Facial Recognition': ['Facial Recognition',
#   'Recognition, Facial',
#   'Face Perception',
#   'Perception, Face'],
#  'Grandparents': ['Grandparents', 'Grandparent'],
#  'Help-Seeking Behavior': ['Help-Seeking Behavior',
#   'Behavior, Help-Seeking',
#   'Behaviors, Help-Seeking',
#   'Help Seeking Behavior',
#   'Help-Seeking Behaviors'],
#  'Heuristics': ['Heuristics', 'Heuristic', 'Rule of Thumb'],
#  'Intimate Partner Violence': ['Intimate Partner Violence',
#   'Partner Violence, Intimate',
#   'Violence, Intimate Partner',
#   'Intimate Partner Abuse',
#   'Abuse, Intimate Partner',
#   'Partner Abuse, Intimate'],
#  'Neurological Rehabilitation': ['Neurological Rehabilitation',
#   'Rehabilitation, Neurological',
#   'Neurorehabilitation',
#   'Neurologic Rehabilitation',
#   'Rehabilitation, Neurologic'],
#  'Physical Abuse': ['Physical Abuse',
#   'Abuse, Physical',
#   'Physical Violence',
#   'Violence, Physical',
#   'Physical Maltreatment',
#   'Maltreatment, Physical'],
#  'Problem Behavior': ['Problem Behavior',
#   'Behavior, Problem',
#   'Behaviors, Problem',
#   'Problem Behaviors',
#   'Behavioral Problem',
#   'Behavioral Problems',
#   'Problem, Behavioral',
#   'Problems, Behavioral'],
#  'Underage Drinking': ['Underage Drinking',
#   'Drinking, Underage',
#   'Underage Alcohol Use',
#   'Alcohol Use, Underage',
#   'Youth Drinking',
#   'Drinking, Youth',
#   'Underage Alcohol Consumption',
#   'Alcohol Consumption, Underage',
#   'Teen Drinking',
#   'Drinking, Teen',
#   'Teenage Drinking',
#   'Drinking, Teenage',
#   'Adolescent Alcohol Use',
#   'Alcohol Use, Adolescent',
#   'Adolescent Alcohol Consumption',
#   'Alcohol Consumption, Adolescent',
#   'Youth Alcohol Consumption',
#   'Alcohol Consumption, Youth',
#   'Adolescent Drinking',
#   'Drinking, Adolescent'],
#  'Ectopic Gene Expression': ['Ectopic Gene Expression',
#   'Ectopic Gene Expressions',
#   'Expression, Ectopic Gene',
#   'Expressions, Ectopic Gene',
#   'Gene Expression, Ectopic',
#   'Gene Expressions, Ectopic',
#   'Ectopic Expression',
#   'Ectopic Expressions',
#   'Expression, Ectopic',
#   'Expressions, Ectopic'],
#  'Cell Plasticity': ['Cell Plasticity',
#   'Cell Plasticities',
#   'Plasticities, Cell',
#   'Plasticity, Cell',
#   'Cellular Plasticity',
#   'Cellular Plasticities',
#   'Plasticities, Cellular',
#   'Plasticity, Cellular'],
#  'Cell Self Renewal': ['Cell Self Renewal',
#   'Cell Self Renewals',
#   'Renewal, Cell Self',
#   'Renewals, Cell Self',
#   'Self Renewal, Cell',
#   'Self Renewals, Cell'],
#  'Rehabilitation Research': ['Rehabilitation Research',
#   'Research, Rehabilitation'],
#  'Orthodontists': ['Orthodontists', 'Orthodontist'],
#  'Oral and Maxillofacial Surgeons': ['Oral and Maxillofacial Surgeons',
#   'Maxillofacial Surgeons',
#   'Maxillofacial Surgeon',
#   'Surgeon, Maxillofacial',
#   'Surgeons, Maxillofacial',
#   'Oral Surgeons',
#   'Oral Surgeon',
#   'Surgeon, Oral',
#   'Surgeons, Oral'],
#  'Neuroprotection': ['Neuroprotection',
#   'Neural Protection',
#   'Protection, Neural',
#   'Neuron Protection',
#   'Protection, Neuron',
#   'Neuronal Protection',
#   'Protection, Neuronal'],
#  'Diet, Food, and Nutrition': ['Diet, Food, and Nutrition'],
#  'Triticale': ['Triticale', 'Triticosecale', 'Triticum x Secale'],
#  'Critical Care Outcomes': ['Critical Care Outcomes',
#   'Care Outcome, Critical',
#   'Care Outcomes, Critical',
#   'Critical Care Outcome',
#   'Outcome, Critical Care',
#   'Outcomes, Critical Care'],
#  'Simulation Training': ['Simulation Training', 'Training, Simulation'],
#  'Millets': ['Millets', 'Millet'],
#  'Biobehavioral Sciences': ['Biobehavioral Sciences',
#   'Biobehavioral Science',
#   'Science, Biobehavioral',
#   'Sciences, Biobehavioral',
#   'Biobehavioral Model',
#   'Biobehavioral Models',
#   'Model, Biobehavioral',
#   'Models, Biobehavioral',
#   'Biobehavioral Approach',
#   'Approach, Biobehavioral'],
#  'Protein Corona': ['Protein Corona', 'Corona, Protein'],
#  'Vegetarians': ['Vegetarians', 'Vegetarian'],
#  'Vegans': ['Vegans', 'Vegan'],
#  'Accounts Payable and Receivable': ['Accounts Payable and Receivable'],
#  'Youth Sports': ['Youth Sports',
#   'Sport, Youth',
#   'Sports, Youth',
#   'Youth Sport',
#   'Adolescent Sports',
#   'Adolescent Sport',
#   'Sport, Adolescent',
#   'Sports, Adolescent',
#   "Children's Sports",
#   'Children Sports',
#   "Children's Sport",
#   'Childrens Sports',
#   "Sport, Children's",
#   "Sports, Children's"],
#  'Literacy': ['Literacy'],
#  'Severe Acute Malnutrition': ['Severe Acute Malnutrition',
#   'Acute Malnutrition, Severe',
#   'Malnutrition, Severe Acute'],
#  'Banking, Personal': ['Banking, Personal',
#   'Personal Banking',
#   'Banking, Commercial',
#   'Commercial Banking',
#   'Bank Accounts',
#   'Account, Bank',
#   'Accounts, Bank',
#   'Bank Account',
#   'Banking, Financial',
#   'Financial Banking'],
#  'Evidence-Based Facility Design': ['Evidence-Based Facility Design',
#   'Design, Evidence-Based Facility',
#   'Designs, Evidence-Based Facility',
#   'Evidence Based Facility Design',
#   'Evidence-Based Facility Designs',
#   'Facility Design, Evidence-Based',
#   'Facility Designs, Evidence-Based'],
#  'Physical Appearance, Body': ['Physical Appearance, Body',
#   'Appearance, Body Physical',
#   'Body Physical Appearance',
#   'Physical Appearance',
#   'Appearance, Physical',
#   'Outward Appearance',
#   'Appearance, Outward',
#   'Body, Physical Appearance'],
#  'Fruit and Vegetable Juices': ['Fruit and Vegetable Juices'],
#  'Ghee': ['Ghee',
#   'Ghees',
#   'Anhydrous Butterfat',
#   'Anhydrous Butterfats',
#   'Butterfat, Anhydrous',
#   'Butterfats, Anhydrous',
#   'Butter Oil',
#   'Butter Oils',
#   'Oil, Butter',
#   'Oils, Butter',
#   'Clarified Butter',
#   'Butter, Clarified',
#   'Butters, Clarified',
#   'Clarified Butters'],
#  'Hydraulic Fracking': ['Hydraulic Fracking',
#   'Fracking, Hydraulic',
#   'Hydraulic Fracturing',
#   'Fracturing, Hydraulic',
#   'Fraccing',
#   'Hydrofracturing',
#   'Hydrofracturings',
#   'Hydrofracking',
#   'Fracking'],
#  'Psychological Trauma': ['Psychological Trauma', 'Trauma, Psychological'],
#  'Peer Influence': ['Peer Influence', 'Influence, Peer'],
#  'Vegetable Products': ['Vegetable Products',
#   'Product, Vegetable',
#   'Products, Vegetable',
#   'Vegetable Product'],
#  'Direct-to-Consumer Advertising': ['Direct-to-Consumer Advertising',
#   'Advertising, Direct-to-Consumer',
#   'Direct to Consumer Advertising',
#   'Direct-to-Consumer Marketing',
#   'Direct to Consumer Marketing',
#   'Marketing, Direct-to-Consumer'],
#  'Direct-To-Consumer Screening and Testing': ['Direct-To-Consumer Screening and Testing',
#   'Direct To Consumer Screening and Testing',
#   'Direct-To-Consumer Screening',
#   'Direct To Consumer Screening',
#   'Direct-To-Consumer Screenings',
#   'Screening, Direct-To-Consumer',
#   'Screenings, Direct-To-Consumer',
#   'Direct-To-Consumer Testing',
#   'Direct To Consumer Testing',
#   'Direct-To-Consumer Testings',
#   'Testing, Direct-To-Consumer',
#   'Testings, Direct-To-Consumer'],
#  'Extracellular Vesicles': ['Extracellular Vesicles',
#   'Extracellular Vesicle',
#   'Vesicle, Extracellular',
#   'Vesicles, Extracellular'],
#  'Fungal Viruses': ['Fungal Viruses',
#   'Fungal Virus',
#   'Virus, Fungal',
#   'Viruses, Fungal',
#   'Mycoviruses',
#   'Mycovirus'],
#  'Telocytes': ['Telocytes',
#   'Telocyte',
#   'Interstitial Cell of Cajal-Like Cells',
#   'Interstitial Cell of Cajal Like Cells',
#   'Interstitial Cajal-Like Cells',
#   'Cajal-Like Cells, Interstitial',
#   'Cells, Interstitial Cajal-Like',
#   'Interstitial Cajal Like Cells'],
#  'Exoskeleton Device': ['Exoskeleton Device',
#   'Device, Exoskeleton',
#   'Devices, Exoskeleton',
#   'Exoskeleton Devices'],
#  'Shellfish Hypersensitivity': ['Shellfish Hypersensitivity',
#   'Hypersensitivities, Shellfish',
#   'Hypersensitivity, Shellfish',
#   'Shellfish Hypersensitivities',
#   'Shellfish Allergy',
#   'Allergies, Shellfish',
#   'Allergy, Shellfish',
#   'Shellfish Allergies'],
#  'Failure to Rescue, Health Care': ['Failure to Rescue, Health Care',
#   'Health Care, Failures to Rescue',
#   'Health Care, Failure to Rescue',
#   'Failure to Rescue (Health Care)',
#   'Failure to Rescues (Health Care)',
#   'Rescue, Failure to (Health Care)',
#   'Rescues, Failure to (Health Care)'],
#  'Psychiatric Rehabilitation': ['Psychiatric Rehabilitation',
#   'Rehabilitation, Psychiatric',
#   'Mental Health Rehabilitation',
#   'Health Rehabilitation, Mental',
#   'Rehabilitation, Mental Health',
#   'Psychosocial Rehabilitation',
#   'Rehabilitation, Psychosocial'],
#  'Symptom Flare Up': ['Symptom Flare Up',
#   'Flare Up, Symptom',
#   'Flare Ups, Symptom',
#   'Symptom Flare Ups',
#   'Symptom Flaring Up',
#   'Flaring Up, Symptom',
#   'Acute Symptom Flare',
#   'Acute Symptom Flares',
#   'Symptom Flare, Acute',
#   'Symptom Flareup',
#   'Flareup, Symptom',
#   'Flareups, Symptom',
#   'Symptom Flareups',
#   'Symptom Flare-up',
#   'Flare-up, Symptom',
#   'Flare-ups, Symptom',
#   'Symptom Flare-ups'],
#  'Isolated Heart Preparation': ['Isolated Heart Preparation',
#   'Isolated Heart Preparations',
#   'Preparation, Isolated Heart',
#   'Preparations, Isolated Heart',
#   'Isolated Perfused Heart Model'],
#  'Diet, Vegan': ['Diet, Vegan', 'Diets, Vegan', 'Vegan Diets', 'Vegan Diet'],
#  'Behavior Observation Techniques': ['Behavior Observation Techniques',
#   'Behavior Observation Technique',
#   'Observation Technique, Behavior',
#   'Observation Techniques, Behavior',
#   'Behavioral Observation Techniques',
#   'Behavioral Observation Technique',
#   'Observation Technique, Behavioral',
#   'Observation Techniques, Behavioral',
#   'Behavior Observation',
#   'Behavior Observations',
#   'Observation, Behavior',
#   'Observations, Behavior',
#   'Behavioral Observation',
#   'Behavioral Observations',
#   'Observation, Behavioral',
#   'Observations, Behavioral'],
#  'Behavior Rating Scale': ['Behavior Rating Scale',
#   'Behavior Rating Scales',
#   'Rating Scale, Behavior',
#   'Rating Scales, Behavior',
#   'Behavioral Rating Scale',
#   'Behavioral Rating Scales',
#   'Rating Scale, Behavioral',
#   'Rating Scales, Behavioral',
#   'Scale, Behavioral Rating'],
#  'Alcohol Drinking in College': ['Alcohol Drinking in College',
#   'College Student Drinking',
#   'Student Drinking, College',
#   'Alcohol Drinking, College Students',
#   'College Drinking',
#   'Drinking, College',
#   'University Student Drinking',
#   'Student Drinking, University'],
#  'Obesity, Metabolically Benign': ['Obesity, Metabolically Benign',
#   'Benign Obesity, Metabolically',
#   'Metabolically Healthy Obesity',
#   'Healthy Obesity, Metabolically',
#   'Obesity, Metabolically Healthy',
#   'Metabolically Benign Obesity'],
#  'Whole Grains': ['Whole Grains',
#   'Grain, Whole',
#   'Grains, Whole',
#   'Whole Grain'],
#  'Transanal Endoscopic Surgery': ['Transanal Endoscopic Surgery',
#   'Endoscopic Surgeries, Transanal',
#   'Endoscopic Surgery, Transanal',
#   'Surgeries, Transanal Endoscopic',
#   'Surgery, Transanal Endoscopic',
#   'Transanal Endoscopic Surgeries',
#   'Transanal Endoscopic Surgical Procedures'],
#  'Transanal Endoscopic Microsurgery': ['Transanal Endoscopic Microsurgery',
#   'Endoscopic Microsurgeries, Transanal',
#   'Endoscopic Microsurgery, Transanal',
#   'Microsurgeries, Transanal Endoscopic',
#   'Microsurgery, Transanal Endoscopic',
#   'Transanal Endoscopic Microsurgeries'],
#  'Cold Injury': ['Cold Injury',
#   'Cold Injuries',
#   'Injuries, Cold',
#   'Injury, Cold'],
#  'Personal Protective Equipment': ['Personal Protective Equipment',
#   'Equipment, Personal Protective',
#   'Protective Equipment, Personal'],
#  'Nerve Agents': ['Nerve Agents', 'Agents, Nerve'],
#  'War-Related Injuries': ['War-Related Injuries',
#   'Injuries, War-Related',
#   'Injury, War-Related',
#   'War Related Injuries',
#   'War-Related Injury'],
#  'Abnormal Involuntary Movement Scale': ['Abnormal Involuntary Movement Scale'],
#  'Blood Alcohol Content': ['Blood Alcohol Content',
#   'Alcohol Content, Blood',
#   'Content, Blood Alcohol',
#   'Blood Alcohol Concentration',
#   'Alcohol Concentration, Blood',
#   'Concentration, Blood Alcohol',
#   'Blood Alcohol Level',
#   'Alcohol Level, Blood',
#   'Level, Blood Alcohol'],
#  'Social Communication Disorder': ['Social Communication Disorder',
#   'Communication Disorder, Social',
#   'Communication Disorders, Social',
#   'Social Communication Disorders',
#   'Pragmatic Communication Disorder',
#   'Communication Disorder, Pragmatic',
#   'Communication Disorders, Pragmatic',
#   'Disorders, Pragmatic Communication',
#   'Pragmatic Communication Disorders'],
#  'Legal Services': ['Legal Services',
#   'Legal Service',
#   'Service, Legal',
#   'Services, Legal'],
#  'Defamation': ['Defamation',
#   'Defamations',
#   'Vilification',
#   'Vilifications',
#   'Calumny',
#   'Calumnies'],
#  'Anger Management Therapy': ['Anger Management Therapy',
#   'Therapy, Anger Management',
#   'Anger Management Training',
#   'Management Training, Anger',
#   'Training, Anger Management',
#   'Anger Management',
#   'Management, Anger'],
#  'Psychology, Sports': ['Psychology, Sports',
#   'Sport Psychology',
#   'Psychology, Sport',
#   'Sports Psychology'],
#  'War Exposure': ['War Exposure',
#   'Exposure, War',
#   'Exposures, War',
#   'War Exposures'],
#  'Childhood-Onset Fluency Disorder': ['Childhood-Onset Fluency Disorder',
#   'Childhood Onset Fluency Disorder',
#   'Childhood-Onset Fluency Disorders',
#   'Disorder, Childhood-Onset Fluency',
#   'Disorders, Childhood-Onset Fluency',
#   'Fluency Disorder, Childhood-Onset',
#   'Fluency Disorders, Childhood-Onset'],
#  'No-Show Patients': ['No-Show Patients',
#   'No Show Patients',
#   'No-Show Patient',
#   'Patient, No-Show',
#   'Patients, No-Show',
#   'Patient Non-Attendance',
#   'Non-Attendance, Patient',
#   'Patient Non Attendance',
#   'Patient No-Show',
#   'No-Show, Patient',
#   'No-Shows, Patient',
#   'Patient No Show'],
#  'Cellular Reprogramming Techniques': ['Cellular Reprogramming Techniques',
#   'Cellular Reprogramming Technique',
#   'Reprogramming Technique, Cellular',
#   'Reprogramming Techniques, Cellular',
#   'Technique, Cellular Reprogramming',
#   'Techniques, Cellular Reprogramming',
#   'Cell Programming Techniques',
#   'Cell Programming Technique',
#   'Programming Technique, Cell',
#   'Programming Techniques, Cell',
#   'Technique, Cell Programming',
#   'Techniques, Cell Programming',
#   'Cell Reprogramming Techniques',
#   'Cell Reprogramming Technique',
#   'Reprogramming Technique, Cell',
#   'Reprogramming Techniques, Cell',
#   'Technique, Cell Reprogramming',
#   'Techniques, Cell Reprogramming'],
#  'Metacognition': ['Metacognition', 'Meta-cognition', 'Meta cognition'],
#  'Prescription Drug Overuse': ['Prescription Drug Overuse',
#   'Drug Overuse, Prescription',
#   'Drug Overuses, Prescription',
#   'Overuse, Prescription Drug',
#   'Overuses, Prescription Drug',
#   'Prescription Drug Overuses',
#   'Medication Overutilization',
#   'Medication Overutilizations',
#   'Overutilization, Medication',
#   'Overutilizations, Medication',
#   'Medication Overuse',
#   'Medication Overuses',
#   'Overuse, Medication',
#   'Overuses, Medication',
#   'Prescription Drug Overutilization',
#   'Drug Overutilization, Prescription',
#   'Drug Overutilizations, Prescription',
#   'Overutilization, Prescription Drug',
#   'Overutilizations, Prescription Drug',
#   'Prescription Drug Overutilizations'],
#  'Near Miss, Healthcare': ['Near Miss, Healthcare',
#   'Healthcare Near Miss',
#   'Healthcare Near Misses',
#   'Near Misses, Healthcare',
#   'Close Call, Healthcare',
#   'Close Calls, Healthcare',
#   'Healthcare Close Call',
#   'Healthcare Close Calls'],
#  'RNAi Therapeutics': ['RNAi Therapeutics',
#   'RNAi-Based Therapeutics',
#   'RNAi-Based Therapy',
#   'RNAi Based Therapy',
#   'RNAi-Based Therapies',
#   'Therapies, RNAi-Based',
#   'Therapy, RNAi-Based',
#   'RNAi Therapy',
#   'RNAi Therapies',
#   'Therapies, RNAi',
#   'Therapy, RNAi'],
#  'Dynamic Light Scattering': ['Dynamic Light Scattering',
#   'Light Scattering, Dynamic',
#   'Scattering, Dynamic Light'],
#  'Time Out, Healthcare': ['Time Out, Healthcare',
#   'Healthcare Time Out',
#   'Healthcare Time Outs',
#   'Time Outs, Healthcare',
#   'Timeout, Healthcare',
#   'Healthcare Timeout',
#   'Healthcare Timeouts',
#   'Timeouts, Healthcare'],
#  'Healthcare Failure Mode and Effect Analysis': ['Healthcare Failure Mode and Effect Analysis',
#   'HFMEA',
#   'Failure Mode and Effect Analysis, Healthcare'],
#  'Spirit Possession': ['Spirit Possession',
#   'Possession, Spirit',
#   'Possessions, Spirit',
#   'Spirit Possessions',
#   'Demonic Possession',
#   'Demonic Possessions',
#   'Possession, Demonic',
#   'Possessions, Demonic',
#   'Demon Possession',
#   'Demon Possessions',
#   'Possession, Demon',
#   'Possessions, Demon'],
#  'Crew Resource Management, Healthcare': ['Crew Resource Management, Healthcare',
#   'Healthcare Crisis Resource Management',
#   'Crisis Resource Management, Healthcare',
#   'Healthcare Crew Resource Management',
#   'Healthcare CRM',
#   'CRM, Healthcare',
#   'CRMs, Healthcare',
#   'Healthcare CRMs'],
#  'Computer Heuristics': ['Computer Heuristics',
#   'Computer Heuristic',
#   'Heuristic, Computer',
#   'Heuristics, Computer'],
#  'Ataxins': ['Ataxins',
#   'Spinocerebellar Ataxia Proteins',
#   'Ataxia Proteins, Spinocerebellar',
#   'Proteins, Spinocerebellar Ataxia',
#   'Ataxin Proteins',
#   'Proteins, Ataxin'],
#  'Alarmins': ['Alarmins',
#   'Damage-Associated Molecular Pattern Molecules',
#   'Damage Associated Molecular Pattern Molecules',
#   'Danger-Associated Molecular Pattern Molecules',
#   'Danger Associated Molecular Pattern Molecules',
#   'Alarmin Proteins',
#   'Alarmin'],
#  'Dermal Fillers': ['Dermal Fillers',
#   'Fillers, Dermal',
#   'Skin Filler',
#   'Filler, Skin',
#   'Skin Fillers',
#   'Fillers, Skin',
#   'Dermal Filler',
#   'Filler, Dermal'],
#  'Action Spectrum': ['Action Spectrum', 'Spectrum, Action'],
#  'Diplomacy': ['Diplomacy'],
#  'Mutation Accumulation': ['Mutation Accumulation',
#   'Accumulation, Mutation',
#   'Accumulations, Mutation',
#   'Mutation Accumulations'],
#  'Internal Ribosome Entry Sites': ['Internal Ribosome Entry Sites',
#   'Internal Ribosome Entry Site'],
#  'Biological Mimicry': ['Biological Mimicry',
#   'Mimicry, Biological',
#   'Crypses',
#   'Aposematism',
#   'Aposematisms',
#   'Batesian Mimicry',
#   'Batesian Mimicries',
#   'Mimicries, Batesian',
#   'Mimicry, Batesian',
#   'Mullerian Mimicry',
#   'Mimicries, Mullerian',
#   'Mimicry, Mullerian',
#   'Mullerian Mimicries'],
#  'Specific Learning Disorder': ['Specific Learning Disorder',
#   'Disorder, Specific Learning',
#   'Learning Disorder, Specific',
#   'Learning Disorders, Specific',
#   'Specific Learning Disorders'],
#  'Potentially Inappropriate Medication List': ['Potentially Inappropriate Medication List',
#   'PIM List',
#   'PIM Lists',
#   'Potentially Inappropriate Medications',
#   'Inappropriate Medication, Potentially',
#   'Inappropriate Medications, Potentially',
#   'Medication, Potentially Inappropriate',
#   'Medications, Potentially Inappropriate',
#   'Potentially Inappropriate Medication'],
#  'Late Onset Disorders': ['Late Onset Disorders',
#   'Disorder, Late Onset',
#   'Disorders, Late Onset',
#   'Late Onset Disorder',
#   'Onset Disorder, Late',
#   'Onset Disorders, Late',
#   'Later Onset Disorders',
#   'Disorder, Later Onset',
#   'Disorders, Later Onset',
#   'Later Onset Disorder',
#   'Onset Disorder, Later',
#   'Onset Disorders, Later',
#   'Late-Onset Disorders',
#   'Disorder, Late-Onset',
#   'Disorders, Late-Onset',
#   'Late-Onset Disorder',
#   'Late Onset Diseases',
#   'Disease, Late Onset',
#   'Diseases, Late Onset',
#   'Late Onset Disease',
#   'Onset Disease, Late',
#   'Onset Diseases, Late'],
#  'Phakopsora pachyrhizi': ['Phakopsora pachyrhizi',
#   'Phakopsora pachyrhizus',
#   'pachyrhizi, Phakopsora',
#   'pachyrhizus, Phakopsora',
#   'Asian Soybean Rust',
#   'Rust, Asian Soybean',
#   'Soybean Rust, Asian',
#   'Soybean Rusts, Asian'],
#  'Farmers': ['Farmers',
#   'Farmer',
#   'Farm Workers',
#   'Farm Worker',
#   'Worker, Farm',
#   'Workers, Farm',
#   'Agricultural Workers',
#   'Agricultural Worker',
#   'Worker, Agricultural',
#   'Workers, Agricultural',
#   'Farmworkers',
#   'Farmworker'],
#  'Culturally Appropriate Technology': ['Culturally Appropriate Technology',
#   'Appropriate Technologies, Culturally',
#   'Appropriate Technology, Culturally',
#   'Culturally Appropriate Technologies',
#   'Technologies, Culturally Appropriate',
#   'Technology, Culturally Appropriate'],
#  'Social Learning': ['Social Learning', 'Learning, Social'],
#  'Financial Statements': ['Financial Statements',
#   'Financial Statement',
#   'Statement, Financial',
#   'Statements, Financial'],
#  'Miners': ['Miners',
#   'Miner',
#   'Mine Workers',
#   'Mine Worker',
#   'Worker, Mine',
#   'Workers, Mine',
#   'Mineworkers',
#   'Mineworker'],
#  'Chronopharmacokinetics': ['Chronopharmacokinetics', 'Chronopharmacokinetic'],
#  'Administrative Claims, Healthcare': ['Administrative Claims, Healthcare',
#   'Administrative Claim, Healthcare',
#   'Claim, Healthcare Administrative',
#   'Claims, Healthcare Administrative',
#   'Healthcare Administrative Claim',
#   'Healthcare Administrative Claims'],
#  'Child Health': ['Child Health',
#   'Health, Child',
#   "Children's Health",
#   "Health, Children's",
#   'Childrens Health',
#   'Health, Childrens'],
#  'Interleukin-33': ['Interleukin-33', 'Interleukin 33', 'IL33', 'IL-33'],
#  'S100A12 Protein': ['S100A12 Protein',
#   'Protein, S100A12',
#   'S100 A12 Protein',
#   'A12 Protein, S100',
#   'Protein, S100 A12',
#   'MRP-6 Protein',
#   'MRP 6 Protein',
#   'Protein, MRP-6',
#   'Calgranulin C Protein',
#   'C Protein, Calgranulin',
#   'Protein, Calgranulin C',
#   'EN-RAGE Protein',
#   'EN RAGE Protein',
#   'Protein, EN-RAGE',
#   'ENRAGE Protein',
#   'Protein, ENRAGE',
#   'S100A12',
#   'CAAF1 Protein',
#   'Protein, CAAF1'],
#  'Telopodes': ['Telopodes', 'Telopode'],
#  'Drosophila simulans': ['Drosophila simulans',
#   'simulans, Drosophila',
#   'D. simulans'],
#  'Optimism': ['Optimism'],
#  'Pessimism': ['Pessimism', 'Negative Thinking', 'Thinking, Negative'],
#  'Ataxin-1': ['Ataxin-1',
#   'Ataxin 1',
#   'SCA1 Protein',
#   'Protein, SCA1',
#   'Atxn-1 Protein',
#   'Atxn 1 Protein',
#   'Protein, Atxn-1',
#   'Atxn1 Protein',
#   'Protein, Atxn1',
#   'Spinocerebellar Ataxia Type 1 Protein',
#   'Ataxin-1 Protein',
#   'Ataxin 1 Protein',
#   'Protein, Ataxin-1'],
#  'Adolescent Health': ['Adolescent Health',
#   'Health, Adolescent',
#   'Teen Health',
#   'Health, Teen'],
#  'Ataxin-2': ['Ataxin-2',
#   'Ataxin 2',
#   'Ataxin-2 Protein',
#   'Ataxin 2 Protein',
#   'Protein, Ataxin-2',
#   'Spinocerebellar Ataxia Type 2 Protein',
#   'ATXN2 Protein',
#   'Protein, ATXN2',
#   'Atx-2 Protein',
#   'Atx 2 Protein',
#   'Protein, Atx-2',
#   'SCA2 Protein',
#   'Protein, SCA2'],
#  'Ataxin-3': ['Ataxin-3',
#   'Ataxin 3',
#   'SCA3 Protein',
#   'Ataxin-3 Protein',
#   'Ataxin 3 Protein',
#   'Machado-Joseph Disease Protein',
#   'Machado Joseph Disease Protein',
#   'Spinocerebellar Ataxia 3 Protein',
#   'ATXN3 Protein'],
#  'Point-of-Care Testing': ['Point-of-Care Testing',
#   'Point-of-Care Testings',
#   'Testing, Point-of-Care',
#   'Testings, Point-of-Care',
#   'Point of Care Testing'],
#  'Ataxin-7': ['Ataxin-7',
#   'Ataxin 7',
#   'SCA7 Protein',
#   'Protein, SCA7',
#   'Atxn-7 Protein',
#   'Atxn 7 Protein',
#   'Protein, Atxn-7',
#   'Spinocerebellar Ataxia 7 Protein',
#   'ATXN7 Protein',
#   'Protein, ATXN7'],
#  'Ataxin-10': ['Ataxin-10',
#   'Ataxin 10',
#   'Atxn-10 Protein',
#   'Atxn 10 Protein',
#   'Protein, Atxn-10',
#   'Spinocerebellar Ataxia 10 Protein',
#   'ATXN10 Protein',
#   'Protein, ATXN10',
#   'SCA10 Protein',
#   'Protein, SCA10'],
#  'Glucagon-Like Peptide Receptors': ['Glucagon-Like Peptide Receptors',
#   'Glucagon Like Peptide Receptors',
#   'Peptide Receptors, Glucagon-Like',
#   'Receptors, Glucagon-Like Peptide',
#   'Glucagon-Like Receptors',
#   'Glucagon Like Receptors',
#   'Receptors, Glucagon-Like',
#   'GLPR Proteins',
#   'Proteins, GLPR'],
#  'Glucagon-Like Peptide-1 Receptor': ['Glucagon-Like Peptide-1 Receptor',
#   'Glucagon Like Peptide 1 Receptor',
#   'Peptide-1 Receptor, Glucagon-Like',
#   'Receptor, Glucagon-Like Peptide-1',
#   'GLP-1R Receptor',
#   'GLP 1R Receptor',
#   'Receptor, GLP-1R',
#   'GLP1R Protein',
#   'Protein, GLP1R',
#   'GLP-1 Receptor',
#   'GLP 1 Receptor',
#   'Receptor, GLP-1',
#   'GLP1R Receptor',
#   'Receptor, GLP1R'],
#  'Glucagon-Like Peptide-2 Receptor': ['Glucagon-Like Peptide-2 Receptor',
#   'Peptide-2 Receptor, Glucagon-Like',
#   'Receptor, Glucagon-Like Peptide-2',
#   'GLP-2 Receptor',
#   'GLP 2 Receptor',
#   'Receptor, GLP-2',
#   'GLP2R Protein',
#   'Protein, GLP2R',
#   'Glucagon-Like Peptide 2 Receptor',
#   'Glucagon Like Peptide 2 Receptor',
#   'GLP-2R Receptor',
#   'GLP 2R Receptor',
#   'Receptor, GLP-2R'],
#  'Receptor for Advanced Glycation End Products': ['Receptor for Advanced Glycation End Products',
#   'Receptor for Advanced Glycation Endproducts',
#   'Receptor, Advanced Glycosylation End-Product',
#   'Receptor, Advanced Glycosylation End Product',
#   'Receptor, Advanced Glycosylation End-Products',
#   'Receptor, Advanced Glycosylation End Products',
#   'Advanced Glycosylation End Product-Specific Receptor',
#   'Advanced Glycosylation End Product Specific Receptor',
#   'Receptor for Advanced Glycation End Products (RAGE)',
#   'Amphoterin Receptor',
#   'Receptor, Amphoterin',
#   'Advanced Glycosylation Endproduct Receptors',
#   'AGE Receptor',
#   'RAGE (Receptor for Advanced Glycation End Products)',
#   'Advanced Glycosylation End Product Receptors',
#   'Advanced Glycosylation End-Product Receptor',
#   'Advanced Glycosylation End Product Receptor',
#   'Advanced Glycosylation End-Product Receptors',
#   'AGER Protein'],
#  'RNA Recognition Motif Proteins': ['RNA Recognition Motif Proteins',
#   'Ribonucleoprotein Domain Proteins',
#   'RNA-Binding Domain Proteins',
#   'RNA Binding Domain Proteins',
#   'RRM Proteins'],
#  'ELAV-Like Protein 2': ['ELAV-Like Protein 2',
#   '2, ELAV-Like Protein',
#   'ELAV Like Protein 2',
#   'Protein 2, ELAV-Like',
#   'ELAV (Embryonic Lethal, Abnormal Vision, Drosophila)-Like 2 (Hu Antigen B)',
#   'HuB Antigen',
#   'Antigen, HuB',
#   'HuB Protein',
#   'Protein, HuB',
#   'ELAVL2 protein',
#   'protein, ELAVL2',
#   'HuB Paraneoplastic Encephalomyelitis Antigen'],
#  'ELAV-Like Protein 3': ['ELAV-Like Protein 3',
#   '3, ELAV-Like Protein',
#   'ELAV Like Protein 3',
#   'Protein 3, ELAV-Like',
#   'HuC Paraneoplastic Encephalomyelitis Antigen',
#   'HuC Protein',
#   'Protein, HuC',
#   'ELAVL3 Protein',
#   'Protein, ELAVL3',
#   'HuC Antigen',
#   'Antigen, HuC'],
#  'ELAV-Like Protein 4': ['ELAV-Like Protein 4',
#   'ELAV Like Protein 4',
#   'HuD Paraneoplastic Encephalomyelitis Antigen',
#   'HuD Protein',
#   'Protein, HuD',
#   'ELAVL4 Protein',
#   'Protein, ELAVL4',
#   'HuD Antigen',
#   'Antigen, HuD'],
#  'ELAV-Like Protein 1': ['ELAV-Like Protein 1',
#   'ELAV Like Protein 1',
#   'HuR Paraneoplastic Encephalomyelitis Antigen',
#   'HuR Protein',
#   'Protein, HuR',
#   'ELAVL1 protein',
#   'protein, ELAVL1',
#   'HuR Antigen',
#   'Antigen, HuR'],
#  'Whey': ['Whey'],
#  'Whey Proteins': ['Whey Proteins',
#   'Protein, Whey',
#   'Proteins, Whey',
#   'Whey Protein'],
#  'Hoarding Disorder': ['Hoarding Disorder',
#   'Disorders, Hoarding',
#   'Hoarding Disorders'],
#  'Poly(ADP-ribose) Polymerase Inhibitors': ['Poly(ADP-ribose) Polymerase Inhibitors',
#   'Inhibitors of Poly(ADP-ribose) Polymerases',
#   'Poly(ADP-ribosylation) Inhibitors',
#   'PARP Inhibitors',
#   'Inhibitors, PARP'],
#  'Autism Spectrum Disorder': ['Autism Spectrum Disorder',
#   'Spectrum Disorders, Autism',
#   'Autism Spectrum Disorders'],
#  'CELF Proteins': ['CELF Proteins',
#   'Proteins, CELF',
#   'BRUNOL Proteins',
#   'Proteins, BRUNOL',
#   'CUGBP, Elav-Like Family Member Proteins',
#   'CUGBP, Elav Like Family Member Proteins',
#   'CUG Triplet Repeat, RNA-Binding Proteins',
#   'CUG Triplet Repeat, RNA Binding Proteins',
#   'CUG-BP Proteins',
#   'CUG BP Proteins',
#   'Proteins, CUG-BP',
#   'CUGBP Proteins',
#   'Proteins, CUGBP',
#   'Bruno-Like Family Member Proteins',
#   'Bruno Like Family Member Proteins'],
#  'CELF1 Protein': ['CELF1 Protein',
#   'Protein, CELF1',
#   'Bruno-Like 2 Protein',
#   '2 Protein, Bruno-Like',
#   'Bruno Like 2 Protein',
#   'Protein, Bruno-Like 2',
#   'CUGBP, Elav-Like Family Member 1 Protein',
#   'CUGBP, Elav Like Family Member 1 Protein',
#   'CUGBP1 Protein',
#   'Protein, CUGBP1',
#   'BRUNOL2 Protein',
#   'Protein, BRUNOL2',
#   'CUG Triplet Repeat, RNA-Binding Protein 1',
#   'CUG Triplet Repeat, RNA Binding Protein 1'],
#  'Industrial Development': ['Industrial Development',
#   'Development, Industrial',
#   'Developments, Industrial',
#   'Industrial Developments'],
#  'Cloud Computing': ['Cloud Computing',
#   'Computing, Cloud',
#   'Cloud Processing',
#   'Processing, Cloud',
#   'Cloud Storage',
#   'Cloud Storages',
#   'Storage, Cloud',
#   'Storages, Cloud',
#   'Cloud Service',
#   'Service, Cloud'],
#  'Natural Resources': ['Natural Resources',
#   'Natural Resource',
#   'Resource, Natural',
#   'Resources, Natural'],
#  'Glycemic Load': ['Glycemic Load', 'Load, Glycemic'],
#  'Adenylyl Cyclase Inhibitors': ['Adenylyl Cyclase Inhibitors',
#   'Cyclase Inhibitors, Adenylyl',
#   'Inhibitors, Adenylyl Cyclase',
#   'Adenylate Cyclase Inhibitors',
#   'Cyclase Inhibitors, Adenylate',
#   'Inhibitors, Adenylate Cyclase'],
#  'RAW 264.7 Cells': ['RAW 264.7 Cells',
#   '264.7 Cell, RAW',
#   '264.7 Cells, RAW',
#   'Cell, RAW 264.7',
#   'Cells, RAW 264.7',
#   'RAW 264.7 Cell',
#   'RAW 264.7 Cell Line'],
#  'Accreditation': ['Accreditation', 'Accreditations'],
#  'Clostridiales': ['Clostridiales'],
#  'Graphic Novel': ['Graphic Novel', 'Graphic Novels'],
#  'South Sudan': ['South Sudan'],
#  'Motor Disorders': ['Motor Disorders'],
#  'Maternal Health': ['Maternal Health', 'Health, Maternal'],
#  'Seed Bank': ['Seed Bank',
#   'Bank, Seed',
#   'Banks, Seed',
#   'Seed Banks',
#   'Seeds Bank',
#   'Bank, Seeds',
#   'Seedbank',
#   'Seedbanks'],
#  'Trauma and Stressor Related Disorders': ['Trauma and Stressor Related Disorders'],
#  'Maternal-Child Health Services': ['Maternal-Child Health Services',
#   'Health Service, Maternal-Child',
#   'Maternal Child Health Services',
#   'Maternal-Child Health Service',
#   'Service, Maternal-Child Health',
#   'Services, Maternal-Child Health',
#   'Health Services, Maternal-Child',
#   'Health Services, Maternal Child'],
#  'Serine-Arginine Splicing Factors': ['Serine-Arginine Splicing Factors',
#   'Factors, Serine-Arginine Splicing',
#   'Serine Arginine Splicing Factors',
#   'Splicing Factors, Serine-Arginine',
#   'Serine-Arginine-Rich Splicing Proteins',
#   'Proteins, Serine-Arginine-Rich Splicing',
#   'Serine Arginine Rich Splicing Proteins',
#   'Splicing Proteins, Serine-Arginine-Rich',
#   'SR-Rich Splicing Proteins',
#   'Proteins, SR-Rich Splicing',
#   'SR Rich Splicing Proteins',
#   'Splicing Proteins, SR-Rich'],
#  'Infant Health': ['Infant Health',
#   'Health, Infant',
#   'Baby Health',
#   'Health, Baby'],
#  'Bipolar and Related Disorders': ['Bipolar and Related Disorders'],
#  'Gender Dysphoria': ['Gender Dysphoria'],
#  'Formative Feedback': ['Formative Feedback',
#   'Feedback, Formative',
#   'Constructive Feedback',
#   'Feedback, Constructive',
#   'Feedback (Learning)'],
#  'Aripiprazole': ['Aripiprazole',
#   '7-(4-(4-(2,3-dichlorophenyl)-1-piperazinyl)butyloxy)-3,4-dihydro-2(1H)-quinolinone',
#   'Aripiprazol'],
#  'Prunus dulcis': ['Prunus dulcis',
#   'Almond Tree',
#   'Almond Trees',
#   'Tree, Almond',
#   'Trees, Almond',
#   'Prunis communis',
#   'Sweet Almond',
#   'Almond, Sweet',
#   'Almonds, Sweet',
#   'Sweet Almonds',
#   'Prunus amygdalus',
#   'Amygdalus communis'],
#  'Albumin-Bound Paclitaxel': ['Albumin-Bound Paclitaxel',
#   'Albumin Bound Paclitaxel',
#   'Paclitaxel, Albumin-Bound',
#   'Protein-Bound Paclitaxel',
#   'Paclitaxel, Protein-Bound',
#   'Protein Bound Paclitaxel'],
#  'Child Protective Services': ['Child Protective Services',
#   'Child Protective Service',
#   'Child Welfare Agencies',
#   'Child Welfare Agency',
#   'Welfare Agency, Child'],
#  'Social Workers': ['Social Workers',
#   'Social Worker',
#   'Worker, Social',
#   'Workers, Social'],
#  'Prunus africana': ['Prunus africana',
#   'African Prune',
#   'African Prunes',
#   'Prunes, African',
#   'Prune, African',
#   'Pygeum africanum'],
#  'Prunus armeniaca': ['Prunus armeniaca',
#   'Apricot Tree',
#   'Apricot Trees',
#   'Tree, Apricot',
#   'Trees, Apricot'],
#  'Prunus avium': ['Prunus avium',
#   'Sweet Cherry Tree',
#   'Cherry Tree, Sweet',
#   'Cherry Trees, Sweet',
#   'Sweet Cherry Trees',
#   'Tree, Sweet Cherry',
#   'Trees, Sweet Cherry'],
#  'Refugium': ['Refugium', 'Refugia'],
#  'Distance Counseling': ['Distance Counseling',
#   'Counseling, Distance',
#   'E-Therapy',
#   'E Therapy',
#   'E-Therapies',
#   'E-Counseling',
#   'E Counseling'],
#  'Lubiprostone': ['Lubiprostone',
#   'Prostan-1-oic acid, 16,16-difluoro-11-hydroxy-9,15-dioxo-, (11alpha)-'],
#  'Prunus persica': ['Prunus persica',
#   'Peach Tree',
#   'Peach Trees',
#   'Tree, Peach',
#   'Trees, Peach'],
#  'Data Anonymization': ['Data Anonymization', 'Anonymization, Data'],
#  'Personally Identifiable Information': ['Personally Identifiable Information'],
#  'Prunus domestica': ['Prunus domestica',
#   'Plum Tree',
#   'Plum Trees',
#   'Tree, Plum',
#   'Trees, Plum'],
#  'Darbepoetin alfa': ['Darbepoetin alfa',
#   'Novel Erythropoiesis Stimulating Protein',
#   'NESP',
#   'Darbepoietin alfa'],
#  'Efavirenz, Emtricitabine, Tenofovir Disoproxil Fumarate Drug Combination': ['Efavirenz, Emtricitabine, Tenofovir Disoproxil Fumarate Drug Combination'],
#  'Bevacizumab': ['Bevacizumab'],
#  'Giraffes': ['Giraffes', 'Giraffe'],
#  'Risedronic Acid': ['Risedronic Acid'],
#  'Fluticasone-Salmeterol Drug Combination': ['Fluticasone-Salmeterol Drug Combination',
#   'Drug Combination, Fluticasone-Salmeterol',
#   'Fluticasone Salmeterol Drug Combination',
#   'Fluticasone - Salmeterol',
#   'Fluticasone Salmeterol',
#   'Fluticasone-Salmeterol Combination',
#   'Combination, Fluticasone-Salmeterol',
#   'Fluticasone Salmeterol Combination'],
#  'Fluticasone': ['Fluticasone'],
#  'Salmeterol Xinafoate': ['Salmeterol Xinafoate', 'Xinafoate, Salmeterol'],
#  'Parks, Recreational': ['Parks, Recreational',
#   'Park, Recreational',
#   'Recreational Park',
#   'Recreational Parks'],
#  'Warfare and Armed Conflicts': ['Warfare and Armed Conflicts',
#   'Armed Conflicts and Warfare'],
#  'Armed Conflicts': ['Armed Conflicts',
#   'Armed Conflict',
#   'Conflict, Armed',
#   'Conflicts, Armed'],
#  'Everolimus': ['Everolimus',
#   'SDZ RAD',
#   'RAD, SDZ',
#   'SDZ-RAD',
#   '40-O-(2-hydroxyethyl)-rapamycin'],
#  'Aspirin, Dipyridamole Drug Combination': ['Aspirin, Dipyridamole Drug Combination',
#   'Aspirin-Dipyridamole Drug Combination',
#   'Aspirin Dipyridamole Drug Combination',
#   'Combination, Aspirin-Dipyridamole Drug',
#   'Drug Combination, Aspirin-Dipyridamole'],
#  'Self-Control': ['Self-Control',
#   'Self-Regulation',
#   'Self Control',
#   'Control, Self',
#   'Self Regulation',
#   'Regulation, Self'],
#  'Saline Waters': ['Saline Waters',
#   'Saline Water',
#   'Water, Saline',
#   'Waters, Saline'],
#  'Compassion Fatigue': ['Compassion Fatigue',
#   'Fatigue, Compassion',
#   'Vicarious Trauma',
#   'Trauma, Vicarious',
#   'Traumas, Vicarious',
#   'Vicarious Traumas',
#   'Secondary Trauma',
#   'Secondary Traumas',
#   'Trauma, Secondary',
#   'Traumas, Secondary',
#   'Secondary Traumatization',
#   'Secondary Traumatizations',
#   'Traumatization, Secondary',
#   'Traumatizations, Secondary',
#   'Secondary Traumatic Stress',
#   'Stress, Secondary Traumatic',
#   'Stresses, Secondary Traumatic',
#   'Traumatic Stress, Secondary',
#   'Vicarious Traumatization',
#   'Traumatization, Vicarious'],
#  'Plantaginaceae': ['Plantaginaceae',
#   'Speedwell Family',
#   'Families, Speedwell',
#   'Family, Speedwell',
#   'Speedwell Families'],
#  'Lamiales': ['Lamiales'],
#  'Clinical Study': ['Clinical Study'],
#  'Surgical Clearance': ['Surgical Clearance',
#   'Clearance, Surgical',
#   'Clearances, Surgical',
#   'Surgical Clearances',
#   'Medical Clearance',
#   'Clearance, Medical',
#   'Clearances, Medical',
#   'Medical Clearances'],
#  'Pemetrexed': ['Pemetrexed',
#   'MTA',
#   'N-(4-(2-(2-amino-3,4-dihydro-4-oxo-7H-pyrrolo(2,3-d)pyrimdin-5-yl)ethyl)benzoyl)glutamic acid'],
#  'Brimonidine Tartrate': ['Brimonidine Tartrate',
#   '5-Bromo-6-(2-imidazolin-2-ylamino)quinoxaline D-tartrate'],
#  'Clinical Studies as Topic': ['Clinical Studies as Topic'],
#  'Beijing': ['Beijing', 'Peking'],
#  'African Union': ['African Union', 'Union, African'],
#  'Firmicutes': ['Firmicutes'],
#  'Dutasteride': ['Dutasteride',
#   '17beta-N-(2,5-bis(trifluoromethyl))phenyl-carbamoyl-4-aza-5alpha-androst-1-en-3-one'],
#  'Calceolariaceae': ['Calceolariaceae'],
# ...
#   'Cardiovascular Rehabilitations',
#   'Rehabilitation, Cardiovascular',
#   'Rehabilitations, Cardiovascular'],
#  'Fracture Dislocation': ['Fracture Dislocation',
#   'Dislocation, Fracture',
#   'Dislocations, Fracture',
#   'Fracture Dislocations',
#   'Dislocation Fracture',
#   'Dislocation Fractures',
#   'Fracture, Dislocation',
#   'Fractures, Dislocation'],
#  'Apolipoprotein A-V': ['Apolipoprotein A-V',
#   'Apolipoprotein A V',
#   'APOA5 Protein',
#   'ApoA-V Protein',
#   'ApoA V Protein',
#   'Apo A-V Protein',
#   'Apo A V Protein',
#   'Apolipoprotein A5',
#   'Apo A5 Protein'],
#  'PAX3 Transcription Factor': ['PAX3 Transcription Factor',
#   'Transcription Factor, PAX3',
#   'Paired Box Transcription Factor 3',
#   'Transcription Factor PAX3',
#   'Factor PAX3, Transcription',
#   'PAX3, Transcription Factor',
#   'Paired Box 3 Protein'],
#  'Salter-Harris Fractures': ['Salter-Harris Fractures',
#   'Fractures, Salter-Harris',
#   'Salter Harris Fractures',
#   'Growth Plate Injuries',
#   'Growth Plate Injury',
#   'Growth Plate Fractures',
#   'Fracture, Growth Plate',
#   'Fractures, Growth Plate',
#   'Growth Plate Fracture'],
#  'Transcription Factor HES-1': ['Transcription Factor HES-1',
#   'HES-1, Transcription Factor',
#   'Transcription Factor HES 1',
#   'Hairy-Like Transcription Factor',
#   'Hairy Like Transcription Factor',
#   'Transcription Factor, Hairy-Like',
#   'Hairy and Enhancer of Split 1 Protein'],
#  'Anesthetists': ['Anesthetists', 'Anesthetist'],
#  'Positron Emission Tomography Computed Tomography': ['Positron Emission Tomography Computed Tomography',
#   'PET-CT Scan',
#   'PET-CT Scans',
#   'Scan, PET-CT',
#   'Scans, PET-CT',
#   'PET CT Scan',
#   'CT Scan, PET',
#   'CT Scans, PET',
#   'PET CT Scans',
#   'Scan, PET CT',
#   'Scans, PET CT',
#   'CT PET',
#   'Positron Emission Tomography-Computed Tomography',
#   'PET-CT',
#   'CT PET Scan',
#   'CT PET Scans',
#   'PET Scan, CT',
#   'PET Scans, CT',
#   'Scan, CT PET',
#   'Scans, CT PET'],
#  'Patched Receptors': ['Patched Receptors',
#   'Receptors, Patched',
#   'Patched Sonic Hedgehog Receptors',
#   'Patched Receptor',
#   'Receptor, Patched',
#   'Patched Protein'],
#  'Anesthesiologists': ['Anesthesiologists', 'Anesthesiologist'],
#  'Patched-1 Receptor': ['Patched-1 Receptor',
#   'Patched 1 Receptor',
#   'Receptor, Patched-1',
#   'PTCH1 Protein',
#   'Patched Homolog-1',
#   'Patched Homolog 1',
#   'Patched-1 Protein',
#   'Patched 1 Protein',
#   'Patched Receptor-1',
#   'Patched Receptor 1',
#   'Receptor-1, Patched'],
#  'Patched-2 Receptor': ['Patched-2 Receptor',
#   'Patched 2 Receptor',
#   'Receptor, Patched-2',
#   'PTCH2 Protein',
#   'Patched Receptor-2',
#   'Patched Receptor 2',
#   'Patched-2 Protein',
#   'Patched 2 Protein',
#   'Patched Homolog-2',
#   'Patched Homolog 2'],
#  'Dermatologists': ['Dermatologists', 'Dermatologist'],
#  'Smoothened Receptor': ['Smoothened Receptor',
#   'Receptor, Smoothened',
#   'Smoothened Protein',
#   'Smoothened Receptors',
#   'Receptors, Smoothened'],
#  'Occupational Therapists': ['Occupational Therapists',
#   'Occupational Therapist',
#   'Therapist, Occupational',
#   'Therapists, Occupational'],
#  'Cardiologists': ['Cardiologists', 'Cardiologist'],
#  'Endocrinologists': ['Endocrinologists', 'Endocrinologist'],
#  'Single Photon Emission Computed Tomography Computed Tomography': ['Single Photon Emission Computed Tomography Computed Tomography',
#   'SPECT CT',
#   'CT SPECT Scan',
#   'CT SPECT Scans',
#   'SPECT Scan, CT',
#   'SPECT Scans, CT',
#   'Scan, CT SPECT',
#   'Scans, CT SPECT',
#   'CT SPECT',
#   'CT SPECTs',
#   'SPECT, CT',
#   'SPECTs, CT',
#   'SPECT CT Scan',
#   'CT Scan, SPECT',
#   'CT Scans, SPECT',
#   'SPECT CT Scans',
#   'Scan, SPECT CT',
#   'Scans, SPECT CT'],
#  'Serrate-Jagged Proteins': ['Serrate-Jagged Proteins',
#   'Serrate Jagged Proteins',
#   'Jagged Proteins',
#   'Serrate Protein',
#   'Serrate Proteins'],
#  'Jagged-1 Protein': ['Jagged-1 Protein',
#   'Jagged 1 Protein',
#   'Alagille Syndrome Protein',
#   'Jagged1 Protein',
#   'Serrate1 Protein',
#   'Jagged-1',
#   'Jagged 1',
#   'Serrate-1 Protein',
#   'Serrate 1 Protein',
#   'CD339 Antigen',
#   'Antigen, CD339'],
#  'Jagged-2 Protein': ['Jagged-2 Protein',
#   'Jagged 2 Protein',
#   'Serrate2 Protein',
#   'Serrate-2 Protein',
#   'Serrate 2 Protein',
#   'Jagged2 Protein'],
#  'Gastroenterologists': ['Gastroenterologists', 'Gastroenterologist'],
#  'Oncologists': ['Oncologists', 'Oncologist'],
#  'Nephrologists': ['Nephrologists', 'Nephrologist'],
#  'Superoxide Dismutase-1': ['Superoxide Dismutase-1',
#   'Cuprozinc Superoxide Dismutase',
#   'Superoxide Dismutase, Cuprozinc',
#   'Superoxide Dismutase 1',
#   'Cu-Zn Superoxide Dismutase',
#   'Cu Zn Superoxide Dismutase',
#   'Superoxide Dismutase, Cu-Zn',
#   'SOD-1 Protein',
#   'SOD 1 Protein',
#   'SOD1 Protein'],
#  'Pulmonologists': ['Pulmonologists', 'Pulmonologist'],
#  'Counselors': ['Counselors', 'Counselor'],
#  'Vaping': ['Vaping',
#   'E-Cigarette Use',
#   'E Cigarette Use',
#   'E-Cigarette Uses',
#   'Use, E-Cigarette',
#   'Uses, E-Cigarette',
#   'E-Cig Use',
#   'E Cig Use',
#   'E-Cig Uses',
#   'Use, E-Cig',
#   'Uses, E-Cig',
#   'Vape',
#   'Vapes'],
#  'Mosquito Vectors': ['Mosquito Vectors',
#   'Mosquito Vector',
#   'Vector, Mosquito',
#   'Vectors, Mosquito'],
#  'Giant Viruses': ['Giant Viruses',
#   'Giant Virus',
#   'Virus, Giant',
#   'Viruses, Giant',
#   'Giruses'],
#  'Rheumatologists': ['Rheumatologists', 'Rheumatologist'],
#  'Neurologists': ['Neurologists', 'Neurologist'],
#  'Pathologists': ['Pathologists', 'Pathologist'],
#  'Pediatricians': ['Pediatricians', 'Pediatrician'],
#  'Neonatologists': ['Neonatologists', 'Neonatologist'],
#  'Physiatrists': ['Physiatrists', 'Physiatrist'],
#  'Epidemiologists': ['Epidemiologists', 'Epidemiologist'],
#  'Dynactin Complex': ['Dynactin Complex', 'Dynactins'],
#  'Tumor Protein p73': ['Tumor Protein p73',
#   'Protein p73, Tumor',
#   'p73, Tumor Protein',
#   'Protein p73',
#   'p73, Protein',
#   'p73 Protein',
#   'Protein, p73',
#   'Tumor Suppressor Protein p73',
#   'Tap73 Protein, Human',
#   'Human Tap73 Protein',
#   'Protein, Human Tap73'],
#  'Orthopedic Surgeons': ['Orthopedic Surgeons',
#   'Orthopedic Surgeon',
#   'Surgeon, Orthopedic',
#   'Surgeons, Orthopedic',
#   'Orthopedists',
#   'Orthopedist'],
#  'Optometrists': ['Optometrists', 'Optometrist'],
#  'Ophthalmologists': ['Ophthalmologists', 'Ophthalmologist'],
#  'Superconductivity': ['Superconductivity', 'Superconductivities'],
#  'Radiologists': ['Radiologists', 'Radiologist'],
#  'Urologists': ['Urologists', 'Urologist'],
#  'Interleukin-1 Receptor-Like 1 Protein': ['Interleukin-1 Receptor-Like 1 Protein',
#   'Interleukin 1 Receptor Like 1 Protein',
#   'Interleukin 1 Receptor-Related Protein',
#   'Interleukin 1 Receptor Related Protein',
#   'Interleukin-33 Receptor',
#   'Interleukin 33 Receptor',
#   'Receptor, Interleukin-33',
#   'IL1RL1 Protein'],
#  'Phosphoinositide Phosphatases': ['Phosphoinositide Phosphatases',
#   'Phosphatases, Phosphoinositide',
#   'Phosphoinositide Phosphatase',
#   'Phosphatase, Phosphoinositide'],
#  'Inositol Polyphosphate 5-Phosphatases': ['Inositol Polyphosphate 5-Phosphatases',
#   'Inositol Polyphosphate 5 Phosphatases',
#   'Inositol 5-Phosphatase',
#   'Inositol 5 Phosphatase',
#   'Inositol Triphosphate 5-Phosphatase',
#   'Inositol Triphosphate 5 Phosphatase',
#   'Inositol-Polyphosphate 5-Phosphatase',
#   'Inositol Polyphosphate 5 Phosphatase',
#   'Inositol Polyphosphate 5-Phosphatase'],
#  'Non-Medical Public and Private Facilities': ['Non-Medical Public and Private Facilities',
#   'Non Medical Public and Private Facilities'],
#  'Phosphatidylinositol-3,4,5-Trisphosphate 5-Phosphatases': ['Phosphatidylinositol-3,4,5-Trisphosphate 5-Phosphatases',
#   'Src Homology 2 Domain-Containing Inositol Phosphatases',
#   'Src Homology 2 Domain Containing Inositol Phosphatases',
#   'SHIP Phosphatases',
#   'Phosphatases, SHIP'],
#  'Nurse Specialists': ['Nurse Specialists',
#   'Nurse Specialist',
#   'Specialist, Nurse',
#   'Specialists, Nurse'],
#  'Fertilins': ['Fertilins',
#   'Fertilin Protein',
#   'PH-30 Fusion Protein',
#   'PH-30 Protein',
#   'PH 30 Protein',
#   'Fertilin',
#   'PH 30 Fusion Protein'],
#  'ADAM10 Protein': ['ADAM10 Protein',
#   'CD156w Antigen',
#   'Antigen, CD156w',
#   'CD156c Antigen',
#   'Antigen, CD156c',
#   'Disintegrin and Metalloproteinase Domain-Containing Protein 10',
#   'Disintegrin and Metalloproteinase Domain Containing Protein 10',
#   'ADAM-10 Protein',
#   'ADAM 10 Protein'],
#  'ADAM17 Protein': ['ADAM17 Protein',
#   'TACE (Enzyme)',
#   'TNF-alpha Converting Enzyme',
#   'TNF alpha Converting Enzyme',
#   'Tumor Necrosis Factor Alpha Convertase',
#   'ADAM-17',
#   'Tumor Necrosis Factor-alpha Converting Enzyme',
#   'Tumor Necrosis Factor alpha Converting Enzyme',
#   'TNF-alpha Convertase',
#   'Convertase, TNF-alpha',
#   'TNF alpha Convertase',
#   'CD156b Antigen',
#   'Antigen, CD156b',
#   'ADAM-17 Protein',
#   'ADAM 17 Protein',
#   'Disintegrin and Metalloproteinase Domain-Containing Protein 17',
#   'Disintegrin and Metalloproteinase Domain Containing Protein 17',
#   'TACA (Enzyme)',
#   'Tumor Necrosis Factor-alpha Convertase'],
#  'ADAM12 Protein': ['ADAM12 Protein',
#   'ADAM-12 Protein',
#   'Meltrin-alpha Protein',
#   'Meltrin alpha Protein',
#   'Disintegrin and Metalloproteinase Domain-Containing Protein 12',
#   'Disintegrin and Metalloproteinase Domain Containing Protein 12',
#   'ADAM 12 Protein'],
#  'Ku Autoantigen': ['Ku Autoantigen',
#   'Autoantigen, Ku',
#   'Ku Heterodimer',
#   'Heterodimer, Ku',
#   'Ku Protein',
#   'Ku Antigen',
#   'Antigen, Ku',
#   'G22P1 Antigen',
#   'Antigen, G22P1'],
#  'Zona Pellucida Glycoproteins': ['Zona Pellucida Glycoproteins',
#   'Glycoproteins, Zona Pellucida',
#   'Pellucida Glycoproteins, Zona',
#   'ZP Proteins',
#   'Proteins, ZP',
#   'Sperm Receptors',
#   'Receptors, Sperm'],
#  'Endodontists': ['Endodontists', 'Endodontist'],
#  'Geriatricians': ['Geriatricians',
#   'Geriatrician',
#   'Gerontologists',
#   'Gerontologist'],
#  'Otolaryngologists': ['Otolaryngologists', 'Otolaryngologist'],
#  'Nurses, Neonatal': ['Nurses, Neonatal',
#   'Neonatal Nurse',
#   'Neonatal Nurses',
#   'Nurse, Neonatal'],
#  'Nurses, Pediatric': ['Nurses, Pediatric',
#   'Nurse, Pediatric',
#   'Pediatric Nurse',
#   'Pediatric Nurses'],
#  'Allergists': ['Allergists', 'Allergist'],
#  'Bcl-2-Like Protein 11': ['Bcl-2-Like Protein 11',
#   '11, Bcl-2-Like Protein',
#   'Bcl 2 Like Protein 11',
#   'Protein 11, Bcl-2-Like',
#   'Bcl-2-Interacting Mediator of Cell Death',
#   'Bcl 2 Interacting Mediator of Cell Death',
#   'Bcl-2-Binding Protein, BIM',
#   'BIM Bcl-2-Binding Protein',
#   'Bcl 2 Binding Protein, BIM',
#   'Protein, BIM Bcl-2-Binding',
#   'BCL2L11 Protein',
#   'Protein, BCL2L11',
#   'BIM Protein',
#   'Protein, BIM'],
#  'Computed Tomography Angiography': ['Computed Tomography Angiography',
#   'Angiographies, Computed Tomography',
#   'Computed Tomography Angiographies',
#   'Tomography Angiographies, Computed',
#   'Tomography Angiography, Computed',
#   'Angiography, Computed Tomography',
#   'Angiography, CT',
#   'CT Angiography',
#   'Angiographies, CT',
#   'CT Angiographies'],
#  'Shoulder Prosthesis': ['Shoulder Prosthesis',
#   'Prostheses, Shoulder',
#   'Prosthesis, Shoulder',
#   'Shoulder Prostheses',
#   'Prosthetic Shoulder',
#   'Prosthetic Shoulders',
#   'Shoulder, Prosthetic',
#   'Shoulders, Prosthetic',
#   'Artificial Shoulder Joint',
#   'Artificial Shoulder Joints',
#   'Joint, Artificial Shoulder',
#   'Joints, Artificial Shoulder',
#   'Shoulder Joint, Artificial',
#   'Shoulder Joints, Artificial',
#   'Humeral Head Prosthesis',
#   'Head Prostheses, Humeral',
#   'Head Prosthesis, Humeral',
#   'Humeral Head Prostheses',
#   'Prostheses, Humeral Head',
#   'Prosthesis, Humeral Head'],
#  'Arthroplasty, Replacement, Shoulder': ['Arthroplasty, Replacement, Shoulder',
#   'Total Shoulder Replacement',
#   'Replacement, Total Shoulder',
#   'Replacements, Total Shoulder',
#   'Shoulder Replacement, Total',
#   'Shoulder Replacements, Total',
#   'Total Shoulder Replacements',
#   'Shoulder Replacement Arthroplasty',
#   'Arthroplasties, Shoulder Replacement',
#   'Arthroplasty, Shoulder Replacement',
#   'Replacement Arthroplasties, Shoulder',
#   'Replacement Arthroplasty, Shoulder',
#   'Shoulder Replacement Arthroplasties'],
#  'Posterior Cruciate Ligament Reconstruction': ['Posterior Cruciate Ligament Reconstruction'],
#  'Sustained Virologic Response': ['Sustained Virologic Response',
#   'Response, Sustained Virologic',
#   'Sustained Virologic Responses',
#   'Virologic Response, Sustained',
#   'Sustained Viral Suppression',
#   'Suppression, Sustained Viral',
#   'Sustained Viral Suppressions'],
#  'In Vivo Dosimetry': ['In Vivo Dosimetry',
#   'Dosimetries, In Vivo',
#   'Dosimetry, In Vivo',
#   'In Vivo Dosimetries'],
#  'Radiation Dosimeters': ['Radiation Dosimeters',
#   'Dosimeter, Radiation',
#   'Dosimeters, Radiation',
#   'Radiation Dosimeter',
#   'Dosimeters',
#   'Dosimeter'],
#  'Homer Scaffolding Proteins': ['Homer Scaffolding Proteins',
#   'Proteins, Homer Scaffolding',
#   'Scaffolding Proteins, Homer',
#   'Homer Proteins',
#   'Proteins, Homer'],
#  'Donor Conception': ['Donor Conception',
#   'Conception, Donor',
#   'Conceptions, Donor',
#   'Donor Conceptions'],
#  'Mating Factor': ['Mating Factor',
#   'Factor, Mating',
#   'Mating Hormone',
#   'Hormone, Mating'],
#  'Methyl-Accepting Chemotaxis Proteins': ['Methyl-Accepting Chemotaxis Proteins',
#   'Chemotaxis Proteins, Methyl-Accepting',
#   'Methyl Accepting Chemotaxis Proteins',
#   'Proteins, Methyl-Accepting Chemotaxis'],
#  'ERG1 Potassium Channel': ['ERG1 Potassium Channel',
#   'Channel, ERG1 Potassium',
#   'Potassium Channel, ERG1',
#   'Potassium Voltage-Gated Channel, Subfamily H, Member 2',
#   'Ether-A-Go-Go-Related Potassium Channel 1',
#   'Ether A Go Go Related Potassium Channel 1'],
#  'Oxygen Radical Absorbance Capacity': ['Oxygen Radical Absorbance Capacity'],
#  'Tumor Hypoxia': ['Tumor Hypoxia',
#   'Hypoxia, Tumor',
#   'Hypoxias, Tumor',
#   'Tumor Hypoxias',
#   'Tumor Cell Hypoxia',
#   'Cell Hypoxia, Tumor',
#   'Cell Hypoxias, Tumor',
#   'Hypoxia, Tumor Cell',
#   'Hypoxias, Tumor Cell',
#   'Tumor Cell Hypoxias'],
#  'Connexin 26': ['Connexin 26',
#   '26, Connexin',
#   'beta2 Connexin',
#   'Connexin, beta2',
#   'Connexin beta-2',
#   'Connexin beta 2',
#   'beta-2, Connexin',
#   'Connexin Cx26',
#   'Cx26, Connexin'],
#  'RNA Splicing Factors': ['RNA Splicing Factors',
#   'Factors, RNA Splicing',
#   'Splicing Factors, RNA',
#   'Splicing Factors',
#   'Factors, Splicing'],
#  'Dishevelled Proteins': ['Dishevelled Proteins', 'Dishevelled Protein'],
#  'Private Facilities': ['Private Facilities',
#   'Facilities, Private',
#   'Facility, Private',
#   'Private Facility'],
#  'Sports and Recreational Facilities': ['Sports and Recreational Facilities'],
#  'Maximal Respiratory Pressures': ['Maximal Respiratory Pressures',
#   'Pressure, Maximal Respiratory',
#   'Pressures, Maximal Respiratory',
#   'Respiratory Pressure, Maximal',
#   'Respiratory Pressures, Maximal',
#   'Maximal Respiratory Pressure',
#   'Maximum Respiratory Pressure',
#   'Maximum Respiratory Pressures',
#   'Pressure, Maximum Respiratory',
#   'Pressures, Maximum Respiratory',
#   'Respiratory Pressure, Maximum',
#   'Respiratory Pressures, Maximum'],
#  'Forkhead Box Protein M1': ['Forkhead Box Protein M1', 'FOXM1 Protein'],
#  'Bacteria, Thermoduric': ['Bacteria, Thermoduric', 'Thermoduric Bacteria'],
#  'Lymphadenopathy': ['Lymphadenopathy',
#   'Lymphadenopathies',
#   'Adenopathy',
#   'Adenopathies'],
#  'Extraintestinal Pathogenic Escherichia coli': ['Extraintestinal Pathogenic Escherichia coli',
#   'Extraintestinal Pathogenic E. coli',
#   'ExPEC'],
#  'A549 Cells': ['A549 Cells',
#   'A549 Cell',
#   'Cell, A549',
#   'Cells, A549',
#   'A549 Cell Line',
#   'A549 Cell Lines',
#   'Cell Line, A549',
#   'Cell Lines, A549'],
#  'Bathroom Equipment': ['Bathroom Equipment', 'Equipment, Bathroom'],
#  'Dioxins and Dioxin-like Compounds': ['Dioxins and Dioxin-like Compounds',
#   'Dioxins and Dioxin like Compounds'],
#  'Polychlorinated Dibenzodioxins': ['Polychlorinated Dibenzodioxins',
#   'Dibenzodioxins, Polychlorinated',
#   'Polychlorinated Dibenzo-p-dioxins',
#   'Dibenzo-p-dioxins, Polychlorinated',
#   'Polychlorinated Dibenzo p dioxins',
#   'Chlorinated Dibenzo-p-dioxins',
#   'Chlorinated Dibenzo p dioxins',
#   'Dibenzo-p-dioxins, Chlorinated',
#   'Polychlorinated Dibenzodioxin',
#   'Dibenzodioxin, Polychlorinated'],
#  ...}
