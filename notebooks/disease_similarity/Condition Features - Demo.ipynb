# %%
import pandas as pd
import numpy as np

import datetime as dt
import pickle
from importlib import reload

import pdaactconn as pc
from trialexplorer import AACTStudySet
from trialexplorer import studysimilarity as ssim

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
reload(ssim)
# Out:
# <module 'trialexplorer.studysimilarity' from '/home/rmfeng/Documents/GradSchool/capstone/trial-explorer/trialexplorer/studysimilarity.py'>

# %%
## let's load bing's data and make sure we have only values that have data
bd = pickle.load(open('raw_data/all_bing.p', 'rb'))
new_bd = {}
for k, v in bd.items():
    if not ssim.has_no_data(v):
        new_bd[k] = v
bd = new_bd

# %%
all_conds = list(bd.keys())

# %% [markdown]
# ## Featurize the 2 conditions

# %%
c1 = all_conds[10]
c2 = all_conds[20]
c1, c2
# Out:
# ('Stroke', 'Type 2 Diabetes Mellitus')

# %%
f1 = ssim.featurize_one_cond(c1, bd)
f1
# Out:
# {'condition': 'stroke',
#  'nouns': 'stroke',
#  'bing_tokens': {'stroke': 17, 'symptoms': 4, 'causes': 4},
#  'bing_links': ['https://www.mayoclinic.org/diseases-conditions/stroke/symptoms-causes/syc-20350113',
#   'https://en.wikipedia.org/wiki/Stroke',
#   'https://www.cdc.gov/stroke/index.htm',
#   'https://www.ocregister.com/2019/11/29/24-years-after-a-stroke-coach-for-oranges-el-modena-high-is-living-his-dream/',
#   'https://thehill.com/homenews/media/472278-larry-king-says-he-had-a-stroke-in-march-and-was-in-coma-its-been-a-rough-year',
#   'https://www.bbc.co.uk/sport/rowing/50569807',
#   'https://www.webmd.com/stroke/default.htm',
#   'https://www.healthline.com/health/stroke',
#   'https://www.stroke.org/en/about-stroke',
#   'https://medlineplus.gov/stroke.html',
#   'https://www.medicalnewstoday.com/articles/7624.php',
#   'https://www.medicinenet.com/stroke_symptoms_and_treatment/article.htm',
#   'https://www.mayoclinic.org/diseases-conditions/stroke/diagnosis-treatment/drc-20350119',
#   'https://www.bustle.com/p/7-warning-signs-of-a-stroke-that-everyone-should-know-62074',
#   'https://www.wikihow.health/Diagnose-a-Stroke',
#   'https://www.webmd.com/stroke/news/20101215/study-gives-striking-snapshot-of-stroke-prognosis',
#   'https://www.mayoclinic.org/diseases-conditions/stroke/in-depth/stroke-rehabilitation/art-20045172'],
#  'bing_wiki': ['Stroke - Wikipedia'],
#  'stages': None,
#  'adj_and_verbs': ([], [])}

# %%
f2 = ssim.featurize_one_cond(c2, bd)
f2
# Out:
# {'condition': 'type 2 diabetes mellitus',
#  'nouns': 'type diabetes',
#  'bing_tokens': {'diabetes': 20, 'type': 5},
#  'bing_links': ['https://www.webmd.com/diabetes/guide/types-of-diabetes-mellitus',
#   'https://www.webmd.com/diabetes/type-2-diabetes-treatments',
#   'https://www.webmd.com/diabetes/eating-right',
#   'https://www.webmd.com/men/guide/diabetes-men',
#   'https://www.webmd.com/diabetes/guide/risk-factors-for-diabetes',
#   'https://www.drugs.com/health-guide/type-2-diabetes-mellitus.html',
#   'https://www.webmd.com/diabetes/type-2-diabetes',
#   'https://emedicine.medscape.com/article/117853-overview',
#   'https://www.mayoclinic.org/diseases-conditions/type-2-diabetes/symptoms-causes/syc-20351193',
#   'https://en.wikipedia.org/wiki/Diabetes_mellitus_type_2',
#   'https://www.diabetes.org/diabetes/type-2',
#   'https://medlineplus.gov/diabetestype2.html',
#   'https://www.mayoclinic.org/diseases-conditions/type-2-diabetes/diagnosis-treatment/drc-20351199',
#   'https://www.sharecare.com/health/type-2-diabetes/blood-sugar-level-be-with-type-2-diabetes',
#   'https://www.endocrineweb.com/conditions/type-2-diabetes/type-2-diabetes-causes',
#   'https://messageboards.webmd.com/health-conditions/f/diabetes/10099/type-2-is-the-most-common-form-of-diabetes',
#   'https://www.medicinenet.com/type_2_diabetes/article.htm'],
#  'bing_wiki': ['Type 2 diabetes - Wikipedia'],
#  'stages': {'type': ['2'],
#   'genotyp_': [],
#   'grade': [],
#   'stage': [],
#   'ajcc': [],
#   'hepatitis': []},
#  'adj_and_verbs': ([], ['mellitus'])}

# %%
ssim.featurize_conditions(f1, f2)
# Out:
# {'full_fuzzy_ratio': 13,
#  'noun_fuzzy_ratio': 21,
#  'bing_bagoword_dist': 50,
#  'bing_link_sim': 0.0,
#  'same_wiki': 0.0,
#  'stage_dist': 10.0,
#  'adj_dist': 0.0,
#  'vb_dist': 1.0}

# %% [markdown]
# ## how long does this take?

# %%
# %timeit ssim.featurize_cond_full(*np.random.choice(all_conds, 2), bd)
# Out:
# 8.92 ms ± 46.1 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## How much in our entire pair space?

# %%
tot_pairs = 65144 * 65145 / 2
tot_pairs / 1000000
# Out:
# 2121.90294

# %% [markdown]
# > roughly 2 billion pairs of cond1, cond2

# %%
# how long to brute force featurize each pair?
secs_per_pair = 8.92 / 1000
tot_pairs * secs_per_pair / 60 / 60
# Out:
# 5257.6039513333335

# %% [markdown]
# > roughly 5250 hours on my desktop unix, not impossible if we can parallelize

# %% [markdown]
# # Example of 10 random features:

# %%
rand_conds = np.random.choice(all_conds, 10)
rand_conds
# Out:
# array(['Brachiobasilic Arteriovenous Fistula',
#        'Catheter-related Bloodstream Infection (CRBSI) Nos',
#        'Lyme Disease', 'Intraoperative Neurophysiological Monitoring',
#        'Laparoscopic Gynecological Surgery', 'Sympathetic Integrity',
#        'Endovascular Treatment', 'Latent Tuberculosis',
#        'Adult Erythroleukemia', 'Type-2 Diabetes Mellitus'], dtype='<U158')

# %%
cur_featurized = {}
for i, cond in enumerate(rand_conds):
    cur_f = ssim.featurize_one_cond(cond, bd)
    cur_featurized[cond] = cur_f
    print("\n ###### STUDY %s ###### " % i)
    for k, v in cur_f.items():
        if k != 'bing_links':
            print("'%s': %s" % (k, v))
        else:
            print("num_links (not printed): %s" % len(v))
# Out:
#  ###### STUDY 0 ######
# 'condition': brachiobasilic arteriovenous fistula
# 'nouns': fistula
# 'bing_tokens': {'fistula': 12, 'arteriovenous': 11, 'brachiobasilic': 2}
# num_links (not printed): 22
# 'bing_wiki': ['Arteriovenous fistula - Wikipedia']
# 'stages': None
# 'adj_and_verbs': (['brachiobasilic', 'arteriovenous'], [])
#
#  ###### STUDY 1 ######
# 'condition': catheter-related bloodstream infection (crbsi) nos
# 'nouns': bloodstream infection crbsi nos
# 'bing_tokens': {'bloodstream': 7, 'catheterrelated': 6, 'infections': 4, 'infection': 2, 'crbsicom': 1, 'home': 1, '2020': 1, 'icd10cm': 1, 'diagnosis': 1, 'code': 1}
# num_links (not printed): 13
# 'bing_wiki': ['Taurolidine - Wikipedia']
# 'stages': None
# 'adj_and_verbs': (['catheter-related'], [])
#
#  ###### STUDY 2 ######
# 'condition': lyme disease
# 'nouns': lyme disease
# 'bing_tokens': {'lyme': 23, 'disease': 2}
# num_links (not printed): 32
# 'bing_wiki': ['Lyme disease - Wikipedia']
# 'stages': None
# 'adj_and_verbs': ([], [])
#
#  ###### STUDY 3 ######
# 'condition': intraoperative neurophysiological monitoring
# 'nouns': monitoring
# 'bing_tokens': {'intraoperative': 9, 'monitoring': 7, 'neurophysiological': 4, 'wikipedia': 2, 'makes': 1, 'sense': 1, 'sciencedirect': 1}
# num_links (not printed): 9
# 'bing_wiki': ['Neuropsychological test - Wikipedia']
# 'stages': None
# 'adj_and_verbs': (['intraoperative', 'neurophysiological'], [])
#
#  ###### STUDY 4 ######
# 'condition': laparoscopic gynecological surgery
# 'nouns': surgery
# 'bing_tokens': {'laparoscopic': 9, 'surgery': 7, 'gynecological': 6, 'laparoscopy': 3}
# num_links (not printed): 14
# 'bing_wiki': ['Laparoscopy - Wikipedia']
# 'stages': None
# 'adj_and_verbs': (['gynecological'], [])
#
#  ###### STUDY 5 ######
# 'condition': sympathetic integrity
# 'nouns': integrity
# 'bing_tokens': {'sympathetic': 5, 'nervous': 4, 'system': 4, 'integrity': 2, 'wikipedia': 2, 'function': 2, 'role': 1, 'altered': 1, 'signaling': 1, '11': 1, 'sciencedaily': 1, 'assessing': 1}
# num_links (not printed): 13
# 'bing_wiki': ['Sympathetic nervous system - Wikipedia']
# 'stages': None
# 'adj_and_verbs': (['sympathetic'], [])
#
#  ###### STUDY 6 ######
# 'condition': endovascular treatment
# 'nouns': treatment
# 'bing_tokens': {'endovascular': 11, 'treatment': 7, 'stroke': 4, 'brain': 2, 'aneurysm': 1}
# num_links (not printed): 11
# 'bing_wiki': ['Endovascular coiling - Wikipedia']
# 'stages': None
# 'adj_and_verbs': (['endovascular'], [])
#
#  ###### STUDY 7 ######
# 'condition': latent tuberculosis
# 'nouns': tuberculosis
# 'bing_tokens': {'tb': 16, 'latent': 9}
# num_links (not printed): 13
# 'bing_wiki': ['Latent tuberculosis - Wikipedia']
# 'stages': None
# 'adj_and_verbs': (['latent'], [])
#
#  ###### STUDY 8 ######
# 'condition': adult erythroleukemia
# 'nouns': adult erythroleukemia
# 'bing_tokens': {'acute': 9, 'leukemia': 5, 'adult': 4, 'erythroleukemia': 4, 'erythroid': 3}
# num_links (not printed): 13
# 'bing_wiki': ['Acute erythroid leukemia - Wikipedia']
# 'stages': None
# 'adj_and_verbs': ([], [])
#
#  ###### STUDY 9 ######
# 'condition': type-2 diabetes mellitus
# 'nouns': diabetes
# 'bing_tokens': {'diabetes': 15, 'type': 10}
# num_links (not printed): 14
# 'bing_wiki': ['Type 2 diabetes - Wikipedia']
# 'stages': {'type': ['2'], 'genotyp_': [], 'grade': [], 'stage': [], 'ajcc': [], 'hepatitis': []}
# 'adj_and_verbs': (['type-2'], ['mellitus'])

# %% [markdown]
# # Example distances of random features

# %%
used_conds = rand_conds
for i in range(0, len(used_conds)):
    for j in range(i, len(used_conds)):
        f1 = cur_featurized[used_conds[i]]
        f2 = cur_featurized[used_conds[j]]
        cur_fdist = ssim.featurize_conditions(f1, f2)
        print("\n ###### PAIR %s, %s ###### " % (i, j))
        print("c1 =", used_conds[i])
        print("c2 =", used_conds[j])
        print("Distances:")
        for k, v in cur_fdist.items():
            print('-', k, v)
# Out:
#  ###### PAIR 0, 0 ######
# c1 = Brachiobasilic Arteriovenous Fistula
# c2 = Brachiobasilic Arteriovenous Fistula
# Distances:
# - full_fuzzy_ratio 100
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 0
# - bing_link_sim 1.0
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
#
#  ###### PAIR 0, 1 ######
# c1 = Brachiobasilic Arteriovenous Fistula
# c2 = Catheter-related Bloodstream Infection (CRBSI) Nos
# Distances:
# - full_fuzzy_ratio 30
# - noun_fuzzy_ratio 16
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 0, 2 ######
# c1 = Brachiobasilic Arteriovenous Fistula
# c2 = Lyme Disease
# Distances:
# - full_fuzzy_ratio 25
# - noun_fuzzy_ratio 32
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 0, 3 ######
# c1 = Brachiobasilic Arteriovenous Fistula
# c2 = Intraoperative Neurophysiological Monitoring
# Distances:
# - full_fuzzy_ratio 35
# - noun_fuzzy_ratio 24
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 0, 4 ######
# c1 = Brachiobasilic Arteriovenous Fistula
# c2 = Laparoscopic Gynecological Surgery
# Distances:
# - full_fuzzy_ratio 34
# - noun_fuzzy_ratio 29
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 0, 5 ######
# c1 = Brachiobasilic Arteriovenous Fistula
# c2 = Sympathetic Integrity
# Distances:
# - full_fuzzy_ratio 35
# - noun_fuzzy_ratio 25
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 0, 6 ######
# c1 = Brachiobasilic Arteriovenous Fistula
# c2 = Endovascular Treatment
# Distances:
# - full_fuzzy_ratio 38
# - noun_fuzzy_ratio 25
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 0, 7 ######
# c1 = Brachiobasilic Arteriovenous Fistula
# c2 = Latent Tuberculosis
# Distances:
# - full_fuzzy_ratio 33
# - noun_fuzzy_ratio 32
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 0, 8 ######
# c1 = Brachiobasilic Arteriovenous Fistula
# c2 = Adult Erythroleukemia
# Distances:
# - full_fuzzy_ratio 39
# - noun_fuzzy_ratio 21
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 0, 9 ######
# c1 = Brachiobasilic Arteriovenous Fistula
# c2 = Type-2 Diabetes Mellitus
# Distances:
# - full_fuzzy_ratio 30
# - noun_fuzzy_ratio 27
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 10.0
# - adj_dist 1.0
# - vb_dist 1.0
#
#  ###### PAIR 1, 1 ######
# c1 = Catheter-related Bloodstream Infection (CRBSI) Nos
# c2 = Catheter-related Bloodstream Infection (CRBSI) Nos
# Distances:
# - full_fuzzy_ratio 100
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 0
# - bing_link_sim 1.0
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
#
#  ###### PAIR 1, 2 ######
# c1 = Catheter-related Bloodstream Infection (CRBSI) Nos
# c2 = Lyme Disease
# Distances:
# - full_fuzzy_ratio 26
# - noun_fuzzy_ratio 28
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 1, 3 ######
# c1 = Catheter-related Bloodstream Infection (CRBSI) Nos
# c2 = Intraoperative Neurophysiological Monitoring
# Distances:
# - full_fuzzy_ratio 36
# - noun_fuzzy_ratio 34
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 1, 4 ######
# c1 = Catheter-related Bloodstream Infection (CRBSI) Nos
# c2 = Laparoscopic Gynecological Surgery
# Distances:
# - full_fuzzy_ratio 29
# - noun_fuzzy_ratio 21
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 1, 5 ######
# c1 = Catheter-related Bloodstream Infection (CRBSI) Nos
# c2 = Sympathetic Integrity
# Distances:
# - full_fuzzy_ratio 31
# - noun_fuzzy_ratio 25
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 1, 6 ######
# c1 = Catheter-related Bloodstream Infection (CRBSI) Nos
# c2 = Endovascular Treatment
# Distances:
# - full_fuzzy_ratio 31
# - noun_fuzzy_ratio 35
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 1, 7 ######
# c1 = Catheter-related Bloodstream Infection (CRBSI) Nos
# c2 = Latent Tuberculosis
# Distances:
# - full_fuzzy_ratio 35
# - noun_fuzzy_ratio 33
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 1, 8 ######
# c1 = Catheter-related Bloodstream Infection (CRBSI) Nos
# c2 = Adult Erythroleukemia
# Distances:
# - full_fuzzy_ratio 28
# - noun_fuzzy_ratio 27
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 1, 9 ######
# c1 = Catheter-related Bloodstream Infection (CRBSI) Nos
# c2 = Type-2 Diabetes Mellitus
# Distances:
# - full_fuzzy_ratio 30
# - noun_fuzzy_ratio 26
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 10.0
# - adj_dist 1.0
# - vb_dist 1.0
#
#  ###### PAIR 2, 2 ######
# c1 = Lyme Disease
# c2 = Lyme Disease
# Distances:
# - full_fuzzy_ratio 100
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 0
# - bing_link_sim 1.0
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
#
#  ###### PAIR 2, 3 ######
# c1 = Lyme Disease
# c2 = Intraoperative Neurophysiological Monitoring
# Distances:
# - full_fuzzy_ratio 14
# - noun_fuzzy_ratio 18
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 2, 4 ######
# c1 = Lyme Disease
# c2 = Laparoscopic Gynecological Surgery
# Distances:
# - full_fuzzy_ratio 30
# - noun_fuzzy_ratio 21
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 2, 5 ######
# c1 = Lyme Disease
# c2 = Sympathetic Integrity
# Distances:
# - full_fuzzy_ratio 36
# - noun_fuzzy_ratio 19
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 2, 6 ######
# c1 = Lyme Disease
# c2 = Endovascular Treatment
# Distances:
# - full_fuzzy_ratio 35
# - noun_fuzzy_ratio 29
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 2, 7 ######
# c1 = Lyme Disease
# c2 = Latent Tuberculosis
# Distances:
# - full_fuzzy_ratio 32
# - noun_fuzzy_ratio 25
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 2, 8 ######
# c1 = Lyme Disease
# c2 = Adult Erythroleukemia
# Distances:
# - full_fuzzy_ratio 30
# - noun_fuzzy_ratio 30
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
#
#  ###### PAIR 2, 9 ######
# c1 = Lyme Disease
# c2 = Type-2 Diabetes Mellitus
# Distances:
# - full_fuzzy_ratio 44
# - noun_fuzzy_ratio 40
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 10.0
# - adj_dist 1.0
# - vb_dist 1.0
#
#  ###### PAIR 3, 3 ######
# c1 = Intraoperative Neurophysiological Monitoring
# c2 = Intraoperative Neurophysiological Monitoring
# Distances:
# - full_fuzzy_ratio 100
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 0
# - bing_link_sim 1.0
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
#
#  ###### PAIR 3, 4 ######
# c1 = Intraoperative Neurophysiological Monitoring
# c2 = Laparoscopic Gynecological Surgery
# Distances:
# - full_fuzzy_ratio 46
# - noun_fuzzy_ratio 24
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 3, 5 ######
# c1 = Intraoperative Neurophysiological Monitoring
# c2 = Sympathetic Integrity
# Distances:
# - full_fuzzy_ratio 34
# - noun_fuzzy_ratio 42
# - bing_bagoword_dist 46
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 3, 6 ######
# c1 = Intraoperative Neurophysiological Monitoring
# c2 = Endovascular Treatment
# Distances:
# - full_fuzzy_ratio 30
# - noun_fuzzy_ratio 32
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 3, 7 ######
# c1 = Intraoperative Neurophysiological Monitoring
# c2 = Latent Tuberculosis
# Distances:
# - full_fuzzy_ratio 32
# - noun_fuzzy_ratio 27
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 3, 8 ######
# c1 = Intraoperative Neurophysiological Monitoring
# c2 = Adult Erythroleukemia
# Distances:
# - full_fuzzy_ratio 31
# - noun_fuzzy_ratio 19
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 3, 9 ######
# c1 = Intraoperative Neurophysiological Monitoring
# c2 = Type-2 Diabetes Mellitus
# Distances:
# - full_fuzzy_ratio 35
# - noun_fuzzy_ratio 22
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 10.0
# - adj_dist 1.0
# - vb_dist 1.0
#
#  ###### PAIR 4, 4 ######
# c1 = Laparoscopic Gynecological Surgery
# c2 = Laparoscopic Gynecological Surgery
# Distances:
# - full_fuzzy_ratio 100
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 0
# - bing_link_sim 1.0
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
#
#  ###### PAIR 4, 5 ######
# c1 = Laparoscopic Gynecological Surgery
# c2 = Sympathetic Integrity
# Distances:
# - full_fuzzy_ratio 36
# - noun_fuzzy_ratio 38
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 4, 6 ######
# c1 = Laparoscopic Gynecological Surgery
# c2 = Endovascular Treatment
# Distances:
# - full_fuzzy_ratio 29
# - noun_fuzzy_ratio 25
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 4, 7 ######
# c1 = Laparoscopic Gynecological Surgery
# c2 = Latent Tuberculosis
# Distances:
# - full_fuzzy_ratio 34
# - noun_fuzzy_ratio 32
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 4, 8 ######
# c1 = Laparoscopic Gynecological Surgery
# c2 = Adult Erythroleukemia
# Distances:
# - full_fuzzy_ratio 25
# - noun_fuzzy_ratio 29
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 4, 9 ######
# c1 = Laparoscopic Gynecological Surgery
# c2 = Type-2 Diabetes Mellitus
# Distances:
# - full_fuzzy_ratio 28
# - noun_fuzzy_ratio 13
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 10.0
# - adj_dist 1.0
# - vb_dist 1.0
#
#  ###### PAIR 5, 5 ######
# c1 = Sympathetic Integrity
# c2 = Sympathetic Integrity
# Distances:
# - full_fuzzy_ratio 100
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 0
# - bing_link_sim 1.0
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
#
#  ###### PAIR 5, 6 ######
# c1 = Sympathetic Integrity
# c2 = Endovascular Treatment
# Distances:
# - full_fuzzy_ratio 33
# - noun_fuzzy_ratio 33
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 5, 7 ######
# c1 = Sympathetic Integrity
# c2 = Latent Tuberculosis
# Distances:
# - full_fuzzy_ratio 45
# - noun_fuzzy_ratio 38
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 5, 8 ######
# c1 = Sympathetic Integrity
# c2 = Adult Erythroleukemia
# Distances:
# - full_fuzzy_ratio 29
# - noun_fuzzy_ratio 27
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 5, 9 ######
# c1 = Sympathetic Integrity
# c2 = Type-2 Diabetes Mellitus
# Distances:
# - full_fuzzy_ratio 40
# - noun_fuzzy_ratio 35
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 10.0
# - adj_dist 1.0
# - vb_dist 1.0
#
#  ###### PAIR 6, 6 ######
# c1 = Endovascular Treatment
# c2 = Endovascular Treatment
# Distances:
# - full_fuzzy_ratio 100
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 0
# - bing_link_sim 1.0
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
#
#  ###### PAIR 6, 7 ######
# c1 = Endovascular Treatment
# c2 = Latent Tuberculosis
# Distances:
# - full_fuzzy_ratio 29
# - noun_fuzzy_ratio 19
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 6, 8 ######
# c1 = Endovascular Treatment
# c2 = Adult Erythroleukemia
# Distances:
# - full_fuzzy_ratio 37
# - noun_fuzzy_ratio 27
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 6, 9 ######
# c1 = Endovascular Treatment
# c2 = Type-2 Diabetes Mellitus
# Distances:
# - full_fuzzy_ratio 35
# - noun_fuzzy_ratio 35
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 10.0
# - adj_dist 1.0
# - vb_dist 1.0
#
#  ###### PAIR 7, 7 ######
# c1 = Latent Tuberculosis
# c2 = Latent Tuberculosis
# Distances:
# - full_fuzzy_ratio 100
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 0
# - bing_link_sim 1.0
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
#
#  ###### PAIR 7, 8 ######
# c1 = Latent Tuberculosis
# c2 = Adult Erythroleukemia
# Distances:
# - full_fuzzy_ratio 35
# - noun_fuzzy_ratio 30
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 7, 9 ######
# c1 = Latent Tuberculosis
# c2 = Type-2 Diabetes Mellitus
# Distances:
# - full_fuzzy_ratio 37
# - noun_fuzzy_ratio 30
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 10.0
# - adj_dist 1.0
# - vb_dist 1.0
#
#  ###### PAIR 8, 8 ######
# c1 = Adult Erythroleukemia
# c2 = Adult Erythroleukemia
# Distances:
# - full_fuzzy_ratio 100
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 0
# - bing_link_sim 1.0
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
#
#  ###### PAIR 8, 9 ######
# c1 = Adult Erythroleukemia
# c2 = Type-2 Diabetes Mellitus
# Distances:
# - full_fuzzy_ratio 31
# - noun_fuzzy_ratio 28
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 10.0
# - adj_dist 1.0
# - vb_dist 1.0
#
#  ###### PAIR 9, 9 ######
# c1 = Type-2 Diabetes Mellitus
# c2 = Type-2 Diabetes Mellitus
# Distances:
# - full_fuzzy_ratio 100
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 0
# - bing_link_sim 1.0
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0

# %% [markdown]
# # Examples of "stage", "type", "grade" conditions

# %%
typed_conds = [x for x in all_conds if 'stage' in x.lower() \
                                      or 'type' in x.lower() \
                                      or 'grade' in x.lower() \
                                      or 'genotype' in x.lower() \
                                      or 'ajcc' in x.lower() \
                                      or 'hepatitis' in x.lower()]

# %%
rand_typed_conds = np.random.choice(typed_conds, 6)
rand_typed_conds
# Out:
# array(['Stage II Small Lymphocytic Lymphoma',
#        'Hyperlipoproteinemia Type II',
#        'Stage 0a Bladder Urothelial Carcinoma AJCC v6 and v7',
#        'Stage III Skin Melanoma', 'Stage IV Grade 1 Follicular Lymphoma',
#        'Stage IV Esophageal Cancer'], dtype='<U118')

# %%
cur_featurized = {}
for i, cond in enumerate(rand_typed_conds):
    cur_f = ssim.featurize_one_cond(cond, bd)
    cur_featurized[cond] = cur_f
    print("\n ###### STUDY %s ###### " % i)
    for k, v in cur_f.items():
        if k != 'bing_links':
            print("'%s': %s" % (k, v))
        else:
            print("num_links (not printed): %s" % len(v))
# Out:
#  ###### STUDY 0 ######
# 'condition': stage ii small lymphocytic lymphoma
# 'nouns': stage lymphoma
# 'bing_tokens': {'lymphoma': 10, 'lymphocytic': 8, 'small': 6, 'nonhodgkin': 1}
# num_links (not printed): 10
# 'bing_wiki': ['Chronic lymphocytic leukemia - Wikipedia']
# 'stages': {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['2'], 'ajcc': [], 'hepatitis': []}
# 'adj_and_verbs': (['small', 'lymphocytic'], ['ii'])
#
#  ###### STUDY 1 ######
# 'condition': hyperlipoproteinemia type ii
# 'nouns': hyperlipoproteinemia type ii
# 'bing_tokens': {'hyperlipoproteinemia': 8, 'type': 6, 'ii': 4, 'hyperlipidemia': 2, 'symptoms': 2, 'overview': 1, 'sciencedirect': 1, 'topics': 1}
# num_links (not printed): 10
# 'bing_wiki': ['Hyperlipidemia - Wikipedia']
# 'stages': {'type': ['2'], 'genotyp_': [], 'grade': [], 'stage': [], 'ajcc': [], 'hepatitis': []}
# 'adj_and_verbs': ([], [])
#
#  ###### STUDY 2 ######
# 'condition': stage 0a bladder urothelial carcinoma ajcc v6 and v7
# 'nouns': stage bladder carcinoma ajcc v6 v7
# 'bing_tokens': {'bladder': 10, 'cancer': 7, 'atezolizumab': 5, 'stages': 2, 'stage': 1}
# num_links (not printed): 16
# 'bing_wiki': ['AJCC staging system - Wikipedia']
# 'stages': {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['0a'], 'ajcc': ['v6', 'v7'], 'hepatitis': []}
# 'adj_and_verbs': (['urothelial'], [])
#
#  ###### STUDY 3 ######
# 'condition': stage iii skin melanoma
# 'nouns': stage skin melanoma
# 'bing_tokens': {'melanoma': 17, 'stage': 8}
# num_links (not printed): 15
# 'bing_wiki': ['Melanoma - Wikipedia']
# 'stages': {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['3'], 'ajcc': [], 'hepatitis': []}
# 'adj_and_verbs': (['iii'], [])
#
#  ###### STUDY 4 ######
# 'condition': stage iv grade 1 follicular lymphoma
# 'nouns': stage iv lymphoma
# 'bing_tokens': {'lymphoma': 10, 'follicular': 4, 'symptoms': 3, 'treatment': 3, 'stage': 2, '4': 2, 'uptodate': 1}
# num_links (not printed): 10
# 'bing_wiki': ['Follicular lymphoma - Wikipedia']
# 'stages': {'type': [], 'genotyp_': [], 'grade': ['1'], 'stage': ['4'], 'ajcc': [], 'hepatitis': []}
# 'adj_and_verbs': (['follicular'], ['grade'])
#
#  ###### STUDY 5 ######
# 'condition': stage iv esophageal cancer
# 'nouns': stage esophageal cancer
# 'bing_tokens': {'cancer': 19, 'stage': 6}
# num_links (not printed): 13
# 'bing_wiki': ['Esophageal cancer - Wikipedia']
# 'stages': {'type': [], 'genotyp_': [], 'grade': [], 'stage': ['4'], 'ajcc': [], 'hepatitis': []}
# 'adj_and_verbs': (['iv'], [])

# %%
used_conds = rand_typed_conds
for i in range(0, len(used_conds)):
    for j in range(i, len(used_conds)):
        f1 = cur_featurized[used_conds[i]]
        f2 = cur_featurized[used_conds[j]]
        cur_fdist = ssim.featurize_conditions(f1, f2)
        print("\n ###### PAIR %s, %s ###### " % (i, j))
        print("c1 =", used_conds[i])
        print("c2 =", used_conds[j])
        print("Distances:")
        for k, v in cur_fdist.items():
            print('-', k, v)
# Out:
#  ###### PAIR 0, 0 ######
# c1 = Stage II Small Lymphocytic Lymphoma
# c2 = Stage II Small Lymphocytic Lymphoma
# Distances:
# - full_fuzzy_ratio 100
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 0
# - bing_link_sim 1.0
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
#
#  ###### PAIR 0, 1 ######
# c1 = Stage II Small Lymphocytic Lymphoma
# c2 = Hyperlipoproteinemia Type II
# Distances:
# - full_fuzzy_ratio 29
# - noun_fuzzy_ratio 29
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 1.0
#
#  ###### PAIR 0, 2 ######
# c1 = Stage II Small Lymphocytic Lymphoma
# c2 = Stage 0a Bladder Urothelial Carcinoma AJCC v6 and v7
# Distances:
# - full_fuzzy_ratio 37
# - noun_fuzzy_ratio 42
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 10.0
# - adj_dist 1.0
# - vb_dist 1.0
#
#  ###### PAIR 0, 3 ######
# c1 = Stage II Small Lymphocytic Lymphoma
# c2 = Stage III Skin Melanoma
# Distances:
# - full_fuzzy_ratio 55
# - noun_fuzzy_ratio 61
# - bing_bagoword_dist 50
# - bing_link_sim 0.041666666666666664
# - same_wiki 0.0
# - stage_dist 1.0
# - adj_dist 1.0
# - vb_dist 1.0
#
#  ###### PAIR 0, 4 ######
# c1 = Stage II Small Lymphocytic Lymphoma
# c2 = Stage IV Grade 1 Follicular Lymphoma
# Distances:
# - full_fuzzy_ratio 62
# - noun_fuzzy_ratio 90
# - bing_bagoword_dist 30
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 5.5
# - adj_dist 1.0
# - vb_dist 1.0
#
#  ###### PAIR 0, 5 ######
# c1 = Stage II Small Lymphocytic Lymphoma
# c2 = Stage IV Esophageal Cancer
# Distances:
# - full_fuzzy_ratio 46
# - noun_fuzzy_ratio 49
# - bing_bagoword_dist 50
# - bing_link_sim 0.045454545454545456
# - same_wiki 0.0
# - stage_dist 2.0
# - adj_dist 1.0
# - vb_dist 1.0
#
#  ###### PAIR 1, 1 ######
# c1 = Hyperlipoproteinemia Type II
# c2 = Hyperlipoproteinemia Type II
# Distances:
# - full_fuzzy_ratio 100
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 0
# - bing_link_sim 1.0
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
#
#  ###### PAIR 1, 2 ######
# c1 = Hyperlipoproteinemia Type II
# c2 = Stage 0a Bladder Urothelial Carcinoma AJCC v6 and v7
# Distances:
# - full_fuzzy_ratio 30
# - noun_fuzzy_ratio 29
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 10.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 1, 3 ######
# c1 = Hyperlipoproteinemia Type II
# c2 = Stage III Skin Melanoma
# Distances:
# - full_fuzzy_ratio 27
# - noun_fuzzy_ratio 30
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 1.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 1, 4 ######
# c1 = Hyperlipoproteinemia Type II
# c2 = Stage IV Grade 1 Follicular Lymphoma
# Distances:
# - full_fuzzy_ratio 28
# - noun_fuzzy_ratio 27
# - bing_bagoword_dist 46
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 5.5
# - adj_dist 1.0
# - vb_dist 1.0
#
#  ###### PAIR 1, 5 ######
# c1 = Hyperlipoproteinemia Type II
# c2 = Stage IV Esophageal Cancer
# Distances:
# - full_fuzzy_ratio 30
# - noun_fuzzy_ratio 27
# - bing_bagoword_dist 50
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 2.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 2, 2 ######
# c1 = Stage 0a Bladder Urothelial Carcinoma AJCC v6 and v7
# c2 = Stage 0a Bladder Urothelial Carcinoma AJCC v6 and v7
# Distances:
# - full_fuzzy_ratio 100
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 0
# - bing_link_sim 1.0
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
#
#  ###### PAIR 2, 3 ######
# c1 = Stage 0a Bladder Urothelial Carcinoma AJCC v6 and v7
# c2 = Stage III Skin Melanoma
# Distances:
# - full_fuzzy_ratio 40
# - noun_fuzzy_ratio 45
# - bing_bagoword_dist 48
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 10.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 2, 4 ######
# c1 = Stage 0a Bladder Urothelial Carcinoma AJCC v6 and v7
# c2 = Stage IV Grade 1 Follicular Lymphoma
# Distances:
# - full_fuzzy_ratio 45
# - noun_fuzzy_ratio 39
# - bing_bagoword_dist 48
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 10.0
# - adj_dist 1.0
# - vb_dist 1.0
#
#  ###### PAIR 2, 5 ######
# c1 = Stage 0a Bladder Urothelial Carcinoma AJCC v6 and v7
# c2 = Stage IV Esophageal Cancer
# Distances:
# - full_fuzzy_ratio 46
# - noun_fuzzy_ratio 46
# - bing_bagoword_dist 34
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 10.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 3, 3 ######
# c1 = Stage III Skin Melanoma
# c2 = Stage III Skin Melanoma
# Distances:
# - full_fuzzy_ratio 100
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 0
# - bing_link_sim 1.0
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
#
#  ###### PAIR 3, 4 ######
# c1 = Stage III Skin Melanoma
# c2 = Stage IV Grade 1 Follicular Lymphoma
# Distances:
# - full_fuzzy_ratio 47
# - noun_fuzzy_ratio 67
# - bing_bagoword_dist 46
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 5.5
# - adj_dist 1.0
# - vb_dist 1.0
#
#  ###### PAIR 3, 5 ######
# c1 = Stage III Skin Melanoma
# c2 = Stage IV Esophageal Cancer
# Distances:
# - full_fuzzy_ratio 53
# - noun_fuzzy_ratio 52
# - bing_bagoword_dist 38
# - bing_link_sim 0.037037037037037035
# - same_wiki 0.0
# - stage_dist 1.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 4, 4 ######
# c1 = Stage IV Grade 1 Follicular Lymphoma
# c2 = Stage IV Grade 1 Follicular Lymphoma
# Distances:
# - full_fuzzy_ratio 100
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 0
# - bing_link_sim 1.0
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
#
#  ###### PAIR 4, 5 ######
# c1 = Stage IV Grade 1 Follicular Lymphoma
# c2 = Stage IV Esophageal Cancer
# Distances:
# - full_fuzzy_ratio 48
# - noun_fuzzy_ratio 45
# - bing_bagoword_dist 46
# - bing_link_sim 0.0
# - same_wiki 0.0
# - stage_dist 5.0
# - adj_dist 1.0
# - vb_dist 1.0
#
#  ###### PAIR 5, 5 ######
# c1 = Stage IV Esophageal Cancer
# c2 = Stage IV Esophageal Cancer
# Distances:
# - full_fuzzy_ratio 100
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 0
# - bing_link_sim 1.0
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0

# %% [markdown]
# # Examples of very similar conditions

# %%
park_conds = [x for x in all_conds if 'parkin' in x.lower()][:6]
park_conds
# Out:
# ["Parkinson's Disease",
#  'Parkinson Disease',
#  "Idiopathic Parkinson's Disease",
#  "Parkinson's Disease (PD)",
#  'Parkinson',
#  'Idiopathic Parkinson Disease']

# %%
cur_featurized = {}
for i, cond in enumerate(park_conds):
    cur_f = ssim.featurize_one_cond(cond, bd)
    cur_featurized[cond] = cur_f
    print("\n ###### STUDY %s ###### " % i)
    for k, v in cur_f.items():
        if k != 'bing_links':
            print("'%s': %s" % (k, v))
        else:
            print("num_links (not printed): %s" % len(v))
# Out:
#  ###### STUDY 0 ######
# 'condition': parkinson's disease
# 'nouns': parkinson disease
# 'bing_tokens': {'parkinson': 17, 'disease': 8}
# num_links (not printed): 14
# 'bing_wiki': ["Parkinson's disease - Wikipedia"]
# 'stages': None
# 'adj_and_verbs': ([], [])
#
#  ###### STUDY 1 ######
# 'condition': parkinson disease
# 'nouns': parkinson disease
# 'bing_tokens': {'parkinson': 10, 'disease': 8, '’': 4, 'symptoms': 3}
# num_links (not printed): 11
# 'bing_wiki': ["Parkinson's disease - Wikipedia"]
# 'stages': None
# 'adj_and_verbs': ([], [])
#
#  ###### STUDY 2 ######
# 'condition': idiopathic parkinson's disease
# 'nouns': parkinson disease
# 'bing_tokens': {'parkinson': 11, 'disease': 8, 'idiopathic': 6}
# num_links (not printed): 13
# 'bing_wiki': ["Parkinson's disease - Wikipedia"]
# 'stages': None
# 'adj_and_verbs': (['idiopathic'], [])
#
#  ###### STUDY 3 ######
# 'condition': parkinson's disease (pd)
# 'nouns': parkinson disease pd
# 'bing_tokens': {'parkinson': 12, 'disease': 9, 'symptoms': 4}
# num_links (not printed): 15
# 'bing_wiki': ["Parkinson's disease - Wikipedia"]
# 'stages': None
# 'adj_and_verbs': ([], [])
#
#  ###### STUDY 4 ######
# 'condition': parkinson
# 'nouns': parkinson
# 'bing_tokens': {'parkinson': 18, 'disease': 7}
# num_links (not printed): 18
# 'bing_wiki': ["Parkinson's disease - Wikipedia"]
# 'stages': None
# 'adj_and_verbs': ([], [])
#
#  ###### STUDY 5 ######
# 'condition': idiopathic parkinson disease
# 'nouns': parkinson disease
# 'bing_tokens': {'parkinson': 9, 'disease': 7, 'idiopathic': 6, 'symptoms': 3}
# num_links (not printed): 13
# 'bing_wiki': ["Parkinson's disease - Wikipedia"]
# 'stages': None
# 'adj_and_verbs': (['idiopathic'], [])

# %%
used_conds = park_conds
for i in range(0, len(used_conds)):
    for j in range(i, len(used_conds)):
        f1 = cur_featurized[used_conds[i]]
        f2 = cur_featurized[used_conds[j]]
        cur_fdist = ssim.featurize_conditions(f1, f2)
        print("\n ###### PAIR %s, %s ###### " % (i, j))
        print("c1 =", used_conds[i])
        print("c2 =", used_conds[j])
        print("Distances:")
        for k, v in cur_fdist.items():
            print('-', k, v)
# Out:
#  ###### PAIR 0, 0 ######
# c1 = Parkinson's Disease
# c2 = Parkinson's Disease
# Distances:
# - full_fuzzy_ratio 100
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 0
# - bing_link_sim 1.0
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
#
#  ###### PAIR 0, 1 ######
# c1 = Parkinson's Disease
# c2 = Parkinson Disease
# Distances:
# - full_fuzzy_ratio 94
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 14
# - bing_link_sim 0.25
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
#
#  ###### PAIR 0, 2 ######
# c1 = Parkinson's Disease
# c2 = Idiopathic Parkinson's Disease
# Distances:
# - full_fuzzy_ratio 78
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 12
# - bing_link_sim 0.08
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 0, 3 ######
# c1 = Parkinson's Disease
# c2 = Parkinson's Disease (PD)
# Distances:
# - full_fuzzy_ratio 88
# - noun_fuzzy_ratio 92
# - bing_bagoword_dist 10
# - bing_link_sim 0.38095238095238093
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
#
#  ###### PAIR 0, 4 ######
# c1 = Parkinson's Disease
# c2 = Parkinson
# Distances:
# - full_fuzzy_ratio 64
# - noun_fuzzy_ratio 69
# - bing_bagoword_dist 2
# - bing_link_sim 0.14285714285714285
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
#
#  ###### PAIR 0, 5 ######
# c1 = Parkinson's Disease
# c2 = Idiopathic Parkinson Disease
# Distances:
# - full_fuzzy_ratio 72
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 18
# - bing_link_sim 0.08
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 1, 1 ######
# c1 = Parkinson Disease
# c2 = Parkinson Disease
# Distances:
# - full_fuzzy_ratio 100
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 0
# - bing_link_sim 1.0
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
#
#  ###### PAIR 1, 2 ######
# c1 = Parkinson Disease
# c2 = Idiopathic Parkinson's Disease
# Distances:
# - full_fuzzy_ratio 72
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 14
# - bing_link_sim 0.09090909090909091
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 1, 3 ######
# c1 = Parkinson Disease
# c2 = Parkinson's Disease (PD)
# Distances:
# - full_fuzzy_ratio 83
# - noun_fuzzy_ratio 92
# - bing_bagoword_dist 8
# - bing_link_sim 0.4444444444444444
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
#
#  ###### PAIR 1, 4 ######
# c1 = Parkinson Disease
# c2 = Parkinson
# Distances:
# - full_fuzzy_ratio 69
# - noun_fuzzy_ratio 69
# - bing_bagoword_dist 16
# - bing_link_sim 0.2608695652173913
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
#
#  ###### PAIR 1, 5 ######
# c1 = Parkinson Disease
# c2 = Idiopathic Parkinson Disease
# Distances:
# - full_fuzzy_ratio 76
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 12
# - bing_link_sim 0.09090909090909091
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 2, 2 ######
# c1 = Idiopathic Parkinson's Disease
# c2 = Idiopathic Parkinson's Disease
# Distances:
# - full_fuzzy_ratio 100
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 0
# - bing_link_sim 1.0
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
#
#  ###### PAIR 2, 3 ######
# c1 = Idiopathic Parkinson's Disease
# c2 = Parkinson's Disease (PD)
# Distances:
# - full_fuzzy_ratio 70
# - noun_fuzzy_ratio 92
# - bing_bagoword_dist 12
# - bing_link_sim 0.07692307692307693
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 2, 4 ######
# c1 = Idiopathic Parkinson's Disease
# c2 = Parkinson
# Distances:
# - full_fuzzy_ratio 46
# - noun_fuzzy_ratio 69
# - bing_bagoword_dist 14
# - bing_link_sim 0.10714285714285714
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 2, 5 ######
# c1 = Idiopathic Parkinson's Disease
# c2 = Idiopathic Parkinson Disease
# Distances:
# - full_fuzzy_ratio 97
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 6
# - bing_link_sim 0.625
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
#
#  ###### PAIR 3, 3 ######
# c1 = Parkinson's Disease (PD)
# c2 = Parkinson's Disease (PD)
# Distances:
# - full_fuzzy_ratio 100
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 0
# - bing_link_sim 1.0
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
#
#  ###### PAIR 3, 4 ######
# c1 = Parkinson's Disease (PD)
# c2 = Parkinson
# Distances:
# - full_fuzzy_ratio 55
# - noun_fuzzy_ratio 62
# - bing_bagoword_dist 12
# - bing_link_sim 0.2222222222222222
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
#
#  ###### PAIR 3, 5 ######
# c1 = Parkinson's Disease (PD)
# c2 = Idiopathic Parkinson Disease
# Distances:
# - full_fuzzy_ratio 65
# - noun_fuzzy_ratio 92
# - bing_bagoword_dist 12
# - bing_link_sim 0.07692307692307693
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 4, 4 ######
# c1 = Parkinson
# c2 = Parkinson
# Distances:
# - full_fuzzy_ratio 100
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 0
# - bing_link_sim 1.0
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
#
#  ###### PAIR 4, 5 ######
# c1 = Parkinson
# c2 = Idiopathic Parkinson Disease
# Distances:
# - full_fuzzy_ratio 49
# - noun_fuzzy_ratio 69
# - bing_bagoword_dist 18
# - bing_link_sim 0.10714285714285714
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 1.0
# - vb_dist 0.0
#
#  ###### PAIR 5, 5 ######
# c1 = Idiopathic Parkinson Disease
# c2 = Idiopathic Parkinson Disease
# Distances:
# - full_fuzzy_ratio 100
# - noun_fuzzy_ratio 100
# - bing_bagoword_dist 0
# - bing_link_sim 1.0
# - same_wiki 1.0
# - stage_dist 0.0
# - adj_dist 0.0
# - vb_dist 0.0
