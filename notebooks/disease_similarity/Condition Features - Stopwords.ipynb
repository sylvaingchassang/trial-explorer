# %%
import pandas as pd
import numpy as np

from tqdm import tqdm_notebook
from tqdm import tqdm
import datetime as dt
import pickle

import pdaactconn as pc
from trialexplorer.mesh_terms import MeSHCatalog
from trialexplorer import AACTStudySet
from trialexplorer import studysimilarity as ssim

import nltk
from nltk.corpus import stopwords
from nltk.probability import FreqDist
import string

import matplotlib.pyplot as plt
# %matplotlib inline

tqdm.pandas()

# %%
stop_words = set(stopwords.words('english'))

# %%
# selecting all interventional studies
conn = pc.AACTConnection(source=pc.AACTConnection.LOCAL)
ss = AACTStudySet.AACTStudySet(conn= conn, tqdm_handler=tqdm_notebook)
ss.add_constraint("study_type = 'Interventional'")
ss.load_studies()
# Out:
# 250890 studies loaded!

# %%
# loading all dimensional data
ss.add_dimensions('conditions')
ss.add_dimensions('browse_conditions')
ss.refresh_dim_data()
# Out:
# Successfuly added these 1 dimensions: ['conditions']
# Failed to add these 0 dimensions: []
# Successfuly added these 1 dimensions: ['browse_conditions']
# Failed to add these 0 dimensions: []
# HBox(children=(IntProgress(value=0, max=502), HTML(value='')))
# Syncing the temp table temp_cur_studies in 502 chunks x 500 records each
#
# Creating index on the temp table
#  - Loading dimension conditions
#  -- Loading raw data
#  -- Sorting index
#  - Loading dimension browse_conditions
#  -- Loading raw data
#  -- Sorting index

# %%
c = ss.dimensions['conditions']
bc = ss.dimensions['browse_conditions']
c.data.head()
# Out:
#                   id                            name  \
# nct_id
# NCT00000102  8627542  Congenital Adrenal Hyperplasia
# NCT00000106  8626467              Rheumatic Diseases
# NCT00000108  8626464         Cardiovascular Diseases
# NCT00000108  8626465                Coronary Disease
# NCT00000110  8626463                         Obesity
#
#                               downcase_name
# nct_id
# NCT00000102  congenital adrenal hyperplasia
# NCT00000106              rheumatic diseases
# NCT00000108         cardiovascular diseases
# NCT00000108                coronary disease
# NCT00000110                         obesity

# %%
bc.data.head()
# Out:
#                   id                        mesh_term  \
# nct_id
# NCT00000102  9144384  Adrenal Hyperplasia, Congenital
# NCT00000102  9144385           Adrenogenital Syndrome
# NCT00000102  9144386     Adrenocortical Hyperfunction
# NCT00000102  9144387                      Hyperplasia
# NCT00000106  9143121               Rheumatic Diseases
#
#                           downcase_mesh_term
# nct_id
# NCT00000102  adrenal hyperplasia, congenital
# NCT00000102           adrenogenital syndrome
# NCT00000102     adrenocortical hyperfunction
# NCT00000102                      hyperplasia
# NCT00000106               rheumatic diseases

# %% [markdown]
# # Finding extra stop words in conditions

# %%
all_conds = c.data['downcase_name'].unique()
all_mesh = bc.data['downcase_mesh_term'].unique()

# %%
len(all_conds), len(all_mesh)
# Out:
# (63257, 3738)

# %%
joint_mesh = ' '.join(all_mesh)
joint_conds = ' '.join(all_conds)

raw_mesh_tokens = nltk.word_tokenize(joint_mesh)
raw_cond_tokens = nltk.word_tokenize(joint_conds)

# %%
def strip_tokens(tokens, stop_words):
    table = str.maketrans('', '', string.punctuation)
    stripped_tokens = [w.translate(table) for w in tokens]
    no_blank = [w for w in stripped_tokens if w != '']
    no_stop_words = [w for w in no_blank if not w in stop_words]
    return no_stop_words

# %%
stripped_mesh_tokens = strip_tokens(raw_mesh_tokens, stop_words)
stripped_cond_tokens = strip_tokens(raw_cond_tokens, stop_words)

fdist_mesh = FreqDist(stripped_mesh_tokens)
fdist_cond = FreqDist(stripped_cond_tokens)

# %%
mesh_vocab = fdist_mesh.keys()
len(mesh_vocab)
# Out:
# 3221

# %%
cond_dict = dict(fdist_cond)

# %%
cond_extras = [x for x in cond_dict.keys() if x not in mesh_vocab]

# %%
extras_dict = FreqDist()
for k in cond_extras:
    extras_dict[k] = fdist_cond[k]

# %%
extras_dict.most_common()
# Out:
# [('patients', 1043),
#  ('ajcc', 944),
#  ('metastatic', 811),
#  ('advanced', 732),
#  ('v7', 474),
#  ('healthy', 467),
#  ('v8', 463),
#  ('therapy', 416),
#  ('solid', 377),
#  ('health', 366),
#  ('treatment', 356),
#  ('care', 355),
#  ('risk', 343),
#  ('grade', 323),
#  ('prostate', 307),
#  ('post', 287),
#  ('due', 267),
#  ('transplant', 260),
#  ('children', 260),
#  ('nonsmall', 247),
#  ('mutation', 243),
#  ('non', 233),
#  ('moderate', 231),
#  ('gene', 229),
#  ('patient', 222),
#  ('associated', 216),
#  ('effect', 208),
#  ('locally', 205),
#  ('cavity', 202),
#  ('study', 201),
#  ('transplantation', 199),
#  ('relapsed', 197),
#  ('subjects', 191),
#  ('prevention', 190),
#  ('complication', 182),
#  ('bleeding', 177),
#  ('mild', 176),
#  ('total', 159),
#  ('unresectable', 155),
#  ('women', 154),
#  ('lumbar', 153),
#  ('volunteers', 147),
#  ('medical', 147),
#  ('early', 147),
#  ('iiib', 146),
#  ('lesion', 143),
#  ('iva', 141),
#  ('malignancies', 137),
#  ('cancers', 137),
#  ('pharmacokinetics', 136),
#  ('training', 136),
#  ('ivb', 131),
#  ('junction', 130),
#  ('impairment', 129),
#  ('undergoing', 129),
#  ('iiia', 128),
#  ('physical', 127),
#  ('replacement', 127),
#  ('laparoscopic', 127),
#  ('v6', 126),
#  ('unspecified', 125),
#  ('safety', 125),
#  ('catheter', 124),
#  ('management', 121),
#  ('vaccine', 121),
#  ('focus', 121),
#  ('condition', 119),
#  ('exercise', 119),
#  ('diagnosis', 118),
#  ('allergy', 118),
#  ('rate', 117),
#  ('general', 116),
#  ('age', 115),
#  ('quality', 110),
#  ('elderly', 110),
#  ('symptomatic', 109),
#  ('metastases', 108),
#  ('chemotherapy', 108),
#  ('andor', 107),
#  ('following', 104),
#  ('intervention', 103),
#  ('delivery', 103),
#  ('reduction', 102),
#  ('nsclc', 102),
#  ('performance', 102),
#  ('defect', 101),
#  ('ulcers', 100),
#  ('bypass', 100),
#  ('active', 100),
#  ('anal', 99),
#  ('intubation', 98),
#  ('activity', 97),
#  ('pancreas', 95),
#  ('urothelial', 95),
#  ('requiring', 95),
#  ('ann', 94),
#  ('arbor', 94),
#  ('infants', 93),
#  ('problems', 93),
#  ('iia', 92),
#  ('hormone', 92),
#  ('nos', 90),
#  ('ventilation', 90),
#  ('level', 89),
#  ('time', 89),
#  ('her2', 87),
#  ('family', 87),
#  ('arthroplasty', 85),
#  ('recovery', 85),
#  ('impaired', 84),
#  ('resection', 82),
#  ('preterm', 81),
#  ('efficacy', 81),
#  ('procedures', 80),
#  ('cesarean', 80),
#  ('elective', 80),
#  ('malignancy', 78),
#  ('repair', 78),
#  ('iiic', 77),
#  ('procedure', 77),
#  ('opioid', 76),
#  ('sedation', 76),
#  ('neuropathic', 76),
#  ('device', 76),
#  ('specified', 75),
#  ('first', 75),
#  ('smoking', 74),
#  ('burn', 74),
#  ('life', 73),
#  ('analgesia', 73),
#  ('hospital', 73),
#  ('dialysis', 72),
#  ('medication', 72),
#  ('icu', 72),
#  ('resectable', 71),
#  ('ultrasound', 71),
#  ('mechanical', 70),
#  ('hemodialysis', 70),
#  ('oxygen', 70),
#  ('operative', 69),
#  ('volume', 69),
#  ('untreated', 67),
#  ('visual', 67),
#  ('rehabilitation', 67),
#  ('section', 67),
#  ('mass', 67),
#  ('single', 67),
#  ('lymphomas', 66),
#  ('stimulation', 66),
#  ('intensive', 66),
#  ('aml', 65),
#  ('colonoscopy', 65),
#  ('ib', 64),
#  ('complete', 64),
#  ('education', 63),
#  ('copd', 63),
#  ('adolescent', 63),
#  ('egfr', 63),
#  ('imaging', 63),
#  ('monitoring', 63),
#  ('group', 62),
#  ('fusion', 62),
#  ('screening', 62),
#  ('older', 62),
#  ('biopsy', 62),
#  ('scar', 62),
#  ('treated', 61),
#  ('healing', 61),
#  ('rejection', 60),
#  ('prophylaxis', 60),
#  ('access', 60),
#  ('levels', 60),
#  ('assessment', 60),
#  ('relapsedrefractory', 60),
#  ('ivc', 59),
#  ('implantation', 59),
#  ('years', 59),
#  ('hematopoietic', 58),
#  ('diagnosed', 58),
#  ('induction', 58),
#  ('flow', 58),
#  ('4', 57),
#  ('agerelated', 57),
#  ('agents', 57),
#  ('perioperative', 57),
#  ('poor', 56),
#  ('relapse', 56),
#  ('change', 55),
#  ('donor', 55),
#  ('diet', 55),
#  ('support', 54),
#  ('toxicity', 53),
#  ('nutritional', 53),
#  ('inhibitor', 53),
#  ('young', 53),
#  ('dietary', 53),
#  ('ia', 52),
#  ('consumption', 52),
#  ('intake', 52),
#  ('hpv', 52),
#  ('highrisk', 51),
#  ('outcome', 51),
#  ('thickness', 51),
#  ('vaccination', 51),
#  ('home', 51),
#  ('tumour', 51),
#  ('closure', 51),
#  ('outcomes', 50),
#  ('reconstruction', 50),
#  ('genotype', 50),
#  ('balance', 50),
#  ('pelvis', 49),
#  ('mantle', 49),
#  ('otherwise', 49),
#  ('new', 49),
#  ('dose', 49),
#  ('emergency', 49),
#  ('evaluation', 48),
#  ('emotional', 48),
#  ('endoscopic', 48),
#  ('0', 47),
#  ('newly', 47),
#  ('factors', 47),
#  ('exacerbation', 47),
#  ('leukaemia', 47),
#  ('percent', 47),
#  ('versus', 46),
#  ('energy', 46),
#  ('uncomplicated', 46),
#  ('superficial', 46),
#  ('interaction', 46),
#  ('ureter', 45),
#  ('oropharynx', 45),
#  ('larynx', 45),
#  ('psychosis', 45),
#  ('neurological', 45),
#  ('tolerance', 45),
#  ('percutaneous', 45),
#  ('allogeneic', 45),
#  ('tumours', 45),
#  ('postprandial', 45),
#  ('laser', 45),
#  ('obese', 45),
#  ('insertion', 45),
#  ('internal', 45),
#  ('old', 45),
#  ('proximal', 44),
#  ('test', 44),
#  ('services', 43),
#  ('improvement', 43),
#  ('using', 43),
#  ('line', 43),
#  ('disturbance', 43),
#  ('highgrade', 42),
#  ('intrauterine', 42),
#  ('polyp', 42),
#  ('preparation', 42),
#  ('ill', 41),
#  ('nonsquamous', 41),
#  ('anaesthesia', 41),
#  ('suspected', 41),
#  ('duration', 41),
#  ('unit', 41),
#  ('adherence', 41),
#  ('5', 41),
#  ('absorption', 41),
#  ('canal', 41),
#  ('pylori', 40),
#  ('discomfort', 40),
#  ('stent', 40),
#  ('medicine', 40),
#  ('guided', 40),
#  ('insomnia', 39),
#  ('intestine', 39),
#  ('administration', 39),
#  ('aureus', 39),
#  ('men', 39),
#  ('implants', 39),
#  ('uterus', 39),
#  ('one', 39),
#  ('serum', 39),
#  ('concentration', 39),
#  ('subjective', 39),
#  ('position', 39),
#  ('bioavailability', 38),
#  ('behaviour', 38),
#  ('catheterization', 38),
#  ('face', 38),
#  ('degree', 38),
#  ('arteries', 38),
#  ('expression', 38),
#  ('behaviors', 37),
#  ('violence', 37),
#  ('community', 37),
#  ('hysterectomy', 37),
#  ('regurgitation', 37),
#  ('complicated', 37),
#  ('indication', 37),
#  ('increased', 37),
#  ('need', 37),
#  ('contraceptive', 37),
#  ('placement', 37),
#  ('two', 37),
#  ('index', 37),
#  ('postneoadjuvant', 37),
#  ('strain', 36),
#  ('difficile', 36),
#  ('painful', 36),
#  ('strength', 36),
#  ('infected', 36),
#  ('contrast', 36),
#  ('decision', 36),
#  ('augmentation', 36),
#  ('survival', 36),
#  ('mri', 36),
#  ('program', 36),
#  ('recipients', 35),
#  ('mucosal', 35),
#  ('inhibitors', 35),
#  ('hcv', 35),
#  ('articular', 35),
#  ('pregnant', 35),
#  ('aneurysms', 35),
#  ('regulation', 35),
#  ('months', 35),
#  ('techniques', 35),
#  ('difficult', 35),
#  ('novo', 34),
#  ('differentiated', 34),
#  ('gliomas', 34),
#  ('dyslipidemia', 34),
#  ('gynecologic', 34),
#  ('delay', 34),
#  ('prior', 34),
#  ('staphylococcus', 34),
#  ('psychiatric', 34),
#  ('scheduled', 34),
#  ('nursing', 34),
#  ('testing', 34),
#  ('history', 34),
#  ('based', 34),
#  ('preoperative', 34),
#  ('endoscopy', 34),
#  ('assess', 34),
#  ('fetus', 34),
#  ('less', 34),
#  ('anesthetic', 34),
#  ('mutations', 34),
#  ('braf', 34),
#  ('congestive', 33),
#  ('continuous', 33),
#  ('events', 33),
#  ('standard', 33),
#  ('vaccines', 33),
#  ('controlled', 33),
#  ('aged', 33),
#  ('removal', 33),
#  ('wrinkles', 33),
#  ('radiotherapy', 33),
#  ('population', 33),
#  ('perception', 33),
#  ('menopausal', 32),
#  ('estrogen', 32),
#  ('myopathy', 32),
#  ('cml', 32),
#  ('cardiopulmonary', 32),
#  ('indolent', 32),
#  ('mortality', 32),
#  ('haemorrhage', 32),
#  ('mds', 32),
#  ('pacemaker', 32),
#  ('adolescents', 32),
#  ('bacteria', 32),
#  ('living', 32),
#  ('physiology', 32),
#  ('caused', 32),
#  ('including', 32),
#  ('simulation', 32),
#  ('light', 32),
#  ('people', 32),
#  ('effectiveness', 32),
#  ('region', 32),
#  ('accident', 31),
#  ('ablation', 31),
#  ('16', 31),
#  ('nonmetastatic', 31),
#  ('previously', 31),
#  ('gynecological', 31),
#  ('menstrual', 31),
#  ('among', 31),
#  ('morbidity', 31),
#  ('episode', 31),
#  ('autologous', 31),
#  ('ambulatory', 31),
#  ('antibiotic', 31),
#  ('symptom', 31),
#  ('transfer', 31),
#  ('pathology', 31),
#  ('fall', 31),
#  ('operation', 31),
#  ('bariatric', 31),
#  ('gut', 31),
#  ('segment', 31),
#  ('thymic', 30),
#  ('isolated', 30),
#  ('previous', 30),
#  ('receiving', 30),
#  ('school', 30),
#  ('achilles', 30),
#  ('relationship', 30),
#  ('restoration', 30),
#  ('aorta', 30),
#  ('perfusion', 30),
#  ('evaluate', 30),
#  ('rectum', 29),
#  ('lowgrade', 29),
#  ('seizure', 29),
#  ('density', 29),
#  ('satisfaction', 29),
#  ('nicotine', 29),
#  ('nhl', 29),
#  ('participants', 29),
#  ('volunteer', 29),
#  ('individuals', 29),
#  ('lines', 29),
#  ('ridge', 29),
#  ('trimester', 29),
#  ('inoperable', 29),
#  ('technique', 29),
#  ('minor', 29),
#  ('video', 29),
#  ('ph', 29),
#  ('comparison', 29),
#  ('immunization', 28),
#  ('ebv', 28),
#  ('allograft', 28),
#  ('antibody', 28),
#  ('hematological', 28),
#  ('extraction', 28),
#  ('features', 28),
#  ('work', 28),
#  ('event', 28),
#  ('magnetic', 28),
#  ('impact', 28),
#  ('persons', 28),
#  ('score', 28),
#  ('pollen', 28),
#  ('oxygenation', 28),
#  ('sprain', 28),
#  ('utilization', 28),
#  ('responses', 28),
#  ('esophagogastric', 28),
#  ('free', 28),
#  ('affecting', 28),
#  ('supplementation', 28),
#  ('ct', 28),
#  ('adolescence', 28),
#  ('cll', 27),
#  ('fasting', 27),
#  ('knowledge', 27),
#  ('labour', 27),
#  ('rates', 27),
#  ('perineal', 27),
#  ('psa', 27),
#  ('revision', 27),
#  ('devices', 27),
#  ('radical', 27),
#  ('surgeries', 27),
#  ('causing', 27),
#  ('stability', 27),
#  ('appetite', 27),
#  ('dlbcl', 26),
#  ('amplification', 26),
#  ('classical', 26),
#  ('surface', 26),
#  ('deficits', 26),
#  ('agent', 26),
#  ('artificial', 26),
#  ('scars', 26),
#  ('third', 26),
#  ('mastectomy', 26),
#  ('period', 26),
#  ('endotracheal', 26),
#  ('10', 26),
#  ('classic', 26),
#  ('reduced', 26),
#  ('cannulation', 26),
#  ('humerus', 26),
#  ('parenteral', 26),
#  ('figo', 26),
#  ('fraction', 26),
#  ('greater', 26),
#  ('ckd', 26),
#  ('tests', 26),
#  ('staging', 26),
#  ('restriction', 26),
#  ('nucleated', 26),
#  ('transmission', 25),
#  ('adhesion', 25),
#  ('beta', 25),
#  ('minimally', 25),
#  ('pathway', 25),
#  ('contiguous', 25),
#  ('noncontiguous', 25),
#  ('episodic', 25),
#  ('trial', 25),
#  ('mature', 25),
#  ('cocaine', 25),
#  ('full', 25),
#  ('stone', 25),
#  ('recipient', 25),
#  ('prostatectomy', 25),
#  ('rhinosinusitis', 25),
#  ('present', 25),
#  ('placebo', 25),
#  ('prosthetic', 25),
#  ('gi', 25),
#  ('orthopedic', 25),
#  ('extremities', 25),
#  ('ejection', 25),
#  ('measurement', 25),
#  ('poststroke', 25),
#  ('orthodontic', 25),
#  ('driving', 25),
#  ('frequency', 25),
#  ('mandible', 25),
#  ('bmi', 25),
#  ('microbiota', 25),
#  ('improving', 25),
#  ('endstage', 24),
#  ('iic', 24),
#  ('streptococcus', 24),
#  ('contraception', 24),
#  ('adhd', 24),
#  ('gvhd', 24),
#  ('fitness', 24),
#  ('systems', 24),
#  ('critically', 24),
#  ('colonization', 24),
#  ('stones', 24),
#  ('days', 24),
#  ('pharmacokinetic', 24),
#  ('potential', 24),
#  ('enteral', 24),
#  ('transformed', 24),
#  ('ventilator', 24),
#  ('throat', 24),
#  ('stiffness', 24),
#  ('postsurgical', 24),
#  ('anastomosis', 24),
#  ('determine', 24),
#  ('geriatric', 24),
#  ('mucosa', 24),
#  ('pharmacodynamics', 24),
#  ('alk', 24),
#  ('profile', 24),
#  ('different', 24),
#  ('process', 24),
#  ('cmv', 23),
#  ('progesterone', 23),
#  ('nonmalignant', 23),
#  ('infiltrating', 23),
#  ('compliance', 23),
#  ('digital', 23),
#  ('childbirth', 23),
#  ('healthcare', 23),
#  ('neglect', 23),
#  ('resuscitation', 23),
#  ('gastrectomy', 23),
#  ('analgesic', 23),
#  ('tomography', 23),
#  ('immunity', 23),
#  ('survivors', 23),
#  ('markers', 23),
#  ('weeks', 23),
#  ('anatomic', 23),
#  ('preservation', 23),
#  ('wellbeing', 23),
#  ('ivf', 23),
#  ('anesthetics', 23),
#  ('carcinomas', 23),
#  ('research', 23),
#  ('flap', 23),
#  ('analysis', 23),
#  ('kras', 23),
#  ('her2positive', 22),
#  ('extensive', 22),
#  ('preventive', 22),
#  ('anaemia', 22),
#  ('least', 22),
#  ('area', 22),
#  ('nonresectable', 22),
#  ('hospitalized', 22),
#  ('clearance', 22),
#  ('nonspecific', 22),
#  ('incidence', 22),
#  ('oxytocin', 22),
#  ('alteration', 22),
#  ('method', 22),
#  ('sedentary', 21),
#  ('bcrabl1', 21),
#  ('enzyme', 21),
#  ('frail', 21),
#  ('cessation', 21),
#  ('midline', 21),
#  ('sac', 21),
#  ('size', 21),
#  ('information', 21),
#  ('relief', 21),
#  ('evidence', 21),
#  ('processing', 21),
#  ('sensitive', 21),
#  ('daily', 21),
#  ('weaning', 21),
#  ('saphenous', 21),
#  ('caregivers', 21),
#  ('composition', 21),
#  ('amd', 21),
#  ('echocardiography', 21),
#  ('fear', 21),
#  ('aspirin', 21),
#  ('decreased', 21),
#  ('scarring', 21),
#  ('bioequivalence', 21),
#  ('hemodynamic', 21),
#  ('functioning', 21),
#  ('30', 21),
#  ('biomarkers', 21),
#  ('somatic', 21),
#  ('tolerability', 21),
#  ('mutated', 21),
#  ('tnm', 21),
#  ('adjuvant', 20),
#  ('red', 20),
#  ('psychosocial', 20),
#  ('longterm', 20),
#  ('suppression', 20),
#  ('falls', 20),
#  ('ptsd', 20),
#  ('hypopharynx', 20),
#  ('initial', 20),
#  ('mineral', 20),
#  ('relations', 20),
#  ('hiv1', 20),
#  ('breastfeeding', 20),
#  ('adenomas', 20),
#  ('grafting', 20),
#  ('pattern', 20),
#  ('limbs', 20),
#  ('ventilated', 20),
#  ('erosive', 20),
#  ('smokers', 20),
#  ('laceration', 20),
#  ('laxity', 20),
#  ('users', 20),
#  ('structure', 20),
#  ('significant', 20),
#  ('prognostic', 20),
#  ('endometrium', 20),
#  ('subclinical', 20),
#  ('planning', 20),
#  ('males', 20),
#  ('tendinitis', 20),
#  ('chain', 20),
#  ('increase', 20),
#  ('fertilization', 20),
#  ('mps', 20),
#  ('sacroiliac', 20),
#  ('native', 20),
#  ('lumbosacral', 20),
#  ('dilation', 20),
#  ('microbiome', 20),
#  ('noninvasive', 20),
#  ('deficient', 20),
#  ('20', 20),
#  ('mutant', 20),
#  ('interval', 20),
#  ('protocol', 19),
#  ('lymphocyte', 19),
#  ('posttransplant', 19),
#  ('secretion', 19),
#  ('hemiparesis', 19),
#  ('counseling', 19),
#  ('plasmodium', 19),
#  ('hygiene', 19),
#  ('cannabis', 19),
#  ('decline', 19),
#  ('youth', 19),
#  ('pacing', 19),
#  ('ileostomy', 19),
#  ('toxic', 19),
#  ('angiography', 19),
#  ('partner', 19),
#  ('lifestyle', 19),
#  ('conventional', 19),
#  ('parenting', 19),
#  ('prescription', 19),
#  ('valvular', 19),
#  ('caregiver', 19),
#  ('sarcomas', 19),
#  ('nasolabial', 19),
#  ('folds', 19),
#  ('cornea', 19),
#  ('flora', 19),
#  ('vulva', 19),
#  ('antimicrobial', 19),
#  ('stemi', 19),
#  ('influence', 19),
#  ('incision', 19),
#  ('correction', 19),
#  ('application', 19),
#  ('er', 19),
#  ('sports', 19),
#  ('50', 19),
#  ('physician', 19),
#  ('chinese', 19),
#  ('7', 19),
#  ('extubation', 19),
#  ('cytochrome', 19),
#  ('uptake', 19),
#  ('complicating', 19),
#  ('mask', 19),
#  ('platinumresistant', 19),
#  ('suture', 19),
#  ('robotic', 19),
#  ('predominant', 18),
#  ('accidental', 18),
#  ('9', 18),
#  ('yolk', 18),
#  ('oncology', 18),
#  ('image', 18),
#  ('mrsa', 18),
#  ('hypoxic', 18),
#  ('well', 18),
#  ('angioplasty', 18),
#  ('methamphetamine', 18),
#  ('genitourinary', 18),
#  ('ischaemic', 18),
#  ('resonance', 18),
#  ('axillary', 18),
#  ('h', 18),
#  ('arthroscopic', 18),
#  ('walking', 18),
#  ('fixation', 18),
#  ('oesophageal', 18),
#  ('clinically', 18),
#  ('approach', 18),
#  ('donors', 18),
#  ('natural', 18),
#  ('sites', 18),
#  ('combination', 18),
#  ('dysfunctional', 18),
#  ('disk', 18),
#  ('thromboembolic', 18),
#  ('mechanisms', 18),
#  ('eyes', 18),
#  ('detection', 18),
#  ('bloodstream', 18),
#  ('mesh', 18),
#  ('confirmed', 18),
#  ('inhibition', 18),
#  ('nodes', 18),
#  ('manipulation', 18),
#  ('simple', 18),
#  ('uncontrolled', 18),
#  ('educational', 18),
#  ('p450', 18),
#  ('relaxation', 18),
#  ('inadequate', 18),
#  ('caesarean', 18),
#  ('enhancement', 18),
#  ('maxilla', 18),
#  ('organic', 18),
#  ('dexmedetomidine', 18),
#  ('brca', 18),
#  ('pneumoniae', 17),
#  ('dysphagia', 17),
#  ('q22', 17),
#  ('8', 17),
#  ('her2negative', 17),
#  ('nasopharynx', 17),
#  ('glycemic', 17),
#  ('oligoastrocytoma', 17),
#  ('electrical', 17),
#  ('graftversushost', 17),
#  ('practice', 17),
#  ('intracerebral', 17),
#  ('oxidative', 17),
#  ('minimal', 17),
#  ('influenzae', 17),
#  ('tb', 17),
#  ('platinum', 17),
#  ('anticoagulation', 17),
#  ('tibia', 17),
#  ('involvement', 17),
#  ('technology', 17),
#  ('diarrhoea', 17),
#  ('hemiplegic', 17),
#  ('burden', 17),
#  ('lack', 17),
#  ('stasis', 17),
#  ('cd20', 17),
#  ('acl', 17),
#  ('making', 17),
#  ('displaced', 17),
#  ('hcc', 17),
#  ('intensity', 17),
#  ('arthrosis', 17),
#  ('serious', 17),
#  ('retina', 17),
#  ('fold', 17),
#  ('pump', 17),
#  ('needle', 17),
#  ('consent', 17),
#  ('paediatric', 17),
#  ('compare', 17),
#  ('cleansing', 17),
#  ('nash', 17),
#  ('hilar', 17),
#  ('examination', 17),
#  ('organs', 17),
#  ('excluding', 17),
#  ('methods', 17),
#  ('mediated', 17),
#  ('nyha', 17),
#  ('basic', 17),
#  ('circulatory', 17),
#  ('activating', 17),
#  ('mobile', 17),
#  ('rearrangement', 17),
#  ('cystoid', 16),
#  ('extragonadal', 16),
#  ('opiate', 16),
#  ('steatohepatitis', 16),
#  ('brca1', 16),
#  ('deficiencies', 16),
#  ('irritation', 16),
#  ('molar', 16),
#  ('icd', 16),
#  ('antiretroviral', 16),
#  ('interactions', 16),
#  ('nonunion', 16),
#  ('senile', 16),
#  ('bronchoscopy', 16),
#  ('students', 16),
#  ('prenatal', 16),
#  ('electronic', 16),
#  ('prescribing', 16),
#  ('gist', 16),
#  ('24', 16),
#  ('cabg', 16),
#  ('point', 16),
#  ('transit', 16),
#  ('arthrodesis', 16),
#  ('androgen', 16),
#  ('variceal', 16),
#  ('ulceration', 16),
#  ('capacity', 16),
#  ('vasculopathy', 16),
#  ('humans', 16),
#  ('cigarette', 16),
#  ('form', 16),
#  ('interventions', 16),
#  ('nafld', 16),
#  ('herniation', 16),
#  ('action', 16),
#  ('sequelae', 16),
#  ('antiplatelet', 16),
#  ('neonates', 16),
#  ('pci', 16),
#  ('osteochondral', 16),
#  ('hours', 16),
#  ('stoma', 16),
#  ('topical', 16),
#  ('improve', 16),
#  ('parameters', 16),
#  ('accuracy', 16),
#  ('perianal', 16),
#  ('saturation', 16),
#  ('reactivity', 16),
#  ('periampullary', 16),
#  ('current', 16),
#  ('athletes', 16),
#  ('plane', 16),
#  ('task', 16),
#  ('idh1', 16),
#  ('parent', 16),
#  ('sodium', 16),
#  ('prognosis', 15),
#  ('pertussis', 15),
#  ('myelopathy', 15),
#  ('randomized', 15),
#  ('11', 15),
#  ('leukemias', 15),
#  ('adhesive', 15),
#  ('indicated', 15),
#  ('comorbid', 15),
#  ('miscarriage', 15),
#  ('pad', 15),
#  ('pre', 15),
#  ('donation', 15),
#  ('residents', 15),
#  ('blockade', 15),
#  ('stay', 15),
#  ('permanent', 15),
#  ('dependency', 15),
#  ('decompensated', 15),
#  ('branch', 15),
#  ('bed', 15),
#  ('sensitization', 15),
#  ('postnatal', 15),
#  ('laparotomy', 15),
#  ('pigment', 15),
#  ('disruption', 15),
#  ('mothers', 15),
#  ('rhinoconjunctivitis', 15),
#  ('glabellar', 15),
#  ('molecular', 15),
#  ('spondyloarthritis', 15),
#  ('dermal', 15),
#  ('muscles', 15),
#  ('biological', 15),
#  ('involving', 15),
#  ('nipple', 15),
#  ('rapid', 15),
#  ('blunt', 15),
#  ('reversal', 15),
#  ('ampulla', 15),
#  ('modification', 15),
#  ('thumb', 15),
#  ('regeneration', 15),
#  ('tears', 15),
#  ('ptosis', 15),
#  ('females', 15),
#  ('h1n1', 15),
#  ('workers', 15),
#  ('distribution', 15),
#  ('mother', 15),
#  ('diaphragm', 15),
#  ('engagement', 15),
#  ('role', 15),
#  ('deleterious', 15),
#  ('american', 15),
#  ('criteria', 15),
#  ('mf', 15),
#  ('implementation', 15),
#  ('oligometastatic', 15),
#  ('virtual', 15),
#  ('immunisation', 15),
#  ('herniated', 14),
#  ('maturation', 14),
#  ('fungoidessezary', 14),
#  ('differentiation', 14),
#  ('avascular', 14),
#  ('orthopaedic', 14),
#  ('lymphoepithelioma', 14),
#  ('cellular', 14),
#  ('maculopathy', 14),
#  ('brca2', 14),
#  ('endovascular', 14),
#  ('habits', 14),
#  ('fibroids', 14),
#  ('implantable', 14),
#  ('plus', 14),
#  ('radicular', 14),
#  ('drainage', 14),
#  ('osteotomy', 14),
#  ('arthroscopy', 14),
#  ('manual', 14),
#  ('illnesses', 14),
#  ('sore', 14),
#  ('hemostasis', 14),
#  ('cholecystectomy', 14),
#  ('formation', 14),
#  ('within', 14),
#  ('moderately', 14),
#  ('fontan', 14),
#  ('wildtype', 14),
#  ('inpatient', 14),
#  ('insufficient', 14),
#  ('coping', 14),
#  ('undergo', 14),
#  ('trunk', 14),
#  ('tendonitis', 14),
#  ('episodes', 14),
#  ('parental', 14),
#  ('injections', 14),
#  ('ercp', 14),
#  ('advancedmetastatic', 14),
#  ('acids', 14),
#  ('macula', 14),
#  ('intra', 14),
#  ('gall', 14),
#  ('contamination', 14),
#  ('balloon', 14),
#  ('known', 14),
#  ('attitudes', 14),
#  ('psychology', 14),
#  ('vater', 14),
#  ('reduce', 14),
#  ...]
