# %% [markdown]
# This project seeks to evaluate the replicability of trial findings.
# 1. For a handful of diseases collect drug names, collect panel data on trials related to these drugs.
# 2. Evaluate predictive power of early studies on later studies (R^2 and corr coeff can be thought of as replicability measure)
# 3. Predict predictive power on trial observables (strength of the results, sample size, funder, balance, trial design)
#
# An app: create drug studies ratings

# %%
import pandas as pd
import numpy as numpy
from importlib import reload
from tqdm import tqdm_notebook as tqdm
import time

import pdaactconn as pc
from trialexplorer import AACTStudySet

import matplotlib.pyplot
# %matplotlib inline

pd.set_option('display.max_columns', 999)
# Out:
# /Users/akhazan/.virtualenvs/notebooks_venv/lib/python3.7/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
conn = pc.AACTConnection(source=pc.AACTConnection.REMOTE)
ss = AACTStudySet.AACTStudySet(conn=conn, tqdm_handler=tqdm)
ss.add_constraint("study_type = 'Interventional'")
ss.show_constraints()
ss.load_studies()
# Out:
# WHERE 1=1
#     AND (study_type = 'Interventional')
#
# 253162 studies loaded!

# %% [markdown]
# #### Adding dimensions to filter dataset and add data related to results and outcomes

# %%
ss.add_dimensions([
    'countries', 
    'conditions', 
    'browse_conditions',
    'keywords', 
    'pending_results', 
    'design_outcomes', 
    'designs', 
    'result_groups',
    'milestones', 
    'baseline_counts', 
    'baseline_measurements', 
    'outcomes', 
    'outcome_analyses', 
    'outcome_analysis_groups', 
    'outcome_counts',
    'outcome_measurements', 
    'browse_interventions', 
    'interventions', 
    'intervention_other_names'
])
# Out:
# Successfuly added these 19 dimensions: ['countries', 'conditions', 'browse_conditions', 'keywords', 'pending_results', 'design_outcomes', 'designs', 'result_groups', 'milestones', 'baseline_counts', 'baseline_measurements', 'outcomes', 'outcome_analyses', 'outcome_analysis_groups', 'outcome_counts', 'outcome_measurements', 'browse_interventions', 'interventions', 'intervention_other_names']
# Failed to add these 0 dimensions: []

# %%
ss.refresh_dim_data()
# Out:
# HBox(children=(IntProgress(value=0, max=507), HTML(value='')))
# Syncing the temp table temp_cur_studies in 507 chunks x 500 records each
#
# Creating index on the temp table
#  - Loading dimension countries
#  -- Loading raw data
#  -- Sorting index
#  - Loading dimension conditions
#  -- Loading raw data
#  -- Sorting index
#  - Loading dimension browse_conditions
#  -- Loading raw data
#  -- Sorting index
#  - Loading dimension keywords
#  -- Loading raw data
#  -- Sorting index
#  - Loading dimension pending_results
#  -- Loading raw data
#  -- Sorting index
#  - Loading dimension design_outcomes
#  -- Loading raw data
#  -- Sorting index
#  - Loading dimension designs
#  -- Loading raw data
#  -- Sorting index
#  - Loading dimension result_groups
#  -- Loading raw data
#  -- Sorting index
#  - Loading dimension milestones
#  -- Loading raw data
#  -- Sorting index
#  - Loading dimension baseline_counts
#  -- Loading raw data
#  -- Sorting index
#  - Loading dimension baseline_measurements
#  -- Loading raw data
#  -- Sorting index
#  - Loading dimension outcomes
#  -- Loading raw data
#  -- Sorting index
#  - Loading dimension outcome_analyses
#  -- Loading raw data
#  -- Sorting index
#  - Loading dimension outcome_analysis_groups
#  -- Loading raw data
#  -- Sorting index
#  - Loading dimension outcome_counts
#  -- Loading raw data
#  -- Sorting index
#  - Loading dimension outcome_measurements
#  -- Loading raw data
#  -- Sorting index
#  - Loading dimension browse_interventions
#  -- Loading raw data
#  -- Sorting index
#  - Loading dimension interventions
#  -- Loading raw data
#  -- Sorting index
#  - Loading dimension intervention_other_names
#  -- Loading raw data
#  -- Sorting index

# %% [markdown]
# #### Studies with result groups

# %%
df = ss.studies.reset_index().merge(ss.dimensions['result_groups'].data.add_prefix('result_group_'), 
    left_on='nct_id', right_index=True, how='inner')

df['result_group_result_type'] = df['result_group_result_type'].fillna('None')

df.reset_index().groupby(['result_group_result_type']).agg({'nct_id':['count', 'nunique']})
# Out:
#                           nct_id
#                            count nunique
# result_group_result_type
# Baseline                  107767   37348
# Outcome                   678680   37348
# Participant Flow           88348   37348
# Reported Event             89364   37151

# %%
df.reset_index()['nct_id'].nunique()
# Out:
# 37348

# %%
df.shape
# Out:
# (964159, 69)

# %% [markdown]
# #### Joining Interventions

# %%
interventions = ss.dimensions['interventions'].data.add_prefix('intervention_')
interventions.head()

df = df.set_index('nct_id').merge(interventions, left_index=True, right_index=True, how='left')
print(df.shape)
df.reset_index()[['nct_id','result_group_id', 'intervention_id']].nunique()
# Out:
# (2647355, 72)
# nct_id              37348
# result_group_id    964159
# intervention_id     86762
# dtype: int64

# %% [markdown]
# #### Associating studies with the drugs they are testing

# %%
## Sample list of 2019 FDA approved drugs

drugs = [
'certolizumab pegol',
 'esketamine',
 'solriamfetol',
 'risankizumab-rzaa',
 'brexanolone',
 'rimabotulinumtoxinB',
 'oral semaglutide',
 'romosozumab-aqqg',
 'pretomanid tablets',
 'tenapanor',
 'pembrolizumab',
 'apremilast',
 'lasmiditan',
 'amifampridine',
 'pexidartinib',
 'relebactam',
 'onasemnogene abeparvovec-xioi',
 'caplacizumab-yhdp',
 'cladribine',
 'ruxolitinib',
 'fedratinib',
 'upadacitinib',
 'bremelanotide',
 'atezolizumab',
 'dengue tetravalent vaccine',
 'hyaluronidase-oysk',
 'nintedanib',
 'trifarotene',
 'alpelisib',
 'midazolam',
 'selinexor',
 'erdafitinib',
 'polatuzumab vedotin-piiq',
 'ramucirumab',
 'istradefylline',
 'ixekizumab',
 'siponimod',
 'sumatriptan',
 'halobetasol propionate and tazarotene',
 'entrectinib',
 'darolutamide',
 'prabotulinumtoxinA-xvfs',
 'testosterone undecanoate',
 'trastuzumab',
 'dupilumab',
 'pitolisant',
 'triclabendazole',
 'lefamulin',
 'brolucizumab-dbll'
]

# %%
df[['intervention_description', 'intervention_name', 'official_title']] = \
    df[['intervention_description', 'intervention_name', 'official_title']].fillna('None')

# %%
print(df.shape)
df.reset_index()[['nct_id','result_group_id', 'intervention_id']].nunique()
# Out:
# (2647355, 72)
# nct_id              37348
# result_group_id    964159
# intervention_id     86762
# dtype: int64

# %%
# This assumes every intervention can only be associated with one drug

for drug in drugs:
    df.loc[df.intervention_description.str.contains(drug), 'drug_name'] = drug

# %%
df.groupby('drug_name').agg({'intervention_id':'count'})\
    .sort_values(by='intervention_id', ascending=False).head()
# Out:
#                     intervention_id
# drug_name
# midazolam                      2093
# trastuzumab                    1538
# esketamine                      888
# certolizumab pegol              866
# sumatriptan                     717

# %%
df.reset_index().groupby(['drug_name', 'phase']).agg({'nct_id':'nunique'})\
    .reset_index().pivot(index='drug_name', columns='phase', values='nct_id')\
    .fillna(0)
# Out:
# phase                      N/A  Phase 1  Phase 1/Phase 2  Phase 2  \
# drug_name
# apremilast                 0.0      0.0              0.0      2.0
# atezolizumab               0.0      0.0              1.0      2.0
# bremelanotide              0.0      0.0              0.0      1.0
# certolizumab pegol         0.0      1.0              0.0      1.0
# cladribine                 0.0      1.0              1.0      1.0
# esketamine                 0.0      0.0              0.0      1.0
# istradefylline             0.0      0.0              0.0      0.0
# lasmiditan                 0.0      0.0              0.0      0.0
# midazolam                 16.0      9.0              1.0      4.0
# nintedanib                 0.0      0.0              0.0      0.0
# pembrolizumab              0.0      1.0              0.0      1.0
# ramucirumab                0.0      0.0              0.0      7.0
# relebactam                 0.0      0.0              0.0      1.0
# rimabotulinumtoxinB        0.0      0.0              0.0      0.0
# ruxolitinib                0.0      0.0              0.0      3.0
# selinexor                  0.0      0.0              0.0      1.0
# sumatriptan                0.0      1.0              0.0      0.0
# testosterone undecanoate   0.0      0.0              1.0      1.0
# trastuzumab                1.0      5.0              9.0     22.0
# trifarotene                0.0      0.0              0.0      0.0
# upadacitinib               0.0      0.0              0.0      0.0
#
# phase                     Phase 2/Phase 3  Phase 3  Phase 4
# drug_name
# apremilast                            0.0      3.0      2.0
# atezolizumab                          0.0      1.0      0.0
# bremelanotide                         0.0      0.0      0.0
# certolizumab pegol                    0.0      2.0      1.0
# cladribine                            0.0      3.0      0.0
# esketamine                            0.0      4.0      0.0
# istradefylline                        0.0      1.0      0.0
# lasmiditan                            0.0      1.0      0.0
# midazolam                             1.0      3.0     18.0
# nintedanib                            0.0      0.0      1.0
# pembrolizumab                         1.0      2.0      0.0
# ramucirumab                           0.0      2.0      0.0
# relebactam                            0.0      0.0      0.0
# rimabotulinumtoxinB                   0.0      1.0      0.0
# ruxolitinib                           0.0      2.0      0.0
# selinexor                             0.0      0.0      0.0
# sumatriptan                           0.0      9.0      8.0
# testosterone undecanoate              0.0      2.0      0.0
# trastuzumab                           1.0      8.0      1.0
# trifarotene                           0.0      1.0      0.0
# upadacitinib                          0.0      1.0      0.0

# %%
df.head()
# Out:
#                                  nlm_download_date_description  \
# nct_id
# NCT00000125  ClinicalTrials.gov processed this data on Octo...
# NCT00000125  ClinicalTrials.gov processed this data on Octo...
# NCT00000125  ClinicalTrials.gov processed this data on Octo...
# NCT00000125  ClinicalTrials.gov processed this data on Octo...
# NCT00000125  ClinicalTrials.gov processed this data on Octo...
#
#             study_first_submitted_date results_first_submitted_date  \
# nct_id
# NCT00000125                 1999-09-23                   2015-03-06
# NCT00000125                 1999-09-23                   2015-03-06
# NCT00000125                 1999-09-23                   2015-03-06
# NCT00000125                 1999-09-23                   2015-03-06
# NCT00000125                 1999-09-23                   2015-03-06
#
#             disposition_first_submitted_date last_update_submitted_date  \
# nct_id
# NCT00000125                             None                 2019-09-06
# NCT00000125                             None                 2019-09-06
# NCT00000125                             None                 2019-09-06
# NCT00000125                             None                 2019-09-06
# NCT00000125                             None                 2019-09-06
#
#             study_first_submitted_qc_date study_first_posted_date  \
# nct_id
# NCT00000125                    1999-09-23              1999-09-24
# NCT00000125                    1999-09-23              1999-09-24
# NCT00000125                    1999-09-23              1999-09-24
# NCT00000125                    1999-09-23              1999-09-24
# NCT00000125                    1999-09-23              1999-09-24
#
#             study_first_posted_date_type results_first_submitted_qc_date  \
# nct_id
# NCT00000125                     Estimate                      2015-03-06
# NCT00000125                     Estimate                      2015-03-06
# NCT00000125                     Estimate                      2015-03-06
# NCT00000125                     Estimate                      2015-03-06
# NCT00000125                     Estimate                      2015-03-06
#
#             results_first_posted_date results_first_posted_date_type  \
# nct_id
# NCT00000125                2015-03-19                       Estimate
# NCT00000125                2015-03-19                       Estimate
# NCT00000125                2015-03-19                       Estimate
# NCT00000125                2015-03-19                       Estimate
# NCT00000125                2015-03-19                       Estimate
#
#             disposition_first_submitted_qc_date disposition_first_posted_date  \
# nct_id
# NCT00000125                                None                          None
# NCT00000125                                None                          None
# NCT00000125                                None                          None
# NCT00000125                                None                          None
# NCT00000125                                None                          None
#
#             disposition_first_posted_date_type last_update_submitted_qc_date  \
# nct_id
# NCT00000125                               None                    2019-09-06
# NCT00000125                               None                    2019-09-06
# NCT00000125                               None                    2019-09-06
# NCT00000125                               None                    2019-09-06
# NCT00000125                               None                    2019-09-06
#
#             last_update_posted_date last_update_posted_date_type  \
# nct_id
# NCT00000125              2019-09-17                       Actual
# NCT00000125              2019-09-17                       Actual
# NCT00000125              2019-09-17                       Actual
# NCT00000125              2019-09-17                       Actual
# NCT00000125              2019-09-17                       Actual
#
#             start_month_year start_date_type  start_date  \
# nct_id
# NCT00000125    February 1994          Actual  1994-02-28
# NCT00000125    February 1994          Actual  1994-02-28
# NCT00000125    February 1994          Actual  1994-02-28
# NCT00000125    February 1994          Actual  1994-02-28
# NCT00000125    February 1994          Actual  1994-02-28
#
#             verification_month_year verification_date completion_month_year  \
# nct_id
# NCT00000125          September 2019        2019-09-30            March 2020
# NCT00000125          September 2019        2019-09-30            March 2020
# NCT00000125          September 2019        2019-09-30            March 2020
# NCT00000125          September 2019        2019-09-30            March 2020
# NCT00000125          September 2019        2019-09-30            March 2020
#
#             completion_date_type completion_date  \
# nct_id
# NCT00000125          Anticipated      2020-03-31
# NCT00000125          Anticipated      2020-03-31
# NCT00000125          Anticipated      2020-03-31
# NCT00000125          Anticipated      2020-03-31
# NCT00000125          Anticipated      2020-03-31
#
#             primary_completion_month_year primary_completion_date_type  \
# nct_id
# NCT00000125                     June 2002                       Actual
# NCT00000125                     June 2002                       Actual
# NCT00000125                     June 2002                       Actual
# NCT00000125                     June 2002                       Actual
# NCT00000125                     June 2002                       Actual
#
#             primary_completion_date target_duration      study_type acronym  \
# nct_id
# NCT00000125              2002-06-30            None  Interventional    OHTS
# NCT00000125              2002-06-30            None  Interventional    OHTS
# NCT00000125              2002-06-30            None  Interventional    OHTS
# NCT00000125              2002-06-30            None  Interventional    OHTS
# NCT00000125              2002-06-30            None  Interventional    OHTS
#
#                                            baseline_population  \
# nct_id
# NCT00000125  1636 ocular hypertensive patients were randomi...
# NCT00000125  1636 ocular hypertensive patients were randomi...
# NCT00000125  1636 ocular hypertensive patients were randomi...
# NCT00000125  1636 ocular hypertensive patients were randomi...
# NCT00000125  1636 ocular hypertensive patients were randomi...
#
#                                             brief_title  \
# nct_id
# NCT00000125  Ocular Hypertension Treatment Study (OHTS)
# NCT00000125  Ocular Hypertension Treatment Study (OHTS)
# NCT00000125  Ocular Hypertension Treatment Study (OHTS)
# NCT00000125  Ocular Hypertension Treatment Study (OHTS)
# NCT00000125  Ocular Hypertension Treatment Study (OHTS)
#
#                                          official_title  \
# nct_id
# NCT00000125  Ocular Hypertension Treatment Study (OHTS)
# NCT00000125  Ocular Hypertension Treatment Study (OHTS)
# NCT00000125  Ocular Hypertension Treatment Study (OHTS)
# NCT00000125  Ocular Hypertension Treatment Study (OHTS)
# NCT00000125  Ocular Hypertension Treatment Study (OHTS)
#
#                      overall_status last_known_status    phase  enrollment  \
# nct_id
# NCT00000125  Active, not recruiting              None  Phase 3      1636.0
# NCT00000125  Active, not recruiting              None  Phase 3      1636.0
# NCT00000125  Active, not recruiting              None  Phase 3      1636.0
# NCT00000125  Active, not recruiting              None  Phase 3      1636.0
# NCT00000125  Active, not recruiting              None  Phase 3      1636.0
#
#             enrollment_type                                    source  \
# nct_id
# NCT00000125          Actual  Washington University School of Medicine
# NCT00000125          Actual  Washington University School of Medicine
# NCT00000125          Actual  Washington University School of Medicine
# NCT00000125          Actual  Washington University School of Medicine
# NCT00000125          Actual  Washington University School of Medicine
#
#             limitations_and_caveats  number_of_arms number_of_groups  \
# nct_id
# NCT00000125                                     2.0             None
# NCT00000125                                     2.0             None
# NCT00000125                                     2.0             None
# NCT00000125                                     2.0             None
# NCT00000125                                     2.0             None
#
#             why_stopped has_expanded_access expanded_access_type_individual  \
# nct_id
# NCT00000125        None               False                            None
# NCT00000125        None               False                            None
# NCT00000125        None               False                            None
# NCT00000125        None               False                            None
# NCT00000125        None               False                            None
#
#             expanded_access_type_intermediate expanded_access_type_treatment  \
# nct_id
# NCT00000125                              None                           None
# NCT00000125                              None                           None
# NCT00000125                              None                           None
# NCT00000125                              None                           None
# NCT00000125                              None                           None
#
#             has_dmc is_fda_regulated_drug is_fda_regulated_device  \
# nct_id
# NCT00000125    True                  None                    None
# NCT00000125    True                  None                    None
# NCT00000125    True                  None                    None
# NCT00000125    True                  None                    None
# NCT00000125    True                  None                    None
#
#             is_unapproved_device is_ppsd is_us_export biospec_retention  \
# nct_id
# NCT00000125                 None    None         None              None
# NCT00000125                 None    None         None              None
# NCT00000125                 None    None         None              None
# NCT00000125                 None    None         None              None
# NCT00000125                 None    None         None              None
#
#             biospec_description ipd_time_frame ipd_access_criteria ipd_url  \
# nct_id
# NCT00000125                               None                None    None
# NCT00000125                               None                None    None
# NCT00000125                               None                None    None
# NCT00000125                               None                None    None
# NCT00000125                               None                None    None
#
#             plan_to_share_ipd plan_to_share_ipd_description  \
# nct_id
# NCT00000125              None                          None
# NCT00000125              None                          None
# NCT00000125              None                          None
# NCT00000125              None                          None
# NCT00000125              None                          None
#
#                             created_at                 updated_at  \
# nct_id
# NCT00000125 2019-11-01 21:13:15.921729 2019-11-01 21:13:15.921729
# NCT00000125 2019-11-01 21:13:15.921729 2019-11-01 21:13:15.921729
# NCT00000125 2019-11-01 21:13:15.921729 2019-11-01 21:13:15.921729
# NCT00000125 2019-11-01 21:13:15.921729 2019-11-01 21:13:15.921729
# NCT00000125 2019-11-01 21:13:15.921729 2019-11-01 21:13:15.921729
#
#              result_group_id result_group_ctgov_group_code  \
# nct_id
# NCT00000125         16234355                            B3
# NCT00000125         16234356                            B2
# NCT00000125         16234357                            B1
# NCT00000125         16234358                            P2
# NCT00000125         16234359                            P1
#
#             result_group_result_type result_group_title  \
# nct_id
# NCT00000125                 Baseline              Total
# NCT00000125                 Baseline          Treatment
# NCT00000125                 Baseline        Observation
# NCT00000125         Participant Flow          Treatment
# NCT00000125         Participant Flow        Observation
#
#                                       result_group_description  \
# nct_id
# NCT00000125                      Total of all reporting groups
# NCT00000125  Topical Antiglaucoma Agents: Topical Antiglauc...
# NCT00000125                                   Observation only
# NCT00000125              Topical ocular hypotensive eye drops.
# NCT00000125                                  Close Observation
#
#              intervention_id intervention_intervention_type  \
# nct_id
# NCT00000125         10239365                           Drug
# NCT00000125         10239365                           Drug
# NCT00000125         10239365                           Drug
# NCT00000125         10239365                           Drug
# NCT00000125         10239365                           Drug
#
#                                  intervention_name  \
# nct_id
# NCT00000125  Topical ocular hypotensive eye drops.
# NCT00000125  Topical ocular hypotensive eye drops.
# NCT00000125  Topical ocular hypotensive eye drops.
# NCT00000125  Topical ocular hypotensive eye drops.
# NCT00000125  Topical ocular hypotensive eye drops.
#
#                           intervention_description drug_name
# nct_id
# NCT00000125  Topical ocular hypotensive eye drops.       NaN
# NCT00000125  Topical ocular hypotensive eye drops.       NaN
# NCT00000125  Topical ocular hypotensive eye drops.       NaN
# NCT00000125  Topical ocular hypotensive eye drops.       NaN
# NCT00000125  Topical ocular hypotensive eye drops.       NaN

# %%
df[df.result_group_id.notnull()].shape
# Out:
# (2647355, 73)

# %%
df.reset_index()[['nct_id', 'result_group_id', 'intervention_id']].nunique()
# Out:
# nct_id              37348
# result_group_id    964159
# intervention_id     86762
# dtype: int64

# %% [markdown]
# #### Distinct studies per drug

# %%
df.reset_index().groupby(['nct_id', 'drug_name']).agg({'intervention_id':'count'})\
    .reset_index().groupby('drug_name').agg({'nct_id':'nunique'}).sort_values(by='nct_id', ascending=False).head()
# Out:
#              nct_id
# drug_name
# midazolam        52
# trastuzumab      47
# sumatriptan      18
# ramucirumab       9
# apremilast        7

# %% [markdown]
# #### Distinct drugs per study

# %%
df.groupby(['nct_id', 'drug_name']).agg({'intervention_id':'count'})\
    .reset_index().groupby('nct_id').agg({'drug_name':'nunique'}).sort_values(by='drug_name', ascending=False).head()
# Out:
#              drug_name
# nct_id
# NCT00140140          1
# NCT00182793          1
# NCT01567163          1
# NCT01632904          1
# NCT01641939          1

# %% [markdown]
# #### Limit to only studies related to sample 2019 drugs and apply drug name to entire study

# %%
df[df.drug_name.notnull()].reset_index().groupby(['nct_id', 'drug_name']).\
    agg({'intervention_id':'count'}).reset_index()[['nct_id', 'drug_name']].set_index('nct_id').shape
# Out:
# (176, 1)

# %%
df = df.reset_index().set_index('nct_id').merge(df[df.drug_name.notnull()].reset_index().groupby(['nct_id', 'drug_name']).\
    agg({'intervention_id':'count'}).reset_index()[['nct_id', 'drug_name']].set_index('nct_id'), left_index=True,
                                          right_index=True, how='inner')

# %%
df.head()
# Out:
#                                  nlm_download_date_description  \
# nct_id
# NCT00140140  ClinicalTrials.gov processed this data on Octo...
# NCT00140140  ClinicalTrials.gov processed this data on Octo...
# NCT00140140  ClinicalTrials.gov processed this data on Octo...
# NCT00140140  ClinicalTrials.gov processed this data on Octo...
# NCT00140140  ClinicalTrials.gov processed this data on Octo...
#
#             study_first_submitted_date results_first_submitted_date  \
# nct_id
# NCT00140140                 2005-08-30                   2013-08-20
# NCT00140140                 2005-08-30                   2013-08-20
# NCT00140140                 2005-08-30                   2013-08-20
# NCT00140140                 2005-08-30                   2013-08-20
# NCT00140140                 2005-08-30                   2013-08-20
#
#             disposition_first_submitted_date last_update_submitted_date  \
# nct_id
# NCT00140140                             None                 2013-08-20
# NCT00140140                             None                 2013-08-20
# NCT00140140                             None                 2013-08-20
# NCT00140140                             None                 2013-08-20
# NCT00140140                             None                 2013-08-20
#
#             study_first_submitted_qc_date study_first_posted_date  \
# nct_id
# NCT00140140                    2005-08-30              2005-09-01
# NCT00140140                    2005-08-30              2005-09-01
# NCT00140140                    2005-08-30              2005-09-01
# NCT00140140                    2005-08-30              2005-09-01
# NCT00140140                    2005-08-30              2005-09-01
#
#             study_first_posted_date_type results_first_submitted_qc_date  \
# nct_id
# NCT00140140                     Estimate                      2013-08-20
# NCT00140140                     Estimate                      2013-08-20
# NCT00140140                     Estimate                      2013-08-20
# NCT00140140                     Estimate                      2013-08-20
# NCT00140140                     Estimate                      2013-08-20
#
#             results_first_posted_date results_first_posted_date_type  \
# nct_id
# NCT00140140                2013-10-24                       Estimate
# NCT00140140                2013-10-24                       Estimate
# NCT00140140                2013-10-24                       Estimate
# NCT00140140                2013-10-24                       Estimate
# NCT00140140                2013-10-24                       Estimate
#
#             disposition_first_submitted_qc_date disposition_first_posted_date  \
# nct_id
# NCT00140140                                None                          None
# NCT00140140                                None                          None
# NCT00140140                                None                          None
# NCT00140140                                None                          None
# NCT00140140                                None                          None
#
#             disposition_first_posted_date_type last_update_submitted_qc_date  \
# nct_id
# NCT00140140                               None                    2013-08-20
# NCT00140140                               None                    2013-08-20
# NCT00140140                               None                    2013-08-20
# NCT00140140                               None                    2013-08-20
# NCT00140140                               None                    2013-08-20
#
#             last_update_posted_date last_update_posted_date_type  \
# nct_id
# NCT00140140              2013-10-24                     Estimate
# NCT00140140              2013-10-24                     Estimate
# NCT00140140              2013-10-24                     Estimate
# NCT00140140              2013-10-24                     Estimate
# NCT00140140              2013-10-24                     Estimate
#
#             start_month_year start_date_type  start_date  \
# nct_id
# NCT00140140      August 2005            None  2005-08-31
# NCT00140140      August 2005            None  2005-08-31
# NCT00140140      August 2005            None  2005-08-31
# NCT00140140      August 2005            None  2005-08-31
# NCT00140140      August 2005            None  2005-08-31
#
#             verification_month_year verification_date completion_month_year  \
# nct_id
# NCT00140140             August 2013        2013-08-31         February 2008
# NCT00140140             August 2013        2013-08-31         February 2008
# NCT00140140             August 2013        2013-08-31         February 2008
# NCT00140140             August 2013        2013-08-31         February 2008
# NCT00140140             August 2013        2013-08-31         February 2008
#
#             completion_date_type completion_date  \
# nct_id
# NCT00140140               Actual      2008-02-29
# NCT00140140               Actual      2008-02-29
# NCT00140140               Actual      2008-02-29
# NCT00140140               Actual      2008-02-29
# NCT00140140               Actual      2008-02-29
#
#             primary_completion_month_year primary_completion_date_type  \
# nct_id
# NCT00140140                 February 2008                       Actual
# NCT00140140                 February 2008                       Actual
# NCT00140140                 February 2008                       Actual
# NCT00140140                 February 2008                       Actual
# NCT00140140                 February 2008                       Actual
#
#             primary_completion_date target_duration      study_type acronym  \
# nct_id
# NCT00140140              2008-02-29            None  Interventional    None
# NCT00140140              2008-02-29            None  Interventional    None
# NCT00140140              2008-02-29            None  Interventional    None
# NCT00140140              2008-02-29            None  Interventional    None
# NCT00140140              2008-02-29            None  Interventional    None
#
#             baseline_population  \
# nct_id
# NCT00140140
# NCT00140140
# NCT00140140
# NCT00140140
# NCT00140140
#
#                                                    brief_title  \
# nct_id
# NCT00140140  A Phase I/II Study of ABI-007 (Abraxane®, Nab®...
# NCT00140140  A Phase I/II Study of ABI-007 (Abraxane®, Nab®...
# NCT00140140  A Phase I/II Study of ABI-007 (Abraxane®, Nab®...
# NCT00140140  A Phase I/II Study of ABI-007 (Abraxane®, Nab®...
# NCT00140140  A Phase I/II Study of ABI-007 (Abraxane®, Nab®...
#
#                                                 official_title overall_status  \
# nct_id
# NCT00140140  An Open-Label Phase I/II Study of Weekly ABI-0...     Terminated
# NCT00140140  An Open-Label Phase I/II Study of Weekly ABI-0...     Terminated
# NCT00140140  An Open-Label Phase I/II Study of Weekly ABI-0...     Terminated
# NCT00140140  An Open-Label Phase I/II Study of Weekly ABI-0...     Terminated
# NCT00140140  An Open-Label Phase I/II Study of Weekly ABI-0...     Terminated
#
#             last_known_status            phase  enrollment enrollment_type  \
# nct_id
# NCT00140140              None  Phase 1/Phase 2        16.0          Actual
# NCT00140140              None  Phase 1/Phase 2        16.0          Actual
# NCT00140140              None  Phase 1/Phase 2        16.0          Actual
# NCT00140140              None  Phase 1/Phase 2        16.0          Actual
# NCT00140140              None  Phase 1/Phase 2        16.0          Actual
#
#               source limitations_and_caveats  number_of_arms number_of_groups  \
# nct_id
# NCT00140140  Celgene                                     3.0             None
# NCT00140140  Celgene                                     3.0             None
# NCT00140140  Celgene                                     3.0             None
# NCT00140140  Celgene                                     3.0             None
# NCT00140140  Celgene                                     3.0             None
#
#                                                 why_stopped  \
# nct_id
# NCT00140140  Unable to determine the optimum tolerated dose
# NCT00140140  Unable to determine the optimum tolerated dose
# NCT00140140  Unable to determine the optimum tolerated dose
# NCT00140140  Unable to determine the optimum tolerated dose
# NCT00140140  Unable to determine the optimum tolerated dose
#
#             has_expanded_access expanded_access_type_individual  \
# nct_id
# NCT00140140               False                            None
# NCT00140140               False                            None
# NCT00140140               False                            None
# NCT00140140               False                            None
# NCT00140140               False                            None
#
#             expanded_access_type_intermediate expanded_access_type_treatment  \
# nct_id
# NCT00140140                              None                           None
# NCT00140140                              None                           None
# NCT00140140                              None                           None
# NCT00140140                              None                           None
# NCT00140140                              None                           None
#
#             has_dmc is_fda_regulated_drug is_fda_regulated_device  \
# nct_id
# NCT00140140   False                  None                    None
# NCT00140140   False                  None                    None
# NCT00140140   False                  None                    None
# NCT00140140   False                  None                    None
# NCT00140140   False                  None                    None
#
#             is_unapproved_device is_ppsd is_us_export biospec_retention  \
# nct_id
# NCT00140140                 None    None         None              None
# NCT00140140                 None    None         None              None
# NCT00140140                 None    None         None              None
# NCT00140140                 None    None         None              None
# NCT00140140                 None    None         None              None
#
#             biospec_description ipd_time_frame ipd_access_criteria ipd_url  \
# nct_id
# NCT00140140                               None                None    None
# NCT00140140                               None                None    None
# NCT00140140                               None                None    None
# NCT00140140                               None                None    None
# NCT00140140                               None                None    None
#
#             plan_to_share_ipd plan_to_share_ipd_description  \
# nct_id
# NCT00140140              None                          None
# NCT00140140              None                          None
# NCT00140140              None                          None
# NCT00140140              None                          None
# NCT00140140              None                          None
#
#                             created_at                 updated_at  \
# nct_id
# NCT00140140 2019-11-01 20:28:32.458523 2019-11-01 20:28:32.458523
# NCT00140140 2019-11-01 20:28:32.458523 2019-11-01 20:28:32.458523
# NCT00140140 2019-11-01 20:28:32.458523 2019-11-01 20:28:32.458523
# NCT00140140 2019-11-01 20:28:32.458523 2019-11-01 20:28:32.458523
# NCT00140140 2019-11-01 20:28:32.458523 2019-11-01 20:28:32.458523
#
#              result_group_id result_group_ctgov_group_code  \
# nct_id
# NCT00140140         16200343                            B4
# NCT00140140         16200343                            B4
# NCT00140140         16200343                            B4
# NCT00140140         16200343                            B4
# NCT00140140         16200344                            B3
#
#             result_group_result_type  \
# nct_id
# NCT00140140                 Baseline
# NCT00140140                 Baseline
# NCT00140140                 Baseline
# NCT00140140                 Baseline
# NCT00140140                 Baseline
#
#                                     result_group_title  \
# nct_id
# NCT00140140                                      Total
# NCT00140140                                      Total
# NCT00140140                                      Total
# NCT00140140                                      Total
# NCT00140140  Part 2: 90 mg ABI-007 + 20 mg Vinorelbine
#
#                                       result_group_description  \
# nct_id
# NCT00140140                      Total of all reporting groups
# NCT00140140                      Total of all reporting groups
# NCT00140140                      Total of all reporting groups
# NCT00140140                      Total of all reporting groups
# NCT00140140  Weekly intravenous infusion of 90 mg/m^2 ABI-0...
#
#              intervention_id intervention_intervention_type intervention_name  \
# nct_id
# NCT00140140         10209955                           Drug           ABI-007
# NCT00140140         10209956                           Drug       vinorelbine
# NCT00140140         10209957                           Drug       Trastuzumab
# NCT00140140         10209958                     Biological             G-CSF
# NCT00140140         10209955                           Drug           ABI-007
#
#                                       intervention_description  drug_name_x  \
# nct_id
# NCT00140140      Weekly intravenous infusions over 30 minutes.          NaN
# NCT00140140  Weekly intravenous infusions over 10-30 minute...          NaN
# NCT00140140  Trastuzumab was administered to participants w...  trastuzumab
# NCT00140140  During Part 1, participants followed a dosing ...          NaN
# NCT00140140      Weekly intravenous infusions over 30 minutes.          NaN
#
#              drug_name_y
# nct_id
# NCT00140140  trastuzumab
# NCT00140140  trastuzumab
# NCT00140140  trastuzumab
# NCT00140140  trastuzumab
# NCT00140140  trastuzumab

# %%
df.reset_index()[['nct_id']].nunique()
# Out:
# nct_id    176
# dtype: int64

# %%
df.shape
# Out:
# (17383, 74)

# %% [markdown]
# #### Outcome analysis groups
#
# Identifies the comparison groups that were involved with each outcome analysis

# %%
outcome_analysis_groups = ss.dimensions['outcome_analysis_groups'].data.add_prefix(
    'outcome_analysis_group_')

outcome_analysis_groups.head()
# Out:
#                                                  outcome_analysis_group_id  \
# nct_id      result_group_id outcome_analysis_id
# NCT00000378 16234181        2700782                                5224736
#             16234182        2700782                                5224737
# NCT00000392 16233928        2700769                                5224710
#             16233929        2700769                                5224711
# NCT00000620 16234205        2700783                                5224738
#
#                                                 outcome_analysis_group_ctgov_group_code
# nct_id      result_group_id outcome_analysis_id
# NCT00000378 16234181        2700782                                                  O2
#             16234182        2700782                                                  O1
# NCT00000392 16233928        2700769                                                  O2
#             16233929        2700769                                                  O1
# NCT00000620 16234205        2700783                                                  O2

# %%
df = df[df.result_group_id.notnull()].reset_index().set_index(['nct_id', 'result_group_id']).merge(
    outcome_analysis_groups.reset_index().set_index(['nct_id', 'result_group_id']),
    left_index=True, right_index=True, how='left')
df.shape
# Out:
# (18358, 76)

# %%
df.reset_index()[['nct_id', 'result_group_id', 'intervention_id', 'outcome_analysis_group_id']].nunique()
# Out:
# nct_id                        176
# result_group_id              5305
# intervention_id               504
# outcome_analysis_group_id     961
# dtype: int64

# %% [markdown]
# #### Outcome analyses
#
# Results of scientifically appropriate statistical analyses performed on primary and
# secondary study outcomes. Includes results for treatment effect estimates,
# confidence intervals and othe rmeasures of dispersion, and p-values.

# %%
outcome_analyses = ss.dimensions['outcome_analyses'].data.add_prefix('outcome_analysis_')
outcome_analyses.head()
# Out:
#                         outcome_analysis_id  \
# nct_id      outcome_id
# NCT00000378 4909014                 2700782
# NCT00000392 4908952                 2700769
# NCT00000620 4909016                 2700783
#             4909017                 2700784
#             4909018                 2700785
#
#                        outcome_analysis_non_inferiority_type  \
# nct_id      outcome_id
# NCT00000378 4909014                     Superiority or Other
# NCT00000392 4908952                     Superiority or Other
# NCT00000620 4909016                     Superiority or Other
#             4909017                     Superiority or Other
#             4909018                     Superiority or Other
#
#                        outcome_analysis_non_inferiority_description  \
# nct_id      outcome_id
# NCT00000378 4909014
# NCT00000392 4908952
# NCT00000620 4909016
#             4909017
#             4909018
#
#                        outcome_analysis_param_type  \
# nct_id      outcome_id
# NCT00000378 4909014
# NCT00000392 4908952
# NCT00000620 4909016              Hazard Ratio (HR)
#             4909017              Hazard Ratio (HR)
#             4909018              Hazard Ratio (HR)
#
#                         outcome_analysis_param_value  \
# nct_id      outcome_id
# NCT00000378 4909014                              NaN
# NCT00000392 4908952                              NaN
# NCT00000620 4909016                             0.94
#             4909017                             0.92
#             4909018                             0.59
#
#                        outcome_analysis_dispersion_type  \
# nct_id      outcome_id
# NCT00000378 4909014
# NCT00000392 4908952
# NCT00000620 4909016
#             4909017
#             4909018
#
#                         outcome_analysis_dispersion_value  \
# nct_id      outcome_id
# NCT00000378 4909014                                   NaN
# NCT00000392 4908952                                   NaN
# NCT00000620 4909016                                   NaN
#             4909017                                   NaN
#             4909018                                   NaN
#
#                        outcome_analysis_p_value_modifier  \
# nct_id      outcome_id
# NCT00000378 4909014                                    <
# NCT00000392 4908952                                 None
# NCT00000620 4909016                                 None
#             4909017                                 None
#             4909018                                 None
#
#                         outcome_analysis_p_value outcome_analysis_ci_n_sides  \
# nct_id      outcome_id
# NCT00000378 4909014                         0.05
# NCT00000392 4908952                         0.18
# NCT00000620 4909016                         0.30                     2-Sided
#             4909017                         0.32                     2-Sided
#             4909018                         0.01                     2-Sided
#
#                         outcome_analysis_ci_percent  \
# nct_id      outcome_id
# NCT00000378 4909014                             NaN
# NCT00000392 4908952                             NaN
# NCT00000620 4909016                            95.0
#             4909017                            95.0
#             4909018                            95.0
#
#                         outcome_analysis_ci_lower_limit  \
# nct_id      outcome_id
# NCT00000378 4909014                                 NaN
# NCT00000392 4908952                                 NaN
# NCT00000620 4909016                                0.85
#             4909017                                0.79
#             4909018                                0.39
#
#                         outcome_analysis_ci_upper_limit  \
# nct_id      outcome_id
# NCT00000378 4909014                                 NaN
# NCT00000392 4908952                                 NaN
# NCT00000620 4909016                                1.05
#             4909017                                1.08
#             4909018                                0.89
#
#                        outcome_analysis_ci_upper_limit_na_comment  \
# nct_id      outcome_id
# NCT00000378 4909014
# NCT00000392 4908952
# NCT00000620 4909016
#             4909017
#             4909018
#
#                                      outcome_analysis_p_value_description  \
# nct_id      outcome_id
# NCT00000378 4909014                                    actual calculation
# NCT00000392 4908952
# NCT00000620 4909016     P-value presented is not adjusted for multiple...
#             4909017     P-value is adjusted for interim monitoring. A ...
#             4909018     P-value presented is not adjusted for multiple...
#
#                        outcome_analysis_method  \
# nct_id      outcome_id
# NCT00000378 4909014       Regression, Logistic
# NCT00000392 4908952                      ANOVA
# NCT00000620 4909016            Regression, Cox
#             4909017            Regression, Cox
#             4909018            Regression, Cox
#
#                                       outcome_analysis_method_description  \
# nct_id      outcome_id
# NCT00000378 4909014
# NCT00000392 4908952
# NCT00000620 4909016     Adjustment for the seven clinical center netwo...
#             4909017     Adjustment for the seven clinical center netwo...
#             4909018     Adjustment for the seven clinical center netwo...
#
#                        outcome_analysis_estimate_description  \
# nct_id      outcome_id
# NCT00000378 4909014
# NCT00000392 4908952
# NCT00000620 4909016
#             4909017
#             4909018
#
#                                       outcome_analysis_groups_description  \
# nct_id      outcome_id
# NCT00000378 4909014           logistic regression and mixed effects model
# NCT00000392 4908952
# NCT00000620 4909016
#             4909017     Recruitment for the Glycemia Trial was designe...
#             4909018
#
#                        outcome_analysis_other_analysis_description
# nct_id      outcome_id
# NCT00000378 4909014
# NCT00000392 4908952
# NCT00000620 4909016
#             4909017
#             4909018

# %%
df = df.reset_index().set_index(['nct_id', 'outcome_analysis_id']).merge(
    outcome_analyses.reset_index().set_index(['nct_id', 'outcome_analysis_id']),
    left_index=True, right_index=True, how='left')
df.shape
# Out:
# (18358, 96)

# %%
df.reset_index()[['nct_id', 'result_group_id', 'intervention_id', 'outcome_analysis_group_id', 'outcome_analysis_id']].nunique()
# Out:
# nct_id                        176
# result_group_id              5305
# intervention_id               504
# outcome_analysis_group_id     961
# outcome_analysis_id           468
# dtype: int64

# %% [markdown]
# #### Outcomes
#
# Descriptions of outcomes, or observation that were measured to determine patterns
# of diseases or traits, or associations with exposures, risk factors, or treatment.
# Includes information such as time frame, population and units.
# (Specific measurement results are stored in the Outcome_Measurements table.)

# %%
outcomes = ss.dimensions['outcomes'].data.add_prefix('outcome_')
outcomes.head()
# Out:
#              outcome_id outcome_outcome_type  \
# nct_id
# NCT00000125     4909043              Primary
# NCT00000134     4909042              Primary
# NCT00000135     4909041              Primary
# NCT00000136     4909040              Primary
# NCT00000142     4909039              Primary
#
#                                                  outcome_title  \
# nct_id
# NCT00000125  Incidence of Primary Open-Angle Glaucoma in Hy...
# NCT00000134                                          Morbidity
# NCT00000135                                     Mortality Rate
# NCT00000136                                          Mortality
# NCT00000142                                           Survival
#
#                                            outcome_description  \
# nct_id
# NCT00000125  Comparison of the cumulative proportion of par...
# NCT00000134  To determine the best therapeutic regimen, usi...
# NCT00000135  to evaluate the efficacy of an intravenous hum...
# NCT00000136
# NCT00000142
#
#                                             outcome_time_frame  \
# nct_id
# NCT00000125  5 yrs (OHTS I, June 2002) and 13.0 yrs (comple...
# NCT00000134  Patients will be seen at baseline, monthly for...
# NCT00000135  All patients enrolled were followed for a 17 m...
# NCT00000136  All patients enrolled will be followed until a...
# NCT00000142  All patients enrolled will be followed until a...
#
#                                             outcome_population  \
# nct_id
# NCT00000125  1636 ocular hypertensive participants were ran...
# NCT00000134
# NCT00000135
# NCT00000136
# NCT00000142
#
#             outcome_anticipated_posting_date  \
# nct_id
# NCT00000125                             None
# NCT00000134                             None
# NCT00000135                             None
# NCT00000136                             None
# NCT00000142                             None
#
#             outcome_anticipated_posting_month_year            outcome_units  \
# nct_id
# NCT00000125                                         percent of participants
# NCT00000134                                                    participants
# NCT00000135                                          deaths per person-year
# NCT00000136                                                    participants
# NCT00000142                                                    participants
#
#             outcome_units_analyzed outcome_dispersion_type outcome_param_type
# nct_id
# NCT00000125                                                            Number
# NCT00000134                                                            Number
# NCT00000135                                                            Number
# NCT00000136                                                            Number
# NCT00000142                                                            Number

# %%
df = df.reset_index().set_index(['nct_id', 'outcome_id']).merge(
    outcomes.reset_index().set_index(['nct_id', 'outcome_id']), left_index=True, right_index=True, how='left')

df.shape
# Out:
# (18358, 107)

# %%
df.reset_index()[['nct_id', 'result_group_id', 'intervention_id', 'outcome_analysis_group_id', \
                  'outcome_analysis_id', 'outcome_id']].nunique()
# Out:
# nct_id                        176
# result_group_id              5305
# intervention_id               504
# outcome_analysis_group_id     961
# outcome_analysis_id           468
# outcome_id                    287
# dtype: int64

# %% [markdown]
# #### Outcome counts
#
# Sample size included in analysis for each outcome for each study group;
# usually participants but can represent other units of measure such as eyes 'lesions', etc.

# %%
outcome_counts = ss.dimensions['outcome_counts'].data.add_prefix('outcome_count_')
outcome_counts.head()
# Out:
#                                         outcome_count_id  \
# nct_id      result_group_id outcome_id
# NCT00000125 16234360        4909043             11576970
#             16234361        4909043             11576971
# NCT00000134 16234349        4909042             11576967
#             16234350        4909042             11576968
#             16234351        4909042             11576969
#
#                                        outcome_count_ctgov_group_code  \
# nct_id      result_group_id outcome_id
# NCT00000125 16234360        4909043                                O2
#             16234361        4909043                                O1
# NCT00000134 16234349        4909042                                O3
#             16234350        4909042                                O2
#             16234351        4909042                                O1
#
#                                        outcome_count_scope  \
# nct_id      result_group_id outcome_id
# NCT00000125 16234360        4909043                Measure
#             16234361        4909043                Measure
# NCT00000134 16234349        4909042                Measure
#             16234350        4909042                Measure
#             16234351        4909042                Measure
#
#                                        outcome_count_units  \
# nct_id      result_group_id outcome_id
# NCT00000125 16234360        4909043           Participants
#             16234361        4909043           Participants
# NCT00000134 16234349        4909042           Participants
#             16234350        4909042           Participants
#             16234351        4909042           Participants
#
#                                         outcome_count_count
# nct_id      result_group_id outcome_id
# NCT00000125 16234360        4909043                     817
#             16234361        4909043                     819
# NCT00000134 16234349        4909042                      93
#             16234350        4909042                      93
#             16234351        4909042                      88

# %%
df = df.reset_index().set_index(['nct_id', 'result_group_id', 'outcome_id']).merge(
    outcome_counts, left_index=True, right_index=True, how='left')

df.shape
# Out:
# (18370, 111)

# %%
df.reset_index()[['nct_id', 'result_group_id', 'intervention_id', 'outcome_analysis_group_id', 
                  'outcome_id', 'outcome_count_id']].nunique()
# Out:
# nct_id                        176
# result_group_id              5305
# intervention_id               504
# outcome_analysis_group_id     961
# outcome_id                    287
# outcome_count_id              678
# dtype: int64

# %% [markdown]
# #### Outcome measurements
#
# Summary data for primary and secondary outcome measures for each study group.
# Includes parameter estimates and measures of dispersion/precision.

# %%
outcome_measurements = ss.dimensions['outcome_measurements'].data.add_prefix('outcome_measurement_')
outcome_measurements.head()
# Out:
#                                         outcome_measurement_id  \
# nct_id      result_group_id outcome_id
# NCT00000125 16234360        4909043                   36764756
#                             4909043                   36764758
#             16234361        4909043                   36764757
#                             4909043                   36764759
# NCT00000134 16234349        4909042                   36764753
#
#                                        outcome_measurement_ctgov_group_code  \
# nct_id      result_group_id outcome_id
# NCT00000125 16234360        4909043                                      O2
#                             4909043                                      O2
#             16234361        4909043                                      O1
#                             4909043                                      O1
# NCT00000134 16234349        4909042                                      O3
#
#                                                        outcome_measurement_classification  \
# nct_id      result_group_id outcome_id
# NCT00000125 16234360        4909043     Incidence of glaucoma 13 yr (OHTS II, March 2009)
#                             4909043     Incidence of glaucoma at 5 yr (OHTS I, June 2002)
#             16234361        4909043     Incidence of glaucoma 13 yr (OHTS II, March 2009)
#                             4909043     Incidence of glaucoma at 5 yr (OHTS I, June 2002)
# NCT00000134 16234349        4909042
#
#                                        outcome_measurement_category  \
# nct_id      result_group_id outcome_id
# NCT00000125 16234360        4909043
#                             4909043
#             16234361        4909043
#                             4909043
# NCT00000134 16234349        4909042
#
#                                                                 outcome_measurement_title  \
# nct_id      result_group_id outcome_id
# NCT00000125 16234360        4909043     Incidence of Primary Open-Angle Glaucoma in Hy...
#                             4909043     Incidence of Primary Open-Angle Glaucoma in Hy...
#             16234361        4909043     Incidence of Primary Open-Angle Glaucoma in Hy...
#                             4909043     Incidence of Primary Open-Angle Glaucoma in Hy...
# NCT00000134 16234349        4909042                                             Morbidity
#
#                                                           outcome_measurement_description  \
# nct_id      result_group_id outcome_id
# NCT00000125 16234360        4909043     Comparison of the cumulative proportion of par...
#                             4909043     Comparison of the cumulative proportion of par...
#             16234361        4909043     Comparison of the cumulative proportion of par...
#                             4909043     Comparison of the cumulative proportion of par...
# NCT00000134 16234349        4909042     To determine the best therapeutic regimen, usi...
#
#                                        outcome_measurement_units  \
# nct_id      result_group_id outcome_id
# NCT00000125 16234360        4909043      percent of participants
#                             4909043      percent of participants
#             16234361        4909043      percent of participants
#                             4909043      percent of participants
# NCT00000134 16234349        4909042                 participants
#
#                                        outcome_measurement_param_type  \
# nct_id      result_group_id outcome_id
# NCT00000125 16234360        4909043                            Number
#                             4909043                            Number
#             16234361        4909043                            Number
#                             4909043                            Number
# NCT00000134 16234349        4909042                            Number
#
#                                        outcome_measurement_param_value  \
# nct_id      result_group_id outcome_id
# NCT00000125 16234360        4909043                               14.1
#                             4909043                                4.4
#             16234361        4909043                               20.0
#                             4909043                                9.5
# NCT00000134 16234349        4909042                                 93
#
#                                         outcome_measurement_param_value_num  \
# nct_id      result_group_id outcome_id
# NCT00000125 16234360        4909043                                    14.1
#                             4909043                                     4.4
#             16234361        4909043                                    20.0
#                             4909043                                     9.5
# NCT00000134 16234349        4909042                                    93.0
#
#                                        outcome_measurement_dispersion_type  \
# nct_id      result_group_id outcome_id
# NCT00000125 16234360        4909043
#                             4909043
#             16234361        4909043
#                             4909043
# NCT00000134 16234349        4909042
#
#                                        outcome_measurement_dispersion_value  \
# nct_id      result_group_id outcome_id
# NCT00000125 16234360        4909043                                    None
#                             4909043                                    None
#             16234361        4909043                                    None
#                             4909043                                    None
# NCT00000134 16234349        4909042                                    None
#
#                                         outcome_measurement_dispersion_value_num  \
# nct_id      result_group_id outcome_id
# NCT00000125 16234360        4909043                                          NaN
#                             4909043                                          NaN
#             16234361        4909043                                          NaN
#                             4909043                                          NaN
# NCT00000134 16234349        4909042                                          NaN
#
#                                         outcome_measurement_dispersion_lower_limit  \
# nct_id      result_group_id outcome_id
# NCT00000125 16234360        4909043                                            NaN
#                             4909043                                            NaN
#             16234361        4909043                                            NaN
#                             4909043                                            NaN
# NCT00000134 16234349        4909042                                            NaN
#
#                                         outcome_measurement_dispersion_upper_limit  \
# nct_id      result_group_id outcome_id
# NCT00000125 16234360        4909043                                            NaN
#                             4909043                                            NaN
#             16234361        4909043                                            NaN
#                             4909043                                            NaN
# NCT00000134 16234349        4909042                                            NaN
#
#                                        outcome_measurement_explanation_of_na
# nct_id      result_group_id outcome_id
# NCT00000125 16234360        4909043
#                             4909043
#             16234361        4909043
#                             4909043
# NCT00000134 16234349        4909042

# %%
df = df.merge(outcome_measurements, left_index=True, right_index=True, how='left')
df.shape
# Out:
# (19871, 127)

# %%
df.reset_index()[['nct_id','result_group_id', 'outcome_analysis_group_id', 'outcome_id', 'intervention_id', \
                  'outcome_count_id', 'outcome_measurement_id']].nunique()
# Out:
# nct_id                        176
# result_group_id              5305
# outcome_analysis_group_id     961
# outcome_id                    287
# intervention_id               504
# outcome_count_id              678
# outcome_measurement_id        907
# dtype: int64

# %%
df.reset_index().head()
# Out:
#         nct_id  result_group_id  outcome_id  outcome_analysis_id  \
# 0  NCT00140140         16200343         NaN                  NaN
# 1  NCT00140140         16200343         NaN                  NaN
# 2  NCT00140140         16200343         NaN                  NaN
# 3  NCT00140140         16200343         NaN                  NaN
# 4  NCT00140140         16200344         NaN                  NaN
#
#                        nlm_download_date_description  \
# 0  ClinicalTrials.gov processed this data on Octo...
# 1  ClinicalTrials.gov processed this data on Octo...
# 2  ClinicalTrials.gov processed this data on Octo...
# 3  ClinicalTrials.gov processed this data on Octo...
# 4  ClinicalTrials.gov processed this data on Octo...
#
#   study_first_submitted_date results_first_submitted_date  \
# 0                 2005-08-30                   2013-08-20
# 1                 2005-08-30                   2013-08-20
# 2                 2005-08-30                   2013-08-20
# 3                 2005-08-30                   2013-08-20
# 4                 2005-08-30                   2013-08-20
#
#   disposition_first_submitted_date last_update_submitted_date  \
# 0                             None                 2013-08-20
# 1                             None                 2013-08-20
# 2                             None                 2013-08-20
# 3                             None                 2013-08-20
# 4                             None                 2013-08-20
#
#   study_first_submitted_qc_date study_first_posted_date  \
# 0                    2005-08-30              2005-09-01
# 1                    2005-08-30              2005-09-01
# 2                    2005-08-30              2005-09-01
# 3                    2005-08-30              2005-09-01
# 4                    2005-08-30              2005-09-01
#
#   study_first_posted_date_type results_first_submitted_qc_date  \
# 0                     Estimate                      2013-08-20
# 1                     Estimate                      2013-08-20
# 2                     Estimate                      2013-08-20
# 3                     Estimate                      2013-08-20
# 4                     Estimate                      2013-08-20
#
#   results_first_posted_date results_first_posted_date_type  \
# 0                2013-10-24                       Estimate
# 1                2013-10-24                       Estimate
# 2                2013-10-24                       Estimate
# 3                2013-10-24                       Estimate
# 4                2013-10-24                       Estimate
#
#   disposition_first_submitted_qc_date disposition_first_posted_date  \
# 0                                None                          None
# 1                                None                          None
# 2                                None                          None
# 3                                None                          None
# 4                                None                          None
#
#   disposition_first_posted_date_type last_update_submitted_qc_date  \
# 0                               None                    2013-08-20
# 1                               None                    2013-08-20
# 2                               None                    2013-08-20
# 3                               None                    2013-08-20
# 4                               None                    2013-08-20
#
#   last_update_posted_date last_update_posted_date_type start_month_year  \
# 0              2013-10-24                     Estimate      August 2005
# 1              2013-10-24                     Estimate      August 2005
# 2              2013-10-24                     Estimate      August 2005
# 3              2013-10-24                     Estimate      August 2005
# 4              2013-10-24                     Estimate      August 2005
#
#   start_date_type  start_date verification_month_year verification_date  \
# 0            None  2005-08-31             August 2013        2013-08-31
# 1            None  2005-08-31             August 2013        2013-08-31
# 2            None  2005-08-31             August 2013        2013-08-31
# 3            None  2005-08-31             August 2013        2013-08-31
# 4            None  2005-08-31             August 2013        2013-08-31
#
#   completion_month_year completion_date_type completion_date  \
# 0         February 2008               Actual      2008-02-29
# 1         February 2008               Actual      2008-02-29
# 2         February 2008               Actual      2008-02-29
# 3         February 2008               Actual      2008-02-29
# 4         February 2008               Actual      2008-02-29
#
#   primary_completion_month_year primary_completion_date_type  \
# 0                 February 2008                       Actual
# 1                 February 2008                       Actual
# 2                 February 2008                       Actual
# 3                 February 2008                       Actual
# 4                 February 2008                       Actual
#
#   primary_completion_date target_duration      study_type acronym  \
# 0              2008-02-29            None  Interventional    None
# 1              2008-02-29            None  Interventional    None
# 2              2008-02-29            None  Interventional    None
# 3              2008-02-29            None  Interventional    None
# 4              2008-02-29            None  Interventional    None
#
#   baseline_population                                        brief_title  \
# 0                      A Phase I/II Study of ABI-007 (Abraxane®, Nab®...
# 1                      A Phase I/II Study of ABI-007 (Abraxane®, Nab®...
# 2                      A Phase I/II Study of ABI-007 (Abraxane®, Nab®...
# 3                      A Phase I/II Study of ABI-007 (Abraxane®, Nab®...
# 4                      A Phase I/II Study of ABI-007 (Abraxane®, Nab®...
#
#                                       official_title overall_status  \
# 0  An Open-Label Phase I/II Study of Weekly ABI-0...     Terminated
# 1  An Open-Label Phase I/II Study of Weekly ABI-0...     Terminated
# 2  An Open-Label Phase I/II Study of Weekly ABI-0...     Terminated
# 3  An Open-Label Phase I/II Study of Weekly ABI-0...     Terminated
# 4  An Open-Label Phase I/II Study of Weekly ABI-0...     Terminated
#
#   last_known_status            phase  enrollment enrollment_type   source  \
# 0              None  Phase 1/Phase 2        16.0          Actual  Celgene
# 1              None  Phase 1/Phase 2        16.0          Actual  Celgene
# 2              None  Phase 1/Phase 2        16.0          Actual  Celgene
# 3              None  Phase 1/Phase 2        16.0          Actual  Celgene
# 4              None  Phase 1/Phase 2        16.0          Actual  Celgene
#
#   limitations_and_caveats  number_of_arms number_of_groups  \
# 0                                     3.0             None
# 1                                     3.0             None
# 2                                     3.0             None
# 3                                     3.0             None
# 4                                     3.0             None
#
#                                       why_stopped has_expanded_access  \
# 0  Unable to determine the optimum tolerated dose               False
# 1  Unable to determine the optimum tolerated dose               False
# 2  Unable to determine the optimum tolerated dose               False
# 3  Unable to determine the optimum tolerated dose               False
# 4  Unable to determine the optimum tolerated dose               False
#
#   expanded_access_type_individual expanded_access_type_intermediate  \
# 0                            None                              None
# 1                            None                              None
# 2                            None                              None
# 3                            None                              None
# 4                            None                              None
#
#   expanded_access_type_treatment has_dmc is_fda_regulated_drug  \
# 0                           None   False                  None
# 1                           None   False                  None
# 2                           None   False                  None
# 3                           None   False                  None
# 4                           None   False                  None
#
#   is_fda_regulated_device is_unapproved_device is_ppsd is_us_export  \
# 0                    None                 None    None         None
# 1                    None                 None    None         None
# 2                    None                 None    None         None
# 3                    None                 None    None         None
# 4                    None                 None    None         None
#
#   biospec_retention biospec_description ipd_time_frame ipd_access_criteria  \
# 0              None                               None                None
# 1              None                               None                None
# 2              None                               None                None
# 3              None                               None                None
# 4              None                               None                None
#
#   ipd_url plan_to_share_ipd plan_to_share_ipd_description  \
# 0    None              None                          None
# 1    None              None                          None
# 2    None              None                          None
# 3    None              None                          None
# 4    None              None                          None
#
#                   created_at                 updated_at  \
# 0 2019-11-01 20:28:32.458523 2019-11-01 20:28:32.458523
# 1 2019-11-01 20:28:32.458523 2019-11-01 20:28:32.458523
# 2 2019-11-01 20:28:32.458523 2019-11-01 20:28:32.458523
# 3 2019-11-01 20:28:32.458523 2019-11-01 20:28:32.458523
# 4 2019-11-01 20:28:32.458523 2019-11-01 20:28:32.458523
#
#   result_group_ctgov_group_code result_group_result_type  \
# 0                            B4                 Baseline
# 1                            B4                 Baseline
# 2                            B4                 Baseline
# 3                            B4                 Baseline
# 4                            B3                 Baseline
#
#                           result_group_title  \
# 0                                      Total
# 1                                      Total
# 2                                      Total
# 3                                      Total
# 4  Part 2: 90 mg ABI-007 + 20 mg Vinorelbine
#
#                             result_group_description  intervention_id  \
# 0                      Total of all reporting groups         10209958
# 1                      Total of all reporting groups         10209957
# 2                      Total of all reporting groups         10209955
# 3                      Total of all reporting groups         10209956
# 4  Weekly intravenous infusion of 90 mg/m^2 ABI-0...         10209957
#
#   intervention_intervention_type intervention_name  \
# 0                     Biological             G-CSF
# 1                           Drug       Trastuzumab
# 2                           Drug           ABI-007
# 3                           Drug       vinorelbine
# 4                           Drug       Trastuzumab
#
#                             intervention_description  drug_name_x  \
# 0  During Part 1, participants followed a dosing ...          NaN
# 1  Trastuzumab was administered to participants w...  trastuzumab
# 2      Weekly intravenous infusions over 30 minutes.          NaN
# 3  Weekly intravenous infusions over 10-30 minute...          NaN
# 4  Trastuzumab was administered to participants w...  trastuzumab
#
#    drug_name_y  outcome_analysis_group_id  \
# 0  trastuzumab                        NaN
# 1  trastuzumab                        NaN
# 2  trastuzumab                        NaN
# 3  trastuzumab                        NaN
# 4  trastuzumab                        NaN
#
#   outcome_analysis_group_ctgov_group_code  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   outcome_analysis_non_inferiority_type  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   outcome_analysis_non_inferiority_description outcome_analysis_param_type  \
# 0                                          NaN                         NaN
# 1                                          NaN                         NaN
# 2                                          NaN                         NaN
# 3                                          NaN                         NaN
# 4                                          NaN                         NaN
#
#    outcome_analysis_param_value outcome_analysis_dispersion_type  \
# 0                           NaN                              NaN
# 1                           NaN                              NaN
# 2                           NaN                              NaN
# 3                           NaN                              NaN
# 4                           NaN                              NaN
#
#    outcome_analysis_dispersion_value outcome_analysis_p_value_modifier  \
# 0                                NaN                               NaN
# 1                                NaN                               NaN
# 2                                NaN                               NaN
# 3                                NaN                               NaN
# 4                                NaN                               NaN
#
#    outcome_analysis_p_value outcome_analysis_ci_n_sides  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
#
#    outcome_analysis_ci_percent  outcome_analysis_ci_lower_limit  \
# 0                          NaN                              NaN
# 1                          NaN                              NaN
# 2                          NaN                              NaN
# 3                          NaN                              NaN
# 4                          NaN                              NaN
#
#    outcome_analysis_ci_upper_limit outcome_analysis_ci_upper_limit_na_comment  \
# 0                              NaN                                        NaN
# 1                              NaN                                        NaN
# 2                              NaN                                        NaN
# 3                              NaN                                        NaN
# 4                              NaN                                        NaN
#
#   outcome_analysis_p_value_description outcome_analysis_method  \
# 0                                  NaN                     NaN
# 1                                  NaN                     NaN
# 2                                  NaN                     NaN
# 3                                  NaN                     NaN
# 4                                  NaN                     NaN
#
#   outcome_analysis_method_description outcome_analysis_estimate_description  \
# 0                                 NaN                                   NaN
# 1                                 NaN                                   NaN
# 2                                 NaN                                   NaN
# 3                                 NaN                                   NaN
# 4                                 NaN                                   NaN
#
#   outcome_analysis_groups_description  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   outcome_analysis_other_analysis_description outcome_outcome_type  \
# 0                                         NaN                  NaN
# 1                                         NaN                  NaN
# 2                                         NaN                  NaN
# 3                                         NaN                  NaN
# 4                                         NaN                  NaN
#
#   outcome_title outcome_description outcome_time_frame outcome_population  \
# 0           NaN                 NaN                NaN                NaN
# 1           NaN                 NaN                NaN                NaN
# 2           NaN                 NaN                NaN                NaN
# 3           NaN                 NaN                NaN                NaN
# 4           NaN                 NaN                NaN                NaN
#
#   outcome_anticipated_posting_date outcome_anticipated_posting_month_year  \
# 0                              NaN                                    NaN
# 1                              NaN                                    NaN
# 2                              NaN                                    NaN
# 3                              NaN                                    NaN
# 4                              NaN                                    NaN
#
#   outcome_units outcome_units_analyzed outcome_dispersion_type  \
# 0           NaN                    NaN                     NaN
# 1           NaN                    NaN                     NaN
# 2           NaN                    NaN                     NaN
# 3           NaN                    NaN                     NaN
# 4           NaN                    NaN                     NaN
#
#   outcome_param_type  outcome_count_id outcome_count_ctgov_group_code  \
# 0                NaN               NaN                            NaN
# 1                NaN               NaN                            NaN
# 2                NaN               NaN                            NaN
# 3                NaN               NaN                            NaN
# 4                NaN               NaN                            NaN
#
#   outcome_count_scope outcome_count_units  outcome_count_count  \
# 0                 NaN                 NaN                  NaN
# 1                 NaN                 NaN                  NaN
# 2                 NaN                 NaN                  NaN
# 3                 NaN                 NaN                  NaN
# 4                 NaN                 NaN                  NaN
#
#    outcome_measurement_id outcome_measurement_ctgov_group_code  \
# 0                     NaN                                  NaN
# 1                     NaN                                  NaN
# 2                     NaN                                  NaN
# 3                     NaN                                  NaN
# 4                     NaN                                  NaN
#
#   outcome_measurement_classification outcome_measurement_category  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                                NaN                          NaN
# 3                                NaN                          NaN
# 4                                NaN                          NaN
#
#   outcome_measurement_title outcome_measurement_description  \
# 0                       NaN                             NaN
# 1                       NaN                             NaN
# 2                       NaN                             NaN
# 3                       NaN                             NaN
# 4                       NaN                             NaN
#
#   outcome_measurement_units outcome_measurement_param_type  \
# 0                       NaN                            NaN
# 1                       NaN                            NaN
# 2                       NaN                            NaN
# 3                       NaN                            NaN
# 4                       NaN                            NaN
#
#   outcome_measurement_param_value  outcome_measurement_param_value_num  \
# 0                             NaN                                  NaN
# 1                             NaN                                  NaN
# 2                             NaN                                  NaN
# 3                             NaN                                  NaN
# 4                             NaN                                  NaN
#
#   outcome_measurement_dispersion_type outcome_measurement_dispersion_value  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
#
#    outcome_measurement_dispersion_value_num  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    outcome_measurement_dispersion_lower_limit  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    outcome_measurement_dispersion_upper_limit  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   outcome_measurement_explanation_of_na
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN

# %% [markdown]
# #### Rename drug_name columns

# %%
df = df.rename(columns={'drug_name_x':'drug_name_intervention', 'drug_name_y':'drug_name_study'})

# %%
df.reset_index().groupby(['nct_id'])\
    .agg({'drug_name_intervention':'count', 'drug_name_study':'count', 'result_group_id':'count'}).head()
# Out:
#              drug_name_intervention  drug_name_study  result_group_id
# nct_id
# NCT00140140                      42              168              168
# NCT00182793                      15               45               45
# NCT00199381                       4                4                4
# NCT00213135                      69               69               69
# NCT00232479                       5                5                5

# %%
df.shape
# Out:
# (19871, 127)

# %%
df = df.reset_index()

# %% [markdown]
# #### Finding drugs with multiple studies

# %%
df = df.set_index('drug_name_study')\
    .merge(df.groupby(['drug_name_study']).agg({'nct_id':'nunique'})\
           .rename(columns={'nct_id':'studies_related_to_drug'}), left_index=True, right_index=True, how='inner')

# %%
df = df[df['studies_related_to_drug'] > 1]

# %%
df.shape
# Out:
# (18462, 130)

# %%
# 'outcome_measurement_classification',
# 'outcome_measurement_category',
# 'outcome_measurement_title',
# 'outcome_measurement_description',
# 'outcome_measurement_units',
# 'outcome_measurement_param_type',
# 'outcome_measurement_param_value_num',
# 'outcome_measurement_dispersion_type',
# 'outcome_measurement_dispersion_value',
# 'outcome_measurement_dispersion_lower_limit',
# 'outcome_measurement_dispersion_upper_limit']].head()

# %%
df[df.outcome_measurement_classification!=''].groupby([
    'drug_name_study', 'outcome_measurement_classification']).agg({'nct_id':'nunique'})\
    .sort_values(by='nct_id', ascending=False).head()
# Out:
#                                                            nct_id
# drug_name_study outcome_measurement_classification
# apremilast      Complete Response                               1
# midazolam       midazolam control AUC                           1
# sumatriptan     Diastolic, Change from Baseline, n=47, 36       1
#                 Diastolic, Change from Baseline, n=47           1
#                 Diastolic, Change from Baseline, n=41, 36       1

# %%
df[df.outcome_measurement_category!=''].groupby(['drug_name_study', 'outcome_measurement_category'])\
    .agg({'nct_id':'nunique'}).sort_values(by='nct_id', ascending=False)
# Out:
#                                                  nct_id
# drug_name_study outcome_measurement_category
# midazolam       Satisfactory mask induction           1
#                 memory of mask induction-no           1
#                 memory of mask induction-yes          1
#                 satisfactory wake up behavior         1
#                 unsatisfactory mask induction         1
#                 unsatisfactory wake up behavior       1

# %%
df[df.outcome_measurement_title!=''].groupby(['drug_name_study', 'outcome_measurement_title'])\
    .agg({'nct_id':'nunique'}).reset_index().sort_values(by='nct_id', ascending=False).head(20)
# Out:
#     drug_name_study                          outcome_measurement_title  nct_id
# 155   pembrolizumab                              Overall Survival (OS)       3
# 211     trastuzumab                              Overall Survival (OS)       3
# 167     ramucirumab                    Progression-Free Survival (PFS)       2
# 194     sumatriptan  Sustained Freedom From Migraine Pain Between 2...       2
# 51     atezolizumab                              Overall Survival (OS)       2
# 160     ramucirumab                              Overall Survival (OS)       2
# 226     trastuzumab                    Progression-Free Survival (PFS)       2
# 158   pembrolizumab  Progression-free Survival (PFS) by Response Ev...       1
# 157   pembrolizumab                    Progression-free Survival (PFS)       1
# 156   pembrolizumab  Progression Free Survival (PFS) Assessed by Cl...       1
# 0        apremilast  Area Under the Curve (AUC) for the Number of O...       1
# 154   pembrolizumab          Overall Response Rate (ORR) by RECIST 1.1       1
# 153   pembrolizumab  Overall Response Rate (ORR) Evaluated Accordin...       1
# 152   pembrolizumab                        Overall Response Rate (ORR)       1
# 151       midazolam                                   Wake up Behavior       1
# 150       midazolam                                  Verbal Complaints       1
# 159     ramucirumab                               Duration of Response       1
# 162     ramucirumab  Part A: Pharmacokinetics - Dose-Normalized Max...       1
# 161     ramucirumab  Part A: Pharmacokinetics - Dose-Normalized Are...       1
# 148       midazolam                                    Ventilator Days       1

# %%
df[df.outcome_measurement_description!=''].groupby(['drug_name_study', 'outcome_measurement_description'])\
    .agg({'nct_id':'nunique'}).reset_index().sort_values(by='nct_id', ascending=False).head()
# Out:
#     drug_name_study                    outcome_measurement_description  nct_id
# 159     sumatriptan  Sustained freedom from migraine pain was defin...       2
# 60       esketamine  MADRS is clinician-rated scale designed to mea...       2
# 0        apremilast  A 100-mm VAS pain scale for oral ulcers was co...       1
# 139     ramucirumab  PFS was defined as time from randomization unt...       1
# 130   pembrolizumab  Progression free survival was defined as the t...       1

# %%
df[df.outcome_measurement_units!=''].groupby(['drug_name_study', 'outcome_measurement_units'])\
    .agg({'nct_id':'nunique'}).reset_index().sort_values(by='nct_id', ascending=False).head(20)
# Out:
#    drug_name_study            outcome_measurement_units  nct_id
# 41       midazolam                         participants       5
# 77     trastuzumab                               months       4
# 35       midazolam                              minutes       4
# 47       midazolam                     units on a scale       4
# 0       apremilast           Percentage of Participants       3
# 74     trastuzumab                               Months       3
# 8       apremilast           percentage of participants       3
# 64     sumatriptan                         Participants       3
# 11      apremilast                     units on a scale       3
# 49   pembrolizumab                               Months       3
# 14    atezolizumab                               months       3
# 51   pembrolizumab           Percentage of participants       2
# 32       midazolam                                   mg       2
# 39       midazolam                                ng/mL       2
# 50   pembrolizumab           Percentage of Participants       2
# 54     ramucirumab       nanograms/milliliter/milligram       2
# 52     ramucirumab                               months       2
# 53     ramucirumab  nanograms*hour/milliliter/milligram       2
# 25      esketamine                     Units on a scale       2
# 55     ramucirumab           percentage of participants       2
