# %%
import pandas as pd
import numpy as np
from tqdm import tqdm_notebook
from tqdm import tqdm
import datetime as dt
import pickle
from collections import Counter

from fuzzywuzzy import fuzz
from fuzzywuzzy import process

import pdaactconn as pc
from trialexplorer.mesh_terms import MeSHCatalog
from trialexplorer import AACTStudySet

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tqdm.pandas()

# %%
# intializing MeSH object
mc = MeSHCatalog()
# Out:
# Parsing MeSH xml: xml/desc2020.xml ...
# Parse Complete! (parsed ElementTree root can be found in the .root attribute)

# %%
# selecting all interventional studies
conn = pc.AACTConnection(source=pc.AACTConnection.REMOTE)
ss = AACTStudySet.AACTStudySet(conn= conn, tqdm_handler=tqdm_notebook)
ss.add_constraint("study_type = 'Interventional'")
ss.load_studies()
# Out:
# 254139 studies loaded!

# %%
# loading all dimensional data
ss.add_dimensions('browse_conditions')
ss.add_dimensions('conditions')
ss.refresh_dim_data()
# Out:
# Successfuly added these 1 dimensions: ['browse_conditions']
# Failed to add these 0 dimensions: []
# Successfuly added these 1 dimensions: ['conditions']
# Failed to add these 0 dimensions: []
# HBox(children=(IntProgress(value=0, max=509), HTML(value='')))
# Syncing the temp table temp_cur_studies in 509 chunks x 500 records each
#
# Creating index on the temp table
#  - Loading dimension browse_conditions
#  -- Loading raw data
#  -- Sorting index
#  - Loading dimension conditions
#  -- Loading raw data
#  -- Sorting index

# %%
bc = ss.dimensions['browse_conditions']
c = ss.dimensions['conditions']

# %%
bc.data.head()
# Out:
#                    id                        mesh_term  \
# nct_id
# NCT00000102  10563497  Adrenal Hyperplasia, Congenital
# NCT00000102  10563498           Adrenogenital Syndrome
# NCT00000102  10563499     Adrenocortical Hyperfunction
# NCT00000102  10563500                      Hyperplasia
# NCT00000106  10562244               Rheumatic Diseases
#
#                           downcase_mesh_term
# nct_id
# NCT00000102  adrenal hyperplasia, congenital
# NCT00000102           adrenogenital syndrome
# NCT00000102     adrenocortical hyperfunction
# NCT00000102                      hyperplasia
# NCT00000106               rheumatic diseases

# %%
c.data.head()
# Out:
#                    id                            name  \
# nct_id
# NCT00000102  10058348  Congenital Adrenal Hyperplasia
# NCT00000106  10057277              Rheumatic Diseases
# NCT00000108  10057274         Cardiovascular Diseases
# NCT00000108  10057275                Coronary Disease
# NCT00000110  10057273                         Obesity
#
#                               downcase_name
# nct_id
# NCT00000102  congenital adrenal hyperplasia
# NCT00000106              rheumatic diseases
# NCT00000108         cardiovascular diseases
# NCT00000108                coronary disease
# NCT00000110                         obesity

# %% [markdown]
# ### Build a dataframe of mesh_tems and conditions

# %%
# method for combining all of the conditions for a study
def combine_all(df, nct_id, col):
    all_strings = []
    if nct_id in df.index:
        sub_df = df.loc[[nct_id]]
        for cur_cat in sub_df[col]:
            if cur_cat not in all_strings:
                all_strings.append(cur_cat)
    return all_strings

# %%
s_conds = ss.studies.reset_index()['nct_id'].progress_apply(lambda x: 
                                                            combine_all(c.data, 
                                                                        x,
                                                                        'downcase_name')).values
# Out:
# 100%|██████████| 254139/254139 [03:07<00:00, 1352.12it/s]

# %%
s_meshs = ss.studies.reset_index()['nct_id'].progress_apply(lambda x: 
                                                            combine_all(bc.data, 
                                                                        x,
                                                                        'downcase_mesh_term')).values
# Out:
# 100%|██████████| 254139/254139 [02:31<00:00, 1673.24it/s]

# %%
df = ss.studies

# %%
df['all_conds'] = s_conds
df['all_mesh'] = s_meshs

# %%
sub_df = df[['all_conds', 'all_mesh']].copy()

# %%
sub_df.head()
# Out:
#                                                      all_conds  \
# nct_id
# NCT02709889  [malignant melanoma, medullary thyroid cancer,...
# NCT02709876                             [retinitis pigmentosa]
# NCT02709863                                [pituitary adenoma]
# NCT02709850  [hypertriglyceridemia, familial hypercholester...
# NCT02709837                                        [nutrition]
#
#                                                       all_mesh
# nct_id
# NCT02709889  [glioblastoma, thyroid neoplasms, carcinoma, n...
# NCT02709876                  [retinitis pigmentosa, retinitis]
# NCT02709863  [adenoma, pituitary neoplasms, pituitary disea...
# NCT02709850  [hyperlipoproteinemia type ii, hypercholestero...
# NCT02709837                                                 []

# %% [markdown]
# ## Random item

# %%
idx = np.random.choice(sub_df.index)
print('Conditions:')
print(sub_df['all_conds'].loc[idx], '\n')

print('MeSHes:')
print(sub_df['all_mesh'].loc[idx])
# Out:
# Conditions:
# ['hepatitis c', 'human immunodeficiency virus']
#
# MeSHes:
# ['hepatitis a', 'hepatitis c', 'acquired immunodeficiency syndrome', 'hiv infections', 'hepatitis', 'liver cirrhosis', 'immunologic deficiency syndromes', 'fibrosis']

# %% [markdown]
# ## let's count the most common conditions and meshes

# %%
cond_c = Counter()
mesh_c = Counter()

for cond_list in tqdm(sub_df['all_conds'].values):
    for term in cond_list:
        cond_c[term] += 1
        
for mesh_list in tqdm(sub_df['all_mesh'].values):
    for term in mesh_list:
        mesh_c[term] += 1
# Out:
# 100%|██████████| 254139/254139 [00:00<00:00, 512429.67it/s]
# 100%|██████████| 254139/254139 [00:00<00:00, 442673.00it/s]

# %%
cond_c.most_common()
# Out:
# [('healthy', 6557),
#  ('breast cancer', 4243),
#  ('obesity', 3945),
#  ('hiv infections', 2836),
#  ('hypertension', 2445),
#  ('pain', 2401),
#  ('prostate cancer', 2379),
#  ('depression', 2276),
#  ('asthma', 2162),
#  ('schizophrenia', 1965),
#  ('stroke', 1936),
#  ('diabetes mellitus, type 2', 1819),
#  ('diabetes', 1727),
#  ('coronary artery disease', 1697),
#  ('colorectal cancer', 1629),
#  ('cancer', 1589),
#  ('lung cancer', 1520),
#  ('lymphoma', 1483),
#  ('heart failure', 1453),
#  ('healthy volunteers', 1382),
#  ('type 2 diabetes mellitus', 1367),
#  ('multiple myeloma', 1329),
#  ('rheumatoid arthritis', 1302),
#  ('leukemia', 1264),
#  ('type 2 diabetes', 1206),
#  ('diabetes mellitus', 1170),
#  ('hiv', 1112),
#  ('atrial fibrillation', 1053),
#  ('ovarian cancer', 1051),
#  ('pancreatic cancer', 1013),
#  ('multiple sclerosis', 1003),
#  ('non-small cell lung cancer', 994),
#  ('influenza', 984),
#  ('osteoarthritis', 957),
#  ('anxiety', 951),
#  ('major depressive disorder', 940),
#  ('cardiovascular diseases', 930),
#  ('chronic obstructive pulmonary disease', 904),
#  ('head and neck cancer', 859),
#  ('infertility', 801),
#  ('overweight', 799),
#  ("parkinson's disease", 793),
#  ('melanoma', 790),
#  ("alzheimer's disease", 785),
#  ('parkinson disease', 768),
#  ('gastric cancer', 765),
#  ('hepatocellular carcinoma', 758),
#  ('postoperative pain', 756),
#  ('cystic fibrosis', 753),
#  ('acute myeloid leukemia', 743),
#  ('pregnancy', 737),
#  ('unspecified adult solid tumor, protocol specific', 723),
#  ('metabolic syndrome', 710),
#  ('bipolar disorder', 700),
#  ('cardiovascular disease', 690),
#  ('anemia', 683),
#  ('neoplasms', 669),
#  ('low back pain', 668),
#  ('physical activity', 667),
#  ('chronic pain', 665),
#  ('smoking cessation', 649),
#  ('myelodysplastic syndromes', 642),
#  ('hepatitis c', 641),
#  ('alzheimer disease', 629),
#  ('pain, postoperative', 628),
#  ('osteoporosis', 628),
#  ('quality of life', 618),
#  ('epilepsy', 615),
#  ('psoriasis', 614),
#  ('chronic kidney disease', 613),
#  ('diabetes mellitus, type 1', 613),
#  ('pulmonary disease, chronic obstructive', 607),
#  ('inflammation', 606),
#  ('myocardial infarction', 596),
#  ('copd', 590),
#  ('insulin resistance', 587),
#  ('hypercholesterolemia', 578),
#  ('malaria', 575),
#  ('knee osteoarthritis', 556),
#  ('aging', 550),
#  ('healthy subjects', 549),
#  ('cervical cancer', 549),
#  ('anesthesia', 545),
#  ('type 1 diabetes', 535),
#  ('obstructive sleep apnea', 534),
#  ('solid tumors', 532),
#  ('ulcerative colitis', 516),
#  ('surgery', 515),
#  ('bladder cancer', 507),
#  ('breast neoplasms', 503),
#  ('dementia', 500),
#  ('esophageal cancer', 500),
#  ('metastatic breast cancer', 500),
#  ('smoking', 483),
#  ('glaucoma', 482),
#  ("crohn's disease", 477),
#  ('osteoarthritis, knee', 475),
#  ('sarcoma', 474),
#  ('chronic lymphocytic leukemia', 463),
#  ('tuberculosis', 459),
#  ('insomnia', 450),
#  ('glioblastoma', 449),
#  ('type 1 diabetes mellitus', 448),
#  ('atopic dermatitis', 446),
#  ('fibromyalgia', 444),
#  ('traumatic brain injury', 441),
#  ('myelodysplastic syndrome', 441),
#  ('cataract', 441),
#  ('carcinoma, non-small-cell lung', 439),
#  ('mild cognitive impairment', 436),
#  ('acute coronary syndrome', 428),
#  ('hiv infection', 427),
#  ('atherosclerosis', 423),
#  ('sepsis', 422),
#  ('myopia', 411),
#  ('non small cell lung cancer', 410),
#  ('schizoaffective disorder', 402),
#  ('rectal cancer', 398),
#  ('fatigue', 389),
#  ('brain and central nervous system tumors', 389),
#  ('solid tumor', 379),
#  ('hepatitis b', 377),
#  ('heart diseases', 376),
#  ('spinal cord injury', 375),
#  ('migraine', 373),
#  ('contraception', 373),
#  ('cerebral palsy', 371),
#  ('advanced solid tumors', 370),
#  ('vitamin d deficiency', 364),
#  ('end stage renal disease', 364),
#  ('ocular hypertension', 363),
#  ('colon cancer', 361),
#  ('metastatic cancer', 360),
#  ('attention deficit hyperactivity disorder', 358),
#  ('peripheral arterial disease', 357),
#  ('autism spectrum disorder', 354),
#  ('weight loss', 346),
#  ('metastatic colorectal cancer', 343),
#  ('sickle cell disease', 343),
#  ('acute lymphoblastic leukemia', 340),
#  ('irritable bowel syndrome', 339),
#  ('acne vulgaris', 337),
#  ('stress', 337),
#  ('advanced cancer', 336),
#  ('neuroblastoma', 328),
#  ('healthy volunteer', 325),
#  ('critical illness', 320),
#  ('spinal cord injuries', 318),
#  ('renal cell carcinoma', 318),
#  ('liver cancer', 318),
#  ('colorectal neoplasms', 316),
#  ('fallopian tube cancer', 313),
#  ('coronary disease', 311),
#  ('malnutrition', 305),
#  ('endometrial cancer', 305),
#  ('congestive heart failure', 304),
#  ('polycystic ovary syndrome', 304),
#  ('pneumonia', 302),
#  ('ischemic stroke', 302),
#  ('kidney cancer', 300),
#  ('dental caries', 299),
#  ('septic shock', 299),
#  ('dyslipidemia', 298),
#  ('kidney transplantation', 298),
#  ('blood pressure', 295),
#  ('chronic hepatitis c', 293),
#  ('hyperlipidemia', 293),
#  ('posttraumatic stress disorder', 292),
#  ("non-hodgkin's lymphoma", 291),
#  ('infection', 287),
#  ('amyotrophic lateral sclerosis', 285),
#  ('erectile dysfunction', 282),
#  ('hepatitis c, chronic', 281),
#  ('hiv/aids', 278),
#  ('glioblastoma multiforme', 277),
#  ('systemic lupus erythematosus', 276),
#  ('prostatic neoplasms', 276),
#  ('overactive bladder', 275),
#  ('constipation', 274),
#  ('melanoma (skin)', 271),
#  ('multiple myeloma and plasma cell neoplasm', 271),
#  ('pulmonary hypertension', 270),
#  ('sleep', 266),
#  ('overweight and obesity', 266),
#  ('acute myocardial infarction', 265),
#  ('anxiety disorders', 264),
#  ('chronic obstructive pulmonary disease (copd)', 264),
#  ('diarrhea', 263),
#  ('health behavior', 261),
#  ('nicotine dependence', 260),
#  ('urinary incontinence', 260),
#  ('pharmacokinetics', 260),
#  ('cirrhosis', 258),
#  ('pulmonary arterial hypertension', 258),
#  ('allergic rhinitis', 257),
#  ('diabetic macular edema', 254),
#  ('acute kidney injury', 252),
#  ('alcohol dependence', 250),
#  ('sarcopenia', 248),
#  ('coronary heart disease', 244),
#  ('ptsd', 243),
#  ('chronic low back pain', 242),
#  ('menopause', 242),
#  ('tobacco use disorder', 241),
#  ('alcoholism', 241),
#  ('cognitive impairment', 239),
#  ('chronic hepatitis b', 239),
#  ('substance-related disorders', 238),
#  ('crohn disease', 238),
#  ('neck pain', 235),
#  ('myocardial ischemia', 234),
#  ('neoplasm metastasis', 230),
#  ('metastatic melanoma', 226),
#  ('arthritis, rheumatoid', 224),
#  ('delirium', 222),
#  ('glioma', 222),
#  ('dry eye', 220),
#  ('morbid obesity', 218),
#  ('depressive disorder', 216),
#  ('liver cirrhosis', 216),
#  ('small cell lung cancer', 215),
#  ('substance abuse', 214),
#  ('autism', 214),
#  ('venous thromboembolism', 213),
#  ('alcohol use disorder', 212),
#  ('lymphoma, non-hodgkin', 211),
#  ('prediabetes', 208),
#  ('major depression', 208),
#  ('exercise', 207),
#  ('periodontitis', 205),
#  ('diabetic retinopathy', 204),
#  ('endometriosis', 204),
#  ('oxidative stress', 203),
#  ('adhd', 202),
#  ('acute pain', 200),
#  ('depressive disorder, major', 198),
#  ('neuropathic pain', 198),
#  ('sedentary lifestyle', 198),
#  ('respiratory failure', 197),
#  ('cardiac arrest', 197),
#  ('pulmonary embolism', 197),
#  ('burns', 196),
#  ('generalized anxiety disorder', 196),
#  ('opioid-related disorders', 196),
#  ('age-related macular degeneration', 195),
#  ('obsessive-compulsive disorder', 195),
#  ('hyperglycemia', 195),
#  ('trauma', 195),
#  ('acute myelogenous leukemia', 192),
#  ('stage iv breast cancer', 191),
#  ('mantle cell lymphoma', 190),
#  ('postoperative complications', 188),
#  ('carcinoma, hepatocellular', 187),
#  ('ischemic heart disease', 186),
#  ('recurrent adult acute myeloid leukemia', 186),
#  ('alcohol abuse', 185),
#  ('macular degeneration', 185),
#  ('tetanus', 185),
#  ('diabetes mellitus type 2', 184),
#  ('diphtheria', 183),
#  ('post-traumatic stress disorder', 182),
#  ('human immunodeficiency virus', 182),
#  ('cerebrovascular accident', 179),
#  ('back pain', 178),
#  ('hearing loss', 177),
#  ('recurrent mantle cell lymphoma', 176),
#  ('plaque psoriasis', 176),
#  ('childhood obesity', 175),
#  ('endothelial dysfunction', 175),
#  ('follicular lymphoma', 174),
#  ('nasopharyngeal carcinoma', 174),
#  ('chronic periodontitis', 173),
#  ('pelvic organ prolapse', 173),
#  ('benign prostatic hyperplasia', 173),
#  ('chronic heart failure', 173),
#  ('diffuse large b-cell lymphoma', 171),
#  ('kidney failure, chronic', 171),
#  ('head and neck neoplasms', 171),
#  ('idiopathic pulmonary fibrosis', 170),
#  ('gastroesophageal reflux disease', 170),
#  ('nausea', 170),
#  ('non-alcoholic fatty liver disease', 170),
#  ('lung diseases', 170),
#  ('colonoscopy', 170),
#  ('medication adherence', 168),
#  ('postoperative nausea and vomiting', 168),
#  ('malignant melanoma', 167),
#  ('hiv-1 infection', 167),
#  ('sleep apnea, obstructive', 167),
#  ('shoulder pain', 166),
#  ('graft versus host disease', 165),
#  ('hodgkin lymphoma', 165),
#  ('hypotension', 164),
#  ('liver transplantation', 163),
#  ('depressive symptoms', 163),
#  ('nsclc', 162),
#  ('cocaine dependence', 162),
#  ('sleep apnea', 161),
#  ('lung neoplasms', 161),
#  ('pancreatic neoplasms', 161),
#  ('head and neck squamous cell carcinoma', 160),
#  ('chronic disease', 160),
#  ('peripheral artery disease', 160),
#  ('psychotic disorders', 160),
#  ('stress disorders, post-traumatic', 159),
#  ('end-stage renal disease', 159),
#  ('cardiovascular risk factor', 159),
#  ('essential hypertension', 158),
#  ('aortic valve stenosis', 158),
#  ('recurrent small lymphocytic lymphoma', 158),
#  ('arthritis', 157),
#  ('triple negative breast cancer', 157),
#  ('cholangiocarcinoma', 157),
#  ('seasonal allergic rhinitis', 157),
#  ('chronic myelomonocytic leukemia', 156),
#  ('inflammatory bowel disease', 155),
#  ('non-hodgkin lymphoma', 155),
#  ('heart failure, congestive', 155),
#  ('hemophilia a', 155),
#  ('stress urinary incontinence', 154),
#  ('substance use disorders', 153),
#  ('actinic keratosis', 153),
#  ('dyslipidemias', 153),
#  ('cocaine-related disorders', 153),
#  ('gingivitis', 152),
#  ('preterm birth', 151),
#  ('diabetic foot ulcer', 151),
#  ('cardiac surgery', 151),
#  ('inflammatory bowel diseases', 151),
#  ('opioid use', 151),
#  ('brain metastases', 150),
#  ('carpal tunnel syndrome', 149),
#  ('type2 diabetes', 149),
#  ('soft tissue sarcoma', 148),
#  ('vomiting', 147),
#  ('helicobacter pylori infection', 147),
#  ('adult acute myeloid leukemia with 11q23 (mll) abnormalities', 147),
#  ('stage iiia breast cancer', 146),
#  ('hypoglycemia', 146),
#  ('acute respiratory distress syndrome', 146),
#  ('elderly', 146),
#  ('stage iiib breast cancer', 145),
#  ('brain tumor', 145),
#  ('recurrent grade 1 follicular lymphoma', 145),
#  ('recurrent grade 2 follicular lymphoma', 145),
#  ('premature birth', 145),
#  ('peripheral vascular disease', 144),
#  ('tinnitus', 144),
#  ('stage iv non-small cell lung cancer', 144),
#  ('adult acute myeloid leukemia with t(16;16)(p13;q22)', 144),
#  ('chronic myeloid leukemia', 143),
#  ('psychosis', 143),
#  ('neuroendocrine tumors', 143),
#  ('renal failure', 143),
#  ('headache', 142),
#  ('analgesia', 142),
#  ('dysphagia', 142),
#  ('urinary tract infections', 141),
#  ('renal insufficiency', 141),
#  ('stress, psychological', 140),
#  ('cesarean section', 140),
#  ('adult acute myeloid leukemia with t(8;21)(q22;q22)', 140),
#  ('osteoarthritis of the knee', 139),
#  ('adult acute myeloid leukemia with inv(16)(p13;q22)', 139),
#  ('hypertriglyceridemia', 138),
#  ('hypogonadism', 138),
#  ('congenital heart disease', 138),
#  ('stomach neoplasms', 138),
#  ('open-angle glaucoma', 138),
#  ('poliomyelitis', 138),
#  ('stage iiic breast cancer', 137),
#  ('heart disease', 137),
#  ('mental disorders', 136),
#  ('surgical site infection', 136),
#  ('dry eye syndromes', 136),
#  ('alcohol drinking', 136),
#  ('squamous cell carcinoma of the head and neck', 135),
#  ('refractory chronic lymphocytic leukemia', 135),
#  ('metabolic syndrome x', 135),
#  ('hot flashes', 134),
#  ('diabetic nephropathy', 134),
#  ('healthy participants', 134),
#  ('recurrent marginal zone lymphoma', 134),
#  ('ankylosing spondylitis', 133),
#  ('hepatitis b, chronic', 133),
#  ('tumors', 133),
#  ('recurrent adult diffuse large cell lymphoma', 133),
#  ('recurrent grade 3 follicular lymphoma', 133),
#  ('chronic kidney diseases', 133),
#  ('pancreatic adenocarcinoma', 132),
#  ('hemodialysis', 132),
#  ('postpartum hemorrhage', 132),
#  ('macular edema', 132),
#  ('attention deficit disorder with hyperactivity', 132),
#  ('psoriatic arthritis', 132),
#  ('allergy', 132),
#  ('thrombosis', 131),
#  ('total knee arthroplasty', 131),
#  ('osteopenia', 131),
#  ('renal impairment', 130),
#  ('vascular diseases', 129),
#  ('gestational diabetes', 128),
#  ('adenocarcinoma', 128),
#  ('gingival recession', 128),
#  ('deep vein thrombosis', 128),
#  ('primary peritoneal cavity cancer', 128),
#  ('anorexia nervosa', 127),
#  ('respiratory insufficiency', 127),
#  ('panic disorder', 127),
#  ('urothelial carcinoma', 127),
#  ('secondary acute myeloid leukemia', 127),
#  ('recurrent breast cancer', 127),
#  ('pertussis', 127),
#  ('hypoxia', 126),
#  ('bleeding', 126),
#  ('suicide', 126),
#  ('ovarian neoplasms', 126),
#  ('astigmatism', 126),
#  ('carcinoma, renal cell', 125),
#  ('sexually transmitted diseases', 125),
#  ('chronic myelogenous leukemia', 124),
#  ('duchenne muscular dystrophy', 124),
#  ('hepatic impairment', 124),
#  ('cigarette smoking', 124),
#  ('gastroesophageal reflux', 124),
#  ('obese', 124),
#  ('critical limb ischemia', 124),
#  ('squamous cell carcinoma', 124),
#  ('diet modification', 124),
#  ('aids', 123),
#  ('substance use', 123),
#  ('hip fractures', 123),
#  ('gout', 123),
#  ('dietary modification', 122),
#  ('malignant neoplasm', 122),
#  ('lymphedema', 121),
#  ('presbyopia', 121),
#  ('bronchopulmonary dysplasia', 121),
#  ('splenic marginal zone lymphoma', 121),
#  ('bipolar depression', 120),
#  ('iron deficiency anemia', 120),
#  ('dermatitis, atopic', 120),
#  ('labor pain', 120),
#  ('malignant glioma', 120),
#  ('recurrent ovarian carcinoma', 120),
#  ('hemorrhage', 120),
#  ('infertility, female', 120),
#  ('carcinoma', 119),
#  ('neutropenia', 119),
#  ('fecal incontinence', 119),
#  ('psoriasis vulgaris', 119),
#  ('pediatric obesity', 118),
#  ('leukemia, myeloid, acute', 118),
#  ('small lymphocytic lymphoma', 118),
#  ('kidney diseases', 118),
#  ('thrombocytopenia', 117),
#  ('brain injuries', 117),
#  ('fever', 117),
#  ('liver metastases', 117),
#  ('muscle weakness', 116),
#  ('children', 116),
#  ('post traumatic stress disorder', 116),
#  ('inguinal hernia', 115),
#  ('multiple sclerosis, relapsing-remitting', 115),
#  ('renal transplantation', 115),
#  ('dyspepsia', 115),
#  ('thyroid cancer', 114),
#  ('unspecified childhood solid tumor, protocol specific', 114),
#  ('stroke, acute', 113),
#  ('renal insufficiency, chronic', 113),
#  ('nodal marginal zone b-cell lymphoma', 113),
#  ('recurrent adult acute lymphoblastic leukemia', 112),
#  ('emphysema', 112),
#  ('bacterial infections', 112),
#  ('gastric adenocarcinoma', 112),
#  ('chronic myeloproliferative disorders', 112),
#  ('breast cancer female', 112),
#  ('keratoconus', 111),
#  ('iron deficiency', 111),
#  ('breastfeeding', 111),
#  ('extranodal marginal zone b-cell lymphoma of mucosa-associated lymphoid tissue',
#   111),
#  ('osteoarthritis, hip', 110),
#  ('tobacco dependence', 110),
#  ('severe sepsis', 110),
#  ('sleep disorders', 110),
#  ('social anxiety disorder', 110),
#  ('rehabilitation', 110),
#  ('acute ischemic stroke', 110),
#  ('cough', 110),
#  ('sleep initiation and maintenance disorders', 109),
#  ('impaired glucose tolerance', 109),
#  ('herpes zoster', 109),
#  ('stage iiib non-small cell lung cancer', 109),
#  ('dyspnea', 109),
#  ('migraine disorders', 109),
#  ('recurrent melanoma', 109),
#  ('hemiparesis', 108),
#  ('insulin sensitivity', 108),
#  ('restless legs syndrome', 108),
#  ('hematologic malignancies', 108),
#  ('myelofibrosis', 108),
#  ('opioid dependence', 108),
#  ('borderline personality disorder', 108),
#  ('adenocarcinoma of the prostate', 108),
#  ('pregnancy related', 108),
#  ('uterine fibroids', 107),
#  ('adolescent behavior', 107),
#  ('infection, human immunodeficiency virus', 107),
#  ('mesothelioma', 107),
#  ('influenza, human', 107),
#  ('metastatic renal cell carcinoma', 107),
#  ('diabetic foot', 106),
#  ('prostate adenocarcinoma', 106),
#  ('stage iv prostate cancer', 106),
#  ('gliosarcoma', 105),
#  ('autistic disorder', 105),
#  ('preeclampsia', 105),
#  ('colorectal carcinoma', 105),
#  ('general anesthesia', 105),
#  ('her2/neu negative', 104),
#  ('suicidal ideation', 104),
#  ('sedation', 104),
#  ('osteosarcoma', 104),
#  ('stage iv melanoma', 104),
#  ('systemic sclerosis', 104),
#  ('skin cancer', 104),
#  ('rotator cuff tear', 104),
#  ('stage ii breast cancer', 104),
#  ('aphasia', 103),
#  ('graft vs host disease', 103),
#  ('untreated adult acute myeloid leukemia', 103),
#  ('acquired immunodeficiency syndrome', 103),
#  ('recurrent adult burkitt lymphoma', 103),
#  ('precancerous condition', 103),
#  ('bronchiolitis', 102),
#  ('metastatic pancreatic cancer', 102),
#  ('respiratory distress syndrome', 102),
#  ('bariatric surgery candidate', 102),
#  ('paroxysmal atrial fibrillation', 101),
#  ('seizures', 101),
#  ('hypothermia', 101),
#  ('bronchiectasis', 101),
#  ('colitis, ulcerative', 101),
#  ('advanced solid tumor', 101),
#  ('angina pectoris', 101),
#  ('chest pain', 101),
#  ('recurrent prostate cancer', 101),
#  ('adult acute myeloid leukemia with del(5q)', 101),
#  ('peripheral neuropathy', 100),
#  ('hypertension, pulmonary', 100),
#  ('accidental falls', 99),
#  ('musculoskeletal pain', 99),
#  ('palliative care', 99),
#  ('liver diseases', 99),
#  ('chronic renal failure', 99),
#  ('dry eye syndrome', 99),
#  ('celiac disease', 99),
#  ('anxiety disorder', 99),
#  ('clostridium difficile infection', 98),
#  ('pre-diabetes', 98),
#  ('refractory multiple myeloma', 98),
#  ('peripheral t-cell lymphoma', 98),
#  ('neuromuscular blockade', 97),
#  ('uveitis', 97),
#  ('parenting', 97),
#  ('abdominal pain', 97),
#  ('esophageal neoplasms', 97),
#  ('intermittent claudication', 97),
#  ('kidney failure', 97),
#  ('allergic conjunctivitis', 97),
#  ('adult acute myeloid leukemia with t(15;17)(q22;q12)', 97),
#  ('pain, acute', 97),
#  ('kidney disease', 96),
#  ('degenerative disc disease', 96),
#  ('rectal neoplasms', 96),
#  ('lupus nephritis', 96),
#  ('epithelial ovarian cancer', 96),
#  ('weight gain', 96),
#  ('myeloma', 96),
#  ('recurrent adult diffuse small cleaved cell lymphoma', 96),
#  ('recurrent adult lymphoblastic lymphoma', 96),
#  ('brain cancer', 95),
#  ('arrhythmia', 95),
#  ('post-operative pain', 95),
#  ('pressure ulcer', 95),
#  ('wound infection', 95),
#  ('breast neoplasm', 95),
#  ('hip fracture', 94),
#  ('urinary tract infection', 94),
#  ('respiratory tract infections', 94),
#  ('acute myeloid leukemia (aml)', 94),
#  ('diffuse large b cell lymphoma', 94),
#  ('recurrent adult diffuse mixed cell lymphoma', 94),
#  ('mood disorders', 93),
#  ('aortic stenosis', 93),
#  ('ischemia', 93),
#  ('anaplastic astrocytoma', 93),
#  ('tobacco use cessation', 93),
#  ('anaplastic large cell lymphoma', 93),
#  ('subarachnoid hemorrhage', 92),
#  ('lower urinary tract symptoms', 92),
#  ('hiv-1-infection', 92),
#  ('recurrent adult hodgkin lymphoma', 92),
#  ('mental health', 91),
#  ('wounds and injuries', 91),
#  ('her2-positive breast cancer', 91),
#  ('breast carcinoma', 90),
#  ('arthroplasty, replacement, knee', 90),
#  ('hyperphosphatemia', 90),
#  ('acromegaly', 90),
#  ('amputation', 90),
#  ('ventricular tachycardia', 90),
#  ('periodontal diseases', 90),
#  ('aml', 90),
#  ('gastroparesis', 90),
#  ('percutaneous coronary intervention', 90),
#  ('cognitive decline', 89),
#  ('gastrointestinal cancer', 89),
#  ('esophageal squamous cell carcinoma', 89),
#  ('acute respiratory failure', 89),
#  ('pneumococcal infections', 89),
#  ('gerd', 89),
#  ('child development', 88),
#  ('glucose metabolism disorders', 88),
#  ('hemiplegia', 88),
#  ('child', 88),
#  ('recurrent non-small cell lung cancer', 88),
#  ('liver neoplasms', 88),
#  ('sinusitis', 88),
#  ('pain management', 88),
#  ('anesthesia, local', 88),
#  ('pancreas cancer', 87),
#  ('essential tremor', 87),
#  ('refractive error', 87),
#  ('sleep deprivation', 87),
#  ('colonic neoplasms', 87),
#  ('appendicitis', 87),
#  ('neoplasm', 87),
#  ('waldenström macroglobulinemia', 87),
#  ('primary peritoneal carcinoma', 87),
#  ('obesity, morbid', 87),
#  ('tobacco use', 87),
#  ('secondary hyperparathyroidism', 87),
#  ('mechanical ventilation', 87),
#  ('prematurity', 87),
#  ('age related macular degeneration', 86),
#  ('biliary tract cancer', 86),
#  ('recurrent primary peritoneal carcinoma', 86),
#  ('critically ill', 86),
#  ('rosacea', 86),
#  ('bone metastases', 86),
#  ('relapsing-remitting multiple sclerosis', 86),
#  ('haemophilus influenzae type b', 86),
#  ('cancer survivor', 85),
#  ('recurrent fallopian tube carcinoma', 85),
#  ('angioimmunoblastic t-cell lymphoma', 85),
#  ('primary myelofibrosis', 85),
#  ('portal hypertension', 85),
#  ('recurrent adult immunoblastic large cell lymphoma', 85),
#  ('retinitis pigmentosa', 84),
#  ('atrial flutter', 84),
#  ('opioid-use disorder', 84),
#  ('cytomegalovirus infections', 84),
#  ('tourette syndrome', 84),
#  ('respiratory syncytial virus infections', 84),
#  ('recurrent breast carcinoma', 84),
#  ('down syndrome', 84),
#  ('sickle cell anemia', 84),
#  ('previously treated myelodysplastic syndromes', 84),
#  ('bacterial vaginosis', 83),
#  ('growth hormone deficiency', 83),
#  ('stage iv pancreatic cancer', 83),
#  ('acute lymphocytic leukemia', 83),
#  ('obsessive compulsive disorder', 83),
#  ("hodgkin's lymphoma", 83),
#  ('acne', 82),
#  ('stable angina', 82),
#  ('non-small-cell lung cancer', 82),
#  ('postpartum depression', 82),
#  ('sarcoidosis', 82),
#  ('meningitis', 82),
#  ('body weight', 82),
#  ('recurrent cutaneous t-cell non-hodgkin lymphoma', 82),
#  ('diabetic foot ulcers', 81),
#  ('pre-eclampsia', 81),
#  ('acute stroke', 81),
#  ('cervical intraepithelial neoplasia', 81),
#  ('eczema', 81),
#  ('aplastic anemia', 81),
#  ('vitiligo', 81),
#  ('glucose intolerance', 80),
#  ('stage iiia non-small cell lung cancer', 80),
#  ('lupus erythematosus, systemic', 80),
#  ('venous thrombosis', 80),
#  ('glaucoma, open-angle', 80),
#  ('kidney transplant', 80),
#  ('obstructive sleep apnea syndrome', 79),
#  ('fatty liver', 79),
#  ('persistent atrial fibrillation', 79),
#  ('onychomycosis', 79),
#  ('acute lung injury', 79),
#  ('clear cell renal cell carcinoma', 78),
#  ('hip osteoarthritis', 78),
#  ('drug abuse', 78),
#  ('social phobia', 78),
#  ('cardiopulmonary bypass', 78),
#  ('peritoneal cancer', 78),
#  ('hyperlipidemias', 78),
#  ('sexual dysfunction', 78),
#  ("hodgkin's disease", 78),
#  ('hepatic encephalopathy', 78),
#  ('open angle glaucoma', 78),
#  ('opiate dependence', 78),
#  ('adult glioblastoma', 78),
#  ('proteinuria', 78),
#  ('acute leukemia', 78),
#  ('adult gliosarcoma', 78),
#  ('cesarean section complications', 78),
#  ('hepatitis c virus', 77),
#  ('communication', 77),
#  ('autoimmune diseases', 77),
#  ('liver disease', 77),
#  ('cerebral infarction', 77),
#  ('mucositis', 77),
#  ('waldenstrom macroglobulinemia', 77),
#  ('basal cell carcinoma', 77),
#  ('stage iv renal cell cancer', 77),
#  ('retinal vein occlusion', 77),
#  ('coronary arteriosclerosis', 77),
#  ('recurrent mycosis fungoides/sezary syndrome', 77),
#  ('relapsing remitting multiple sclerosis', 76),
#  ('pancreatic ductal adenocarcinoma', 76),
#  ('autism spectrum disorders', 76),
#  ('hyperuricemia', 76),
#  ('chemotherapy-induced nausea and vomiting', 76),
#  ('dental plaque', 75),
#  ('abdominal aortic aneurysm', 75),
#  ('post operative pain', 75),
#  ('common cold', 75),
#  ('treatment resistant depression', 75),
#  ('pruritus', 75),
#  ('lymphoma, b-cell', 75),
#  ('cardiomyopathy', 75),
#  ('carcinoma, squamous cell', 75),
#  ('adult acute myeloid leukemia in remission', 75),
#  ('diabetic neuropathies', 75),
#  ('adult giant cell glioblastoma', 75),
#  ('myelodysplastic/myeloproliferative neoplasms', 75),
#  ('pancreatitis', 74),
#  ('anaemia', 74),
#  ('healthy adults', 74),
#  ('intracerebral hemorrhage', 74),
#  ('hodgkin disease', 74),
#  ('tobacco smoking', 74),
#  ('myelodysplastic syndrome (mds)', 74),
#  ('unstable angina', 74),
#  ('bipolar i disorder', 74),
#  ('prostatic hyperplasia', 74),
#  ('pelvic pain', 74),
#  ('radiation toxicity', 74),
#  ('male breast cancer', 74),
#  ('non-small-cell lung carcinoma', 74),
#  ('recurrent colon cancer', 74),
#  ('patellofemoral pain syndrome', 73),
#  ('spinal stenosis', 73),
#  ('anesthesia, general', 73),
#  ('hematopoietic stem cell transplantation', 73),
#  ('advanced cancers', 73),
#  ('interstitial lung disease', 73),
#  ('thromboembolism', 73),
#  ('polycythemia vera', 73),
#  ('recurrent rectal cancer', 73),
#  ('fabry disease', 73),
#  ('scoliosis', 72),
#  ('eating disorders', 72),
#  ('nerve block', 72),
#  ('b-cell chronic lymphocytic leukemia', 72),
#  ('pain, chronic', 72),
#  ('safety', 72),
#  ('measles', 72),
#  ('nonalcoholic steatohepatitis', 72),
#  ('rhinitis, allergic, seasonal', 72),
#  ('cerebrovascular disorders', 71),
#  ('wounds', 71),
#  ('functional dyspepsia', 71),
#  ('alcohol consumption', 71),
#  ('bariatric surgery', 71),
#  ('neovascular age-related macular degeneration', 71),
#  ('interstitial cystitis', 71),
#  ('behavior', 71),
#  ('intubation', 71),
#  ('estrogen receptor negative', 70),
#  ('prediabetic state', 70),
#  ('stage ia breast cancer', 70),
#  ('stage ib breast cancer', 70),
#  ('recurrent plasma cell myeloma', 70),
#  ('amblyopia', 70),
#  ('motor activity', 70),
#  ('bacteremia', 70),
#  ('recurrent adult t-cell leukemia/lymphoma', 70),
#  ('diabetes type 2', 70),
#  ('recurrent ovarian epithelial cancer', 70),
#  ('de novo myelodysplastic syndromes', 70),
#  ('brain neoplasms', 69),
#  ('hemophilia b', 69),
#  ('metastasis', 69),
#  ('menorrhagia', 69),
#  ('mood', 69),
#  ('aged', 69),
#  ('eosinophilic esophagitis', 69),
#  ('frailty', 69),
#  ('mds', 69),
#  ('hematologic diseases', 69),
#  ('choroidal neovascularization', 69),
#  ('solid tumor, adult', 69),
#  ('sleep disturbance', 69),
#  ('mental health wellness 1', 68),
#  ('hiv prevention', 68),
#  ('cognitive function', 68),
#  ('hepatitis c virus infection', 68),
#  ('cognition', 68),
#  ('gestational diabetes mellitus', 68),
#  ('high blood pressure', 68),
#  ('primary open angle glaucoma', 68),
#  ('stage iii pancreatic cancer', 68),
#  ('osteo arthritis knee', 68),
#  ('colorectal cancer metastatic', 68),
#  ('small intestine cancer', 68),
#  ('relapsing chronic myelogenous leukemia', 68),
#  ('cognitive change', 68),
#  ('triple-negative breast carcinoma', 67),
#  ('alopecia areata', 67),
#  ('short bowel syndrome', 67),
#  ('rhabdomyosarcoma', 67),
#  ('dengue', 67),
#  ('advanced breast cancer', 67),
#  ('osteoporosis, postmenopausal', 67),
#  ('primary peritoneal cancer', 67),
#  ('recurrent childhood acute lymphoblastic leukemia', 67),
#  ('malocclusion', 67),
#  ('refractory plasma cell myeloma', 67),
#  ('recurrent adult grade iii lymphomatoid granulomatosis', 67),
#  ('ovarian carcinoma', 66),
#  ('progesterone receptor negative', 66),
#  ('primary insomnia', 66),
#  ('cachexia', 66),
#  ('bradycardia', 66),
#  ('aggression', 66),
#  ('brain tumors', 66),
#  ('lymphoma, large b-cell, diffuse', 66),
#  ('surgical wound infection', 66),
#  ('nafld', 66),
#  ('rhinitis', 66),
#  ('refractory acute myeloid leukemia', 66),
#  ('androgenetic alopecia', 66),
#  ('juvenile idiopathic arthritis', 66),
#  ('postmenopausal osteoporosis', 66),
#  ('thalassemia', 66),
#  ('laparoscopy', 66),
#  ('xerostomia', 65),
#  ('gastrointestinal stromal tumor', 65),
#  ('stage iv mantle cell lymphoma', 65),
#  ('metastatic pancreatic adenocarcinoma', 65),
#  ('hysterectomy', 65),
#  ('transient ischemic attack', 65),
#  ('shock', 65),
#  ('gallbladder cancer', 65),
#  ('recurrent glioblastoma', 65),
#  ('sleep apnea syndromes', 65),
#  ('gastrointestinal stromal tumors', 65),
#  ('recurrent childhood acute myeloid leukemia', 65),
#  ('preterm infant', 65),
#  ('wound healing', 65),
#  ('chemotherapy', 65),
#  ('urinary bladder, overactive', 64),
#  ('non-small cell lung cancer (nsclc)', 64),
#  ('lumbar spinal stenosis', 64),
#  ('rhinitis, allergic, perennial', 64),
#  ('stage iv adult diffuse large cell lymphoma', 64),
#  ('hematological malignancies', 64),
#  ('periodontal disease', 64),
#  ('renal cancer', 64),
#  ('fasting', 64),
#  ('virus diseases', 64),
#  ('gastroesophageal junction adenocarcinoma', 64),
#  ('intraocular lymphoma', 64),
#  ('stage iii multiple myeloma', 64),
#  ('sexual behavior', 63),
#  ('psychological distress', 63),
#  ('brain injury', 63),
#  ('scleroderma', 63),
#  ('peripheral vascular diseases', 63),
#  ('infant, premature', 63),
#  ('oncology', 63),
#  ("barrett's esophagus", 63),
#  ('mechanical ventilation complication', 63),
#  ('obesity, childhood', 63),
#  ('safety issues', 63),
#  ('nutrition', 62),
#  ('migraine headache', 62),
#  ('pcos', 62),
#  ('urinary retention', 62),
#  ('diabetic neuropathy', 62),
#  ('bronchial asthma', 62),
#  ('huntington disease', 62),
#  ("huntington's disease", 62),
#  ('immunosuppression', 62),
#  ('postmenopause', 62),
#  ('arthroplasty, replacement, hip', 61),
#  ('proliferative diabetic retinopathy', 61),
#  ('stage iv grade 1 follicular lymphoma', 61),
#  ('stage iv grade 2 follicular lymphoma', 61),
#  ('triple-negative breast cancer', 61),
#  ('dehydration', 61),
#  ('recurrent acute myeloid leukemia', 61),
#  ('mild traumatic brain injury', 61),
#  ('tendinopathy', 61),
#  ('acute heart failure', 61),
#  ('chronic fatigue syndrome', 61),
#  ('adult nasal type extranodal nk/t-cell lymphoma', 61),
#  ('stage iv small lymphocytic lymphoma', 61),
#  ('varicella', 61),
#  ('hyponatremia', 60),
#  ('heart valve diseases', 60),
#  ('plasma cell myeloma', 60),
#  ('intraocular pressure', 60),
#  ('hyperopia', 60),
#  ('oral mucositis', 60),
#  ('b-cell lymphoma', 60),
#  ('sleep disorder', 60),
#  ('bioequivalence', 60),
#  ('carotid stenosis', 60),
#  ('peri-implantitis', 60),
#  ('domestic violence', 60),
#  ('schizophreniform disorder', 60),
#  ('addiction', 60),
#  ('congenital bleeding disorder', 60),
#  ('drug use', 60),
#  ('suicide, attempted', 60),
#  ('acellular pertussis', 60),
#  ('neoplasms, breast', 60),
#  ('adult acute myeloblastic leukemia without maturation (m1)', 60),
#  ('type1diabetes', 60),
#  ('testicular germ cell tumor', 60),
#  ('otitis media', 59),
#  ('prehypertension', 59),
#  ('hemorrhoids', 59),
#  ('distal radius fracture', 59),
#  ('varicose veins', 59),
#  ('gastrointestinal neoplasms', 59),
#  ('cardiac disease', 59),
#  ('dysmenorrhea', 59),
#  ('recurrence', 59),
#  ('type2 diabetes mellitus', 59),
#  ('magnetic resonance imaging', 59),
#  ('metabolic diseases', 59),
#  ('food allergy', 59),
#  ('venous insufficiency', 59),
#  ('marginal zone lymphoma', 59),
#  ('respiratory distress syndrome, adult', 59),
#  ('copd exacerbation', 59),
#  ('non hodgkin lymphoma', 59),
#  ('psychosocial effects of cancer and its treatment', 59),
#  ('adult pure erythroid leukemia (m6b)', 59),
#  ('adult erythroleukemia (m6a)', 59),
#  ('adult acute monocytic leukemia (m5b)', 59),
#  ('acute renal failure', 59),
#  ('secondary myelodysplastic syndromes', 59),
#  ('stroke, ischemic', 59),
#  ('total knee replacement', 58),
#  ('chronic pancreatitis', 58),
#  ('diabetes mellitus, non-insulin-dependent', 58),
#  ('medulloblastoma', 58),
#  ('barrett esophagus', 58),
#  ('stage iii mantle cell lymphoma', 58),
#  ('stage iv grade 3 follicular lymphoma', 58),
#  ('dilated cardiomyopathy', 58),
#  ('immune thrombocytopenia', 58),
#  ('ascites', 58),
#  ('malaria, falciparum', 58),
#  ('peanut allergy', 58),
#  ('satisfaction', 58),
#  ('hypoxemia', 58),
#  ('uterine cancer', 58),
#  ('anal cancer', 58),
#  ('health knowledge, attitudes, practice', 58),
#  ('gynecologic cancer', 58),
#  ('stage ii multiple myeloma', 58),
#  ('adult acute myelomonocytic leukemia (m4)', 58),
#  ('adult acute megakaryoblastic leukemia (m7)', 58),
#  ('adult acute monoblastic leukemia (m5a)', 58),
#  ('adult acute myeloblastic leukemia with maturation (m2)', 58),
#  ('violence', 57),
#  ('ventricular fibrillation', 57),
#  ('dentin sensitivity', 57),
#  ('pregnancy complications', 57),
#  ('out-of-hospital cardiac arrest', 57),
#  ('fibrosis', 57),
#  ('mobility limitation', 57),
#  ('metastatic prostate cancer', 57),
#  ...]

# %%
len(cond_c)
# Out:
# 63932

# %%
mesh_c.most_common()
# Out:
# [('diabetes mellitus', 6180),
#  ('breast neoplasms', 6042),
#  ('syndrome', 5252),
#  ('diabetes mellitus, type 2', 4834),
#  ('neoplasms', 4573),
#  ('carcinoma', 4466),
#  ('disease', 4362),
#  ('leukemia', 4184),
#  ('lymphoma', 4114),
#  ('lung neoplasms', 3985),
#  ('depression', 3949),
#  ('hypertension', 3673),
#  ('prostatic neoplasms', 3376),
#  ('infection', 3260),
#  ('depressive disorder', 3215),
#  ('carcinoma, non-small-cell lung', 3179),
#  ('hiv infections', 2800),
#  ('coronary artery disease', 2560),
#  ('stroke', 2503),
#  ('colorectal neoplasms', 2456),
#  ('heart failure', 2452),
#  ('hepatitis', 2297),
#  ('wounds and injuries', 2238),
#  ('osteoarthritis', 2200),
#  ('schizophrenia', 2191),
#  ('asthma', 2165),
#  ('communicable diseases', 2147),
#  ('kidney diseases', 2142),
#  ('multiple myeloma', 2130),
#  ('pulmonary disease, chronic obstructive', 2028),
#  ('arthritis', 2011),
#  ('adenocarcinoma', 1946),
#  ('leukemia, myeloid', 1923),
#  ('obesity', 1910),
#  ('neoplasms, plasma cell', 1830),
#  ('cardiovascular diseases', 1826),
#  ('parkinson disease', 1826),
#  ('pain, postoperative', 1825),
#  ('diabetes mellitus, type 1', 1821),
#  ('melanoma', 1788),
#  ('sclerosis', 1786),
#  ('lung diseases', 1767),
#  ('hepatitis a', 1735),
#  ('neoplasm metastasis', 1697),
#  ('alzheimer disease', 1692),
#  ('fibrosis', 1691),
#  ('myocardial ischemia', 1647),
#  ('leukemia, myeloid, acute', 1625),
#  ('lung diseases, obstructive', 1602),
#  ('hepatitis c', 1575),
#  ('pancreatic neoplasms', 1527),
#  ('myelodysplastic syndromes', 1523),
#  ('leukemia, lymphoid', 1517),
#  ('osteoarthritis, knee', 1504),
#  ('hemorrhage', 1500),
#  ('arthritis, rheumatoid', 1482),
#  ('multiple sclerosis', 1476),
#  ('heart diseases', 1472),
#  ('inflammation', 1462),
#  ('overweight', 1457),
#  ('influenza, human', 1439),
#  ('depressive disorder, major', 1430),
#  ('ischemia', 1424),
#  ('lymphoma, non-hodgkin', 1401),
#  ('ulcer', 1391),
#  ('atrial fibrillation', 1384),
#  ('coronary disease', 1371),
#  ('infarction', 1356),
#  ('back pain', 1338),
#  ('renal insufficiency, chronic', 1324),
#  ('carcinoma, hepatocellular', 1312),
#  ('cognitive dysfunction', 1252),
#  ('myocardial infarction', 1240),
#  ('renal insufficiency', 1233),
#  ('anxiety disorders', 1219),
#  ('infertility', 1203),
#  ('precursor cell lymphoblastic leukemia-lymphoma', 1199),
#  ('ovarian neoplasms', 1182),
#  ('preleukemia', 1170),
#  ('low back pain', 1161),
#  ('kidney failure, chronic', 1160),
#  ('stomach neoplasms', 1158),
#  ('head and neck neoplasms', 1152),
#  ('leukemia, lymphocytic, chronic, b-cell', 1090),
#  ('sleep apnea syndromes', 1090),
#  ('psoriasis', 1087),
#  ('glioblastoma', 1084),
#  ('carcinoma, ovarian epithelial', 1049),
#  ('carcinoma, renal cell', 1049),
#  ('anemia', 1033),
#  ('fractures, bone', 1033),
#  ('carcinoma, squamous cell', 1026),
#  ('insulin resistance', 1022),
#  ('premature birth', 1022),
#  ('stress disorders, post-traumatic', 990),
#  ('substance-related disorders', 978),
#  ('metabolic syndrome', 972),
#  ('mental disorders', 969),
#  ('sarcoma', 962),
#  ('brain injuries', 961),
#  ('lymphoma, b-cell', 958),
#  ('acquired immunodeficiency syndrome', 950),
#  ('sleep apnea, obstructive', 948),
#  ('glaucoma', 945),
#  ('hepatitis b', 942),
#  ('chronic pain', 941),
#  ('bipolar disorder', 938),
#  ('hypersensitivity', 935),
#  ('weight loss', 932),
#  ('psychotic disorders', 922),
#  ('pneumonia', 889),
#  ('osteoporosis', 883),
#  ('alcoholism', 879),
#  ('liver diseases', 868),
#  ('malaria', 846),
#  ('spinal cord injuries', 832),
#  ('cystic fibrosis', 825),
#  ('apnea', 819),
#  ('dermatitis', 818),
#  ('hepatitis c, chronic', 802),
#  ('crohn disease', 790),
#  ('epilepsy', 789),
#  ('recurrence', 788),
#  ('hypercholesterolemia', 779),
#  ('rhinitis', 778),
#  ('glioma', 773),
#  ('malnutrition', 772),
#  ('fatigue', 771),
#  ('esophageal neoplasms', 769),
#  ('dementia', 764),
#  ('emergencies', 761),
#  ('peripheral arterial disease', 761),
#  ('lymphoma, large b-cell, diffuse', 753),
#  ('stress disorders, traumatic', 752),
#  ('rectal neoplasms', 743),
#  ('attention deficit disorder with hyperactivity', 739),
#  ('migraine disorders', 734),
#  ('leukemia, myelogenous, chronic, bcr-abl positive', 717),
#  ('brain injuries, traumatic', 716),
#  ('macular degeneration', 715),
#  ('uterine cervical neoplasms', 715),
#  ('cataract', 712),
#  ('sleep initiation and maintenance disorders', 704),
#  ('brain neoplasms', 703),
#  ('urinary bladder neoplasms', 703),
#  ('rhinitis, allergic', 692),
#  ('tuberculosis', 688),
#  ('colitis, ulcerative', 680),
#  ('liver neoplasms', 671),
#  ('liver cirrhosis', 663),
#  ('colitis', 652),
#  ('atherosclerosis', 648),
#  ('thrombosis', 648),
#  ('tobacco use disorder', 639),
#  ('dermatitis, atopic', 636),
#  ('fatty liver', 624),
#  ('vomiting', 620),
#  ('neuralgia', 615),
#  ('body weight', 612),
#  ('respiratory insufficiency', 610),
#  ('peripheral vascular diseases', 603),
#  ('hodgkin disease', 595),
#  ('urinary incontinence', 595),
#  ('virus diseases', 591),
#  ('acute coronary syndrome', 591),
#  ('headache', 588),
#  ('hepatitis, chronic', 588),
#  ('small cell lung carcinoma', 586),
#  ('colonic neoplasms', 583),
#  ('dyslipidemias', 574),
#  ('diarrhea', 573),
#  ('eczema', 572),
#  ('autistic disorder', 561),
#  ('constipation', 561),
#  ('critical illness', 558),
#  ('fibromyalgia', 555),
#  ('myofascial pain syndromes', 549),
#  ('respiratory distress syndrome, adult', 548),
#  ('macular edema', 546),
#  ('squamous cell carcinoma of head and neck', 545),
#  ('non-alcoholic fatty liver disease', 542),
#  ('atrophy', 539),
#  ('kidney neoplasms', 538),
#  ('autism spectrum disorder', 533),
#  ('hyperkinesis', 529),
#  ('hernia', 516),
#  ('central nervous system neoplasms', 516),
#  ('vascular diseases', 516),
#  ('graft vs host disease', 515),
#  ('periodontitis', 514),
#  ('dry eye syndromes', 512),
#  ('lymphoma, mantle-cell', 511),
#  ('hyperplasia', 510),
#  ('edema', 505),
#  ('respiratory aspiration', 504),
#  ('irritable bowel syndrome', 503),
#  ('constriction, pathologic', 503),
#  ('nervous system neoplasms', 501),
#  ('aneurysm', 500),
#  ('gastroesophageal reflux', 499),
#  ('glaucoma, open-angle', 498),
#  ('hyperlipidemias', 498),
#  ('anemia, sickle cell', 496),
#  ('endometrial neoplasms', 492),
#  ('lymphoma, t-cell', 487),
#  ('hypertension, pulmonary', 486),
#  ('cerebral palsy', 480),
#  ('enuresis', 471),
#  ('pediatric obesity', 469),
#  ('keratoconjunctivitis sicca', 469),
#  ('prediabetic state', 468),
#  ('opioid-related disorders', 467),
#  ('hepatitis b, chronic', 465),
#  ('peripheral nervous system diseases', 464),
#  ('respiratory distress syndrome, newborn', 463),
#  ('triple negative breast neoplasms', 461),
#  ('sepsis', 460),
#  ('dental caries', 459),
#  ('alcohol drinking', 459),
#  ('seizures', 458),
#  ('immunologic deficiency syndromes', 454),
#  ('hypoxia', 451),
#  ('nausea', 451),
#  ('fallopian tube neoplasms', 445),
#  ('lymphoma, follicular', 444),
#  ('diabetic foot', 442),
#  ('lupus erythematosus, systemic', 440),
#  ('acne vulgaris', 432),
#  ('cardiomyopathies', 428),
#  ('vitamin d deficiency', 427),
#  ('urinary bladder, overactive', 427),
#  ('sleep wake disorders', 425),
#  ('acute kidney injury', 423),
#  ('ocular hypertension', 423),
#  ('chronic disease', 420),
#  ('neuroblastoma', 414),
#  ('thyroid diseases', 413),
#  ('polycystic ovary syndrome', 411),
#  ('hearing loss', 403),
#  ('acute pain', 394),
#  ('myeloproliferative disorders', 394),
#  ('hypotension', 393),
#  ('shock', 390),
#  ('respiratory tract infections', 388),
#  ('glucose intolerance', 387),
#  ('myopia', 386),
#  ('foot ulcer', 385),
#  ('carcinoma, transitional cell', 383),
#  ('anemia, iron-deficiency', 380),
#  ('inflammatory bowel diseases', 376),
#  ('thromboembolism', 376),
#  ('retinal diseases', 369),
#  ('metabolic diseases', 368),
#  ('delirium', 367),
#  ('amyotrophic lateral sclerosis', 366),
#  ('hemophilia a', 366),
#  ('motor neuron disease', 365),
#  ('cocaine-related disorders', 365),
#  ('erectile dysfunction', 364),
#  ('neoplasms, second primary', 364),
#  ('intestinal diseases', 362),
#  ('obesity, morbid', 360),
#  ('cholangiocarcinoma', 360),
#  ('prostatic hyperplasia', 359),
#  ('hyperglycemia', 357),
#  ('joint diseases', 356),
#  ('urinary tract infections', 352),
#  ('mycoses', 351),
#  ('thyroid neoplasms', 348),
#  ('venous thrombosis', 346),
#  ('nasopharyngeal carcinoma', 344),
#  ('shock, septic', 343),
#  ('congenital abnormalities', 342),
#  ('skin neoplasms', 340),
#  ('cerebral infarction', 340),
#  ('heart arrest', 338),
#  ('postoperative complications', 337),
#  ('neck pain', 335),
#  ('multiple sclerosis, relapsing-remitting', 335),
#  ('hypoglycemia', 333),
#  ('fever', 333),
#  ('prolapse', 329),
#  ('fistula', 326),
#  ('diabetic retinopathy', 323),
#  ('diabetic neuropathies', 321),
#  ('surgical wound', 314),
#  ('tachycardia', 314),
#  ('obsessive-compulsive disorder', 313),
#  ('hypertrophy', 312),
#  ('compulsive personality disorder', 311),
#  ('acute lung injury', 311),
#  ('neuroendocrine tumors', 310),
#  ('mesothelioma', 308),
#  ('burns', 307),
#  ('aortic valve stenosis', 306),
#  ('toxemia', 305),
#  ('pancreatitis', 303),
#  ('bacterial infections', 302),
#  ('rhinitis, allergic, seasonal', 300),
#  ('embolism', 299),
#  ('thrombocytopenia', 298),
#  ('psychomotor agitation', 298),
#  ('essential hypertension', 297),
#  ('hip fractures', 296),
#  ('gastrointestinal neoplasms', 296),
#  ('adenoma', 289),
#  ('stress, psychological', 286),
#  ('brain diseases', 286),
#  ('urinary incontinence, stress', 286),
#  ('nervous system diseases', 283),
#  ('feeding and eating disorders', 283),
#  ('paralysis', 283),
#  ('parasomnias', 282),
#  ('diabetes, gestational', 281),
#  ('aortic aneurysm', 281),
#  ('astrocytoma', 278),
#  ('surgical wound infection', 277),
#  ('angina pectoris', 277),
#  ('muscle spasticity', 273),
#  ('pulmonary fibrosis', 270),
#  ('postoperative nausea and vomiting', 270),
#  ('mood disorders', 269),
#  ('waldenstrom macroglobulinemia', 267),
#  ('suicide', 266),
#  ('hypothermia', 265),
#  ('marijuana abuse', 265),
#  ('conjunctivitis', 264),
#  ('venous thromboembolism', 262),
#  ('deafness', 262),
#  ('sarcopenia', 262),
#  ('eye diseases', 261),
#  ('keratosis', 261),
#  ('endometriosis', 260),
#  ('leiomyoma', 259),
#  ('sinusitis', 259),
#  ('diabetic nephropathies', 258),
#  ('mucositis', 258),
#  ('muscular dystrophies', 256),
#  ('keratosis, actinic', 255),
#  ('birth weight', 254),
#  ('osteoarthritis, hip', 253),
#  ('problem behavior', 252),
#  ('rotator cuff injuries', 250),
#  ('burkitt lymphoma', 250),
#  ('rupture', 248),
#  ('pulmonary embolism', 247),
#  ('necrosis', 245),
#  ('peritoneal neoplasms', 245),
#  ('carcinoma in situ', 243),
#  ('meningitis', 243),
#  ('scleroderma, systemic', 243),
#  ('scleroderma, diffuse', 243),
#  ('neutropenia', 241),
#  ('st elevation myocardial infarction', 238),
#  ('pre-eclampsia', 237),
#  ('hypogonadism', 235),
#  ('familial primary pulmonary hypertension', 235),
#  ('chronic periodontitis', 234),
#  ('myofibroma', 234),
#  ('muscle weakness', 233),
#  ('paresis', 231),
#  ('alopecia', 229),
#  ('weight gain', 226),
#  ('gastrointestinal diseases', 226),
#  ('shoulder pain', 225),
#  ('lymphoma, t-cell, peripheral', 223),
#  ('leukemia, myelomonocytic, juvenile', 222),
#  ('wound infection', 221),
#  ('hernia, inguinal', 221),
#  ('lymphoma, t-cell, cutaneous', 221),
#  ('malaria, falciparum', 221),
#  ('amyloidosis', 219),
#  ('thalassemia', 216),
#  ('lymphoma, b-cell, marginal zone', 216),
#  ('postpartum hemorrhage', 214),
#  ('bronchiolitis', 213),
#  ('osteosarcoma', 213),
#  ('idiopathic pulmonary fibrosis', 212),
#  ('anorexia', 212),
#  ('hyperlipoproteinemias', 212),
#  ('idiopathic interstitial pneumonias', 211),
#  ('liver failure', 211),
#  ('aggression', 211),
#  ('diphtheria', 211),
#  ('leukemia, myelomonocytic, chronic', 211),
#  ('primary myelofibrosis', 211),
#  ('dyspepsia', 210),
#  ('behavior, addictive', 210),
#  ('sexually transmitted diseases', 209),
#  ('gliosarcoma', 208),
#  ('digestive system diseases', 208),
#  ('alopecia areata', 206),
#  ('phobia, social', 206),
#  ('child development disorders, pervasive', 205),
#  ('hyperparathyroidism', 204),
#  ('pelvic organ prolapse', 202),
#  ('herpes zoster', 201),
#  ('varicose ulcer', 201),
#  ('hemostatic disorders', 200),
#  ('blood coagulation disorders', 200),
#  ('bone diseases, metabolic', 200),
#  ('dyspnea', 200),
#  ('neoplasms, germ cell and embryonal', 200),
#  ('deglutition disorders', 199),
#  ('cicatrix', 198),
#  ('kidney calculi', 198),
#  ('tendinopathy', 198),
#  ('myelodysplastic-myeloproliferative diseases', 196),
#  ('purpura, thrombocytopenic, idiopathic', 195),
#  ('clostridium infections', 194),
#  ('tinnitus', 194),
#  ('esophageal squamous cell carcinoma', 193),
#  ('muscular dystrophy, duchenne', 191),
#  ('angina, stable', 191),
#  ('gastrointestinal stromal tumors', 191),
#  ('arthritis, psoriatic', 189),
#  ('gingivitis', 188),
#  ('intervertebral disc degeneration', 188),
#  ('hypertriglyceridemia', 187),
#  ('lymphedema', 187),
#  ('spondylitis', 187),
#  ('oropharyngeal neoplasms', 186),
#  ('spondylitis, ankylosing', 184),
#  ('osteoporosis, postmenopausal', 184),
#  ('esophagitis, peptic', 183),
#  ('stomatitis', 183),
#  ('anemia, aplastic', 182),
#  ('hot flashes', 181),
#  ('uveitis', 181),
#  ('pressure ulcer', 181),
#  ('leg ulcer', 181),
#  ('periodontal diseases', 181),
#  ('infertility, female', 181),
#  ('cervical intraepithelial neoplasia', 180),
#  ('muscular atrophy', 180),
#  ('dyssomnias', 180),
#  ('candidiasis', 179),
#  ('neovascularization, pathologic', 179),
#  ('meningococcal infections', 179),
#  ('spinal stenosis', 178),
#  ('cognition disorders', 178),
#  ('emphysema', 178),
#  ('aortic aneurysm, abdominal', 178),
#  ('depressive disorder, treatment-resistant', 178),
#  ('respiratory tract diseases', 175),
#  ('heart defects, congenital', 175),
#  ('plasmacytoma', 175),
#  ('carpal tunnel syndrome', 174),
#  ('personality disorders', 174),
#  ('purpura', 173),
#  ('bulimia', 172),
#  ('disease progression', 172),
#  ('esophagitis', 172),
#  ('mycosis fungoides', 172),
#  ('brain concussion', 171),
#  ('retinal vein occlusion', 171),
#  ('astigmatism', 171),
#  ('carcinoma, basal cell', 170),
#  ('depression, postpartum', 170),
#  ('somatoform disorders', 169),
#  ('skin diseases', 169),
#  ('hepatic insufficiency', 169),
#  ('subarachnoid hemorrhage', 169),
#  ('scoliosis', 168),
#  ('biliary tract neoplasms', 167),
#  ('nephrolithiasis', 167),
#  ('aphasia', 166),
#  ('lung injury', 166),
#  ('cytomegalovirus infections', 165),
#  ('calculi', 165),
#  ('acute disease', 165),
#  ('lymphoma, large-cell, anaplastic', 165),
#  ('conjunctivitis, allergic', 164),
#  ('reperfusion injury', 163),
#  ('pulmonary valve insufficiency', 162),
#  ('anorexia nervosa', 161),
#  ('hematologic diseases', 161),
#  ('heart valve diseases', 160),
#  ('refractive errors', 160),
#  ('arteriosclerosis', 160),
#  ('pneumonia, ventilator-associated', 159),
#  ('polyps', 159),
#  ('gingival recession', 159),
#  ('sarcoma, ewing', 158),
#  ('poliomyelitis', 158),
#  ('pelvic pain', 158),
#  ('uterine neoplasms', 157),
#  ('mitral valve insufficiency', 156),
#  ('gallstones', 156),
#  ('precancerous conditions', 156),
#  ('retinitis', 155),
#  ('otitis media', 155),
#  ('brain ischemia', 155),
#  ('abdominal pain', 155),
#  ('musculoskeletal diseases', 154),
#  ('cough', 154),
#  ('purpura, thrombocytopenic', 154),
#  ('otitis', 153),
#  ('lymphoproliferative disorders', 152),
#  ('pleural effusion', 151),
#  ('barrett esophagus', 151),
#  ('appendicitis', 151),
#  ('tachycardia, ventricular', 151),
#  ('pruritus', 150),
#  ('oligodendroglioma', 150),
#  ('intermittent claudication', 150),
#  ('encephalitis', 150),
#  ('papillomavirus infections', 149),
#  ('epilepsies, partial', 149),
#  ('radiculopathy', 148),
#  ('bronchopulmonary dysplasia', 148),
#  ('cerebral hemorrhage', 147),
#  ('cachexia', 147),
#  ('whooping cough', 147),
#  ('arthritis, juvenile', 146),
#  ('restless legs syndrome', 145),
#  ('bronchitis', 145),
#  ('chest pain', 145),
#  ('signs and symptoms', 144),
#  ('musculoskeletal pain', 144),
#  ('medulloblastoma', 144),
#  ('adenocarcinoma of lung', 143),
#  ('autoimmune diseases', 143),
#  ('cancer pain', 143),
#  ('rhinitis, allergic, perennial', 142),
#  ('frailty', 142),
#  ('panic disorder', 142),
#  ('fecal incontinence', 142),
#  ('labor pain', 141),
#  ('drug-related side effects and adverse reactions', 141),
#  ('beta-thalassemia', 141),
#  ('gastroparesis', 141),
#  ('angina, unstable', 141),
#  ('bone neoplasms', 140),
#  ('temporomandibular joint disorders', 140),
#  ('pneumococcal infections', 140),
#  ('ankle injuries', 139),
#  ('temporomandibular joint dysfunction syndrome', 139),
#  ('radius fractures', 139),
#  ('malocclusion', 139),
#  ('tuberculosis, pulmonary', 139),
#  ('rhabdomyosarcoma', 138),
#  ('bacteremia', 138),
#  ('rosacea', 138),
#  ('dystonia', 137),
#  ('tissue adhesions', 137),
#  ('arterial occlusive diseases', 136),
#  ('gastrointestinal hemorrhage', 136),
#  ('hematologic neoplasms', 135),
#  ('leukemia, myelomonocytic, acute', 135),
#  ('hyperparathyroidism, secondary', 135),
#  ('nutrition disorders', 134),
#  ('lower urinary tract symptoms', 134),
#  ('nasopharyngeal neoplasms', 134),
#  ('lung diseases, interstitial', 134),
#  ('huntington disease', 134),
#  ('presbyopia', 133),
#  ('endocrine system diseases', 132),
#  ('bronchiectasis', 132),
#  ('leukemia, myeloid, chronic-phase', 131),
#  ('binge-eating disorder', 131),
#  ('digestive system neoplasms', 131),
#  ('choroidal neovascularization', 131),
#  ('pharyngitis', 130),
#  ('keratoconus', 130),
#  ('cystitis', 130),
#  ('carcinoma, neuroendocrine', 129),
#  ('gastroenteritis', 129),
#  ('polycythemia', 129),
#  ('pulmonary emphysema', 128),
#  ('suicidal ideation', 128),
#  ('respiration disorders', 127),
#  ('dengue', 127),
#  ('sezary syndrome', 127),
#  ('sarcoidosis', 126),
#  ('papilloma', 126),
#  ('polycythemia vera', 126),
#  ('carotid stenosis', 125),
#  ('ventricular dysfunction', 125),
#  ('dyskinesias', 125),
#  ('tremor', 124),
#  ('spondylarthritis', 124),
#  ("sjogren's syndrome", 123),
#  ('tourette syndrome', 123),
#  ('tetanus', 123),
#  ('dystonic disorders', 123),
#  ('ataxia', 122),
#  ('neuralgia, postherpetic', 122),
#  ('sleep deprivation', 122),
#  ('laryngeal neoplasms', 122),
#  ('ascites', 122),
#  ('borderline personality disorder', 122),
#  ('intracranial aneurysm', 121),
#  ('hemiplegia', 121),
#  ('leishmaniasis', 121),
#  ('arrhythmias, cardiac', 121),
#  ('mouth neoplasms', 121),
#  ('polyneuropathies', 120),
#  ('cerebrovascular disorders', 120),
#  ('obstetric labor, premature', 120),
#  ('cholestasis', 120),
#  ('cystadenocarcinoma, serous', 120),
#  ('bile duct neoplasms', 120),
#  ('hiv seropositivity', 119),
#  ('leukemia, t-cell', 119),
#  ('celiac disease', 119),
#  ('lymphoma, extranodal nk-t-cell', 119),
#  ('blast crisis', 119),
#  ('nephritis', 118),
#  ('obesity, abdominal', 118),
#  ('dilatation, pathologic', 118),
#  ('gallbladder neoplasms', 118),
#  ('plasmablastic lymphoma', 118),
#  ('lymphoma, large-cell, immunoblastic', 118),
#  ('vaginosis, bacterial', 117),
#  ('pain', 117),
#  ('hypertension, portal', 117),
#  ('intestinal neoplasms', 117),
#  ('sprains and strains', 116),
#  ('death', 116),
#  ('urticaria', 116),
#  ('proteinuria', 116),
#  ('eclampsia', 115),
#  ('cholelithiasis', 115),
#  ('myalgia', 115),
#  ('hemophilia b', 115),
#  ('coronary stenosis', 114),
#  ('ependymoma', 114),
#  ('cholecystolithiasis', 113),
#  ('neurofibromatoses', 113),
#  ('staphylococcal infections', 113),
#  ('wet macular degeneration', 113),
#  ('neuroectodermal tumors, primitive', 113),
#  ('developmental disabilities', 113),
#  ('wasting syndrome', 113),
#  ('ischemic attack, transient', 112),
#  ('femoral fractures', 112),
#  ('hyperalgesia', 112),
#  ('anterior cruciate ligament injuries', 112),
#  ('memory disorders', 112),
#  ('dysmenorrhea', 112),
#  ('rheumatic diseases', 111),
#  ('agnosia', 111),
#  ('philadelphia chromosome', 111),
#  ('neuroectodermal tumors', 111),
#  ('sarcoma, kaposi', 111),
#  ('thrombocytosis', 111),
#  ('carcinoid tumor', 111),
#  ('onychomycosis', 110),
#  ('bone diseases', 110),
#  ('colonic polyps', 109),
#  ('lipodystrophy', 109),
#  ('gout', 109),
#  ('respiratory syncytial virus infections', 109),
#  ('food hypersensitivity', 109),
#  ('peptic ulcer', 109),
#  ('carcinoma, ductal', 109),
#  ('cholangitis', 108),
#  ('glucose metabolism disorders', 108),
#  ('thrombocythemia, essential', 108),
#  ('hyperlipoproteinemia type ii', 107),
#  ('arthralgia', 107),
#  ('leukemia-lymphoma, adult t-cell', 107),
#  ('lupus nephritis', 107),
#  ('vaginal diseases', 106),
#  ('xerostomia', 106),
#  ('menorrhagia', 106),
#  ('down syndrome', 106),
#  ('herpes simplex', 106),
#  ('hyperphosphatemia', 105),
#  ('common cold', 105),
#  ('carcinoma, intraductal, noninfiltrating', 104),
#  ('varicose veins', 104),
#  ('venous insufficiency', 104),
#  ('cerebellar ataxia', 103),
#  ('urinary retention', 103),
#  ('immunoblastic lymphadenopathy', 103),
#  ('cellulitis', 103),
#  ('shoulder impingement syndrome', 102),
#  ('influenza in birds', 102),
#  ('iron overload', 102),
#  ('hepatic encephalopathy', 102),
#  ('facies', 102),
#  ('bursitis', 101),
#  ('dentin sensitivity', 101),
#  ('spondylolisthesis', 101),
#  ('anus neoplasms', 101),
#  ('atrial flutter', 101),
#  ('deficiency diseases', 101),
#  ('hearing loss, sensorineural', 101),
#  ('dwarfism, pituitary', 100),
#  ('optic neuritis', 100),
#  ('vitiligo', 100),
#  ('hyperuricemia', 100),
#  ('neurofibroma', 100),
#  ('retinitis pigmentosa', 99),
#  ('essential tremor', 99),
#  ('cardiomyopathy, dilated', 99),
#  ('enterocolitis', 99),
#  ('cystitis, interstitial', 99),
#  ('tennis elbow', 98),
#  ('neurofibromatosis 1', 98),
#  ('out-of-hospital cardiac arrest', 98),
#  ('bradycardia', 98),
#  ('nasal polyps', 98),
#  ('telangiectasis', 98),
#  ('prehypertension', 97),
#  ('abortion, spontaneous', 97),
#  ('breast neoplasms, male', 97),
#  ('pick disease of the brain', 96),
#  ('pulpitis', 96),
#  ('meningioma', 96),
#  ('bone marrow diseases', 96),
#  ('acromegaly', 96),
#  ('aspergillosis', 96),
#  ('aneurysm, dissecting', 96),
#  ('heart failure, systolic', 96),
#  ('fasciitis', 95),
#  ('craniocerebral trauma', 95),
#  ('muscular diseases', 95),
#  ('hernia, ventral', 94),
#  ('hematoma', 94),
#  ('neoplasms, squamous cell', 94),
#  ('phobic disorders', 94),
#  ('pregnancy complications', 93),
#  ('pulmonary atelectasis', 93),
#  ('vision disorders', 92),
#  ('spinal diseases', 92),
#  ('streptococcal infections', 92),
#  ('gait disorders, neurologic', 91),
#  ('end stage liver disease', 91),
#  ('angioedema', 91),
#  ('peritonitis', 91),
#  ('chickenpox', 91),
#  ('neuromuscular diseases', 91),
#  ('sleepiness', 91),
#  ('alveolar bone loss', 90),
#  ('pancreatitis, chronic', 90),
#  ('cholecystitis', 90),
#  ('dental plaque', 90),
#  ('polycystic kidney diseases', 90),
#  ('retinal detachment', 90),
#  ('leiomyosarcoma', 90),
#  ('dizziness', 89),
#  ('blood loss, surgical', 89),
#  ('mobility limitation', 89),
#  ('mouth, edentulous', 89),
#  ('vision, low', 89),
#  ('eosinophilic esophagitis', 89),
#  ('bronchitis, chronic', 89),
#  ('vertigo', 88),
#  ('primary ovarian insufficiency', 88),
#  ('hemorrhoids', 88),
#  ('heart failure, diastolic', 88),
#  ('pituitary diseases', 87),
#  ('patellofemoral pain syndrome', 87),
#  ('genetic diseases, inborn', 87),
#  ('death, sudden, cardiac', 87),
#  ('vasculitis', 87),
#  ('arteriovenous fistula', 87),
#  ('acidosis', 87),
#  ('breast carcinoma in situ', 86),
#  ('abscess', 86),
#  ('warts', 86),
#  ('glomerulonephritis, iga', 86),
#  ('frontotemporal dementia', 85),
#  ('aphasia, primary progressive', 85),
#  ('collagen diseases', 85),
#  ('suicide, attempted', 85),
#  ('fasciitis, plantar', 85),
#  ('reflex sympathetic dystrophy', 85),
#  ('salivary gland neoplasms', 85),
#  ('quadriplegia', 85),
#  ('colic', 84),
#  ('helicobacter infections', 84),
#  ('altitude sickness', 84),
#  ('lipid metabolism disorders', 83),
#  ('ankle fractures', 83),
#  ('complex regional pain syndromes', 83),
#  ('urinary incontinence, urge', 83),
#  ('body weight changes', 83),
#  ('carotid artery diseases', 83),
#  ('gambling', 83),
#  ('ileus', 83),
#  ('femoral neck fractures', 82),
#  ('dehydration', 82),
#  ('ureteral neoplasms', 82),
#  ('meningitis, meningococcal', 82),
#  ('fatigue syndrome, chronic', 82),
#  ('lymphomatoid granulomatosis', 82),
#  ('coinfection', 81),
#  ('syncope', 81),
#  ('pneumonia, bacterial', 81),
#  ('urolithiasis', 81),
#  ('hypercapnia', 81),
#  ('leukemia, erythroblastic, acute', 81),
#  ('fabry disease', 81),
#  ('hyponatremia', 80),
#  ('carcinoma, ductal, breast', 80),
#  ('ventricular dysfunction, left', 80),
#  ('neoplasm, residual', 80),
#  ('peanut hypersensitivity', 80),
#  ('measles', 80),
#  ('substance withdrawal syndrome', 80),
#  ('dissociative disorders', 80),
#  ('liver cirrhosis, biliary', 80),
#  ('sexual dysfunctions, psychological', 80),
#  ('drug resistant epilepsy', 79),
#  ('emergence delirium', 79),
#  ('immune system diseases', 79),
#  ('leukemia, prolymphocytic', 79),
#  ('carcinoma, small cell', 79),
#  ('poisoning', 79),
#  ('hypothyroidism', 79),
#  ('laryngeal diseases', 79),
#  ('cystadenocarcinoma', 79),
#  ('mucopolysaccharidoses', 78),
#  ('esophageal and gastric varices', 78),
#  ('hyperhidrosis', 78),
#  ('joint dislocations', 78),
#  ('cardiomyopathy, hypertrophic', 78),
#  ('calcinosis', 78),
#  ('muscular atrophy, spinal', 78),
#  ('testicular neoplasms', 78),
#  ('infertility, male', 78),
#  ('intellectual disability', 78),
#  ('multiple sclerosis, chronic progressive', 78),
#  ('enterocolitis, necrotizing', 77),
#  ('contracture', 77),
#  ('leukemia, monocytic, acute', 77),
#  ('jaw, edentulous', 77),
#  ('leukemia, hairy cell', 77),
#  ('fetal growth retardation', 76),
#  ('tooth loss', 76),
#  ('polycystic kidney, autosomal dominant', 76),
#  ('amblyopia', 76),
#  ('carcinoma, endometrioid', 76),
#  ('liposarcoma', 76),
#  ('vulvar neoplasms', 76),
#  ('leukemia, megakaryoblastic, acute', 76),
#  ('leukemia, myeloid, accelerated phase', 76),
#  ('hypotension, orthostatic', 75),
#  ('uterine hemorrhage', 75),
#  ('gastritis', 75),
#  ('keratoconjunctivitis', 75),
#  ('genital neoplasms, female', 75),
#  ('cross infection', 75),
#  ('knee injuries', 74),
#  ('attention deficit and disruptive behavior disorders', 74),
#  ('self-injurious behavior', 74),
#  ('diabetes complications', 74),
#  ('hemolysis', 74),
#  ('leukemia, promyelocytic, acute', 74),
#  ('skin diseases, infectious', 74),
#  ('adenocarcinoma, clear cell', 74),
#  ('neurotoxicity syndromes', 74),
#  ('pneumothorax', 73),
#  ('spinal fractures', 73),
#  ('peri-implantitis', 73),
#  ('pleural effusion, malignant', 72),
#  ('hypoxia-ischemia, brain', 72),
#  ('movement disorders', 72),
#  ('aortic aneurysm, thoracic', 72),
#  ('blindness', 72),
#  ('hemangioma', 72),
#  ('burnout, psychological', 72),
#  ('urinary bladder, neurogenic', 71),
#  ('erythema', 71),
#  ('rabies', 71),
#  ('spinal cord diseases', 71),
#  ('incisional hernia', 70),
#  ('albuminuria', 70),
#  ('immunoglobulin light-chain amyloidosis', 70),
#  ('jaundice', 70),
#  ('myasthenia gravis', 70),
#  ('heroin dependence', 70),
#  ('short bowel syndrome', 69),
#  ('stomach ulcer', 69),
#  ('retinopathy of prematurity', 69),
#  ('glomerulonephritis', 69),
#  ('cardiotoxicity', 69),
#  ('angioedemas, hereditary', 69),
#  ('spasm', 69),
#  ('ductus arteriosus, patent', 69),
#  ('lichen planus', 69),
#  ('anemia, refractory, with excess of blasts', 69),
#  ('hypoventilation', 69),
#  ('mycobacterium infections', 69),
#  ('wilms tumor', 68),
#  ('tinea', 68),
#  ('pterygium', 68),
#  ('humeral fractures', 68),
#  ('intervertebral disc displacement', 68),
#  ('vaginal neoplasms', 68),
#  ('toothache', 68),
#  ('gaucher disease', 68),
#  ('geographic atrophy', 67),
#  ('phantom limb', 67),
#  ('retinoblastoma', 67),
#  ('hemoglobinuria, paroxysmal', 67),
#  ('gonorrhea', 66),
#  ('neoplastic cells, circulating', 66),
#  ('lacerations', 66),
#  ('bulimia nervosa', 66),
#  ('rubella', 66),
#  ('epidermolysis bullosa', 66),
#  ('urethral neoplasms', 66),
#  ('nephrotic syndrome', 66),
#  ('nephrosis', 66),
#  ('urologic diseases', 66),
#  ('intracranial hypertension', 65),
#  ('hyperopia', 65),
#  ('esophageal achalasia', 65),
#  ('torticollis', 65),
#  ('prader-willi syndrome', 65),
#  ('intraocular lymphoma', 65),
#  ('leishmaniasis, cutaneous', 64),
#  ('systemic inflammatory response syndrome', 64),
#  ('rectal fistula', 64),
#  ('tonsillitis', 64),
#  ('dementia, vascular', 64),
#  ('hemoglobinuria', 64),
#  ('post-concussion syndrome', 63),
#  ('heartburn', 63),
#  ('uterine cervical dysplasia', 63),
#  ('hidradenitis suppurativa', 63),
#  ('hidradenitis', 63),
#  ('optic nerve diseases', 63),
#  ('avitaminosis', 63),
#  ('colonic diseases', 63),
#  ('phenylketonurias', 63),
#  ('endotoxemia', 63),
#  ('tibial fractures', 63),
#  ('intracranial hemorrhages', 63),
#  ('alcohol-related disorders', 63),
#  ('encephalitis, japanese', 63),
#  ('vaginitis', 63),
#  ('hallux valgus', 63),
#  ('neoplasms, unknown primary', 63),
#  ('sleep disorders, circadian rhythm', 63),
#  ('ventricular fibrillation', 62),
#  ('cholangitis, sclerosing', 62),
#  ('intestinal obstruction', 62),
#  ('latent tuberculosis', 62),
#  ('osteonecrosis', 62),
#  ('neuritis', 62),
#  ('pneumonia, pneumocystis', 62),
#  ('diverticulitis', 62),
#  ('hypereosinophilic syndrome', 62),
#  ('radiodermatitis', 62),
#  ('rotavirus infections', 62),
#  ('disease susceptibility', 62),
#  ('melanosis', 62),
#  ('headache disorders', 61),
#  ('keratitis', 61),
#  ('raynaud disease', 61),
#  ('hydrocephalus', 61),
#  ('intraabdominal infections', 61),
#  ('sciatica', 61),
#  ('carcinoma, merkel cell', 61),
#  ('narcolepsy', 61),
#  ('carcinoma, adenosquamous', 61),
#  ('anemia, refractory', 61),
#  ('hypertension, pregnancy-induced', 61),
#  ('multiple system atrophy', 60),
#  ('uveal neoplasms', 60),
#  ('inflammatory breast neoplasms', 60),
#  ('scleroderma, localized', 60),
#  ('glycogen storage disease type ii', 60),
#  ('hemorrhagic fever, ebola', 60),
#  ('dwarfism', 60),
#  ('exocrine pancreatic insufficiency', 60),
#  ('breast diseases', 60),
#  ('arteritis', 59),
#  ('parkinsonian disorders', 59),
#  ('central nervous system diseases', 59),
#  ('retinal perforations', 59),
#  ('fragile x syndrome', 59),
#  ('dermatomyositis', 59),
#  ('vaccinia', 59),
#  ('coronary restenosis', 59),
#  ('neonatal sepsis', 59),
#  ('hallucinations', 58),
#  ('tooth, impacted', 58),
#  ('neurodegenerative diseases', 58),
#  ('conduct disorder', 58),
#  ('thyroid nodule', 58),
#  ('hepatitis, alcoholic', 58),
#  ('thyroid cancer, papillary', 58),
#  ('growth disorders', 58),
#  ('pituitary neoplasms', 57),
#  ('lewy body disease', 57),
#  ('shy-drager syndrome', 57),
#  ('giant cell arteritis', 57),
#  ('malaria, vivax', 57),
#  ('menopause, premature', 57),
#  ('sarcoma, synovial', 57),
#  ('child nutrition disorders', 57),
#  ('drug overdose', 57),
#  ('lymphadenopathy', 57),
#  ...]

# %%
cond1 = 'non small cell lung cancer'
cond2 = 'carcinoma, non-small-cell lung'

# %%
sub_df['is_cond1'] = sub_df['all_conds'].apply(lambda x: True if cond1 in x else False)
sub_df['is_cond2'] = sub_df['all_conds'].apply(lambda x: True if cond2 in x else False)

# %%
df_cond_nscl = sub_df[(sub_df['is_cond1']) | (sub_df['is_cond2'])]
df_cond_nsc
# Out:
#                                                      all_conds  \
# nct_id
# NCT02705339  [carcinoma, non-small-cell lung, non-small cel...
# NCT02702921                       [non small cell lung cancer]
# NCT02695290   [carcinoma, non-small-cell lung, erbb receptors]
# NCT02684461                       [non small cell lung cancer]
# NCT02679963                       [non small cell lung cancer]
# ...                                                        ...
# NCT02733159                   [carcinoma, non-small-cell lung]
# NCT02716311                       [non small cell lung cancer]
# NCT02716116                   [carcinoma, non-small-cell lung]
# NCT02716038                   [carcinoma, non-small-cell lung]
# NCT02710396  [esophageal squamous cell carcinoma, carcinoma...
#
#                                                       all_mesh  is_cond1  \
# nct_id
# NCT02705339   [lung neoplasms, carcinoma, non-small-cell lung]     False
# NCT02702921                   [carcinoma, non-small-cell lung]      True
# NCT02695290                   [carcinoma, non-small-cell lung]     False
# NCT02684461                   [carcinoma, non-small-cell lung]      True
# NCT02679963   [lung neoplasms, carcinoma, non-small-cell lung]      True
# ...                                                        ...       ...
# NCT02733159                   [carcinoma, non-small-cell lung]     False
# NCT02716311   [lung neoplasms, carcinoma, non-small-cell lung]      True
# NCT02716116                   [carcinoma, non-small-cell lung]     False
# NCT02716038                   [carcinoma, non-small-cell lung]     False
# NCT02710396  [esophageal squamous cell carcinoma, head and ...     False
#
#              is_cond2
# nct_id
# NCT02705339      True
# NCT02702921     False
# NCT02695290      True
# NCT02684461     False
# NCT02679963     False
# ...               ...
# NCT02733159      True
# NCT02716311     False
# NCT02716116      True
# NCT02716038      True
# NCT02710396      True
#
# [848 rows x 4 columns]

# %%
idx = 'NCT02710396'
print('Conditions:')
print(sub_df['all_conds'].loc[idx], '\n')

print('MeSHes:')
print(sub_df['all_mesh'].loc[idx])
# Out:
# Conditions:
# ['esophageal squamous cell carcinoma', 'carcinoma, transitional cell', 'carcinoma, non-small-cell lung', 'cancer of the head and neck', 'urinary bladder neoplasms']
#
# MeSHes:
# ['esophageal squamous cell carcinoma', 'head and neck neoplasms', 'urinary bladder neoplasms', 'carcinoma, transitional cell', 'carcinoma', 'carcinoma, squamous cell', 'carcinoma, non-small-cell lung', 'neoplasms']

# %% [markdown]
# ### Notes
# - build vocabulary on the individual conditions
# - if a condition has sufficient similarity to and existing dictionary term, map it to that term
# - make matrix of conditions-bags to mesh-terms,
# - specifically pay attention to those rows where the condition-bags have the smallest number of conditions (ie none of the conditions in the condition set exists as a single bag)
#     - this sub matrix is our conds to mesh mapping dictionary
#
# - define:
#     - conditions are sufficiently similar when their mesh mappings are sufficiently similar
#         - mesh mapping distance can be calculated using jacobian distance?
#     - non-single condition bags are computed by collecting the mappings on their sub bags
#     - manually tag a few "training data" such as
#         -[carcinoma, non-small-cell lung]
#         -[non small cell lung cancer]
#     - validate jacobian distance cut off such we balance FPR and TPR
