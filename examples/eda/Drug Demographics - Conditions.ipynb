# %%
import pandas as pd
import numpy as np
from tqdm import tqdm_notebook
from tqdm import tqdm
import datetime as dt
import pickle

from fuzzywuzzy import fuzz
from fuzzywuzzy import process

import pdaactconn as pc
from trialexplorer.mesh_terms import MeSHCatalog
from trialexplorer import AACTStudySet

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tqdm.pandas()

# %%
# intializing MeSH object
mc = MeSHCatalog()
# Out:
# Parsing MeSH xml: xml/desc2020.xml ...
# Parse Complete! (parsed ElementTree root can be found in the .root attribute)

# %%
# selecting all interventional studies
conn = pc.AACTConnection(source=pc.AACTConnection.REMOTE)
ss = AACTStudySet.AACTStudySet(conn= conn, tqdm_handler=tqdm_notebook)
ss.add_constraint("study_type = 'Interventional'")
ss.add_constraint("start_date is not Null")
ss.load_studies()
# Out:
# 252613 studies loaded!

# %%
ss.avail_dims.list
# Out:
# ['brief_summaries',
#  'browse_interventions',
#  'detailed_descriptions',
#  'conditions',
#  'browse_conditions',
#  'id_information',
#  'keywords',
#  'countries',
#  'calculated_values',
#  'central_contacts',
#  'responsible_parties',
#  'overall_officials',
#  'sponsors',
#  'pending_results',
#  'result_contacts',
#  'study_references',
#  'links',
#  'documents',
#  'ipd_information_types',
#  'result_agreements',
#  'provided_documents',
#  'design_outcomes',
#  'eligibilities',
#  'designs',
#  'result_groups',
#  'milestones',
#  'drop_withdrawals',
#  'reported_events',
#  'baseline_counts',
#  'baseline_measurements',
#  'outcomes',
#  'outcome_analyses',
#  'outcome_analysis_groups',
#  'outcome_counts',
#  'outcome_measurements',
#  'interventions',
#  'intervention_other_names',
#  'facilities',
#  'facility_contacts',
#  'facility_investigators']

# %%
ss.add_dimensions('conditions')
ss.add_dimensions('sponsors')
ss.add_dimensions('countries')
ss.refresh_dim_data()
# Out:
# Successfuly added these 1 dimensions: ['conditions']
# Failed to add these 0 dimensions: []
# Successfuly added these 1 dimensions: ['sponsors']
# Failed to add these 0 dimensions: []
# Successfuly added these 1 dimensions: ['countries']
# Failed to add these 0 dimensions: []
# HBox(children=(IntProgress(value=0, max=506), HTML(value='')))
# Syncing the temp table temp_cur_studies in 506 chunks x 500 records each
#
# Creating index on the temp table
#  - Loading dimension conditions
#  -- Loading raw data
#  -- Sorting index
#  - Loading dimension sponsors
#  -- Loading raw data
#  -- Sorting index
#  - Loading dimension countries
#  -- Loading raw data
#  -- Sorting index

# %%
c = ss.dimensions['conditions']

# %%
s_counts = c.data.groupby('downcase_name')['downcase_name'].count().sort_values(ascending=False)
s_sig = s_counts[s_counts > 500]

# %%
fig = plt.figure(figsize=(10, 20))
fig.tight_layout()
plt.barh(s_sig.index, s_sig)
plt.gca().invert_yaxis()
plt.show()

# %%
s_counts[:1000].sum() / s_counts.sum()
# Out:
# 0.5301180535560035

# %%
# manually map the top 1000 conditions
pd.DataFrame(s_counts)[0:1000].to_csv('manual_maps/top_conditions_unmapped.csv')

# %% [markdown]
# ### work in excel to map the top 1000 conditions

# %%
df_mapped = pd.read_csv('manual_maps/top_conditions.csv', index_col='downcase_name')
s_g_counts = df_mapped.groupby('cond_group')['counts'].sum().sort_values(ascending=False)

# %%
s_g_counts.plot.barh(figsize=(6,6))
plt.gca().invert_yaxis()
plt.show()

# %%
# for mapping conditions to their groups
cond2grp = df_mapped['cond_group'].to_dict()

# %% [markdown]
# ### Let's look at the distribution of diseases over time

# %%
ss.studies.shape
# Out:
# (252613, 65)

# %%
c.data['category'] = c.data['downcase_name'].progress_apply(lambda x: cond2grp[x] 
                                                            if x in cond2grp.keys() 
                                                            else 'other')
# Out:
# 100%|██████████| 416760/416760 [00:00<00:00, 1192239.97it/s]

# %%
all_categories = list(s_g_counts.index)
all_categories
# Out:
# ['cancer',
#  'other',
#  'cardiovascular',
#  'diabetes',
#  'mental',
#  'infectiousdiseases',
#  'respiratory',
#  'pain',
#  'healthy',
#  'obesity',
#  'depression-anxiety',
#  'orthopedic',
#  'nerve',
#  'reproductivehealth',
#  'substanceuse',
#  'ocular',
#  'liver',
#  'kidney',
#  'dermatology',
#  'hematology']

# %%
# method for combining all of the categories for a study
def combine_all_grps(df, nct_id):
    all_cond_grps = []
    if nct_id in df.index:
        sub_df = df.loc[[nct_id]]
        for cur_cat in sub_df['category']:
            if cur_cat not in all_cond_grps:
                all_cond_grps.append(cur_cat)
    return all_cond_grps

# %%
s_cats = ss.studies.reset_index()['nct_id'].progress_apply(lambda x: combine_all_grps(c.data, x)).values
# Out:
# 100%|██████████| 252613/252613 [01:45<00:00, 2392.67it/s]

# %%
ss.studies['cond_categories'] = s_cats
ss.studies[['cond_categories']].head()
# Out:
#                     cond_categories
# nct_id
# NCT00690924  [cancer, substanceuse]
# NCT00690898                 [other]
# NCT00690885    [respiratory, other]
# NCT00690872                [cancer]
# NCT00690846                 [other]

# %% [markdown]
# ### we now have a column that has a list representation of the categories per study

# %% [markdown]
# ## Next, we can get the dummy variables per category

# %%
for cur_cat in all_categories:
    ss.studies['is_' + cur_cat] = ss.studies['cond_categories'].progress_apply(lambda x: 1 
                                                                               if cur_cat in x
                                                                               else 0)
# Out:
# 100%|██████████| 252613/252613 [00:00<00:00, 1205009.25it/s]
# 100%|██████████| 252613/252613 [00:00<00:00, 1208661.59it/s]
# 100%|██████████| 252613/252613 [00:00<00:00, 1188398.52it/s]
# 100%|██████████| 252613/252613 [00:00<00:00, 1230294.43it/s]
# 100%|██████████| 252613/252613 [00:00<00:00, 1206470.56it/s]
# 100%|██████████| 252613/252613 [00:00<00:00, 1223386.29it/s]
# 100%|██████████| 252613/252613 [00:00<00:00, 1207289.89it/s]
# 100%|██████████| 252613/252613 [00:00<00:00, 1217145.05it/s]
# 100%|██████████| 252613/252613 [00:00<00:00, 1218530.84it/s]
# 100%|██████████| 252613/252613 [00:00<00:00, 1234648.36it/s]
# 100%|██████████| 252613/252613 [00:00<00:00, 1225673.28it/s]
# 100%|██████████| 252613/252613 [00:00<00:00, 1240483.86it/s]
# 100%|██████████| 252613/252613 [00:00<00:00, 1205330.03it/s]
# 100%|██████████| 252613/252613 [00:00<00:00, 1198900.73it/s]
# 100%|██████████| 252613/252613 [00:00<00:00, 1220405.97it/s]
# 100%|██████████| 252613/252613 [00:00<00:00, 1182422.52it/s]
# 100%|██████████| 252613/252613 [00:00<00:00, 1188230.60it/s]
# 100%|██████████| 252613/252613 [00:00<00:00, 1207478.38it/s]
# 100%|██████████| 252613/252613 [00:00<00:00, 1212683.03it/s]
# 100%|██████████| 252613/252613 [00:00<00:00, 1205382.13it/s]

# %%
ss.studies[['is_' + x for x in all_categories]].head()
# Out:
#              is_cancer  is_other  is_cardiovascular  is_diabetes  is_mental  \
# nct_id
# NCT00690924          1         0                  0            0          0
# NCT00690898          0         1                  0            0          0
# NCT00690885          0         1                  0            0          0
# NCT00690872          1         0                  0            0          0
# NCT00690846          0         1                  0            0          0
#
#              is_infectiousdiseases  is_respiratory  is_pain  is_healthy  \
# nct_id
# NCT00690924                      0               0        0           0
# NCT00690898                      0               0        0           0
# NCT00690885                      0               1        0           0
# NCT00690872                      0               0        0           0
# NCT00690846                      0               0        0           0
#
#              is_obesity  is_depression-anxiety  is_orthopedic  is_nerve  \
# nct_id
# NCT00690924           0                      0              0         0
# NCT00690898           0                      0              0         0
# NCT00690885           0                      0              0         0
# NCT00690872           0                      0              0         0
# NCT00690846           0                      0              0         0
#
#              is_reproductivehealth  is_substanceuse  is_ocular  is_liver  \
# nct_id
# NCT00690924                      0                1          0         0
# NCT00690898                      0                0          0         0
# NCT00690885                      0                0          0         0
# NCT00690872                      0                0          0         0
# NCT00690846                      0                0          0         0
#
#              is_kidney  is_dermatology  is_hematology
# nct_id
# NCT00690924          0               0              0
# NCT00690898          0               0              0
# NCT00690885          0               0              0
# NCT00690872          0               0              0
# NCT00690846          0               0              0

# %%
# let's see our count per category
dummy_categories = ['is_' + x for x in all_categories]
ss.studies[dummy_categories].sum()
# Out:
# is_cancer                 40613
# is_other                 138884
# is_cardiovascular         17992
# is_diabetes               11035
# is_mental                  8665
# is_infectiousdiseases      7729
# is_respiratory             8770
# is_pain                    8887
# is_healthy                 9289
# is_obesity                 7113
# is_depression-anxiety      5815
# is_orthopedic              6080
# is_nerve                   6203
# is_reproductivehealth      4959
# is_substanceuse            4155
# is_ocular                  3134
# is_liver                   3374
# is_kidney                  2993
# is_dermatology             2865
# is_hematology              2491
# dtype: int64

# %% [markdown]
# ### Can group this by time windows and see what is studies at which times

# %%
ss.studies['start_year'] = ss.studies['start_date'].apply(lambda x: pd.Timestamp(x).year)

# %%
plt.figure(figsize=(15, 6))
ss.studies.groupby('start_year')['start_date'].count().plot.bar()
plt.title('distribution of studies by year of study start')
plt.show()

# %%
ss.studies.head(1).T.to_csv('example.csv')

# %%
# making a column with the year buckets
ss.studies['start_year_bucket'] = ss.studies['start_year'].apply(lambda x: '1999-' if x < 2000
                                                                 else ('2019+'
                                                                       if x > 2019 
                                                                       else str(x))
                                                                 )

# %%
plt.figure(figsize=(15, 6))
ss.studies.groupby('start_year_bucket')['start_date'].count().plot.bar()
plt.title('distribution of studies by bucket')
plt.show()

# %% [markdown]
# ### Now we can compute the % of studies studying each subject
#
# **since each study can study multiple conditions, this % can add up to more than 100%**

# %%
all_buckets = ss.studies['start_year_bucket'].unique()
all_buckets
# Out:
# array(['2008', '2007', '2003', '2005', '2001', '2006', '2002', '2009',
#        '2004', '1999-', '2000', '2012', '2011', '2019', '2010', '2013',
#        '2018', '2015', '2017', '2019+', '2014', '2016'], dtype=object)

# %%
# calculating % studies in each bucket
bucket_dict = {}
for cur_bucket in all_buckets:
    sub_df = ss.studies[ss.studies['start_year_bucket'] == cur_bucket]
    bucket_dict[cur_bucket] = sub_df[dummy_categories].sum() / sub_df.shape[0]

# %%
# this data frame now contains the % of all studies in that year used on a certain group of studies
df_pcts = pd.DataFrame(bucket_dict)[sorted(bucket_dict.keys())]
df_pcts.reset_index()
df_pcts.index = df_pcts.reset_index()['index'].apply(lambda x: x[3:])
df_pcts.head()
# Out:
#                    1999-      2000      2001      2002      2003      2004  \
# index
# cancer          0.446977  0.428264  0.341423  0.269021  0.240168  0.226905
# other           0.361897  0.369694  0.390795  0.404823  0.419979  0.419426
# cardiovascular  0.072257  0.061257  0.067782  0.072639  0.087066  0.086674
# diabetes        0.021168  0.032778  0.041423  0.048521  0.045216  0.047378
# mental          0.020761  0.033315  0.038912  0.035889  0.040799  0.043892
#
#                     2005      2006      2007      2008  ...      2011  \
# index                                                   ...
# cancer          0.215544  0.201271  0.189083  0.175213  ...  0.139970
# other           0.423057  0.452509  0.463753  0.468615  ...  0.534213
# cardiovascular  0.090415  0.083674  0.083277  0.078145  ...  0.076296
# diabetes        0.050389  0.053952  0.051603  0.051618  ...  0.048146
# mental          0.039508  0.037476  0.035525  0.039875  ...  0.030348
#
#                     2012      2013      2014      2015      2016      2017  \
# index
# cancer          0.130081  0.124172  0.124768  0.136263  0.133193  0.132178
# other           0.567560  0.577050  0.579740  0.565321  0.594893  0.639881
# cardiovascular  0.071289  0.074058  0.070352  0.065456  0.067083  0.062023
# diabetes        0.047773  0.045593  0.045202  0.041187  0.038837  0.035709
# mental          0.033595  0.028782  0.031236  0.032269  0.034846  0.032274
#
#                     2018      2019     2019+
# index
# cancer          0.130946  0.136522  0.132176
# other           0.645422  0.652982  0.665702
# cardiovascular  0.061284  0.060243  0.070429
# diabetes        0.034194  0.036729  0.028461
# mental          0.035566  0.038563  0.053063
#
# [5 rows x 22 columns]

# %% [markdown]
# ### let's normalize the data to without "other" and drop really old and anticipated studies

# %%
df_no_other = df_pcts.drop("other").drop(['2019+', '1999-'], axis=1)
df_no_other = df_no_other / df_no_other.sum()
df_no_other.head()
# Out:
#                         2000      2001      2002      2003      2004  \
# index
# cancer              0.518543  0.428571  0.342847  0.311172  0.292424
# cardiovascular      0.074170  0.085084  0.092572  0.112807  0.111701
# diabetes            0.039688  0.051996  0.061837  0.058583  0.061058
# mental              0.040338  0.048845  0.045737  0.052861  0.056565
# infectiousdiseases  0.042941  0.051471  0.057812  0.058583  0.056157
#
#                         2005      2006      2007      2008      2009  \
# index
# cancer              0.284008  0.272489  0.265801  0.253514  0.240014
# cardiovascular      0.119133  0.113282  0.117066  0.113067  0.108797
# diabetes            0.066394  0.073043  0.072540  0.074685  0.082508
# mental              0.052057  0.050736  0.049939  0.057695  0.046205
# infectiousdiseases  0.061615  0.062254  0.059007  0.051705  0.060430
#
#                         2010      2011      2012      2013      2014  \
# index
# cancer              0.229286  0.219528  0.214849  0.209813  0.208341
# cardiovascular      0.112303  0.119662  0.117745  0.125134  0.117476
# diabetes            0.076923  0.075512  0.078904  0.077039  0.075479
# mental              0.047934  0.047598  0.055488  0.048634  0.052158
# infectiousdiseases  0.052043  0.047820  0.046499  0.047773  0.043062
#
#                         2015      2016      2017      2018      2019
# index
# cancer              0.224328  0.225974  0.228160  0.226180  0.232296
# cardiovascular      0.107759  0.113812  0.107062  0.105855  0.102505
# diabetes            0.067806  0.065891  0.061639  0.059062  0.062495
# mental              0.053123  0.059120  0.055711  0.061432  0.065616
# infectiousdiseases  0.046628  0.041236  0.038187  0.034270  0.036489

# %%
# exludes "other"
plt.figure(figsize=(14,10))
plt.stackplot(df_no_other.columns, 
              [df_no_other.loc[x].values for x in df_no_other.index], 
              labels=df_no_other.index)

plt.legend(bbox_to_anchor=(1.2,1))
plt.title('percent of studies on each category over time')
plt.show()

# %% [markdown]
# ### let's unstack them to see what is increasing / decreasing over time

# %%
plt.figure(figsize=(14,10))
for idx in df_no_other.index:
    plt.plot(df_no_other.loc[idx].T, label=idx)
    
plt.legend(bbox_to_anchor=(1,1))
plt.title('percent of studies on each category over time')
plt.show()

# %% [markdown]
# ### we can normalize the data by their 2000 ratios

# %%
df_indexed_2007 = df_no_other/ df_no_other['2007'][:, np.newaxis]

# %%
plt.figure(figsize=(10,20))
for idx in df_indexed_2007.index:
    plt.plot(df_indexed_2007.loc[idx].T, label=idx)
    
#plt.legend(bbox_to_anchor=(1,1))
plt.title('percent of studies indexed to 2007 levels over time')

for idx in df_indexed_2007['2019'].index:
    plt.annotate(xy=[19, df_indexed_2007['2019'][idx]], s=idx)
    
plt.axhline(1., linestyle='--', color='k')
plt.axhline(2., linestyle='--', color='k', alpha=0.5)
plt.show()

# %% [markdown]
# ### This is a bit crowded, so let's plot 6/7 at a time

# %%
cur_df = df_indexed_2007[0:10]

plt.figure(figsize=(10,10))
for idx in cur_df.index:
    plt.plot(cur_df.loc[idx].T, label=idx)
    
#plt.legend(bbox_to_anchor=(1,1))
plt.title('percent of studies indexed to 2007 levels over time')

for idx in cur_df['2019'].index:
    plt.annotate(xy=[19, cur_df['2019'][idx]], s=idx)
    
plt.axhline(1., linestyle='--', color='k')
plt.axhline(2., linestyle='--', color='k', alpha=0.5)
plt.show()

# %%
cur_df = df_indexed_2007[10:]

plt.figure(figsize=(10,10))
for idx in cur_df.index:
    plt.plot(cur_df.loc[idx].T, label=idx)
    
#plt.legend(bbox_to_anchor=(1,1))
plt.title('percent of studies indexed to 2007 levels over time')

for idx in cur_df['2019'].index:
    plt.annotate(xy=[19, cur_df['2019'][idx]], s=idx)
    
plt.axhline(1., linestyle='--', color='k')
plt.axhline(2., linestyle='--', color='k', alpha=0.5)
plt.show()

# %% [markdown]
# # Now we will build the pivatable dataframe

# %%
ss.studies.columns
# Out:
# Index(['nlm_download_date_description', 'study_first_submitted_date',
#        'results_first_submitted_date', 'disposition_first_submitted_date',
#        'last_update_submitted_date', 'study_first_submitted_qc_date',
#        'study_first_posted_date', 'study_first_posted_date_type',
#        'results_first_submitted_qc_date', 'results_first_posted_date',
#        'results_first_posted_date_type', 'disposition_first_submitted_qc_date',
#        'disposition_first_posted_date', 'disposition_first_posted_date_type',
#        'last_update_submitted_qc_date', 'last_update_posted_date',
#        'last_update_posted_date_type', 'start_month_year', 'start_date_type',
#        'start_date', 'verification_month_year', 'verification_date',
#        'completion_month_year', 'completion_date_type', 'completion_date',
#        'primary_completion_month_year', 'primary_completion_date_type',
#        'primary_completion_date', 'target_duration', 'study_type', 'acronym',
#        'baseline_population', 'brief_title', 'official_title',
#        'overall_status', 'last_known_status', 'phase', 'enrollment',
#        'enrollment_type', 'source', 'limitations_and_caveats',
#        'number_of_arms', 'number_of_groups', 'why_stopped',
#        'has_expanded_access', 'expanded_access_type_individual',
#        'expanded_access_type_intermediate', 'expanded_access_type_treatment',
#        'has_dmc', 'is_fda_regulated_drug', 'is_fda_regulated_device',
#        'is_unapproved_device', 'is_ppsd', 'is_us_export', 'biospec_retention',
#        'biospec_description', 'ipd_time_frame', 'ipd_access_criteria',
#        'ipd_url', 'plan_to_share_ipd', 'plan_to_share_ipd_description',
#        'created_at', 'updated_at', 'start_year', 'start_year_bucket',
#        'cond_categories', 'is_cancer', 'is_other', 'is_cardiovascular',
#        'is_diabetes', 'is_mental', 'is_infectiousdiseases', 'is_respiratory',
#        'is_pain', 'is_healthy', 'is_obesity', 'is_depression-anxiety',
#        'is_orthopedic', 'is_nerve', 'is_reproductivehealth', 'is_substanceuse',
#        'is_ocular', 'is_liver', 'is_kidney', 'is_dermatology',
#        'is_hematology'],
#       dtype='object')

# %%
df = ss.studies[['start_date', 'start_date_type', 'enrollment_type', 'verification_date', 
                 'phase', 'number_of_arms', 'source', 'cond_categories', 'start_year']]
df
# Out:
#              start_date start_date_type enrollment_type verification_date  \
# nct_id
# NCT00690924  2008-07-17          Actual          Actual        2018-05-31
# NCT00690898  2008-05-31            None          Actual        2019-01-31
# NCT00690885  2008-06-30            None          Actual        2012-04-30
# NCT00690872  2008-07-31            None     Anticipated        2009-06-30
# NCT00690846  2007-07-31     Anticipated          Actual        2018-07-31
# ...                 ...             ...             ...               ...
# NCT00691002  2008-05-31            None          Actual        2010-01-31
# NCT00690976  2008-07-31            None     Anticipated        2010-03-31
# NCT00690963  2008-09-30            None          Actual        2016-04-30
# NCT00690950  2008-05-31            None     Anticipated        2008-06-30
# NCT00690937  2008-02-29            None          Actual        2014-03-31
#
#                        phase  number_of_arms  \
# nct_id
# NCT00690924              N/A             1.0
# NCT00690898          Phase 3             1.0
# NCT00690885          Phase 2             2.0
# NCT00690872          Phase 2             NaN
# NCT00690846          Phase 2             1.0
# ...                      ...             ...
# NCT00691002          Phase 3             4.0
# NCT00690976              N/A             2.0
# NCT00690963  Phase 1/Phase 2             NaN
# NCT00690950          Phase 4             NaN
# NCT00690937          Phase 2             5.0
#
#                                                  source  \
# nct_id
# NCT00690924               Roswell Park Cancer Institute
# NCT00690898                                       Ipsen
# NCT00690885                  Amarillo Biosciences, Inc.
# NCT00690872             National Cancer Institute (NCI)
# NCT00690846      Wake Forest University Health Sciences
# ...                                                 ...
# NCT00691002                                  LEO Pharma
# NCT00690976  Centers for Disease Control and Prevention
# NCT00690963                  AHS Cancer Control Alberta
# NCT00690950     Urologic Consultants of Southeastern PA
# NCT00690937                                      Sanofi
#
#                     cond_categories  start_year
# nct_id
# NCT00690924  [cancer, substanceuse]        2008
# NCT00690898                 [other]        2008
# NCT00690885    [respiratory, other]        2008
# NCT00690872                [cancer]        2008
# NCT00690846                 [other]        2007
# ...                             ...         ...
# NCT00691002           [dermatology]        2008
# NCT00690976    [infectiousdiseases]        2008
# NCT00690963                [cancer]        2008
# NCT00690950    [reproductivehealth]        2008
# NCT00690937        [cardiovascular]        2008
#
# [252613 rows x 9 columns]

# %% [markdown]
# ## All the subsequent code will be how to add extra columns to this dataframe

# %% [markdown]
# ### let's crawl the conditions table to see if they are orphan diseases

# %%
orph_list = pickle.load(open('raw_data/orphan_list.pkl', 'rb'))
orph_list[:10]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-58-ce9f03c4af02> in <module>
# ----> 1 orph_list = pickle.load(open('raw_data/orphan_list.pkl', 'rb'))
#       2 orph_list[:10]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'raw_data/orphan_list.pkl'

# %%
ss.dimensions['conditions'].data.head()
# Out:
#                  id                    name           downcase_name category
# nct_id
# NCT00000113  538926                  Myopia                  myopia   ocular
# NCT00000114  538925    Retinitis Pigmentosa    retinitis pigmentosa   ocular
# NCT00000115  538924  Macular Edema, Cystoid  macular edema, cystoid    other
# NCT00000116  538923    Retinitis Pigmentosa    retinitis pigmentosa   ocular
# NCT00000117  538922          Optic Neuritis          optic neuritis    other

# %%
SIM_THRESH = 90  # the match score has to be greater than this

# %%
def extract_highest_fuzz(x):
    return process.extract(x, orph_list, scorer=fuzz.ratio, limit=1)[0]

# %%
try_df = ss.dimensions['conditions'].data[:1000].copy()
try_df.shape
# Out:
# (1000, 4)

# %%
try_df['orph_match'] = try_df['downcase_name'].apply(extract_highest_fuzz)

# %%
try_df[['closest_orphan', 'orph_score']] = pd.DataFrame(try_df['orph_match'].values.tolist(), index=try_df.index)

# %%
try_df.shape
# Out:
# (1000, 7)

# %%
df_orph = try_df[try_df['orph_score'] > SIM_THRESH]
df_orph.shape
# Out:
# (40, 7)

# %%
df_orph.head()
# Out:
#                    id                                name  \
# nct_id
# NCT00000114  10059527                Retinitis Pigmentosa
# NCT00000116  10059525                Retinitis Pigmentosa
# NCT00000117  10059524                      Optic Neuritis
# NCT00000118  10059522  Acquired Immunodeficiency Syndrome
# NCT00000118  10059523           Cytomegalovirus Retinitis
#
#                                   downcase_name category  \
# nct_id
# NCT00000114                retinitis pigmentosa   ocular
# NCT00000116                retinitis pigmentosa   ocular
# NCT00000117                      optic neuritis    other
# NCT00000118  acquired immunodeficiency syndrome    other
# NCT00000118           cytomegalovirus retinitis    other
#
#                                           orph_match  \
# nct_id
# NCT00000114              (retinitis pigmentosa, 100)
# NCT00000116              (retinitis pigmentosa, 100)
# NCT00000117                    (optic neuritis, 100)
# NCT00000118  (aquired immunodeficiency syndrome, 99)
# NCT00000118         (cytomegalovirus retinitis, 100)
#
#                                 closest_orphan  orph_score
# nct_id
# NCT00000114               retinitis pigmentosa         100
# NCT00000116               retinitis pigmentosa         100
# NCT00000117                     optic neuritis         100
# NCT00000118  aquired immunodeficiency syndrome          99
# NCT00000118          cytomegalovirus retinitis         100

# %% [markdown]
# ## Joining sponsors

# %%
cur_df = ss.dimensions['sponsors'].data
cur_df.head()
# Out:
#                   id agency_class lead_or_collaborator  \
# nct_id
# NCT00000113  9238044        Other                 lead
# NCT00000113  9238045          NIH         collaborator
# NCT00000114  9238043          NIH                 lead
# NCT00000115  9238042          NIH                 lead
# NCT00000116  9238041          NIH                 lead
#
#                                      name
# nct_id
# NCT00000113        Stony Brook University
# NCT00000113  National Eye Institute (NEI)
# NCT00000114  National Eye Institute (NEI)
# NCT00000115  National Eye Institute (NEI)
# NCT00000116  National Eye Institute (NEI)

# %%
s_agency_class = cur_df.groupby('agency_class')['name'].count()
s_agency_class.plot.bar();plt.show()

# %%
# how many studies have sponsors
cur_df.index.unique().shape
# Out:
# (250136,)

# %%
# how many leads do we have
cur_df[cur_df['lead_or_collaborator'] == 'lead'].index.unique().shape
# Out:
# (250136,)

# %%
df_lead = cur_df[cur_df['lead_or_collaborator'] == 'lead']
df_lead.shape
# Out:
# (250136, 4)

# %%
df_lead.columns = ['sponsor_' + x for x in df_lead.columns]

# %%
dfj = df.join(df_lead[['sponsor_agency_class', 'sponsor_name']])

# %%
df.shape, dfj.shape
# Out:
# ((250136, 9), (250136, 11))

# %%
df = dfj  # overriding original df

# %% [markdown]
# ### Country

# %%
cur_df = ss.dimensions['countries'].data
cur_df.head()
# Out:
#                   id           name removed
# nct_id
# NCT00000113  9136428  United States    None
# NCT00000116  9136427  United States    None
# NCT00000117  9136426  United States    None
# NCT00000119  9136425  United States    None
# NCT00000132  9136423         Sweden    None

# %%
def generate_countries_list(x):
    if x not in cur_df.index:
        return []
    else:
        return list(cur_df.loc[[x]]['name'].values)

# %%
trial_df = df[:1000].copy()

# %%
df['countries'] = df.reset_index()['nct_id'].progress_apply(generate_countries_list).values

# %%
trial_df['countries'] = trial_df.reset_index()['nct_id'].apply(generate_countries_list).values
trial_df[['countries']].head()
# Out:
#                                                      countries
# nct_id
# NCT01980888  [Australia, Belgium, Canada, Croatia, Czechia,...
# NCT01980875  [Australia, Belgium, Canada, France, Poland, S...
# NCT01980849                                            [China]
# NCT01980836                                           [Israel]
# NCT01980823                                    [United States]

# %% [markdown]
# ### final results:

# %%
df.head()
# Out:
#              start_date start_date_type enrollment_type verification_date  \
# nct_id
# NCT01980888  2014-02-05          Actual          Actual        2017-09-30
# NCT01980875  2015-04-21          Actual          Actual        2017-05-31
# NCT01980849  2013-11-30            None     Anticipated        2013-11-30
# NCT01980836  2013-11-30            None     Anticipated        2013-11-30
# NCT01980823  2013-10-31          Actual     Anticipated        2019-07-31
#
#                      phase  number_of_arms  \
# nct_id
# NCT01980888        Phase 3             2.0
# NCT01980875        Phase 3             3.0
# NCT01980849        Phase 3             2.0
# NCT01980836        Phase 4             2.0
# NCT01980823  Early Phase 1             1.0
#
#                                          source      cond_categories  \
# nct_id
# NCT01980888                     Gilead Sciences             [cancer]
# NCT01980875                     Gilead Sciences             [cancer]
# NCT01980849  Fourth Military Medical University             [cancer]
# NCT01980836    Tel-Aviv Sourasky Medical Center  [orthopedic, other]
# NCT01980823                 Columbia University      [cancer, other]
#
#              start_year sponsor_agency_class                      sponsor_name
# nct_id
# NCT01980888        2014             Industry                   Gilead Sciences
# NCT01980875        2015             Industry                   Gilead Sciences
# NCT01980849        2013                Other                      Shengqing Li
# NCT01980836        2013                Other  Tel-Aviv Sourasky Medical Center
# NCT01980823        2013                Other               Columbia University

# %%
df.to_pickle('raw_data/drug_demo.pkl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-46d80b055376> in <module>
# ----> 1 df.to_pickle('raw_data/drug_demo.pkl')
#
# NameError: name 'df' is not defined
